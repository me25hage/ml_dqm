# %%
import os
import numpy as np
import matplotlib
import matplotlib.pyplot as plt
import pandas as pd
import keras
import pickle

from keras import backend as K
from keras.callbacks import EarlyStopping, ModelCheckpoint, ReduceLROnPlateau
from keras.initializers import Ones, Zeros, Constant
from keras.models import Model, load_model
from keras.layers import Dense, Input, Lambda, SimpleRNN, Reshape, RepeatVector, PReLU,BatchNormalization
from keras.losses import mse
from keras.constraints import non_neg

# %%
# Change presentation settings

# %matplotlib inline

matplotlib.rcParams["figure.figsize"] = (16.0, 10.0)

#matplotlib.rcParams['font.family'] = 'sans-serif'
#matplotlib.rcParams['font.sans-serif'] = ['Liberation Sans']

matplotlib.rcParams["axes.spines.left"] = True
matplotlib.rcParams["axes.spines.top"] = True
matplotlib.rcParams["axes.spines.right"] = True
matplotlib.rcParams["axes.spines.bottom"] = True
matplotlib.rcParams["axes.labelsize"] = 16
matplotlib.rcParams["axes.titlesize"] = 18

matplotlib.rcParams["xtick.top"] = True
matplotlib.rcParams["ytick.right"] = True
matplotlib.rcParams["xtick.direction"] = "in"
matplotlib.rcParams["ytick.direction"] = "in"
matplotlib.rcParams["xtick.labelsize"] = 10
matplotlib.rcParams["ytick.labelsize"] = 10
matplotlib.rcParams["xtick.major.size"] = 10
matplotlib.rcParams["ytick.major.size"] = 10
matplotlib.rcParams["xtick.minor.size"] = 5
matplotlib.rcParams["ytick.minor.size"] = 5
matplotlib.rcParams["xtick.minor.visible"] = True

matplotlib.rcParams["lines.linewidth"] = 2

matplotlib.rcParams["legend.fontsize"] = 14

color_palette = {"Indigo": {
                    50: "#E8EAF6",
                    100: "#C5CAE9",
                    200: "#9FA8DA",
                    300: "#7986CB",
                    400: "#5C6BC0",
                    500: "#3F51B5",
                    600: "#3949AB",
                    700: "#303F9F",
                    800: "#283593",
                    900: "#1A237E"},
                 "Orange": {      
                    50: "#FFF3E0",
                    100: "#FFE0B2",
                    200: "#FFCC80",
                    300: "#FFB74D",
                    400: "#FFA726",
                    500: "#FF9800",
                    600: "#FB8C00",
                    700: "#F57C00",
                    800: "#EF6C00",
                    900: "#E65100"}
                }

line_styles = [(0, ()), (0, (1, 2)), (0, (3, 2))]

# %%
def plot_loss(data, save_name=False):
    """Plots the training and validation loss"""
    fig, ax = plt.subplots()

    plt.xlabel("Epoch", horizontalalignment='right', x=1.0)
    plt.ylabel("Cross-entropy", horizontalalignment='right', y=1.0)

    plt.plot(data["loss"], linestyle=line_styles[0], color=color_palette["Indigo"][800])
    plt.plot(data["val_loss"], linestyle=line_styles[2], color=color_palette["Orange"][400])
    plt.legend(["Training data set", "Validation data set"], loc="upper right", frameon=False)
    #plt.yscale("log")
    
    if save_name:
        fig.savefig("%s/%s.eps" % (figure_export_directory, save_name), bbox_inches="tight")

    plt.show();

# %%
def train_nn(model, x, y, batch_size, loss, name, xval):

    adam = keras.optimizers.Adam(lr=0.003,
                                 beta_1=0.9,
                                 beta_2=0.999,
                                 epsilon=None,
                                 decay=0.0,
                                 amsgrad=False)

    early_stopper = EarlyStopping(monitor="val_loss",
                                  patience=32,
                                  verbose=True,
                                  mode="auto")

    reduce_lr = ReduceLROnPlateau(monitor="val_loss",
                                  factor=0.1,
                                  patience=24)
    
    checkpoint_callback = ModelCheckpoint(("%s.h5" % (name)),
                                          monitor="val_loss",
                                          verbose=False,
                                          save_best_only=True,
                                          mode="min")
    
    model.compile(loss=loss, optimizer=adam)
    
    history = model.fit(x, y,
                     batch_size=batch_size,
                     epochs=1000,
                     verbose=2,
                     initial_epoch=0,
                     shuffle=True,
                     validation_data=(xval,xval),
                     callbacks=[early_stopper, checkpoint_callback])
    return history

# %% [markdown]
# ## Data

# %%
runs = [304125,302263,304508]
with open("pileup_dataNotNorm.pickle", 'rb') as handle:
    data = pickle.load(handle)

x_train = np.array(data[str(runs[0])]['samples'])
x_val = np.array(data[str(runs[1])]['samples'])
x_test = np.array(data[str(runs[2])]['samples'])

WINDOW = 1
num_parts = 6

# %%
plots = [x_train,x_val,x_test]
titles = ["train","val","test"]

stuff = [[],[],[]]
lumi = [[],[],[]]
for h in range(3):
    labels = data['HLT'] 
    lumi[h] = data[str(runs[h])]['lumiid']
    stuff[h] = data[str(runs[h])]['rates']
    
plt.figure(figsize=[15,10])
              
for i in range(num_parts):
    plt.subplot(2,3,i+1)
    for k in range(0,3):
        #print(len(lumi[k]),len(stuff[k][i]))
        plt.scatter(lumi[k],stuff[k][i],label=titles[k],alpha=.5)
    plt.xlabel('lumi id')
    plt.ylabel('error')
    plt.title(labels[i])
    plt.legend()

plt.tight_layout()
plt.show()

# %%
runs = [304125,304508,302263]

with open('pileup_dataNotNorm.pickle', 'rb') as handle:
    data = pickle.load(handle)
with open('pileup_bad_dataNotNorm.pickle', 'rb') as handle:
    bad_data = pickle.load(handle)

x_train = np.array(data[str(runs[0])]['samples'])
x_val = np.array(data[str(runs[1])]['samples'])
x_test = np.array(data[str(runs[2])]['samples'])

x_bad = np.array(bad_data['301480']['samples'])

WINDOW = 1

# %%
plots = [x_train,x_test,x_bad]
titles = ["train","test","bad"]

stuff = [[],[],[]]
lumi = [[],[],[]]
inst = [[],[],[]]
pileup = [[],[],[]]
for h in range(3):
    if h == 0 or h == 1:
        lumi[h] = data[str(runs[h])]['lumiid']
        inst[h] = data[str(runs[h])]['instlumi']
        pileup[h] = data[str(runs[h])]['pileup']
        stuff[h] = data[str(runs[h])]['rates']
    else:
        lumi[h] = bad_data["301480"]['lumiid']
        inst[h] = bad_data["301480"]['instlumi']
        pileup[h] = bad_data["301480"]['pileup']
        stuff[h] = bad_data["301480"]['rates']
    
labels = data['HLT'] 
colors = ["g","b","r"]
    
plt.figure(figsize=[15,10])
for i in range(num_parts):
    plt.subplot(2,3,i+1)
    for k in range(0,3):
        #print(len(i[k]),len(stuff[k][i]))
        plt.scatter(lumi[k],stuff[k][i],c=colors[k],label=titles[k],alpha=.5)
    plt.xlabel('lumi id')
    plt.ylabel('rate')
    plt.title(labels[i])
    plt.legend()

plt.tight_layout()

plt.figure(figsize=[15,10])
              
for i in range(num_parts):
    plt.subplot(2,3,i+1)
    for k in range(0,3):
        #print(len(inst[k][i]),len(stuff[k][i]))
        plt.scatter(inst[k][i],stuff[k][i],c=colors[k],label=titles[k],alpha=.5)
    plt.xlabel('instantaneous luminosity')
    plt.ylabel('rate')
    plt.title(labels[i])
    plt.legend()

plt.tight_layout()

plt.figure(figsize=[15,10])
              
for i in range(num_parts):
    plt.subplot(2,3,i+1)
    for k in range(0,3):
        #print(len(lumi[k]),len(stuff[k][i]))
        plt.scatter(pileup[k][i],stuff[k][i],c=colors[k],label=titles[k],alpha=.5)
    plt.xlabel('pileup')
    plt.ylabel('rate/pileup')
    plt.title(labels[i])
    plt.legend()

plt.tight_layout()

plt.show()

# %% [markdown]
# ## Simple Autoencoder

# %%
model_name = "added_layer"

# %%
# Define the architecture

_input = Input(shape=(num_parts*WINDOW,), name="input")

mid = Dense(5,
               kernel_initializer=Ones(),
               bias_initializer=Zeros(),
               kernel_constraint=non_neg(),
               bias_constraint=non_neg(),
               activation=None,
               name="mid1")(_input)

hidden = Dense(3,
               kernel_initializer=Ones(),
               bias_initializer=Zeros(),
               kernel_constraint=non_neg(),
               bias_constraint=non_neg(),
               activation=None,
               name="encoded")(mid)

mid = Dense(5,
               kernel_initializer=Ones(),
               bias_initializer=Zeros(),
               kernel_constraint=non_neg(),
               bias_constraint=non_neg(),
               activation=None,
               name="mid2")(hidden)

output = Dense(num_parts*WINDOW,
               kernel_initializer=Ones(),
               bias_initializer=Zeros(),
               kernel_constraint=non_neg(),
               bias_constraint=non_neg(),
               activation=None,
               name="reconstructed")(mid)

model = Model(_input, output)
model.summary()
# Out:
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# input (InputLayer)           (None, 6)                 0
# _________________________________________________________________
# mid1 (Dense)                 (None, 5)                 35
# _________________________________________________________________
# encoded (Dense)              (None, 3)                 18
# _________________________________________________________________
# mid2 (Dense)                 (None, 5)                 20
# _________________________________________________________________
# reconstructed (Dense)        (None, 6)                 36
# =================================================================
# Total params: 109
# Trainable params: 109
# Non-trainable params: 0
# _________________________________________________________________

# %%
# Train neural networks
history = train_nn(model, x_train, x_train, 1024, "mse", model_name, x_val).history
plot_loss(history)
# Out:
# Train on 1669 samples, validate on 1224 samples
# Epoch 1/1000
#  - 1s - loss: 12.0130 - val_loss: 12.1701
# Epoch 2/1000
#  - 0s - loss: 11.4475 - val_loss: 11.5947
# Epoch 3/1000
#  - 0s - loss: 10.9046 - val_loss: 11.0452
# Epoch 4/1000
#  - 0s - loss: 10.3889 - val_loss: 10.5212
# Epoch 5/1000
#  - 0s - loss: 9.8954 - val_loss: 10.0224
# Epoch 6/1000
#  - 0s - loss: 9.4262 - val_loss: 9.5481
# Epoch 7/1000
#  - 0s - loss: 8.9801 - val_loss: 9.0980
# Epoch 8/1000
#  - 0s - loss: 8.5579 - val_loss: 8.6711
# Epoch 9/1000
#  - 0s - loss: 8.1563 - val_loss: 8.2651
# Epoch 10/1000
#  - 0s - loss: 7.7752 - val_loss: 7.8827
# Epoch 11/1000
#  - 0s - loss: 7.4166 - val_loss: 7.5212
# Epoch 12/1000
#  - 0s - loss: 7.0767 - val_loss: 7.1797
# Epoch 13/1000
#  - 0s - loss: 6.7558 - val_loss: 6.8572
# Epoch 14/1000
#  - 0s - loss: 6.4534 - val_loss: 6.5527
# Epoch 15/1000
#  - 0s - loss: 6.1673 - val_loss: 6.2654
# Epoch 16/1000
#  - 0s - loss: 5.8976 - val_loss: 5.9927
# Epoch 17/1000
#  - 0s - loss: 5.6409 - val_loss: 5.7355
# Epoch 18/1000
#  - 0s - loss: 5.3997 - val_loss: 5.4942
# Epoch 19/1000
#  - 0s - loss: 5.1735 - val_loss: 5.2664
# Epoch 20/1000
#  - 0s - loss: 4.9595 - val_loss: 5.0514
# Epoch 21/1000
#  - 0s - loss: 4.7572 - val_loss: 4.8473
# Epoch 22/1000
#  - 0s - loss: 4.5656 - val_loss: 4.6555
# Epoch 23/1000
#  - 0s - loss: 4.3859 - val_loss: 4.4741
# Epoch 24/1000
#  - 0s - loss: 4.2157 - val_loss: 4.3027
# Epoch 25/1000
#  - 0s - loss: 4.0548 - val_loss: 4.1404
# Epoch 26/1000
#  - 0s - loss: 3.9021 - val_loss: 3.9862
# Epoch 27/1000
#  - 0s - loss: 3.7571 - val_loss: 3.8408
# Epoch 28/1000
#  - 0s - loss: 3.6206 - val_loss: 3.7029
# Epoch 29/1000
#  - 0s - loss: 3.4906 - val_loss: 3.5710
# Epoch 30/1000
#  - 0s - loss: 3.3668 - val_loss: 3.4463
# Epoch 31/1000
#  - 0s - loss: 3.2500 - val_loss: 3.3283
# Epoch 32/1000
#  - 0s - loss: 3.1387 - val_loss: 3.2162
# Epoch 33/1000
#  - 0s - loss: 3.0334 - val_loss: 3.1095
# Epoch 34/1000
#  - 0s - loss: 2.9329 - val_loss: 3.0076
# Epoch 35/1000
#  - 0s - loss: 2.8373 - val_loss: 2.9109
# Epoch 36/1000
#  - 0s - loss: 2.7461 - val_loss: 2.8183
# Epoch 37/1000
#  - 0s - loss: 2.6591 - val_loss: 2.7304
# Epoch 38/1000
#  - 0s - loss: 2.5764 - val_loss: 2.6464
# Epoch 39/1000
#  - 0s - loss: 2.4975 - val_loss: 2.5661
# Epoch 40/1000
#  - 0s - loss: 2.4218 - val_loss: 2.4894
# Epoch 41/1000
#  - 0s - loss: 2.3496 - val_loss: 2.4159
# Epoch 42/1000
#  - 0s - loss: 2.2806 - val_loss: 2.3457
# Epoch 43/1000
#  - 0s - loss: 2.2145 - val_loss: 2.2785
# Epoch 44/1000
#  - 0s - loss: 2.1511 - val_loss: 2.2139
# Epoch 45/1000
#  - 0s - loss: 2.0902 - val_loss: 2.1522
# Epoch 46/1000
#  - 0s - loss: 2.0322 - val_loss: 2.0928
# Epoch 47/1000
#  - 0s - loss: 1.9763 - val_loss: 2.0360
# Epoch 48/1000
#  - 0s - loss: 1.9227 - val_loss: 1.9814
# Epoch 49/1000
#  - 0s - loss: 1.8713 - val_loss: 1.9288
# Epoch 50/1000
#  - 0s - loss: 1.8217 - val_loss: 1.8784
# Epoch 51/1000
#  - 0s - loss: 1.7743 - val_loss: 1.8298
# Epoch 52/1000
#  - 0s - loss: 1.7284 - val_loss: 1.7831
# Epoch 53/1000
#  - 0s - loss: 1.6845 - val_loss: 1.7381
# Epoch 54/1000
#  - 0s - loss: 1.6420 - val_loss: 1.6948
# Epoch 55/1000
#  - 0s - loss: 1.6011 - val_loss: 1.6530
# Epoch 56/1000
#  - 0s - loss: 1.5618 - val_loss: 1.6126
# Epoch 57/1000
#  - 0s - loss: 1.5237 - val_loss: 1.5737
# Epoch 58/1000
#  - 0s - loss: 1.4871 - val_loss: 1.5362
# Epoch 59/1000
#  - 0s - loss: 1.4518 - val_loss: 1.5001
# Epoch 60/1000
#  - 0s - loss: 1.4177 - val_loss: 1.4652
# Epoch 61/1000
#  - 0s - loss: 1.3847 - val_loss: 1.4315
# Epoch 62/1000
#  - 0s - loss: 1.3530 - val_loss: 1.3989
# Epoch 63/1000
#  - 0s - loss: 1.3222 - val_loss: 1.3673
# Epoch 64/1000
#  - 0s - loss: 1.2925 - val_loss: 1.3368
# Epoch 65/1000
#  - 0s - loss: 1.2636 - val_loss: 1.3073
# Epoch 66/1000
#  - 0s - loss: 1.2359 - val_loss: 1.2787
# Epoch 67/1000
#  - 0s - loss: 1.2088 - val_loss: 1.2511
# Epoch 68/1000
#  - 0s - loss: 1.1828 - val_loss: 1.2242
# Epoch 69/1000
#  - 0s - loss: 1.1574 - val_loss: 1.1983
# Epoch 70/1000
#  - 0s - loss: 1.1329 - val_loss: 1.1732
# Epoch 71/1000
#  - 0s - loss: 1.1092 - val_loss: 1.1488
# Epoch 72/1000
#  - 0s - loss: 1.0862 - val_loss: 1.1251
# Epoch 73/1000
#  - 0s - loss: 1.0639 - val_loss: 1.1021
# Epoch 74/1000
#  - 0s - loss: 1.0421 - val_loss: 1.0799
# Epoch 75/1000
#  - 0s - loss: 1.0212 - val_loss: 1.0583
# Epoch 76/1000
#  - 0s - loss: 1.0008 - val_loss: 1.0373
# Epoch 77/1000
#  - 0s - loss: 0.9810 - val_loss: 1.0169
# Epoch 78/1000
#  - 0s - loss: 0.9617 - val_loss: 0.9971
# Epoch 79/1000
#  - 0s - loss: 0.9431 - val_loss: 0.9779
# Epoch 80/1000
#  - 0s - loss: 0.9249 - val_loss: 0.9592
# Epoch 81/1000
#  - 0s - loss: 0.9072 - val_loss: 0.9410
# Epoch 82/1000
#  - 0s - loss: 0.8901 - val_loss: 0.9233
# Epoch 83/1000
#  - 0s - loss: 0.8734 - val_loss: 0.9061
# Epoch 84/1000
#  - 0s - loss: 0.8571 - val_loss: 0.8894
# Epoch 85/1000
#  - 0s - loss: 0.8413 - val_loss: 0.8731
# Epoch 86/1000
#  - 0s - loss: 0.8259 - val_loss: 0.8573
# Epoch 87/1000
#  - 0s - loss: 0.8110 - val_loss: 0.8418
# Epoch 88/1000
#  - 0s - loss: 0.7964 - val_loss: 0.8267
# Epoch 89/1000
#  - 0s - loss: 0.7822 - val_loss: 0.8121
# Epoch 90/1000
#  - 0s - loss: 0.7683 - val_loss: 0.7978
# Epoch 91/1000
#  - 0s - loss: 0.7548 - val_loss: 0.7839
# Epoch 92/1000
#  - 0s - loss: 0.7417 - val_loss: 0.7704
# Epoch 93/1000
#  - 0s - loss: 0.7289 - val_loss: 0.7571
# Epoch 94/1000
#  - 0s - loss: 0.7164 - val_loss: 0.7443
# Epoch 95/1000
#  - 0s - loss: 0.7042 - val_loss: 0.7317
# Epoch 96/1000
#  - 0s - loss: 0.6923 - val_loss: 0.7194
# Epoch 97/1000
#  - 0s - loss: 0.6808 - val_loss: 0.7074
# Epoch 98/1000
#  - 0s - loss: 0.6694 - val_loss: 0.6958
# Epoch 99/1000
#  - 0s - loss: 0.6584 - val_loss: 0.6844
# Epoch 100/1000
#  - 0s - loss: 0.6476 - val_loss: 0.6732
# Epoch 101/1000
#  - 0s - loss: 0.6371 - val_loss: 0.6624
# Epoch 102/1000
#  - 0s - loss: 0.6269 - val_loss: 0.6517
# Epoch 103/1000
#  - 0s - loss: 0.6168 - val_loss: 0.6414
# Epoch 104/1000
#  - 0s - loss: 0.6070 - val_loss: 0.6313
# Epoch 105/1000
#  - 0s - loss: 0.5975 - val_loss: 0.6214
# Epoch 106/1000
#  - 0s - loss: 0.5881 - val_loss: 0.6117
# Epoch 107/1000
#  - 0s - loss: 0.5789 - val_loss: 0.6022
# Epoch 108/1000
#  - 0s - loss: 0.5700 - val_loss: 0.5930
# Epoch 109/1000
#  - 0s - loss: 0.5613 - val_loss: 0.5839
# Epoch 110/1000
#  - 0s - loss: 0.5527 - val_loss: 0.5751
# Epoch 111/1000
#  - 0s - loss: 0.5444 - val_loss: 0.5665
# Epoch 112/1000
#  - 0s - loss: 0.5362 - val_loss: 0.5580
# Epoch 113/1000
#  - 0s - loss: 0.5282 - val_loss: 0.5497
# Epoch 114/1000
#  - 0s - loss: 0.5204 - val_loss: 0.5416
# Epoch 115/1000
#  - 0s - loss: 0.5127 - val_loss: 0.5337
# Epoch 116/1000
#  - 0s - loss: 0.5052 - val_loss: 0.5259
# Epoch 117/1000
#  - 0s - loss: 0.4979 - val_loss: 0.5184
# Epoch 118/1000
#  - 0s - loss: 0.4907 - val_loss: 0.5109
# Epoch 119/1000
#  - 0s - loss: 0.4837 - val_loss: 0.5036
# Epoch 120/1000
#  - 0s - loss: 0.4768 - val_loss: 0.4965
# Epoch 121/1000
#  - 0s - loss: 0.4701 - val_loss: 0.4895
# Epoch 122/1000
#  - 0s - loss: 0.4635 - val_loss: 0.4827
# Epoch 123/1000
#  - 0s - loss: 0.4570 - val_loss: 0.4760
# Epoch 124/1000
#  - 0s - loss: 0.4507 - val_loss: 0.4694
# Epoch 125/1000
#  - 0s - loss: 0.4445 - val_loss: 0.4630
# Epoch 126/1000
#  - 0s - loss: 0.4384 - val_loss: 0.4567
# Epoch 127/1000
#  - 0s - loss: 0.4324 - val_loss: 0.4505
# Epoch 128/1000
#  - 0s - loss: 0.4265 - val_loss: 0.4444
# Epoch 129/1000
#  - 0s - loss: 0.4208 - val_loss: 0.4385
# Epoch 130/1000
#  - 0s - loss: 0.4152 - val_loss: 0.4326
# Epoch 131/1000
#  - 0s - loss: 0.4097 - val_loss: 0.4269
# Epoch 132/1000
#  - 0s - loss: 0.4043 - val_loss: 0.4213
# Epoch 133/1000
#  - 0s - loss: 0.3989 - val_loss: 0.4158
# Epoch 134/1000
#  - 0s - loss: 0.3937 - val_loss: 0.4104
# Epoch 135/1000
#  - 0s - loss: 0.3886 - val_loss: 0.4051
# Epoch 136/1000
#  - 0s - loss: 0.3836 - val_loss: 0.3999
# Epoch 137/1000
#  - 0s - loss: 0.3787 - val_loss: 0.3948
# Epoch 138/1000
#  - 0s - loss: 0.3739 - val_loss: 0.3898
# Epoch 139/1000
#  - 0s - loss: 0.3691 - val_loss: 0.3849
# Epoch 140/1000
#  - 0s - loss: 0.3645 - val_loss: 0.3800
# Epoch 141/1000
#  - 0s - loss: 0.3599 - val_loss: 0.3753
# Epoch 142/1000
#  - 0s - loss: 0.3554 - val_loss: 0.3706
# Epoch 143/1000
#  - 0s - loss: 0.3510 - val_loss: 0.3661
# Epoch 144/1000
#  - 0s - loss: 0.3467 - val_loss: 0.3616
# Epoch 145/1000
#  - 0s - loss: 0.3424 - val_loss: 0.3572
# Epoch 146/1000
#  - 0s - loss: 0.3383 - val_loss: 0.3528
# Epoch 147/1000
#  - 0s - loss: 0.3342 - val_loss: 0.3486
# Epoch 148/1000
#  - 0s - loss: 0.3301 - val_loss: 0.3444
# Epoch 149/1000
#  - 0s - loss: 0.3262 - val_loss: 0.3403
# Epoch 150/1000
#  - 0s - loss: 0.3223 - val_loss: 0.3362
# Epoch 151/1000
#  - 0s - loss: 0.3185 - val_loss: 0.3322
# Epoch 152/1000
#  - 0s - loss: 0.3147 - val_loss: 0.3283
# Epoch 153/1000
#  - 0s - loss: 0.3110 - val_loss: 0.3245
# Epoch 154/1000
#  - 0s - loss: 0.3074 - val_loss: 0.3207
# Epoch 155/1000
#  - 0s - loss: 0.3038 - val_loss: 0.3170
# Epoch 156/1000
#  - 0s - loss: 0.3003 - val_loss: 0.3134
# Epoch 157/1000
#  - 0s - loss: 0.2968 - val_loss: 0.3098
# Epoch 158/1000
#  - 0s - loss: 0.2934 - val_loss: 0.3063
# Epoch 159/1000
#  - 0s - loss: 0.2901 - val_loss: 0.3028
# Epoch 160/1000
#  - 0s - loss: 0.2868 - val_loss: 0.2994
# Epoch 161/1000
#  - 0s - loss: 0.2836 - val_loss: 0.2960
# Epoch 162/1000
#  - 0s - loss: 0.2804 - val_loss: 0.2927
# Epoch 163/1000
#  - 0s - loss: 0.2773 - val_loss: 0.2895
# Epoch 164/1000
#  - 0s - loss: 0.2742 - val_loss: 0.2863
# Epoch 165/1000
#  - 0s - loss: 0.2712 - val_loss: 0.2831
# Epoch 166/1000
#  - 0s - loss: 0.2682 - val_loss: 0.2800
# Epoch 167/1000
#  - 0s - loss: 0.2653 - val_loss: 0.2770
# Epoch 168/1000
#  - 0s - loss: 0.2624 - val_loss: 0.2740
# Epoch 169/1000
#  - 0s - loss: 0.2596 - val_loss: 0.2710
# Epoch 170/1000
#  - 0s - loss: 0.2568 - val_loss: 0.2681
# Epoch 171/1000
#  - 0s - loss: 0.2540 - val_loss: 0.2652
# Epoch 172/1000
#  - 0s - loss: 0.2513 - val_loss: 0.2624
# Epoch 173/1000
#  - 0s - loss: 0.2486 - val_loss: 0.2596
# Epoch 174/1000
#  - 0s - loss: 0.2460 - val_loss: 0.2569
# Epoch 175/1000
#  - 0s - loss: 0.2434 - val_loss: 0.2542
# Epoch 176/1000
#  - 0s - loss: 0.2409 - val_loss: 0.2516
# Epoch 177/1000
#  - 0s - loss: 0.2383 - val_loss: 0.2490
# Epoch 178/1000
#  - 0s - loss: 0.2359 - val_loss: 0.2464
# Epoch 179/1000
#  - 0s - loss: 0.2334 - val_loss: 0.2438
# Epoch 180/1000
#  - 0s - loss: 0.2310 - val_loss: 0.2413
# Epoch 181/1000
#  - 0s - loss: 0.2287 - val_loss: 0.2389
# Epoch 182/1000
#  - 0s - loss: 0.2263 - val_loss: 0.2365
# Epoch 183/1000
#  - 0s - loss: 0.2240 - val_loss: 0.2341
# Epoch 184/1000
#  - 0s - loss: 0.2218 - val_loss: 0.2317
# Epoch 185/1000
#  - 0s - loss: 0.2195 - val_loss: 0.2294
# Epoch 186/1000
#  - 0s - loss: 0.2174 - val_loss: 0.2271
# Epoch 187/1000
#  - 0s - loss: 0.2152 - val_loss: 0.2248
# Epoch 188/1000
#  - 0s - loss: 0.2130 - val_loss: 0.2226
# Epoch 189/1000
#  - 0s - loss: 0.2109 - val_loss: 0.2204
# Epoch 190/1000
#  - 0s - loss: 0.2089 - val_loss: 0.2183
# Epoch 191/1000
#  - 0s - loss: 0.2068 - val_loss: 0.2161
# Epoch 192/1000
#  - 0s - loss: 0.2048 - val_loss: 0.2140
# Epoch 193/1000
#  - 0s - loss: 0.2028 - val_loss: 0.2120
# Epoch 194/1000
#  - 0s - loss: 0.2009 - val_loss: 0.2099
# Epoch 195/1000
#  - 0s - loss: 0.1989 - val_loss: 0.2079
# Epoch 196/1000
#  - 0s - loss: 0.1970 - val_loss: 0.2059
# Epoch 197/1000
#  - 0s - loss: 0.1951 - val_loss: 0.2040
# Epoch 198/1000
#  - 0s - loss: 0.1933 - val_loss: 0.2020
# Epoch 199/1000
#  - 0s - loss: 0.1915 - val_loss: 0.2001
# Epoch 200/1000
#  - 0s - loss: 0.1897 - val_loss: 0.1982
# Epoch 201/1000
#  - 0s - loss: 0.1879 - val_loss: 0.1964
# Epoch 202/1000
#  - 0s - loss: 0.1861 - val_loss: 0.1946
# Epoch 203/1000
#  - 0s - loss: 0.1844 - val_loss: 0.1928
# Epoch 204/1000
#  - 0s - loss: 0.1827 - val_loss: 0.1910
# Epoch 205/1000
#  - 0s - loss: 0.1810 - val_loss: 0.1892
# Epoch 206/1000
#  - 0s - loss: 0.1793 - val_loss: 0.1875
# Epoch 207/1000
#  - 0s - loss: 0.1777 - val_loss: 0.1858
# Epoch 208/1000
#  - 0s - loss: 0.1760 - val_loss: 0.1841
# Epoch 209/1000
#  - 0s - loss: 0.1744 - val_loss: 0.1824
# Epoch 210/1000
#  - 0s - loss: 0.1729 - val_loss: 0.1808
# Epoch 211/1000
#  - 0s - loss: 0.1713 - val_loss: 0.1791
# Epoch 212/1000
#  - 0s - loss: 0.1698 - val_loss: 0.1775
# Epoch 213/1000
#  - 0s - loss: 0.1682 - val_loss: 0.1759
# Epoch 214/1000
#  - 0s - loss: 0.1667 - val_loss: 0.1744
# Epoch 215/1000
#  - 0s - loss: 0.1653 - val_loss: 0.1728
# Epoch 216/1000
#  - 0s - loss: 0.1638 - val_loss: 0.1713
# Epoch 217/1000
#  - 0s - loss: 0.1624 - val_loss: 0.1698
# Epoch 218/1000
#  - 0s - loss: 0.1609 - val_loss: 0.1683
# Epoch 219/1000
#  - 0s - loss: 0.1595 - val_loss: 0.1669
# Epoch 220/1000
#  - 0s - loss: 0.1581 - val_loss: 0.1654
# Epoch 221/1000
#  - 0s - loss: 0.1568 - val_loss: 0.1640
# Epoch 222/1000
#  - 0s - loss: 0.1554 - val_loss: 0.1626
# Epoch 223/1000
#  - 0s - loss: 0.1541 - val_loss: 0.1612
# Epoch 224/1000
#  - 0s - loss: 0.1528 - val_loss: 0.1598
# Epoch 225/1000
#  - 0s - loss: 0.1514 - val_loss: 0.1584
# Epoch 226/1000
#  - 0s - loss: 0.1502 - val_loss: 0.1571
# Epoch 227/1000
#  - 0s - loss: 0.1489 - val_loss: 0.1558
# Epoch 228/1000
#  - 0s - loss: 0.1476 - val_loss: 0.1544
# Epoch 229/1000
#  - 0s - loss: 0.1464 - val_loss: 0.1531
# Epoch 230/1000
#  - 0s - loss: 0.1451 - val_loss: 0.1519
# Epoch 231/1000
#  - 0s - loss: 0.1439 - val_loss: 0.1506
# Epoch 232/1000
#  - 0s - loss: 0.1427 - val_loss: 0.1493
# Epoch 233/1000
#  - 0s - loss: 0.1415 - val_loss: 0.1481
# Epoch 234/1000
#  - 0s - loss: 0.1404 - val_loss: 0.1469
# Epoch 235/1000
#  - 0s - loss: 0.1392 - val_loss: 0.1457
# Epoch 236/1000
#  - 0s - loss: 0.1381 - val_loss: 0.1445
# Epoch 237/1000
#  - 0s - loss: 0.1369 - val_loss: 0.1433
# Epoch 238/1000
#  - 0s - loss: 0.1358 - val_loss: 0.1421
# Epoch 239/1000
#  - 0s - loss: 0.1347 - val_loss: 0.1410
# Epoch 240/1000
#  - 0s - loss: 0.1336 - val_loss: 0.1398
# Epoch 241/1000
#  - 0s - loss: 0.1326 - val_loss: 0.1387
# Epoch 242/1000
#  - 0s - loss: 0.1315 - val_loss: 0.1376
# Epoch 243/1000
#  - 0s - loss: 0.1304 - val_loss: 0.1365
# Epoch 244/1000
#  - 0s - loss: 0.1294 - val_loss: 0.1354
# Epoch 245/1000
#  - 0s - loss: 0.1284 - val_loss: 0.1343
# Epoch 246/1000
#  - 0s - loss: 0.1273 - val_loss: 0.1333
# Epoch 247/1000
#  - 0s - loss: 0.1263 - val_loss: 0.1322
# Epoch 248/1000
#  - 0s - loss: 0.1253 - val_loss: 0.1312
# Epoch 249/1000
#  - 0s - loss: 0.1244 - val_loss: 0.1302
# Epoch 250/1000
#  - 0s - loss: 0.1234 - val_loss: 0.1291
# Epoch 251/1000
#  - 0s - loss: 0.1224 - val_loss: 0.1281
# Epoch 252/1000
#  - 0s - loss: 0.1215 - val_loss: 0.1271
# Epoch 253/1000
#  - 0s - loss: 0.1205 - val_loss: 0.1262
# Epoch 254/1000
#  - 0s - loss: 0.1196 - val_loss: 0.1252
# Epoch 255/1000
#  - 0s - loss: 0.1187 - val_loss: 0.1242
# Epoch 256/1000
#  - 0s - loss: 0.1178 - val_loss: 0.1233
# Epoch 257/1000
#  - 0s - loss: 0.1169 - val_loss: 0.1223
# Epoch 258/1000
#  - 0s - loss: 0.1160 - val_loss: 0.1214
# Epoch 259/1000
#  - 0s - loss: 0.1151 - val_loss: 0.1205
# Epoch 260/1000
#  - 0s - loss: 0.1142 - val_loss: 0.1196
# Epoch 261/1000
#  - 0s - loss: 0.1134 - val_loss: 0.1187
# Epoch 262/1000
#  - 0s - loss: 0.1125 - val_loss: 0.1178
# Epoch 263/1000
#  - 0s - loss: 0.1117 - val_loss: 0.1169
# Epoch 264/1000
#  - 0s - loss: 0.1108 - val_loss: 0.1160
# Epoch 265/1000
#  - 0s - loss: 0.1100 - val_loss: 0.1152
# Epoch 266/1000
#  - 0s - loss: 0.1092 - val_loss: 0.1143
# Epoch 267/1000
#  - 0s - loss: 0.1084 - val_loss: 0.1135
# Epoch 268/1000
#  - 0s - loss: 0.1076 - val_loss: 0.1126
# Epoch 269/1000
#  - 0s - loss: 0.1068 - val_loss: 0.1118
# Epoch 270/1000
#  - 0s - loss: 0.1060 - val_loss: 0.1110
# Epoch 271/1000
#  - 0s - loss: 0.1052 - val_loss: 0.1102
# Epoch 272/1000
#  - 0s - loss: 0.1044 - val_loss: 0.1094
# Epoch 273/1000
#  - 0s - loss: 0.1037 - val_loss: 0.1086
# Epoch 274/1000
#  - 0s - loss: 0.1029 - val_loss: 0.1078
# Epoch 275/1000
#  - 0s - loss: 0.1022 - val_loss: 0.1070
# Epoch 276/1000
#  - 0s - loss: 0.1015 - val_loss: 0.1062
# Epoch 277/1000
#  - 0s - loss: 0.1007 - val_loss: 0.1055
# Epoch 278/1000
#  - 0s - loss: 0.1000 - val_loss: 0.1047
# Epoch 279/1000
#  - 0s - loss: 0.0993 - val_loss: 0.1040
# Epoch 280/1000
#  - 0s - loss: 0.0986 - val_loss: 0.1033
# Epoch 281/1000
#  - 0s - loss: 0.0979 - val_loss: 0.1025
# Epoch 282/1000
#  - 0s - loss: 0.0972 - val_loss: 0.1018
# Epoch 283/1000
#  - 0s - loss: 0.0965 - val_loss: 0.1011
# Epoch 284/1000
#  - 0s - loss: 0.0958 - val_loss: 0.1004
# Epoch 285/1000
#  - 0s - loss: 0.0952 - val_loss: 0.0997
# Epoch 286/1000
#  - 0s - loss: 0.0945 - val_loss: 0.0990
# Epoch 287/1000
#  - 0s - loss: 0.0938 - val_loss: 0.0983
# Epoch 288/1000
#  - 0s - loss: 0.0932 - val_loss: 0.0976
# Epoch 289/1000
#  - 0s - loss: 0.0925 - val_loss: 0.0969
# Epoch 290/1000
#  - 0s - loss: 0.0919 - val_loss: 0.0963
# Epoch 291/1000
#  - 0s - loss: 0.0913 - val_loss: 0.0956
# Epoch 292/1000
#  - 0s - loss: 0.0906 - val_loss: 0.0949
# Epoch 293/1000
#  - 0s - loss: 0.0900 - val_loss: 0.0943
# Epoch 294/1000
#  - 0s - loss: 0.0894 - val_loss: 0.0936
# Epoch 295/1000
#  - 0s - loss: 0.0888 - val_loss: 0.0930
# Epoch 296/1000
#  - 0s - loss: 0.0882 - val_loss: 0.0924
# Epoch 297/1000
#  - 0s - loss: 0.0876 - val_loss: 0.0918
# Epoch 298/1000
#  - 0s - loss: 0.0870 - val_loss: 0.0911
# Epoch 299/1000
#  - 0s - loss: 0.0864 - val_loss: 0.0905
# Epoch 300/1000
#  - 0s - loss: 0.0858 - val_loss: 0.0899
# Epoch 301/1000
#  - 0s - loss: 0.0853 - val_loss: 0.0893
# Epoch 302/1000
#  - 0s - loss: 0.0847 - val_loss: 0.0887
# Epoch 303/1000
#  - 0s - loss: 0.0841 - val_loss: 0.0881
# Epoch 304/1000
#  - 0s - loss: 0.0836 - val_loss: 0.0875
# Epoch 305/1000
#  - 0s - loss: 0.0830 - val_loss: 0.0870
# Epoch 306/1000
#  - 0s - loss: 0.0825 - val_loss: 0.0864
# Epoch 307/1000
#  - 0s - loss: 0.0819 - val_loss: 0.0858
# Epoch 308/1000
#  - 0s - loss: 0.0814 - val_loss: 0.0853
# Epoch 309/1000
#  - 0s - loss: 0.0808 - val_loss: 0.0847
# Epoch 310/1000
#  - 0s - loss: 0.0803 - val_loss: 0.0842
# Epoch 311/1000
#  - 0s - loss: 0.0798 - val_loss: 0.0836
# Epoch 312/1000
#  - 0s - loss: 0.0793 - val_loss: 0.0831
# Epoch 313/1000
#  - 0s - loss: 0.0788 - val_loss: 0.0825
# Epoch 314/1000
#  - 0s - loss: 0.0782 - val_loss: 0.0820
# Epoch 315/1000
#  - 0s - loss: 0.0777 - val_loss: 0.0815
# Epoch 316/1000
#  - 0s - loss: 0.0772 - val_loss: 0.0809
# Epoch 317/1000
#  - 0s - loss: 0.0767 - val_loss: 0.0804
# Epoch 318/1000
#  - 0s - loss: 0.0763 - val_loss: 0.0799
# Epoch 319/1000
#  - 0s - loss: 0.0758 - val_loss: 0.0794
# Epoch 320/1000
#  - 0s - loss: 0.0753 - val_loss: 0.0789
# Epoch 321/1000
#  - 0s - loss: 0.0748 - val_loss: 0.0784
# Epoch 322/1000
#  - 0s - loss: 0.0743 - val_loss: 0.0779
# Epoch 323/1000
#  - 0s - loss: 0.0739 - val_loss: 0.0774
# Epoch 324/1000
#  - 0s - loss: 0.0734 - val_loss: 0.0769
# Epoch 325/1000
#  - 0s - loss: 0.0729 - val_loss: 0.0764
# Epoch 326/1000
#  - 0s - loss: 0.0725 - val_loss: 0.0760
# Epoch 327/1000
#  - 0s - loss: 0.0720 - val_loss: 0.0755
# Epoch 328/1000
#  - 0s - loss: 0.0716 - val_loss: 0.0750
# Epoch 329/1000
#  - 0s - loss: 0.0711 - val_loss: 0.0746
# Epoch 330/1000
#  - 0s - loss: 0.0707 - val_loss: 0.0741
# Epoch 331/1000
#  - 0s - loss: 0.0703 - val_loss: 0.0736
# Epoch 332/1000
#  - 0s - loss: 0.0698 - val_loss: 0.0732
# Epoch 333/1000
#  - 0s - loss: 0.0694 - val_loss: 0.0727
# Epoch 334/1000
#  - 0s - loss: 0.0690 - val_loss: 0.0723
# Epoch 335/1000
#  - 0s - loss: 0.0685 - val_loss: 0.0718
# Epoch 336/1000
#  - 0s - loss: 0.0681 - val_loss: 0.0714
# Epoch 337/1000
#  - 0s - loss: 0.0677 - val_loss: 0.0710
# Epoch 338/1000
#  - 0s - loss: 0.0673 - val_loss: 0.0705
# Epoch 339/1000
#  - 0s - loss: 0.0669 - val_loss: 0.0701
# Epoch 340/1000
#  - 0s - loss: 0.0665 - val_loss: 0.0697
# Epoch 341/1000
#  - 0s - loss: 0.0661 - val_loss: 0.0693
# Epoch 342/1000
#  - 0s - loss: 0.0657 - val_loss: 0.0689
# Epoch 343/1000
#  - 0s - loss: 0.0653 - val_loss: 0.0684
# Epoch 344/1000
#  - 0s - loss: 0.0649 - val_loss: 0.0680
# Epoch 345/1000
#  - 0s - loss: 0.0645 - val_loss: 0.0676
# Epoch 346/1000
#  - 0s - loss: 0.0641 - val_loss: 0.0672
# Epoch 347/1000
#  - 0s - loss: 0.0637 - val_loss: 0.0668
# Epoch 348/1000
#  - 0s - loss: 0.0634 - val_loss: 0.0664
# Epoch 349/1000
#  - 0s - loss: 0.0630 - val_loss: 0.0660
# Epoch 350/1000
#  - 0s - loss: 0.0626 - val_loss: 0.0657
# Epoch 351/1000
#  - 0s - loss: 0.0623 - val_loss: 0.0653
# Epoch 352/1000
#  - 0s - loss: 0.0619 - val_loss: 0.0649
# Epoch 353/1000
#  - 0s - loss: 0.0615 - val_loss: 0.0645
# Epoch 354/1000
#  - 0s - loss: 0.0612 - val_loss: 0.0641
# Epoch 355/1000
#  - 0s - loss: 0.0608 - val_loss: 0.0638
# Epoch 356/1000
#  - 0s - loss: 0.0605 - val_loss: 0.0634
# Epoch 357/1000
#  - 0s - loss: 0.0601 - val_loss: 0.0630
# Epoch 358/1000
#  - 0s - loss: 0.0598 - val_loss: 0.0627
# Epoch 359/1000
#  - 0s - loss: 0.0594 - val_loss: 0.0623
# Epoch 360/1000
#  - 0s - loss: 0.0591 - val_loss: 0.0619
# Epoch 361/1000
#  - 0s - loss: 0.0587 - val_loss: 0.0616
# Epoch 362/1000
#  - 0s - loss: 0.0584 - val_loss: 0.0612
# Epoch 363/1000
#  - 0s - loss: 0.0581 - val_loss: 0.0609
# Epoch 364/1000
#  - 0s - loss: 0.0577 - val_loss: 0.0605
# Epoch 365/1000
#  - 0s - loss: 0.0574 - val_loss: 0.0602
# Epoch 366/1000
#  - 0s - loss: 0.0571 - val_loss: 0.0598
# Epoch 367/1000
#  - 0s - loss: 0.0567 - val_loss: 0.0595
# Epoch 368/1000
#  - 0s - loss: 0.0564 - val_loss: 0.0592
# Epoch 369/1000
#  - 0s - loss: 0.0561 - val_loss: 0.0588
# Epoch 370/1000
#  - 0s - loss: 0.0558 - val_loss: 0.0585
# Epoch 371/1000
#  - 0s - loss: 0.0555 - val_loss: 0.0582
# Epoch 372/1000
#  - 0s - loss: 0.0552 - val_loss: 0.0578
# Epoch 373/1000
#  - 0s - loss: 0.0549 - val_loss: 0.0575
# Epoch 374/1000
#  - 0s - loss: 0.0546 - val_loss: 0.0572
# Epoch 375/1000
#  - 0s - loss: 0.0542 - val_loss: 0.0569
# Epoch 376/1000
#  - 0s - loss: 0.0539 - val_loss: 0.0566
# Epoch 377/1000
#  - 0s - loss: 0.0536 - val_loss: 0.0563
# Epoch 378/1000
#  - 0s - loss: 0.0533 - val_loss: 0.0559
# Epoch 379/1000
#  - 0s - loss: 0.0531 - val_loss: 0.0556
# Epoch 380/1000
#  - 0s - loss: 0.0528 - val_loss: 0.0553
# Epoch 381/1000
#  - 0s - loss: 0.0525 - val_loss: 0.0550
# Epoch 382/1000
#  - 0s - loss: 0.0522 - val_loss: 0.0547
# Epoch 383/1000
#  - 0s - loss: 0.0519 - val_loss: 0.0544
# Epoch 384/1000
#  - 0s - loss: 0.0516 - val_loss: 0.0541
# Epoch 385/1000
#  - 0s - loss: 0.0513 - val_loss: 0.0538
# Epoch 386/1000
#  - 0s - loss: 0.0511 - val_loss: 0.0535
# Epoch 387/1000
#  - 0s - loss: 0.0508 - val_loss: 0.0533
# Epoch 388/1000
#  - 0s - loss: 0.0505 - val_loss: 0.0530
# Epoch 389/1000
#  - 0s - loss: 0.0502 - val_loss: 0.0527
# Epoch 390/1000
#  - 0s - loss: 0.0500 - val_loss: 0.0524
# Epoch 391/1000
#  - 0s - loss: 0.0497 - val_loss: 0.0521
# Epoch 392/1000
#  - 0s - loss: 0.0494 - val_loss: 0.0518
# Epoch 393/1000
#  - 0s - loss: 0.0492 - val_loss: 0.0516
# Epoch 394/1000
#  - 0s - loss: 0.0489 - val_loss: 0.0513
# Epoch 395/1000
#  - 0s - loss: 0.0486 - val_loss: 0.0510
# Epoch 396/1000
#  - 0s - loss: 0.0484 - val_loss: 0.0507
# Epoch 397/1000
#  - 0s - loss: 0.0481 - val_loss: 0.0505
# Epoch 398/1000
#  - 0s - loss: 0.0479 - val_loss: 0.0502
# Epoch 399/1000
#  - 0s - loss: 0.0476 - val_loss: 0.0499
# Epoch 400/1000
#  - 0s - loss: 0.0474 - val_loss: 0.0497
# Epoch 401/1000
#  - 0s - loss: 0.0471 - val_loss: 0.0494
# Epoch 402/1000
#  - 0s - loss: 0.0469 - val_loss: 0.0491
# Epoch 403/1000
#  - 0s - loss: 0.0466 - val_loss: 0.0489
# Epoch 404/1000
#  - 0s - loss: 0.0464 - val_loss: 0.0486
# Epoch 405/1000
#  - 0s - loss: 0.0461 - val_loss: 0.0484
# Epoch 406/1000
#  - 0s - loss: 0.0459 - val_loss: 0.0481
# Epoch 407/1000
#  - 0s - loss: 0.0456 - val_loss: 0.0479
# Epoch 408/1000
#  - 0s - loss: 0.0454 - val_loss: 0.0476
# Epoch 409/1000
#  - 0s - loss: 0.0452 - val_loss: 0.0474
# Epoch 410/1000
#  - 0s - loss: 0.0449 - val_loss: 0.0471
# Epoch 411/1000
#  - 0s - loss: 0.0447 - val_loss: 0.0469
# Epoch 412/1000
#  - 0s - loss: 0.0445 - val_loss: 0.0467
# Epoch 413/1000
#  - 0s - loss: 0.0442 - val_loss: 0.0464
# Epoch 414/1000
#  - 0s - loss: 0.0440 - val_loss: 0.0462
# Epoch 415/1000
#  - 0s - loss: 0.0438 - val_loss: 0.0459
# Epoch 416/1000
#  - 0s - loss: 0.0436 - val_loss: 0.0457
# Epoch 417/1000
#  - 0s - loss: 0.0433 - val_loss: 0.0455
# Epoch 418/1000
#  - 0s - loss: 0.0431 - val_loss: 0.0452
# Epoch 419/1000
#  - 0s - loss: 0.0429 - val_loss: 0.0450
# Epoch 420/1000
#  - 0s - loss: 0.0427 - val_loss: 0.0448
# Epoch 421/1000
#  - 0s - loss: 0.0425 - val_loss: 0.0446
# Epoch 422/1000
#  - 0s - loss: 0.0423 - val_loss: 0.0443
# Epoch 423/1000
#  - 0s - loss: 0.0420 - val_loss: 0.0441
# Epoch 424/1000
#  - 0s - loss: 0.0418 - val_loss: 0.0439
# Epoch 425/1000
#  - 0s - loss: 0.0416 - val_loss: 0.0437
# Epoch 426/1000
#  - 0s - loss: 0.0414 - val_loss: 0.0434
# Epoch 427/1000
#  - 0s - loss: 0.0412 - val_loss: 0.0432
# Epoch 428/1000
#  - 0s - loss: 0.0410 - val_loss: 0.0430
# Epoch 429/1000
#  - 0s - loss: 0.0408 - val_loss: 0.0428
# Epoch 430/1000
#  - 0s - loss: 0.0406 - val_loss: 0.0426
# Epoch 431/1000
#  - 0s - loss: 0.0404 - val_loss: 0.0424
# Epoch 432/1000
#  - 0s - loss: 0.0402 - val_loss: 0.0422
# Epoch 433/1000
#  - 0s - loss: 0.0400 - val_loss: 0.0420
# Epoch 434/1000
#  - 0s - loss: 0.0398 - val_loss: 0.0418
# Epoch 435/1000
#  - 0s - loss: 0.0396 - val_loss: 0.0415
# Epoch 436/1000
#  - 0s - loss: 0.0394 - val_loss: 0.0413
# Epoch 437/1000
#  - 0s - loss: 0.0392 - val_loss: 0.0411
# Epoch 438/1000
#  - 0s - loss: 0.0390 - val_loss: 0.0409
# Epoch 439/1000
#  - 0s - loss: 0.0388 - val_loss: 0.0407
# Epoch 440/1000
#  - 0s - loss: 0.0386 - val_loss: 0.0405
# Epoch 441/1000
#  - 0s - loss: 0.0385 - val_loss: 0.0403
# Epoch 442/1000
#  - 0s - loss: 0.0383 - val_loss: 0.0401
# Epoch 443/1000
#  - 0s - loss: 0.0381 - val_loss: 0.0400
# Epoch 444/1000
#  - 0s - loss: 0.0379 - val_loss: 0.0398
# Epoch 445/1000
#  - 0s - loss: 0.0377 - val_loss: 0.0396
# Epoch 446/1000
#  - 0s - loss: 0.0375 - val_loss: 0.0394
# Epoch 447/1000
#  - 0s - loss: 0.0373 - val_loss: 0.0392
# Epoch 448/1000
#  - 0s - loss: 0.0372 - val_loss: 0.0390
# Epoch 449/1000
#  - 0s - loss: 0.0370 - val_loss: 0.0388
# Epoch 450/1000
#  - 0s - loss: 0.0368 - val_loss: 0.0386
# Epoch 451/1000
#  - 0s - loss: 0.0366 - val_loss: 0.0384
# Epoch 452/1000
#  - 0s - loss: 0.0365 - val_loss: 0.0383
# Epoch 453/1000
#  - 0s - loss: 0.0363 - val_loss: 0.0381
# Epoch 454/1000
#  - 0s - loss: 0.0361 - val_loss: 0.0379
# Epoch 455/1000
#  - 0s - loss: 0.0359 - val_loss: 0.0377
# Epoch 456/1000
#  - 0s - loss: 0.0358 - val_loss: 0.0375
# Epoch 457/1000
#  - 0s - loss: 0.0356 - val_loss: 0.0374
# Epoch 458/1000
#  - 0s - loss: 0.0354 - val_loss: 0.0372
# Epoch 459/1000
#  - 0s - loss: 0.0353 - val_loss: 0.0370
# Epoch 460/1000
#  - 0s - loss: 0.0351 - val_loss: 0.0368
# Epoch 461/1000
#  - 0s - loss: 0.0349 - val_loss: 0.0367
# Epoch 462/1000
#  - 0s - loss: 0.0348 - val_loss: 0.0365
# Epoch 463/1000
#  - 0s - loss: 0.0346 - val_loss: 0.0363
# Epoch 464/1000
#  - 0s - loss: 0.0344 - val_loss: 0.0361
# Epoch 465/1000
#  - 0s - loss: 0.0343 - val_loss: 0.0360
# Epoch 466/1000
#  - 0s - loss: 0.0341 - val_loss: 0.0358
# Epoch 467/1000
#  - 0s - loss: 0.0340 - val_loss: 0.0356
# Epoch 468/1000
#  - 0s - loss: 0.0338 - val_loss: 0.0355
# Epoch 469/1000
#  - 0s - loss: 0.0337 - val_loss: 0.0353
# Epoch 470/1000
#  - 0s - loss: 0.0335 - val_loss: 0.0352
# Epoch 471/1000
#  - 0s - loss: 0.0333 - val_loss: 0.0350
# Epoch 472/1000
#  - 0s - loss: 0.0332 - val_loss: 0.0348
# Epoch 473/1000
#  - 0s - loss: 0.0330 - val_loss: 0.0347
# Epoch 474/1000
#  - 0s - loss: 0.0329 - val_loss: 0.0345
# Epoch 475/1000
#  - 0s - loss: 0.0327 - val_loss: 0.0344
# Epoch 476/1000
#  - 0s - loss: 0.0326 - val_loss: 0.0342
# Epoch 477/1000
#  - 0s - loss: 0.0324 - val_loss: 0.0340
# Epoch 478/1000
#  - 0s - loss: 0.0323 - val_loss: 0.0339
# Epoch 479/1000
#  - 0s - loss: 0.0321 - val_loss: 0.0337
# Epoch 480/1000
#  - 0s - loss: 0.0320 - val_loss: 0.0336
# Epoch 481/1000
#  - 0s - loss: 0.0318 - val_loss: 0.0334
# Epoch 482/1000
#  - 0s - loss: 0.0317 - val_loss: 0.0333
# Epoch 483/1000
#  - 0s - loss: 0.0316 - val_loss: 0.0331
# Epoch 484/1000
#  - 0s - loss: 0.0314 - val_loss: 0.0330
# Epoch 485/1000
#  - 0s - loss: 0.0313 - val_loss: 0.0328
# Epoch 486/1000
#  - 0s - loss: 0.0311 - val_loss: 0.0327
# Epoch 487/1000
#  - 0s - loss: 0.0310 - val_loss: 0.0325
# Epoch 488/1000
#  - 0s - loss: 0.0309 - val_loss: 0.0324
# Epoch 489/1000
#  - 0s - loss: 0.0307 - val_loss: 0.0322
# Epoch 490/1000
#  - 0s - loss: 0.0306 - val_loss: 0.0321
# Epoch 491/1000
#  - 0s - loss: 0.0304 - val_loss: 0.0320
# Epoch 492/1000
#  - 0s - loss: 0.0303 - val_loss: 0.0318
# Epoch 493/1000
#  - 0s - loss: 0.0302 - val_loss: 0.0317
# Epoch 494/1000
#  - 0s - loss: 0.0300 - val_loss: 0.0315
# Epoch 495/1000
#  - 0s - loss: 0.0299 - val_loss: 0.0314
# Epoch 496/1000
#  - 0s - loss: 0.0298 - val_loss: 0.0313
# Epoch 497/1000
#  - 0s - loss: 0.0296 - val_loss: 0.0311
# Epoch 498/1000
#  - 0s - loss: 0.0295 - val_loss: 0.0310
# Epoch 499/1000
#  - 0s - loss: 0.0294 - val_loss: 0.0308
# Epoch 500/1000
#  - 0s - loss: 0.0293 - val_loss: 0.0307
# Epoch 501/1000
#  - 0s - loss: 0.0291 - val_loss: 0.0306
# Epoch 502/1000
#  - 0s - loss: 0.0290 - val_loss: 0.0304
# Epoch 503/1000
#  - 0s - loss: 0.0289 - val_loss: 0.0303
# Epoch 504/1000
#  - 0s - loss: 0.0287 - val_loss: 0.0302
# Epoch 505/1000
#  - 0s - loss: 0.0286 - val_loss: 0.0300
# Epoch 506/1000
#  - 0s - loss: 0.0285 - val_loss: 0.0299
# Epoch 507/1000
#  - 0s - loss: 0.0284 - val_loss: 0.0298
# Epoch 508/1000
#  - 0s - loss: 0.0282 - val_loss: 0.0296
# Epoch 509/1000
#  - 0s - loss: 0.0281 - val_loss: 0.0295
# Epoch 510/1000
#  - 0s - loss: 0.0280 - val_loss: 0.0294
# Epoch 511/1000
#  - 0s - loss: 0.0279 - val_loss: 0.0293
# Epoch 512/1000
#  - 0s - loss: 0.0278 - val_loss: 0.0291
# Epoch 513/1000
#  - 0s - loss: 0.0276 - val_loss: 0.0290
# Epoch 514/1000
#  - 0s - loss: 0.0275 - val_loss: 0.0289
# Epoch 515/1000
#  - 0s - loss: 0.0274 - val_loss: 0.0288
# Epoch 516/1000
#  - 0s - loss: 0.0273 - val_loss: 0.0286
# Epoch 517/1000
#  - 0s - loss: 0.0272 - val_loss: 0.0285
# Epoch 518/1000
#  - 0s - loss: 0.0271 - val_loss: 0.0284
# Epoch 519/1000
#  - 0s - loss: 0.0269 - val_loss: 0.0283
# Epoch 520/1000
#  - 0s - loss: 0.0268 - val_loss: 0.0282
# Epoch 521/1000
#  - 0s - loss: 0.0267 - val_loss: 0.0280
# Epoch 522/1000
#  - 0s - loss: 0.0266 - val_loss: 0.0279
# Epoch 523/1000
#  - 0s - loss: 0.0265 - val_loss: 0.0278
# Epoch 524/1000
#  - 0s - loss: 0.0264 - val_loss: 0.0277
# Epoch 525/1000
#  - 0s - loss: 0.0263 - val_loss: 0.0276
# Epoch 526/1000
#  - 0s - loss: 0.0261 - val_loss: 0.0274
# Epoch 527/1000
#  - 0s - loss: 0.0260 - val_loss: 0.0273
# Epoch 528/1000
#  - 0s - loss: 0.0259 - val_loss: 0.0272
# Epoch 529/1000
#  - 0s - loss: 0.0258 - val_loss: 0.0271
# Epoch 530/1000
#  - 0s - loss: 0.0257 - val_loss: 0.0270
# Epoch 531/1000
#  - 0s - loss: 0.0256 - val_loss: 0.0269
# Epoch 532/1000
#  - 0s - loss: 0.0255 - val_loss: 0.0268
# Epoch 533/1000
#  - 0s - loss: 0.0254 - val_loss: 0.0267
# Epoch 534/1000
#  - 0s - loss: 0.0253 - val_loss: 0.0265
# Epoch 535/1000
#  - 0s - loss: 0.0252 - val_loss: 0.0264
# Epoch 536/1000
#  - 0s - loss: 0.0251 - val_loss: 0.0263
# Epoch 537/1000
#  - 0s - loss: 0.0250 - val_loss: 0.0262
# Epoch 538/1000
#  - 0s - loss: 0.0249 - val_loss: 0.0261
# Epoch 539/1000
#  - 0s - loss: 0.0248 - val_loss: 0.0260
# Epoch 540/1000
#  - 0s - loss: 0.0247 - val_loss: 0.0259
# Epoch 541/1000
#  - 0s - loss: 0.0246 - val_loss: 0.0258
# Epoch 542/1000
#  - 0s - loss: 0.0245 - val_loss: 0.0257
# Epoch 543/1000
#  - 0s - loss: 0.0244 - val_loss: 0.0256
# Epoch 544/1000
#  - 0s - loss: 0.0243 - val_loss: 0.0255
# Epoch 545/1000
#  - 0s - loss: 0.0242 - val_loss: 0.0254
# Epoch 546/1000
#  - 0s - loss: 0.0241 - val_loss: 0.0253
# Epoch 547/1000
#  - 0s - loss: 0.0240 - val_loss: 0.0252
# Epoch 548/1000
#  - 0s - loss: 0.0239 - val_loss: 0.0251
# Epoch 549/1000
#  - 0s - loss: 0.0238 - val_loss: 0.0250
# Epoch 550/1000
#  - 0s - loss: 0.0237 - val_loss: 0.0248
# Epoch 551/1000
#  - 0s - loss: 0.0236 - val_loss: 0.0247
# Epoch 552/1000
#  - 0s - loss: 0.0235 - val_loss: 0.0246
# Epoch 553/1000
#  - 0s - loss: 0.0234 - val_loss: 0.0245
# Epoch 554/1000
#  - 0s - loss: 0.0233 - val_loss: 0.0244
# Epoch 555/1000
#  - 0s - loss: 0.0232 - val_loss: 0.0244
# Epoch 556/1000
#  - 0s - loss: 0.0231 - val_loss: 0.0243
# Epoch 557/1000
#  - 0s - loss: 0.0230 - val_loss: 0.0242
# Epoch 558/1000
#  - 0s - loss: 0.0229 - val_loss: 0.0241
# Epoch 559/1000
#  - 0s - loss: 0.0228 - val_loss: 0.0240
# Epoch 560/1000
#  - 0s - loss: 0.0227 - val_loss: 0.0239
# Epoch 561/1000
#  - 0s - loss: 0.0226 - val_loss: 0.0238
# Epoch 562/1000
#  - 0s - loss: 0.0225 - val_loss: 0.0237
# Epoch 563/1000
#  - 0s - loss: 0.0225 - val_loss: 0.0236
# Epoch 564/1000
#  - 0s - loss: 0.0224 - val_loss: 0.0235
# Epoch 565/1000
#  - 0s - loss: 0.0223 - val_loss: 0.0234
# Epoch 566/1000
#  - 0s - loss: 0.0222 - val_loss: 0.0233
# Epoch 567/1000
#  - 0s - loss: 0.0221 - val_loss: 0.0232
# Epoch 568/1000
#  - 0s - loss: 0.0220 - val_loss: 0.0231
# Epoch 569/1000
#  - 0s - loss: 0.0219 - val_loss: 0.0230
# Epoch 570/1000
#  - 0s - loss: 0.0218 - val_loss: 0.0229
# Epoch 571/1000
#  - 0s - loss: 0.0218 - val_loss: 0.0228
# Epoch 572/1000
#  - 0s - loss: 0.0217 - val_loss: 0.0228
# Epoch 573/1000
#  - 0s - loss: 0.0216 - val_loss: 0.0227
# Epoch 574/1000
#  - 0s - loss: 0.0215 - val_loss: 0.0226
# Epoch 575/1000
#  - 0s - loss: 0.0214 - val_loss: 0.0225
# Epoch 576/1000
#  - 0s - loss: 0.0213 - val_loss: 0.0224
# Epoch 577/1000
#  - 0s - loss: 0.0212 - val_loss: 0.0223
# Epoch 578/1000
#  - 0s - loss: 0.0212 - val_loss: 0.0222
# Epoch 579/1000
#  - 0s - loss: 0.0211 - val_loss: 0.0221
# Epoch 580/1000
#  - 0s - loss: 0.0210 - val_loss: 0.0220
# Epoch 581/1000
#  - 0s - loss: 0.0209 - val_loss: 0.0220
# Epoch 582/1000
#  - 0s - loss: 0.0208 - val_loss: 0.0219
# Epoch 583/1000
#  - 0s - loss: 0.0208 - val_loss: 0.0218
# Epoch 584/1000
#  - 0s - loss: 0.0207 - val_loss: 0.0217
# Epoch 585/1000
#  - 0s - loss: 0.0206 - val_loss: 0.0216
# Epoch 586/1000
#  - 0s - loss: 0.0205 - val_loss: 0.0215
# Epoch 587/1000
#  - 0s - loss: 0.0204 - val_loss: 0.0215
# Epoch 588/1000
#  - 0s - loss: 0.0204 - val_loss: 0.0214
# Epoch 589/1000
#  - 0s - loss: 0.0203 - val_loss: 0.0213
# Epoch 590/1000
#  - 0s - loss: 0.0202 - val_loss: 0.0212
# Epoch 591/1000
#  - 0s - loss: 0.0201 - val_loss: 0.0211
# Epoch 592/1000
#  - 0s - loss: 0.0200 - val_loss: 0.0210
# Epoch 593/1000
#  - 0s - loss: 0.0200 - val_loss: 0.0210
# Epoch 594/1000
#  - 0s - loss: 0.0199 - val_loss: 0.0209
# Epoch 595/1000
#  - 0s - loss: 0.0198 - val_loss: 0.0208
# Epoch 596/1000
#  - 0s - loss: 0.0197 - val_loss: 0.0207
# Epoch 597/1000
#  - 0s - loss: 0.0197 - val_loss: 0.0206
# Epoch 598/1000
#  - 0s - loss: 0.0196 - val_loss: 0.0206
# Epoch 599/1000
#  - 0s - loss: 0.0195 - val_loss: 0.0205
# Epoch 600/1000
#  - 0s - loss: 0.0194 - val_loss: 0.0204
# Epoch 601/1000
#  - 0s - loss: 0.0194 - val_loss: 0.0203
# Epoch 602/1000
#  - 0s - loss: 0.0193 - val_loss: 0.0203
# Epoch 603/1000
#  - 0s - loss: 0.0192 - val_loss: 0.0202
# Epoch 604/1000
#  - 0s - loss: 0.0191 - val_loss: 0.0201
# Epoch 605/1000
#  - 0s - loss: 0.0191 - val_loss: 0.0200
# Epoch 606/1000
#  - 0s - loss: 0.0190 - val_loss: 0.0200
# Epoch 607/1000
#  - 0s - loss: 0.0189 - val_loss: 0.0199
# Epoch 608/1000
#  - 0s - loss: 0.0189 - val_loss: 0.0198
# Epoch 609/1000
#  - 0s - loss: 0.0188 - val_loss: 0.0197
# Epoch 610/1000
#  - 0s - loss: 0.0187 - val_loss: 0.0197
# Epoch 611/1000
#  - 0s - loss: 0.0186 - val_loss: 0.0196
# Epoch 612/1000
#  - 0s - loss: 0.0186 - val_loss: 0.0195
# Epoch 613/1000
#  - 0s - loss: 0.0185 - val_loss: 0.0194
# Epoch 614/1000
#  - 0s - loss: 0.0184 - val_loss: 0.0194
# Epoch 615/1000
#  - 0s - loss: 0.0184 - val_loss: 0.0193
# Epoch 616/1000
#  - 0s - loss: 0.0183 - val_loss: 0.0192
# Epoch 617/1000
#  - 0s - loss: 0.0182 - val_loss: 0.0191
# Epoch 618/1000
#  - 0s - loss: 0.0182 - val_loss: 0.0191
# Epoch 619/1000
#  - 0s - loss: 0.0181 - val_loss: 0.0190
# Epoch 620/1000
#  - 0s - loss: 0.0180 - val_loss: 0.0189
# Epoch 621/1000
#  - 0s - loss: 0.0180 - val_loss: 0.0189
# Epoch 622/1000
#  - 0s - loss: 0.0179 - val_loss: 0.0188
# Epoch 623/1000
#  - 0s - loss: 0.0178 - val_loss: 0.0187
# Epoch 624/1000
#  - 0s - loss: 0.0178 - val_loss: 0.0187
# Epoch 625/1000
#  - 0s - loss: 0.0177 - val_loss: 0.0186
# Epoch 626/1000
#  - 0s - loss: 0.0176 - val_loss: 0.0185
# Epoch 627/1000
#  - 0s - loss: 0.0176 - val_loss: 0.0185
# Epoch 628/1000
#  - 0s - loss: 0.0175 - val_loss: 0.0184
# Epoch 629/1000
#  - 0s - loss: 0.0174 - val_loss: 0.0183
# Epoch 630/1000
#  - 0s - loss: 0.0174 - val_loss: 0.0182
# Epoch 631/1000
#  - 0s - loss: 0.0173 - val_loss: 0.0182
# Epoch 632/1000
#  - 0s - loss: 0.0173 - val_loss: 0.0181
# Epoch 633/1000
#  - 0s - loss: 0.0172 - val_loss: 0.0181
# Epoch 634/1000
#  - 0s - loss: 0.0171 - val_loss: 0.0180
# Epoch 635/1000
#  - 0s - loss: 0.0171 - val_loss: 0.0179
# Epoch 636/1000
#  - 0s - loss: 0.0170 - val_loss: 0.0179
# Epoch 637/1000
#  - 0s - loss: 0.0169 - val_loss: 0.0178
# Epoch 638/1000
#  - 0s - loss: 0.0169 - val_loss: 0.0177
# Epoch 639/1000
#  - 0s - loss: 0.0168 - val_loss: 0.0177
# Epoch 640/1000
#  - 0s - loss: 0.0168 - val_loss: 0.0176
# Epoch 641/1000
#  - 0s - loss: 0.0167 - val_loss: 0.0175
# Epoch 642/1000
#  - 0s - loss: 0.0166 - val_loss: 0.0175
# Epoch 643/1000
#  - 0s - loss: 0.0166 - val_loss: 0.0174
# Epoch 644/1000
#  - 0s - loss: 0.0165 - val_loss: 0.0173
# Epoch 645/1000
#  - 0s - loss: 0.0165 - val_loss: 0.0173
# Epoch 646/1000
#  - 0s - loss: 0.0164 - val_loss: 0.0172
# Epoch 647/1000
#  - 0s - loss: 0.0163 - val_loss: 0.0172
# Epoch 648/1000
#  - 0s - loss: 0.0163 - val_loss: 0.0171
# Epoch 649/1000
#  - 0s - loss: 0.0162 - val_loss: 0.0170
# Epoch 650/1000
#  - 0s - loss: 0.0162 - val_loss: 0.0170
# Epoch 651/1000
#  - 0s - loss: 0.0161 - val_loss: 0.0169
# Epoch 652/1000
#  - 0s - loss: 0.0160 - val_loss: 0.0169
# Epoch 653/1000
#  - 0s - loss: 0.0160 - val_loss: 0.0168
# Epoch 654/1000
#  - 0s - loss: 0.0159 - val_loss: 0.0167
# Epoch 655/1000
#  - 0s - loss: 0.0159 - val_loss: 0.0167
# Epoch 656/1000
#  - 0s - loss: 0.0158 - val_loss: 0.0166
# Epoch 657/1000
#  - 0s - loss: 0.0158 - val_loss: 0.0166
# Epoch 658/1000
#  - 0s - loss: 0.0157 - val_loss: 0.0165
# Epoch 659/1000
#  - 0s - loss: 0.0157 - val_loss: 0.0164
# Epoch 660/1000
#  - 0s - loss: 0.0156 - val_loss: 0.0164
# Epoch 661/1000
#  - 0s - loss: 0.0155 - val_loss: 0.0163
# Epoch 662/1000
#  - 0s - loss: 0.0155 - val_loss: 0.0163
# Epoch 663/1000
#  - 0s - loss: 0.0154 - val_loss: 0.0162
# Epoch 664/1000
#  - 0s - loss: 0.0154 - val_loss: 0.0162
# Epoch 665/1000
#  - 0s - loss: 0.0153 - val_loss: 0.0161
# Epoch 666/1000
#  - 0s - loss: 0.0153 - val_loss: 0.0160
# Epoch 667/1000
#  - 0s - loss: 0.0152 - val_loss: 0.0160
# Epoch 668/1000
#  - 0s - loss: 0.0152 - val_loss: 0.0159
# Epoch 669/1000
#  - 0s - loss: 0.0151 - val_loss: 0.0159
# Epoch 670/1000
#  - 0s - loss: 0.0151 - val_loss: 0.0158
# Epoch 671/1000
#  - 0s - loss: 0.0150 - val_loss: 0.0158
# Epoch 672/1000
#  - 0s - loss: 0.0150 - val_loss: 0.0157
# Epoch 673/1000
#  - 0s - loss: 0.0149 - val_loss: 0.0157
# Epoch 674/1000
#  - 0s - loss: 0.0149 - val_loss: 0.0156
# Epoch 675/1000
#  - 0s - loss: 0.0148 - val_loss: 0.0155
# Epoch 676/1000
#  - 0s - loss: 0.0147 - val_loss: 0.0155
# Epoch 677/1000
#  - 0s - loss: 0.0147 - val_loss: 0.0154
# Epoch 678/1000
#  - 0s - loss: 0.0146 - val_loss: 0.0154
# Epoch 679/1000
#  - 0s - loss: 0.0146 - val_loss: 0.0153
# Epoch 680/1000
#  - 0s - loss: 0.0145 - val_loss: 0.0153
# Epoch 681/1000
#  - 0s - loss: 0.0145 - val_loss: 0.0152
# Epoch 682/1000
#  - 0s - loss: 0.0144 - val_loss: 0.0152
# Epoch 683/1000
#  - 0s - loss: 0.0144 - val_loss: 0.0151
# Epoch 684/1000
#  - 0s - loss: 0.0143 - val_loss: 0.0151
# Epoch 685/1000
#  - 0s - loss: 0.0143 - val_loss: 0.0150
# Epoch 686/1000
#  - 0s - loss: 0.0142 - val_loss: 0.0150
# Epoch 687/1000
#  - 0s - loss: 0.0142 - val_loss: 0.0149
# Epoch 688/1000
#  - 0s - loss: 0.0142 - val_loss: 0.0149
# Epoch 689/1000
#  - 0s - loss: 0.0141 - val_loss: 0.0148
# Epoch 690/1000
#  - 0s - loss: 0.0141 - val_loss: 0.0148
# Epoch 691/1000
#  - 0s - loss: 0.0140 - val_loss: 0.0147
# Epoch 692/1000
#  - 0s - loss: 0.0140 - val_loss: 0.0147
# Epoch 693/1000
#  - 0s - loss: 0.0139 - val_loss: 0.0146
# Epoch 694/1000
#  - 0s - loss: 0.0139 - val_loss: 0.0146
# Epoch 695/1000
#  - 0s - loss: 0.0138 - val_loss: 0.0145
# Epoch 696/1000
#  - 0s - loss: 0.0138 - val_loss: 0.0145
# Epoch 697/1000
#  - 0s - loss: 0.0137 - val_loss: 0.0144
# Epoch 698/1000
#  - 0s - loss: 0.0137 - val_loss: 0.0144
# Epoch 699/1000
#  - 0s - loss: 0.0136 - val_loss: 0.0143
# Epoch 700/1000
#  - 0s - loss: 0.0136 - val_loss: 0.0143
# Epoch 701/1000
#  - 0s - loss: 0.0135 - val_loss: 0.0142
# Epoch 702/1000
#  - 0s - loss: 0.0135 - val_loss: 0.0142
# Epoch 703/1000
#  - 0s - loss: 0.0134 - val_loss: 0.0141
# Epoch 704/1000
#  - 0s - loss: 0.0134 - val_loss: 0.0141
# Epoch 705/1000
#  - 0s - loss: 0.0134 - val_loss: 0.0140
# Epoch 706/1000
#  - 0s - loss: 0.0133 - val_loss: 0.0140
# Epoch 707/1000
#  - 0s - loss: 0.0133 - val_loss: 0.0139
# Epoch 708/1000
#  - 0s - loss: 0.0132 - val_loss: 0.0139
# Epoch 709/1000
#  - 0s - loss: 0.0132 - val_loss: 0.0138
# Epoch 710/1000
#  - 0s - loss: 0.0131 - val_loss: 0.0138
# Epoch 711/1000
#  - 0s - loss: 0.0131 - val_loss: 0.0138
# Epoch 712/1000
#  - 0s - loss: 0.0130 - val_loss: 0.0137
# Epoch 713/1000
#  - 0s - loss: 0.0130 - val_loss: 0.0137
# Epoch 714/1000
#  - 0s - loss: 0.0130 - val_loss: 0.0136
# Epoch 715/1000
#  - 0s - loss: 0.0129 - val_loss: 0.0136
# Epoch 716/1000
#  - 0s - loss: 0.0129 - val_loss: 0.0135
# Epoch 717/1000
#  - 0s - loss: 0.0128 - val_loss: 0.0135
# Epoch 718/1000
#  - 0s - loss: 0.0128 - val_loss: 0.0134
# Epoch 719/1000
#  - 0s - loss: 0.0127 - val_loss: 0.0134
# Epoch 720/1000
#  - 0s - loss: 0.0127 - val_loss: 0.0133
# Epoch 721/1000
#  - 0s - loss: 0.0127 - val_loss: 0.0133
# Epoch 722/1000
#  - 0s - loss: 0.0126 - val_loss: 0.0133
# Epoch 723/1000
#  - 0s - loss: 0.0126 - val_loss: 0.0132
# Epoch 724/1000
#  - 0s - loss: 0.0125 - val_loss: 0.0132
# Epoch 725/1000
#  - 0s - loss: 0.0125 - val_loss: 0.0131
# Epoch 726/1000
#  - 0s - loss: 0.0125 - val_loss: 0.0131
# Epoch 727/1000
#  - 0s - loss: 0.0124 - val_loss: 0.0130
# Epoch 728/1000
#  - 0s - loss: 0.0124 - val_loss: 0.0130
# Epoch 729/1000
#  - 0s - loss: 0.0123 - val_loss: 0.0130
# Epoch 730/1000
#  - 0s - loss: 0.0123 - val_loss: 0.0129
# Epoch 731/1000
#  - 0s - loss: 0.0123 - val_loss: 0.0129
# Epoch 732/1000
#  - 0s - loss: 0.0122 - val_loss: 0.0128
# Epoch 733/1000
#  - 0s - loss: 0.0122 - val_loss: 0.0128
# Epoch 734/1000
#  - 0s - loss: 0.0121 - val_loss: 0.0127
# Epoch 735/1000
#  - 0s - loss: 0.0121 - val_loss: 0.0127
# Epoch 736/1000
#  - 0s - loss: 0.0121 - val_loss: 0.0127
# Epoch 737/1000
#  - 0s - loss: 0.0120 - val_loss: 0.0126
# Epoch 738/1000
#  - 0s - loss: 0.0120 - val_loss: 0.0126
# Epoch 739/1000
#  - 0s - loss: 0.0119 - val_loss: 0.0125
# Epoch 740/1000
#  - 0s - loss: 0.0119 - val_loss: 0.0125
# Epoch 741/1000
#  - 0s - loss: 0.0119 - val_loss: 0.0125
# Epoch 742/1000
#  - 0s - loss: 0.0118 - val_loss: 0.0124
# Epoch 743/1000
#  - 0s - loss: 0.0118 - val_loss: 0.0124
# Epoch 744/1000
#  - 0s - loss: 0.0117 - val_loss: 0.0123
# Epoch 745/1000
#  - 0s - loss: 0.0117 - val_loss: 0.0123
# Epoch 746/1000
#  - 0s - loss: 0.0117 - val_loss: 0.0123
# Epoch 747/1000
#  - 0s - loss: 0.0116 - val_loss: 0.0122
# Epoch 748/1000
#  - 0s - loss: 0.0116 - val_loss: 0.0122
# Epoch 749/1000
#  - 0s - loss: 0.0116 - val_loss: 0.0121
# Epoch 750/1000
#  - 0s - loss: 0.0115 - val_loss: 0.0121
# Epoch 751/1000
#  - 0s - loss: 0.0115 - val_loss: 0.0121
# Epoch 752/1000
#  - 0s - loss: 0.0115 - val_loss: 0.0120
# Epoch 753/1000
#  - 0s - loss: 0.0114 - val_loss: 0.0120
# Epoch 754/1000
#  - 0s - loss: 0.0114 - val_loss: 0.0120
# Epoch 755/1000
#  - 0s - loss: 0.0113 - val_loss: 0.0119
# Epoch 756/1000
#  - 0s - loss: 0.0113 - val_loss: 0.0119
# Epoch 757/1000
#  - 0s - loss: 0.0113 - val_loss: 0.0118
# Epoch 758/1000
#  - 0s - loss: 0.0112 - val_loss: 0.0118
# Epoch 759/1000
#  - 0s - loss: 0.0112 - val_loss: 0.0118
# Epoch 760/1000
#  - 0s - loss: 0.0112 - val_loss: 0.0117
# Epoch 761/1000
#  - 0s - loss: 0.0111 - val_loss: 0.0117
# Epoch 762/1000
#  - 0s - loss: 0.0111 - val_loss: 0.0117
# Epoch 763/1000
#  - 0s - loss: 0.0111 - val_loss: 0.0116
# Epoch 764/1000
#  - 0s - loss: 0.0110 - val_loss: 0.0116
# Epoch 765/1000
#  - 0s - loss: 0.0110 - val_loss: 0.0115
# Epoch 766/1000
#  - 0s - loss: 0.0110 - val_loss: 0.0115
# Epoch 767/1000
#  - 0s - loss: 0.0109 - val_loss: 0.0115
# Epoch 768/1000
#  - 0s - loss: 0.0109 - val_loss: 0.0114
# Epoch 769/1000
#  - 0s - loss: 0.0108 - val_loss: 0.0114
# Epoch 770/1000
#  - 0s - loss: 0.0108 - val_loss: 0.0114
# Epoch 771/1000
#  - 0s - loss: 0.0108 - val_loss: 0.0113
# Epoch 772/1000
#  - 0s - loss: 0.0107 - val_loss: 0.0113
# Epoch 773/1000
#  - 0s - loss: 0.0107 - val_loss: 0.0113
# Epoch 774/1000
#  - 0s - loss: 0.0107 - val_loss: 0.0112
# Epoch 775/1000
#  - 0s - loss: 0.0106 - val_loss: 0.0112
# Epoch 776/1000
#  - 0s - loss: 0.0106 - val_loss: 0.0112
# Epoch 777/1000
#  - 0s - loss: 0.0106 - val_loss: 0.0111
# Epoch 778/1000
#  - 0s - loss: 0.0105 - val_loss: 0.0111
# Epoch 779/1000
#  - 0s - loss: 0.0105 - val_loss: 0.0110
# Epoch 780/1000
#  - 0s - loss: 0.0105 - val_loss: 0.0110
# Epoch 781/1000
#  - 0s - loss: 0.0104 - val_loss: 0.0110
# Epoch 782/1000
#  - 0s - loss: 0.0104 - val_loss: 0.0109
# Epoch 783/1000
#  - 0s - loss: 0.0104 - val_loss: 0.0109
# Epoch 784/1000
#  - 0s - loss: 0.0104 - val_loss: 0.0109
# Epoch 785/1000
#  - 0s - loss: 0.0103 - val_loss: 0.0108
# Epoch 786/1000
#  - 0s - loss: 0.0103 - val_loss: 0.0108
# Epoch 787/1000
#  - 0s - loss: 0.0103 - val_loss: 0.0108
# Epoch 788/1000
#  - 0s - loss: 0.0102 - val_loss: 0.0107
# Epoch 789/1000
#  - 0s - loss: 0.0102 - val_loss: 0.0107
# Epoch 790/1000
#  - 0s - loss: 0.0102 - val_loss: 0.0107
# Epoch 791/1000
#  - 0s - loss: 0.0101 - val_loss: 0.0106
# Epoch 792/1000
#  - 0s - loss: 0.0101 - val_loss: 0.0106
# Epoch 793/1000
#  - 0s - loss: 0.0101 - val_loss: 0.0106
# Epoch 794/1000
#  - 0s - loss: 0.0100 - val_loss: 0.0105
# Epoch 795/1000
#  - 0s - loss: 0.0100 - val_loss: 0.0105
# Epoch 796/1000
#  - 0s - loss: 0.0100 - val_loss: 0.0105
# Epoch 797/1000
#  - 0s - loss: 0.0099 - val_loss: 0.0104
# Epoch 798/1000
#  - 0s - loss: 0.0099 - val_loss: 0.0104
# Epoch 799/1000
#  - 0s - loss: 0.0099 - val_loss: 0.0104
# Epoch 800/1000
#  - 0s - loss: 0.0099 - val_loss: 0.0104
# Epoch 801/1000
#  - 0s - loss: 0.0098 - val_loss: 0.0103
# Epoch 802/1000
#  - 0s - loss: 0.0098 - val_loss: 0.0103
# Epoch 803/1000
#  - 0s - loss: 0.0098 - val_loss: 0.0103
# Epoch 804/1000
#  - 0s - loss: 0.0097 - val_loss: 0.0102
# Epoch 805/1000
#  - 0s - loss: 0.0097 - val_loss: 0.0102
# Epoch 806/1000
#  - 0s - loss: 0.0097 - val_loss: 0.0102
# Epoch 807/1000
#  - 0s - loss: 0.0096 - val_loss: 0.0101
# Epoch 808/1000
#  - 0s - loss: 0.0096 - val_loss: 0.0101
# Epoch 809/1000
#  - 0s - loss: 0.0096 - val_loss: 0.0101
# Epoch 810/1000
#  - 0s - loss: 0.0096 - val_loss: 0.0100
# Epoch 811/1000
#  - 0s - loss: 0.0095 - val_loss: 0.0100
# Epoch 812/1000
#  - 0s - loss: 0.0095 - val_loss: 0.0100
# Epoch 813/1000
#  - 0s - loss: 0.0095 - val_loss: 0.0100
# Epoch 814/1000
#  - 0s - loss: 0.0094 - val_loss: 0.0099
# Epoch 815/1000
#  - 0s - loss: 0.0094 - val_loss: 0.0099
# Epoch 816/1000
#  - 0s - loss: 0.0094 - val_loss: 0.0099
# Epoch 817/1000
#  - 0s - loss: 0.0094 - val_loss: 0.0098
# Epoch 818/1000
#  - 0s - loss: 0.0093 - val_loss: 0.0098
# Epoch 819/1000
#  - 0s - loss: 0.0093 - val_loss: 0.0098
# Epoch 820/1000
#  - 0s - loss: 0.0093 - val_loss: 0.0097
# Epoch 821/1000
#  - 0s - loss: 0.0092 - val_loss: 0.0097
# Epoch 822/1000
#  - 0s - loss: 0.0092 - val_loss: 0.0097
# Epoch 823/1000
#  - 0s - loss: 0.0092 - val_loss: 0.0097
# Epoch 824/1000
#  - 0s - loss: 0.0092 - val_loss: 0.0096
# Epoch 825/1000
#  - 0s - loss: 0.0091 - val_loss: 0.0096
# Epoch 826/1000
#  - 0s - loss: 0.0091 - val_loss: 0.0096
# Epoch 827/1000
#  - 0s - loss: 0.0091 - val_loss: 0.0095
# Epoch 828/1000
#  - 0s - loss: 0.0091 - val_loss: 0.0095
# Epoch 829/1000
#  - 0s - loss: 0.0090 - val_loss: 0.0095
# Epoch 830/1000
#  - 0s - loss: 0.0090 - val_loss: 0.0095
# Epoch 831/1000
#  - 0s - loss: 0.0090 - val_loss: 0.0094
# Epoch 832/1000
#  - 0s - loss: 0.0089 - val_loss: 0.0094
# Epoch 833/1000
#  - 0s - loss: 0.0089 - val_loss: 0.0094
# Epoch 834/1000
#  - 0s - loss: 0.0089 - val_loss: 0.0093
# Epoch 835/1000
#  - 0s - loss: 0.0089 - val_loss: 0.0093
# Epoch 836/1000
#  - 0s - loss: 0.0088 - val_loss: 0.0093
# Epoch 837/1000
#  - 0s - loss: 0.0088 - val_loss: 0.0093
# Epoch 838/1000
#  - 0s - loss: 0.0088 - val_loss: 0.0092
# Epoch 839/1000
#  - 0s - loss: 0.0088 - val_loss: 0.0092
# Epoch 840/1000
#  - 0s - loss: 0.0087 - val_loss: 0.0092
# Epoch 841/1000
#  - 0s - loss: 0.0087 - val_loss: 0.0092
# Epoch 842/1000
#  - 0s - loss: 0.0087 - val_loss: 0.0091
# Epoch 843/1000
#  - 0s - loss: 0.0087 - val_loss: 0.0091
# Epoch 844/1000
#  - 0s - loss: 0.0086 - val_loss: 0.0091
# Epoch 845/1000
#  - 0s - loss: 0.0086 - val_loss: 0.0090
# Epoch 846/1000
#  - 0s - loss: 0.0086 - val_loss: 0.0090
# Epoch 847/1000
#  - 0s - loss: 0.0086 - val_loss: 0.0090
# Epoch 848/1000
#  - 0s - loss: 0.0085 - val_loss: 0.0090
# Epoch 849/1000
#  - 0s - loss: 0.0085 - val_loss: 0.0089
# Epoch 850/1000
#  - 0s - loss: 0.0085 - val_loss: 0.0089
# Epoch 851/1000
#  - 0s - loss: 0.0085 - val_loss: 0.0089
# Epoch 852/1000
#  - 0s - loss: 0.0084 - val_loss: 0.0089
# Epoch 853/1000
#  - 0s - loss: 0.0084 - val_loss: 0.0088
# Epoch 854/1000
#  - 0s - loss: 0.0084 - val_loss: 0.0088
# Epoch 855/1000
#  - 0s - loss: 0.0084 - val_loss: 0.0088
# Epoch 856/1000
#  - 0s - loss: 0.0083 - val_loss: 0.0088
# Epoch 857/1000
#  - 0s - loss: 0.0083 - val_loss: 0.0087
# Epoch 858/1000
#  - 0s - loss: 0.0083 - val_loss: 0.0087
# Epoch 859/1000
#  - 0s - loss: 0.0083 - val_loss: 0.0087
# Epoch 860/1000
#  - 0s - loss: 0.0082 - val_loss: 0.0087
# Epoch 861/1000
#  - 0s - loss: 0.0082 - val_loss: 0.0086
# Epoch 862/1000
#  - 0s - loss: 0.0082 - val_loss: 0.0086
# Epoch 863/1000
#  - 0s - loss: 0.0082 - val_loss: 0.0086
# Epoch 864/1000
#  - 0s - loss: 0.0081 - val_loss: 0.0086
# Epoch 865/1000
#  - 0s - loss: 0.0081 - val_loss: 0.0085
# Epoch 866/1000
#  - 0s - loss: 0.0081 - val_loss: 0.0085
# Epoch 867/1000
#  - 0s - loss: 0.0081 - val_loss: 0.0085
# Epoch 868/1000
#  - 0s - loss: 0.0081 - val_loss: 0.0085
# Epoch 869/1000
#  - 0s - loss: 0.0080 - val_loss: 0.0084
# Epoch 870/1000
#  - 0s - loss: 0.0080 - val_loss: 0.0084
# Epoch 871/1000
#  - 0s - loss: 0.0080 - val_loss: 0.0084
# Epoch 872/1000
#  - 0s - loss: 0.0080 - val_loss: 0.0084
# Epoch 873/1000
#  - 0s - loss: 0.0079 - val_loss: 0.0083
# Epoch 874/1000
#  - 0s - loss: 0.0079 - val_loss: 0.0083
# Epoch 875/1000
#  - 0s - loss: 0.0079 - val_loss: 0.0083
# Epoch 876/1000
#  - 0s - loss: 0.0079 - val_loss: 0.0083
# Epoch 877/1000
#  - 0s - loss: 0.0078 - val_loss: 0.0082
# Epoch 878/1000
#  - 0s - loss: 0.0078 - val_loss: 0.0082
# Epoch 879/1000
#  - 0s - loss: 0.0078 - val_loss: 0.0082
# Epoch 880/1000
#  - 0s - loss: 0.0078 - val_loss: 0.0082
# Epoch 881/1000
#  - 0s - loss: 0.0078 - val_loss: 0.0082
# Epoch 882/1000
#  - 0s - loss: 0.0077 - val_loss: 0.0081
# Epoch 883/1000
#  - 0s - loss: 0.0077 - val_loss: 0.0081
# Epoch 884/1000
#  - 0s - loss: 0.0077 - val_loss: 0.0081
# Epoch 885/1000
#  - 0s - loss: 0.0077 - val_loss: 0.0081
# Epoch 886/1000
#  - 0s - loss: 0.0076 - val_loss: 0.0080
# Epoch 887/1000
#  - 0s - loss: 0.0076 - val_loss: 0.0080
# Epoch 888/1000
#  - 0s - loss: 0.0076 - val_loss: 0.0080
# Epoch 889/1000
#  - 0s - loss: 0.0076 - val_loss: 0.0080
# Epoch 890/1000
#  - 0s - loss: 0.0076 - val_loss: 0.0079
# Epoch 891/1000
#  - 0s - loss: 0.0075 - val_loss: 0.0079
# Epoch 892/1000
#  - 0s - loss: 0.0075 - val_loss: 0.0079
# Epoch 893/1000
#  - 0s - loss: 0.0075 - val_loss: 0.0079
# Epoch 894/1000
#  - 0s - loss: 0.0075 - val_loss: 0.0079
# Epoch 895/1000
#  - 0s - loss: 0.0075 - val_loss: 0.0078
# Epoch 896/1000
#  - 0s - loss: 0.0074 - val_loss: 0.0078
# Epoch 897/1000
#  - 0s - loss: 0.0074 - val_loss: 0.0078
# Epoch 898/1000
#  - 0s - loss: 0.0074 - val_loss: 0.0078
# Epoch 899/1000
#  - 0s - loss: 0.0074 - val_loss: 0.0077
# Epoch 900/1000
#  - 0s - loss: 0.0074 - val_loss: 0.0077
# Epoch 901/1000
#  - 0s - loss: 0.0073 - val_loss: 0.0077
# Epoch 902/1000
#  - 0s - loss: 0.0073 - val_loss: 0.0077
# Epoch 903/1000
#  - 0s - loss: 0.0073 - val_loss: 0.0077
# Epoch 904/1000
#  - 0s - loss: 0.0073 - val_loss: 0.0076
# Epoch 905/1000
#  - 0s - loss: 0.0072 - val_loss: 0.0076
# Epoch 906/1000
#  - 0s - loss: 0.0072 - val_loss: 0.0076
# Epoch 907/1000
#  - 0s - loss: 0.0072 - val_loss: 0.0076
# Epoch 908/1000
#  - 0s - loss: 0.0072 - val_loss: 0.0076
# Epoch 909/1000
#  - 0s - loss: 0.0072 - val_loss: 0.0075
# Epoch 910/1000
#  - 0s - loss: 0.0071 - val_loss: 0.0075
# Epoch 911/1000
#  - 0s - loss: 0.0071 - val_loss: 0.0075
# Epoch 912/1000
#  - 0s - loss: 0.0071 - val_loss: 0.0075
# Epoch 913/1000
#  - 0s - loss: 0.0071 - val_loss: 0.0074
# Epoch 914/1000
#  - 0s - loss: 0.0071 - val_loss: 0.0074
# Epoch 915/1000
#  - 0s - loss: 0.0070 - val_loss: 0.0074
# Epoch 916/1000
#  - 0s - loss: 0.0070 - val_loss: 0.0074
# Epoch 917/1000
#  - 0s - loss: 0.0070 - val_loss: 0.0074
# Epoch 918/1000
#  - 0s - loss: 0.0070 - val_loss: 0.0073
# Epoch 919/1000
#  - 0s - loss: 0.0070 - val_loss: 0.0073
# Epoch 920/1000
#  - 0s - loss: 0.0070 - val_loss: 0.0073
# Epoch 921/1000
#  - 0s - loss: 0.0069 - val_loss: 0.0073
# Epoch 922/1000
#  - 0s - loss: 0.0069 - val_loss: 0.0073
# Epoch 923/1000
#  - 0s - loss: 0.0069 - val_loss: 0.0072
# Epoch 924/1000
#  - 0s - loss: 0.0069 - val_loss: 0.0072
# Epoch 925/1000
#  - 0s - loss: 0.0069 - val_loss: 0.0072
# Epoch 926/1000
#  - 0s - loss: 0.0068 - val_loss: 0.0072
# Epoch 927/1000
#  - 0s - loss: 0.0068 - val_loss: 0.0072
# Epoch 928/1000
#  - 0s - loss: 0.0068 - val_loss: 0.0071
# Epoch 929/1000
#  - 0s - loss: 0.0068 - val_loss: 0.0071
# Epoch 930/1000
#  - 0s - loss: 0.0068 - val_loss: 0.0071
# Epoch 931/1000
#  - 0s - loss: 0.0067 - val_loss: 0.0071
# Epoch 932/1000
#  - 0s - loss: 0.0067 - val_loss: 0.0071
# Epoch 933/1000
#  - 0s - loss: 0.0067 - val_loss: 0.0070
# Epoch 934/1000
#  - 0s - loss: 0.0067 - val_loss: 0.0070
# Epoch 935/1000
#  - 0s - loss: 0.0067 - val_loss: 0.0070
# Epoch 936/1000
#  - 0s - loss: 0.0067 - val_loss: 0.0070
# Epoch 937/1000
#  - 0s - loss: 0.0066 - val_loss: 0.0070
# Epoch 938/1000
#  - 0s - loss: 0.0066 - val_loss: 0.0070
# Epoch 939/1000
#  - 0s - loss: 0.0066 - val_loss: 0.0069
# Epoch 940/1000
#  - 0s - loss: 0.0066 - val_loss: 0.0069
# Epoch 941/1000
#  - 0s - loss: 0.0066 - val_loss: 0.0069
# Epoch 942/1000
#  - 0s - loss: 0.0065 - val_loss: 0.0069
# Epoch 943/1000
#  - 0s - loss: 0.0065 - val_loss: 0.0069
# Epoch 944/1000
#  - 0s - loss: 0.0065 - val_loss: 0.0068
# Epoch 945/1000
#  - 0s - loss: 0.0065 - val_loss: 0.0068
# Epoch 946/1000
#  - 0s - loss: 0.0065 - val_loss: 0.0068
# Epoch 947/1000
#  - 0s - loss: 0.0065 - val_loss: 0.0068
# Epoch 948/1000
#  - 0s - loss: 0.0064 - val_loss: 0.0068
# Epoch 949/1000
#  - 0s - loss: 0.0064 - val_loss: 0.0067
# Epoch 950/1000
#  - 0s - loss: 0.0064 - val_loss: 0.0067
# Epoch 951/1000
#  - 0s - loss: 0.0064 - val_loss: 0.0067
# Epoch 952/1000
#  - 0s - loss: 0.0064 - val_loss: 0.0067
# Epoch 953/1000
#  - 0s - loss: 0.0064 - val_loss: 0.0067
# Epoch 954/1000
#  - 0s - loss: 0.0063 - val_loss: 0.0067
# Epoch 955/1000
#  - 0s - loss: 0.0063 - val_loss: 0.0066
# Epoch 956/1000
#  - 0s - loss: 0.0063 - val_loss: 0.0066
# Epoch 957/1000
#  - 0s - loss: 0.0063 - val_loss: 0.0066
# Epoch 958/1000
#  - 0s - loss: 0.0063 - val_loss: 0.0066
# Epoch 959/1000
#  - 0s - loss: 0.0062 - val_loss: 0.0066
# Epoch 960/1000
#  - 0s - loss: 0.0062 - val_loss: 0.0066
# Epoch 961/1000
#  - 0s - loss: 0.0062 - val_loss: 0.0065
# Epoch 962/1000
#  - 0s - loss: 0.0062 - val_loss: 0.0065
# Epoch 963/1000
#  - 0s - loss: 0.0062 - val_loss: 0.0065
# Epoch 964/1000
#  - 0s - loss: 0.0062 - val_loss: 0.0065
# Epoch 965/1000
#  - 0s - loss: 0.0062 - val_loss: 0.0065
# Epoch 966/1000
#  - 0s - loss: 0.0061 - val_loss: 0.0064
# Epoch 967/1000
#  - 0s - loss: 0.0061 - val_loss: 0.0064
# Epoch 968/1000
#  - 0s - loss: 0.0061 - val_loss: 0.0064
# Epoch 969/1000
#  - 0s - loss: 0.0061 - val_loss: 0.0064
# Epoch 970/1000
#  - 0s - loss: 0.0061 - val_loss: 0.0064
# Epoch 971/1000
#  - 0s - loss: 0.0061 - val_loss: 0.0064
# Epoch 972/1000
#  - 0s - loss: 0.0060 - val_loss: 0.0063
# Epoch 973/1000
#  - 0s - loss: 0.0060 - val_loss: 0.0063
# Epoch 974/1000
#  - 0s - loss: 0.0060 - val_loss: 0.0063
# Epoch 975/1000
#  - 0s - loss: 0.0060 - val_loss: 0.0063
# Epoch 976/1000
#  - 0s - loss: 0.0060 - val_loss: 0.0063
# Epoch 977/1000
#  - 0s - loss: 0.0060 - val_loss: 0.0063
# Epoch 978/1000
#  - 0s - loss: 0.0059 - val_loss: 0.0062
# Epoch 979/1000
#  - 0s - loss: 0.0059 - val_loss: 0.0062
# Epoch 980/1000
#  - 0s - loss: 0.0059 - val_loss: 0.0062
# Epoch 981/1000
#  - 0s - loss: 0.0059 - val_loss: 0.0062
# Epoch 982/1000
#  - 0s - loss: 0.0059 - val_loss: 0.0062
# Epoch 983/1000
#  - 0s - loss: 0.0059 - val_loss: 0.0062
# Epoch 984/1000
#  - 0s - loss: 0.0058 - val_loss: 0.0061
# Epoch 985/1000
#  - 0s - loss: 0.0058 - val_loss: 0.0061
# Epoch 986/1000
#  - 0s - loss: 0.0058 - val_loss: 0.0061
# Epoch 987/1000
#  - 0s - loss: 0.0058 - val_loss: 0.0061
# Epoch 988/1000
#  - 0s - loss: 0.0058 - val_loss: 0.0061
# Epoch 989/1000
#  - 0s - loss: 0.0058 - val_loss: 0.0061
# Epoch 990/1000
#  - 0s - loss: 0.0058 - val_loss: 0.0060
# Epoch 991/1000
#  - 0s - loss: 0.0057 - val_loss: 0.0060
# Epoch 992/1000
#  - 0s - loss: 0.0057 - val_loss: 0.0060
# Epoch 993/1000
#  - 0s - loss: 0.0057 - val_loss: 0.0060
# Epoch 994/1000
#  - 0s - loss: 0.0057 - val_loss: 0.0060
# Epoch 995/1000
#  - 0s - loss: 0.0057 - val_loss: 0.0060
# Epoch 996/1000
#  - 0s - loss: 0.0057 - val_loss: 0.0060
# Epoch 997/1000
#  - 0s - loss: 0.0056 - val_loss: 0.0059
# Epoch 998/1000
#  - 0s - loss: 0.0056 - val_loss: 0.0059
# Epoch 999/1000
#  - 0s - loss: 0.0056 - val_loss: 0.0059
# Epoch 1000/1000
#  - 0s - loss: 0.0056 - val_loss: 0.0059

# %%
plot_loss(history)

# %% [markdown]
# ## Training Set

# %%
# Generate predictions

model = load_model("%s.h5" % (model_name))

x_train_new = []
lumi_new = []
lumi = data[str(runs[0])]['lumiid'] 

for l in range(len(x_train)):
    if not 0 in x_train[l]:
        x_train_new.append(x_train[l])
        for i in range(WINDOW):
            lumi_new.append(lumi[l+i])
                
reconstructed = model.predict(np.array(x_train_new))

error = (x_train_new-reconstructed)/x_train_new

# %%
error_reformat = []
for i in range(num_parts):
    error_reformat.append([])

for i in range(len(error)):
    for j in range(num_parts):
        if i == len(error)-1:
            for val in error[i][WINDOW*j:WINDOW+WINDOW*j]:
                error_reformat[j].append(val)
        else:
            error_reformat[j].append(error[i][WINDOW*j])
            
inp = []
outp = []
for i in range(num_parts):
    inp.append([])
    outp.append([])
    
for i in range(len(reconstructed)):
    for j in range(num_parts):
        if i == len(reconstructed)-1:
            for val in reconstructed[i][WINDOW*j:WINDOW+WINDOW*j]:
                outp[j].append(val)
            for val in x_train_new[i][WINDOW*j:WINDOW+WINDOW*j]:
                inp[j].append(val)
        else:
            outp[j].append(reconstructed[i][WINDOW*j])
            inp[j].append(x_train_new[i][WINDOW*j])

# %%
labels = data['HLT']

#bins = np.linspace(0,1,50)
bins = 50
plt.figure(figsize=[15,10])
for i in range(len(error_reformat)):
    plt.subplot(2,3,i+1)
    plt.hist(error_reformat[i],bins=bins,label=labels[i],alpha=.5)
    plt.legend()
plt.tight_layout()

#lumi = np.linspace(0,len(error_reformat[0]),len(error_reformat[0]))
plt.figure(figsize=[15,10])
for i in range(0,num_parts):
    plt.subplot(2,3,i+1)
    plt.scatter(lumi,error_reformat[i],label=labels[i],alpha=.5)
    plt.xlabel('lumi id')
    plt.ylabel('error')
    plt.legend()    
plt.tight_layout()

plt.show()

# %%
plt.figure(figsize=[15,10])
for i in range(0,num_parts):
    plt.subplot(2,3,i+1)
    plt.plot(outp[i],inp[i],label=labels[i], linestyle='',marker='o', markersize=3, alpha=0.5)
    #plt.scatter(lumi,outp[i],label='output',alpha=.5)
    plt.xlabel('output')
    plt.ylabel('input')
    plt.axis('equal')
    #plt.ylim(0,1.8)
    plt.legend()    
plt.tight_layout()
plt.show()

# %% [markdown]
# ## Test Data

# %%
# Generate predictions

model = load_model("%s.h5" % (model_name))

x_test_new = []
for l in x_test:
    if not 0 in l:
        x_test_new.append(l)
                
reconstructed = model.predict(np.array(x_test_new))

error = (x_test_new-reconstructed)/x_test_new

# %%
error_reformat = []
for i in range(num_parts):
    error_reformat.append([])

for i in range(len(error)):
    for j in range(num_parts):
        if i == len(error)-1:
            for val in error[i][WINDOW*j:WINDOW+WINDOW*j]:
                error_reformat[j].append(val)
        else:
            error_reformat[j].append(error[i][WINDOW*j])
            
inp = []
outp = []
for i in range(num_parts):
    inp.append([])
    outp.append([])
    
for i in range(len(reconstructed)):
    for j in range(num_parts):
        if i == len(reconstructed)-1:
            for val in reconstructed[i][WINDOW*j:WINDOW+WINDOW*j]:
                outp[j].append(val)
            for val in x_test_new[i][WINDOW*j:WINDOW+WINDOW*j]:
                inp[j].append(val)
        else:
            outp[j].append(reconstructed[i][WINDOW*j])
            inp[j].append(x_test_new[i][WINDOW*j])

# %%
labels = data['HLT']

#bins = np.linspace(0,1,50)
bins = 50
plt.figure(figsize=[15,10])
for i in range(len(error_reformat)):
    plt.subplot(2,3,i+1)
    plt.hist(error_reformat[i],bins=bins,label=labels[i],alpha=.5)
    plt.legend()
    
plt.tight_layout()

lumi = data[str(runs[2])]['lumiid'] 
#lumi = np.linspace(0,len(error_reformat[0]),len(error_reformat[0]))
plt.figure(figsize=[15,10])
for i in range(0,num_parts):
    plt.subplot(2,3,i+1)
    plt.scatter(lumi,error_reformat[i],label=labels[i],alpha=.5)
    plt.xlabel('lumi id')
    plt.ylabel('error')
    plt.legend()   
plt.tight_layout()

plt.show()

# %%
plt.figure(figsize=[15,10])
for i in range(0,num_parts):
    plt.subplot(2,3,i+1)
    plt.plot(outp[i],inp[i],label=labels[i], linestyle='',marker='o', markersize=3, alpha=0.5)
    #plt.scatter(lumi,outp[i],label='output',alpha=.5)
    plt.xlabel('output')
    plt.ylabel('input')
    plt.axis('equal')
    #plt.xlim(0,1.8)
    #plt.ylim(0,1.8)
    plt.legend()    
    
plt.tight_layout()

plt.show()

# %%
# plt.figure(figsize=[20,10])
# for i in range(0,4):
#     plt.subplot(2,2,i+1)
#     plt.scatter(lumi,inp[i],label='input',alpha=.5)
#     plt.scatter(lumi,outp[i]/max(outp[i]),label='output',alpha=.5)
#     plt.xlabel('index')
#     plt.ylabel('value')
#     plt.legend()    

# plt.show()

# %%
# for i in range(len(outp)):
#     for j in range(i+1,len(outp)):
#         print(sum(np.array(outp[i]/max(outp[i]))-np.array(outp[j]/max(outp[j]))))

# %% [markdown]
# ## Fake Bad Data

# %%
bad = np.array(data[str(runs[2])]['bad_samples'])

# %%
bad_new = []
for l in bad:
    if not 0 in l:
        bad_new.append(l)
                
reconstructed_bad = model.predict(np.array(bad_new))

error_bad = abs(bad_new-reconstructed_bad)/bad_new

# %%
error_reformat_bad = []
for i in range(num_parts):
    error_reformat_bad.append([])

for i in range(len(error_bad)):
    for j in range(num_parts):
        if i == len(error_bad)-1:
            for val in error_bad[i][WINDOW*j:WINDOW+WINDOW*j]:
                error_reformat_bad[j].append(val)
        else:
            error_reformat_bad[j].append(error_bad[i][WINDOW*j])
            
inp_bad = []
outp_bad = []
for i in range(num_parts):
    inp_bad.append([])
    outp_bad.append([])
    
for i in range(len(reconstructed_bad)):
    for j in range(num_parts):
        if i == len(reconstructed_bad)-1:
            for val in reconstructed_bad[i][WINDOW*j:WINDOW+WINDOW*j]:
                outp_bad[j].append(val)
            for val in bad_new[i][WINDOW*j:WINDOW+WINDOW*j]:
                inp_bad[j].append(val)
        else:
            outp_bad[j].append(reconstructed_bad[i][WINDOW*j])
            inp_bad[j].append(bad_new[i][WINDOW*j])

# %%
labels = data['HLT']

#bins = np.linspace(0,1,50)
bins = 50
plt.figure(figsize=[15,10])
for i in range(len(error_reformat_bad)):
    plt.subplot(2,3,i+1)
    plt.hist(error_reformat[i],bins=bins,label='good',alpha=.5)
    plt.hist(error_reformat_bad[i],bins=bins,label='fake bad',alpha=.5)
    plt.legend()
    plt.title(labels[i])
    
plt.tight_layout()

lumi = data[str(runs[2])]['lumiid'] 
print(len(error_reformat_bad[0]),len(lumi))
#lumi = np.linspace(0,len(error_reformat_bad[0]),len(error_reformat_bad[0]))
plt.figure(figsize=[15,10])
for i in range(0,num_parts):
    plt.subplot(2,3,i+1)
    plt.scatter(lumi,error_reformat[i],label = 'good', alpha =.5)
    plt.scatter(lumi,error_reformat_bad[i],label='fake bad',alpha=.5)
    plt.xlabel('lumi id')
    plt.ylabel('error')
    plt.legend()    
    plt.title(labels[i])
    
plt.tight_layout()

plt.show()
# Out:
# 1129 1129

# %%
plt.figure(figsize=[15,10])
for i in range(0,num_parts):
    plt.subplot(2,3,i+1)
    plt.plot(outp_bad[i],inp_bad[i],label=labels[i], linestyle='',marker='o', markersize=3, alpha=0.5)
    plt.xlabel('index')
    plt.ylabel('value')
    plt.axis('equal')
    #plt.xlim(0,2)
    #plt.ylim(0,2)
    plt.legend()  
    
plt.tight_layout()

plt.show()

# %%
# plt.figure(figsize=[20,10])
# for i in range(0,4):
#     plt.subplot(2,2,i+1)
#     plt.scatter(lumi,inp_bad[i],label='inp_badut',alpha=.5)
#     plt.scatter(lumi,outp_bad[i]/max(outp_bad[i]),label='outp_badut',alpha=.5)
#     plt.xlabel('index')
#     plt.ylabel('value')
#     plt.legend()    

# plt.show()

# %%
# labels = data['HLT']

# #bins = np.linspace(0,1,50)
# bins = 50
# plt.figure(figsize=[20,10])
# for i in range(len(error_reformat_bad)):
#     plt.subplot(2,2,i+1)
#     plt.hist(error_reformat_bad[i],bins=bins,label='bad',alpha=.5)
#     plt.hist(error_reformat[i],bins=bins,label='good',alpha=.5)
#     plt.legend()

# # lumi = data[str(runs[0])]['lumiid'] 
# # print(len(error_reformat_bad[0]),len(lumi))
# # #lumi = np.linspace(0,len(error_reformat_bad[0]),len(error_reformat_bad[0]))
# # plt.figure(figsize=[20,10])
# # for i in range(0,4):
# #     plt.subplot(2,2,i+1)
# #     plt.scatter(lumi,error_reformat_bad[i],label='bad',alpha=.5)
# #     plt.scatter(lumi,error_reformat[i],label='good',alpha=.5)
# #     plt.xlabel('lumi id')
# #     plt.ylabel('error')
# #     plt.legend()    

# plt.show()

# %% [markdown]
# ## Fake Bad Data - ALL

# %%
bad = np.array(data[str(runs[2])]['all_bad_samples'])

# %%
bad_new = []
for l in bad:
    if not 0 in l:
        bad_new.append(l)
                
reconstructed_bad = model.predict(np.array(bad_new))

error_bad = abs(bad_new-reconstructed_bad)/bad_new

# %%
error_reformat_bad = []
for i in range(num_parts):
    error_reformat_bad.append([])

for i in range(len(error_bad)):
    for j in range(num_parts):
        if i == len(error_bad)-1:
            for val in error_bad[i][WINDOW*j:WINDOW+WINDOW*j]:
                error_reformat_bad[j].append(val)
        else:
            error_reformat_bad[j].append(error_bad[i][WINDOW*j])
            
inp_bad = []
outp_bad = []
for i in range(num_parts):
    inp_bad.append([])
    outp_bad.append([])
    
for i in range(len(reconstructed_bad)):
    for j in range(num_parts):
        if i == len(reconstructed_bad)-1:
            for val in reconstructed_bad[i][WINDOW*j:WINDOW+WINDOW*j]:
                outp_bad[j].append(val)
            for val in bad_new[i][WINDOW*j:WINDOW+WINDOW*j]:
                inp_bad[j].append(val)
        else:
            outp_bad[j].append(reconstructed_bad[i][WINDOW*j])
            inp_bad[j].append(bad_new[i][WINDOW*j])

# %%
labels = data['HLT']

#bins = np.linspace(0,1,50)
bins = 50
plt.figure(figsize=[15,10])
for i in range(len(error_reformat_bad)):
    plt.subplot(2,3,i+1)
    plt.hist(error_reformat[i],bins=bins,label='good',alpha=.5)
    plt.hist(error_reformat_bad[i],bins=bins,label='fake bad',alpha=.5)
    plt.legend()
    plt.title(labels[i])
    
plt.tight_layout()

lumi = data[str(runs[2])]['lumiid'] 
print(len(error_reformat_bad[0]),len(lumi))
#lumi = np.linspace(0,len(error_reformat_bad[0]),len(error_reformat_bad[0]))
plt.figure(figsize=[15,10])
for i in range(0,num_parts):
    plt.subplot(2,3,i+1)
    plt.scatter(lumi,error_reformat[i],label = 'good', alpha =.5)
    plt.scatter(lumi,error_reformat_bad[i],label='fake bad',alpha=.5)
    plt.xlabel('lumi id')
    plt.ylabel('error')
    plt.legend()    
    plt.title(labels[i])
    
plt.tight_layout()

plt.show()
# Out:
# 1129 1129

# %%
plt.figure(figsize=[15,10])
for i in range(0,num_parts):
    plt.subplot(2,3,i+1)
    plt.plot(outp_bad[i],inp_bad[i],label=labels[i], linestyle='',marker='o', markersize=3, alpha=0.5)
    plt.xlabel('index')
    plt.ylabel('value')
    plt.axis('equal')
    #plt.xlim(0,.6)
    #plt.ylim(0,.6)
    plt.legend()  
    
plt.tight_layout()

plt.show()

# %%
# plt.figure(figsize=[20,10])
# for i in range(0,4):
#     plt.subplot(2,2,i+1)
#     plt.scatter(lumi,inp_bad[i],label='input',alpha=.5)
#     plt.scatter(lumi,outp_bad[i]/max(outp_bad[i]),label='output',alpha=.5)
#     plt.xlabel('index')
#     plt.ylabel('value')
#     plt.legend()    

# plt.show()

# %%
# labels = data['HLT']

# #bins = np.linspace(0,1,50)
# bins = 50
# plt.figure(figsize=[20,10])
# for i in range(len(error_reformat_bad)):
#     plt.subplot(2,2,i+1)
#     plt.hist(error_reformat_bad[i],bins=bins,label='bad',alpha=.5)
#     plt.hist(error_reformat[i],bins=bins,label='good',alpha=.5)
#     plt.legend()

# # lumi = data[str(runs[0])]['lumiid'] 
# # print(len(error_reformat_bad[0]),len(lumi))
# # #lumi = np.linspace(0,len(error_reformat_bad[0]),len(error_reformat_bad[0]))
# # plt.figure(figsize=[20,10])
# # for i in range(0,4):
# #     plt.subplot(2,2,i+1)
# #     plt.scatter(lumi,error_reformat_bad[i],label='bad',alpha=.5)
# #     plt.scatter(lumi,error_reformat[i],label='good',alpha=.5)
# #     plt.xlabel('lumi id')
# #     plt.ylabel('error')
# #     plt.legend()    

# plt.show()

# %% [markdown]
# ## Real Bad Data

# %%
bad_runs = [301480]

with open("pileup_bad_dataNotNorm.pickle", 'rb') as handle:
    baddata = pickle.load(handle)

x_test = np.array(baddata[str(bad_runs[0])]['samples'])

# %%
bad_new = []
lumi_new = []

lumiBad = baddata[str(bad_runs[0])]['lumiid']

for l in range(len(x_test)):
    if not 0 in x_test[l]:
        bad_new.append(x_test[l])
        for i in range(WINDOW):
            lumi_new.append(lumiBad[l+i])
            
lumiBad = []
for n in lumi_new:
    if n not in lumiBad:
        lumiBad.append(n)
    
                
reconstructed_bad = model.predict(np.array(bad_new))

error_bad = abs(bad_new-reconstructed_bad)/bad_new

# %%
error_reformat_bad = []
for i in range(num_parts):
    error_reformat_bad.append([])

for i in range(len(error_bad)):
    for j in range(num_parts):
        if i == len(error_bad)-1:
            for val in error_bad[i][WINDOW*j:WINDOW+WINDOW*j]:
                error_reformat_bad[j].append(val)
        else:
            error_reformat_bad[j].append(error_bad[i][WINDOW*j])
            
inp_bad = []
outp_bad = []
for i in range(num_parts):
    inp_bad.append([])
    outp_bad.append([])
    
for i in range(len(reconstructed_bad)):
    for j in range(num_parts):
        if i == len(reconstructed_bad)-1:
            for val in reconstructed_bad[i][WINDOW*j:WINDOW+WINDOW*j]:
                outp_bad[j].append(val)
            for val in bad_new[i][WINDOW*j:WINDOW+WINDOW*j]:
                inp_bad[j].append(val)
        else:
            outp_bad[j].append(reconstructed_bad[i][WINDOW*j])
            inp_bad[j].append(bad_new[i][WINDOW*j])

# %%
labels = data['HLT']

#bins = np.linspace(0,1,50)
bins = 50
plt.figure(figsize=[15,10])
for i in range(len(error_reformat_bad)):
    plt.subplot(2,3,i+1)
    plt.hist(error_reformat[i],bins=bins,label='good',alpha=.5)
    plt.hist(error_reformat_bad[i],bins=bins,label='bad',alpha=.5)
    plt.legend()
    plt.title(labels[i])
plt.tight_layout()

print(len(error_reformat_bad[0]),len(lumiBad))
plt.figure(figsize=[15,10])
for i in range(0,num_parts):
    plt.subplot(2,3,i+1)
    plt.scatter(lumi,error_reformat[i],label = 'good', alpha =.5)
    plt.scatter(lumiBad,error_reformat_bad[i],label='bad',alpha=.5)
    plt.xlabel('lumi id')
    plt.ylabel('error')
    plt.legend()    
    plt.title(labels[i])
plt.tight_layout()

plt.show()
# Out:
# 154 154

# %%
plt.figure(figsize=[15,10])
for i in range(0,num_parts):
    plt.subplot(2,3,i+1)
    plt.plot(outp_bad[i],inp_bad[i],label=labels[i], linestyle='',marker='o', markersize=3, alpha=0.5)
    plt.xlabel('index')
    plt.ylabel('value')
    plt.axis('equal')
    #plt.ylim(0,.6)
    plt.legend()    

plt.show()

# %% [markdown]
# ## Real Bad Data

# %%
bad_runs = [305588]

with open("pileup_bad_dataNotNorm.pickle", 'rb') as handle:
    baddata = pickle.load(handle)

x_test = np.array(baddata[str(bad_runs[0])]['samples'])

# %%
bad_new = []
lumi_new = []

lumiBad = baddata[str(bad_runs[0])]['lumiid']

for l in range(len(x_test)):
    if not 0 in x_test[l]:
        bad_new.append(x_test[l])
        for i in range(WINDOW):
            lumi_new.append(lumiBad[l+i])
            
lumiBad = []
for n in lumi_new:
    if n not in lumiBad:
        lumiBad.append(n)
    
                
reconstructed_bad = model.predict(np.array(bad_new))

error_bad = abs(bad_new-reconstructed_bad)/bad_new

# %%
error_reformat_bad = []
for i in range(num_parts):
    error_reformat_bad.append([])

for i in range(len(error_bad)):
    for j in range(num_parts):
        if i == len(error_bad)-1:
            for val in error_bad[i][WINDOW*j:WINDOW+WINDOW*j]:
                error_reformat_bad[j].append(val)
        else:
            error_reformat_bad[j].append(error_bad[i][WINDOW*j])
            
inp_bad = []
outp_bad = []
for i in range(num_parts):
    inp_bad.append([])
    outp_bad.append([])
    
for i in range(len(reconstructed_bad)):
    for j in range(num_parts):
        if i == len(reconstructed_bad)-1:
            for val in reconstructed_bad[i][WINDOW*j:WINDOW+WINDOW*j]:
                outp_bad[j].append(val)
            for val in bad_new[i][WINDOW*j:WINDOW+WINDOW*j]:
                inp_bad[j].append(val)
        else:
            outp_bad[j].append(reconstructed_bad[i][WINDOW*j])
            inp_bad[j].append(bad_new[i][WINDOW*j])

# %%
labels = data['HLT']

#bins = np.linspace(0,1,50)
bins = 50
plt.figure(figsize=[15,10])
for i in range(len(error_reformat_bad)):
    plt.subplot(2,3,i+1)
    plt.hist(error_reformat[i],bins=bins,label='good',alpha=.5)
    plt.hist(error_reformat_bad[i],bins=bins,label='bad',alpha=.5)
    plt.legend()
    plt.title(labels[i])
plt.tight_layout()

print(len(error_reformat_bad[0]),len(lumiBad))
plt.figure(figsize=[15,10])
for i in range(0,num_parts):
    plt.subplot(2,3,i+1)
    plt.scatter(lumi,error_reformat[i],label = 'good', alpha =.5)
    plt.scatter(lumiBad,error_reformat_bad[i],label='bad',alpha=.5)
    plt.xlabel('lumi id')
    plt.ylabel('error')
    plt.legend()    
    plt.title(labels[i])
plt.tight_layout()

plt.show()
# Out:
# 99 99

# %%
plt.figure(figsize=[15,10])
for i in range(0,num_parts):
    plt.subplot(2,3,i+1)
    plt.plot(outp_bad[i],inp_bad[i],label=labels[i], linestyle='',marker='o', markersize=3, alpha=0.5)
    plt.xlabel('index')
    plt.ylabel('value')
    plt.axis('equal')
    #plt.ylim(0,.6)
    plt.legend()   
plt.tight_layout()

plt.show()
