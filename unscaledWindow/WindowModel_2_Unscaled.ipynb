# %%
import os
import numpy as np
import matplotlib
import matplotlib.pyplot as plt
import pandas as pd
import keras
import pickle

from keras import backend as K
from keras.callbacks import EarlyStopping, ModelCheckpoint, ReduceLROnPlateau
from keras.initializers import Ones, Zeros, Constant
from keras.models import Model, load_model
from keras.layers import Dense, Input, Lambda, SimpleRNN, Reshape, RepeatVector, PReLU
from keras.losses import mse
from keras.constraints import non_neg
# Out:
# /anaconda3/lib/python3.6/site-packages/h5py/__init__.py:36: FutureWarning: Conversion of the second argument of issubdtype from `float` to `np.floating` is deprecated. In future, it will be treated as `np.float64 == np.dtype(float).type`.
#   from ._conv import register_converters as _register_converters
# Using TensorFlow backend.
# /anaconda3/lib/python3.6/importlib/_bootstrap.py:219: RuntimeWarning: compiletime version 3.5 of module 'tensorflow.python.framework.fast_tensor_util' does not match runtime version 3.6
#   return f(*args, **kwds)

# %%
# Change presentation settings

# %matplotlib inline

matplotlib.rcParams["figure.figsize"] = (16.0, 10.0)

#matplotlib.rcParams['font.family'] = 'sans-serif'
#matplotlib.rcParams['font.sans-serif'] = ['Liberation Sans']

matplotlib.rcParams["axes.spines.left"] = True
matplotlib.rcParams["axes.spines.top"] = True
matplotlib.rcParams["axes.spines.right"] = True
matplotlib.rcParams["axes.spines.bottom"] = True
matplotlib.rcParams["axes.labelsize"] = 18
matplotlib.rcParams["axes.titlesize"] = 12

matplotlib.rcParams["xtick.top"] = True
matplotlib.rcParams["ytick.right"] = True
matplotlib.rcParams["xtick.direction"] = "in"
matplotlib.rcParams["ytick.direction"] = "in"
matplotlib.rcParams["xtick.labelsize"] = 10
matplotlib.rcParams["ytick.labelsize"] = 10
matplotlib.rcParams["xtick.major.size"] = 10
matplotlib.rcParams["ytick.major.size"] = 10
matplotlib.rcParams["xtick.minor.size"] = 5
matplotlib.rcParams["ytick.minor.size"] = 5
matplotlib.rcParams["xtick.minor.visible"] = True

matplotlib.rcParams["lines.linewidth"] = 2

matplotlib.rcParams["legend.fontsize"] = 14

color_palette = {"Indigo": {
                    50: "#E8EAF6",
                    100: "#C5CAE9",
                    200: "#9FA8DA",
                    300: "#7986CB",
                    400: "#5C6BC0",
                    500: "#3F51B5",
                    600: "#3949AB",
                    700: "#303F9F",
                    800: "#283593",
                    900: "#1A237E"},
                 "Orange": {      
                    50: "#FFF3E0",
                    100: "#FFE0B2",
                    200: "#FFCC80",
                    300: "#FFB74D",
                    400: "#FFA726",
                    500: "#FF9800",
                    600: "#FB8C00",
                    700: "#F57C00",
                    800: "#EF6C00",
                    900: "#E65100"}
                }

line_styles = [(0, ()), (0, (1, 2)), (0, (3, 2))]

# %%
def plot_loss(data, save_name=False):
    """Plots the training and validation loss"""
    fig, ax = plt.subplots()

    plt.xlabel("Epoch", horizontalalignment='right', x=1.0)
    plt.ylabel("Cross-entropy", horizontalalignment='right', y=1.0)

    plt.plot(data["loss"], linestyle=line_styles[0], color=color_palette["Indigo"][800])
    plt.plot(data["val_loss"], linestyle=line_styles[2], color=color_palette["Orange"][400])
    plt.legend(["Training data set", "Validation data set"], loc="upper right", frameon=False)
    #plt.yscale("log")
    
    if save_name:
        fig.savefig("%s/%s.eps" % (figure_export_directory, save_name), bbox_inches="tight")

    plt.show();

# %%
def train_nn(model, x, y, batch_size, loss, name, xval):

    adam = keras.optimizers.Adam(lr=0.003,
                                 beta_1=0.9,
                                 beta_2=0.999,
                                 epsilon=None,
                                 decay=0.0,
                                 amsgrad=False)

    early_stopper = EarlyStopping(monitor="val_loss",
                                  patience=32,
                                  verbose=True,
                                  mode="auto")

    reduce_lr = ReduceLROnPlateau(monitor="val_loss",
                                  factor=0.1,
                                  patience=24)
    
    checkpoint_callback = ModelCheckpoint(("%s.h5" % (name)),
                                          monitor="val_loss",
                                          verbose=False,
                                          save_best_only=True,
                                          mode="min")
    
    model.compile(loss=loss, optimizer=adam)
    
    history = model.fit(x, y,
                     batch_size=batch_size,
                     epochs=1000,
                     verbose=2,
                     initial_epoch=0,
                     shuffle=True,
                     validation_data=(xval,xval),
                     callbacks=[early_stopper, checkpoint_callback])
    return history

# %% [markdown]
# ## Data

# %%
runs = [304125,302263,304508]

with open('unscaled_data_WINDOW2.pickle', 'rb') as handle:
    data = pickle.load(handle)

x_train = np.array(data[str(runs[0])]['samples'])
x_val = np.array(data[str(runs[1])]['samples'])
x_test = np.array(data[str(runs[2])]['samples'])

WINDOW = 2

# %%
plots = [x_train,x_val,x_test]
titles = ["train","val","test"]

stuff = [[],[],[]]
lumi = [[],[],[]]
for h in range(3):
    labels = data['HLT'] 
    lumi[h] = data[str(runs[h])]['lumiid']
    stuff[h] = data[str(runs[h])]['rates']
    
plt.figure(figsize=[20,10])
              
for i in range(4):
    plt.subplot(2,2,i+1)
    for k in range(0,3):
        print(len(lumi[k]),len(stuff[k][i]))
        plt.scatter(lumi[k],stuff[k][i],label=titles[k],alpha=.5)
    plt.xlabel('lumi id')
    plt.ylabel('error')
    plt.title(labels[i])
    plt.legend()

plt.tight_layout()
plt.show()
# Out:
# 1669 1669
# 1129 1129
# 1224 1224
# 1669 1669
# 1129 1129
# 1224 1224
# 1669 1669
# 1129 1129
# 1224 1224
# 1669 1669
# 1129 1129
# 1224 1224

# %% [markdown]
# ## Simple Autoencoder

# %%
model_name = "simplest_2"

# %%
# Define the architecture

_input = Input(shape=(4*WINDOW,), name="input")

hidden = Dense(3,
               kernel_initializer=Ones(),
               bias_initializer=Zeros(),
               kernel_constraint=non_neg(),
               bias_constraint=non_neg(),
               activation=None,
               name="encoded")(_input)

output = Dense(4*WINDOW,
               kernel_initializer=Ones(),
               bias_initializer=Zeros(),
               kernel_constraint=non_neg(),
               bias_constraint=non_neg(),
               activation=None,
               name="reconstructed")(hidden)

model = Model(_input, output)
model.summary()
# Out:
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# input (InputLayer)           (None, 8)                 0
# _________________________________________________________________
# encoded (Dense)              (None, 3)                 27
# _________________________________________________________________
# reconstructed (Dense)        (None, 8)                 32
# =================================================================
# Total params: 59
# Trainable params: 59
# Non-trainable params: 0
# _________________________________________________________________

# %%
# Train neural networks
history = train_nn(model, x_train, x_train, 1024, "mse", model_name, x_val).history
plot_loss(history)
# Out:
# Train on 1668 samples, validate on 1128 samples
# Epoch 1/1000
#  - 0s - loss: 31.1131 - val_loss: 21.9479
# Epoch 2/1000
#  - 0s - loss: 30.3412 - val_loss: 21.4015
# Epoch 3/1000
#  - 0s - loss: 29.5887 - val_loss: 20.8741
# Epoch 4/1000
#  - 0s - loss: 28.8602 - val_loss: 20.3498
# Epoch 5/1000
#  - 0s - loss: 28.1321 - val_loss: 19.8371
# Epoch 6/1000
#  - 0s - loss: 27.4256 - val_loss: 19.3355
# Epoch 7/1000
#  - 0s - loss: 26.7277 - val_loss: 18.8444
# Epoch 8/1000
#  - 0s - loss: 26.0505 - val_loss: 18.3657
# Epoch 9/1000
#  - 0s - loss: 25.3852 - val_loss: 17.8986
# Epoch 10/1000
#  - 0s - loss: 24.7412 - val_loss: 17.4403
# Epoch 11/1000
#  - 0s - loss: 24.1114 - val_loss: 16.9934
# Epoch 12/1000
#  - 0s - loss: 23.4897 - val_loss: 16.5606
# Epoch 13/1000
#  - 0s - loss: 22.8940 - val_loss: 16.1363
# Epoch 14/1000
#  - 0s - loss: 22.3085 - val_loss: 15.7258
# Epoch 15/1000
#  - 0s - loss: 21.7383 - val_loss: 15.3241
# Epoch 16/1000
#  - 0s - loss: 21.1854 - val_loss: 14.9355
# Epoch 17/1000
#  - 0s - loss: 20.6475 - val_loss: 14.5554
# Epoch 18/1000
#  - 0s - loss: 20.1214 - val_loss: 14.1878
# Epoch 19/1000
#  - 0s - loss: 19.6146 - val_loss: 13.8303
# Epoch 20/1000
#  - 0s - loss: 19.1234 - val_loss: 13.4826
# Epoch 21/1000
#  - 0s - loss: 18.6410 - val_loss: 13.1450
# Epoch 22/1000
#  - 0s - loss: 18.1739 - val_loss: 12.8169
# Epoch 23/1000
#  - 0s - loss: 17.7216 - val_loss: 12.4978
# Epoch 24/1000
#  - 0s - loss: 17.2802 - val_loss: 12.1879
# Epoch 25/1000
#  - 0s - loss: 16.8495 - val_loss: 11.8852
# Epoch 26/1000
#  - 0s - loss: 16.4327 - val_loss: 11.5923
# Epoch 27/1000
#  - 0s - loss: 16.0299 - val_loss: 11.3075
# Epoch 28/1000
#  - 0s - loss: 15.6349 - val_loss: 11.0298
# Epoch 29/1000
#  - 0s - loss: 15.2519 - val_loss: 10.7609
# Epoch 30/1000
#  - 0s - loss: 14.8798 - val_loss: 10.4996
# Epoch 31/1000
#  - 0s - loss: 14.5190 - val_loss: 10.2456
# Epoch 32/1000
#  - 0s - loss: 14.1679 - val_loss: 9.9987
# Epoch 33/1000
#  - 0s - loss: 13.8286 - val_loss: 9.7579
# Epoch 34/1000
#  - 0s - loss: 13.4946 - val_loss: 9.5231
# Epoch 35/1000
#  - 0s - loss: 13.1710 - val_loss: 9.2965
# Epoch 36/1000
#  - 0s - loss: 12.8578 - val_loss: 9.0764
# Epoch 37/1000
#  - 0s - loss: 12.5521 - val_loss: 8.8624
# Epoch 38/1000
#  - 0s - loss: 12.2574 - val_loss: 8.6541
# Epoch 39/1000
#  - 0s - loss: 11.9698 - val_loss: 8.4516
# Epoch 40/1000
#  - 0s - loss: 11.6900 - val_loss: 8.2546
# Epoch 41/1000
#  - 0s - loss: 11.4176 - val_loss: 8.0631
# Epoch 42/1000
#  - 0s - loss: 11.1527 - val_loss: 7.8768
# Epoch 43/1000
#  - 0s - loss: 10.8964 - val_loss: 7.6950
# Epoch 44/1000
#  - 0s - loss: 10.6451 - val_loss: 7.5183
# Epoch 45/1000
#  - 0s - loss: 10.4000 - val_loss: 7.3464
# Epoch 46/1000
#  - 0s - loss: 10.1635 - val_loss: 7.1795
# Epoch 47/1000
#  - 0s - loss: 9.9317 - val_loss: 7.0173
# Epoch 48/1000
#  - 0s - loss: 9.7086 - val_loss: 6.8593
# Epoch 49/1000
#  - 0s - loss: 9.4896 - val_loss: 6.7055
# Epoch 50/1000
#  - 0s - loss: 9.2771 - val_loss: 6.5559
# Epoch 51/1000
#  - 0s - loss: 9.0696 - val_loss: 6.4102
# Epoch 52/1000
#  - 0s - loss: 8.8687 - val_loss: 6.2682
# Epoch 53/1000
#  - 0s - loss: 8.6728 - val_loss: 6.1299
# Epoch 54/1000
#  - 0s - loss: 8.4820 - val_loss: 5.9953
# Epoch 55/1000
#  - 0s - loss: 8.2964 - val_loss: 5.8642
# Epoch 56/1000
#  - 0s - loss: 8.1145 - val_loss: 5.7367
# Epoch 57/1000
#  - 0s - loss: 7.9376 - val_loss: 5.6122
# Epoch 58/1000
#  - 0s - loss: 7.7671 - val_loss: 5.4910
# Epoch 59/1000
#  - 0s - loss: 7.5988 - val_loss: 5.3729
# Epoch 60/1000
#  - 0s - loss: 7.4352 - val_loss: 5.2580
# Epoch 61/1000
#  - 0s - loss: 7.2769 - val_loss: 5.1460
# Epoch 62/1000
#  - 0s - loss: 7.1218 - val_loss: 5.0370
# Epoch 63/1000
#  - 0s - loss: 6.9712 - val_loss: 4.9306
# Epoch 64/1000
#  - 0s - loss: 6.8242 - val_loss: 4.8269
# Epoch 65/1000
#  - 0s - loss: 6.6806 - val_loss: 4.7259
# Epoch 66/1000
#  - 0s - loss: 6.5411 - val_loss: 4.6274
# Epoch 67/1000
#  - 0s - loss: 6.4045 - val_loss: 4.5311
# Epoch 68/1000
#  - 0s - loss: 6.2711 - val_loss: 4.4374
# Epoch 69/1000
#  - 0s - loss: 6.1417 - val_loss: 4.3458
# Epoch 70/1000
#  - 0s - loss: 6.0155 - val_loss: 4.2564
# Epoch 71/1000
#  - 0s - loss: 5.8916 - val_loss: 4.1693
# Epoch 72/1000
#  - 0s - loss: 5.7717 - val_loss: 4.0844
# Epoch 73/1000
#  - 0s - loss: 5.6539 - val_loss: 4.0015
# Epoch 74/1000
#  - 0s - loss: 5.5391 - val_loss: 3.9206
# Epoch 75/1000
#  - 0s - loss: 5.4274 - val_loss: 3.8416
# Epoch 76/1000
#  - 0s - loss: 5.3186 - val_loss: 3.7646
# Epoch 77/1000
#  - 0s - loss: 5.2119 - val_loss: 3.6895
# Epoch 78/1000
#  - 0s - loss: 5.1083 - val_loss: 3.6162
# Epoch 79/1000
#  - 0s - loss: 5.0070 - val_loss: 3.5446
# Epoch 80/1000
#  - 0s - loss: 4.9079 - val_loss: 3.4748
# Epoch 81/1000
#  - 0s - loss: 4.8115 - val_loss: 3.4067
# Epoch 82/1000
#  - 0s - loss: 4.7169 - val_loss: 3.3402
# Epoch 83/1000
#  - 0s - loss: 4.6245 - val_loss: 3.2753
# Epoch 84/1000
#  - 0s - loss: 4.5348 - val_loss: 3.2117
# Epoch 85/1000
#  - 0s - loss: 4.4477 - val_loss: 3.1496
# Epoch 86/1000
#  - 0s - loss: 4.3616 - val_loss: 3.0890
# Epoch 87/1000
#  - 0s - loss: 4.2781 - val_loss: 3.0297
# Epoch 88/1000
#  - 0s - loss: 4.1960 - val_loss: 2.9720
# Epoch 89/1000
#  - 0s - loss: 4.1167 - val_loss: 2.9156
# Epoch 90/1000
#  - 0s - loss: 4.0380 - val_loss: 2.8606
# Epoch 91/1000
#  - 0s - loss: 3.9619 - val_loss: 2.8068
# Epoch 92/1000
#  - 0s - loss: 3.8881 - val_loss: 2.7543
# Epoch 93/1000
#  - 0s - loss: 3.8151 - val_loss: 2.7029
# Epoch 94/1000
#  - 0s - loss: 3.7439 - val_loss: 2.6527
# Epoch 95/1000
#  - 0s - loss: 3.6746 - val_loss: 2.6037
# Epoch 96/1000
#  - 0s - loss: 3.6069 - val_loss: 2.5557
# Epoch 97/1000
#  - 0s - loss: 3.5406 - val_loss: 2.5088
# Epoch 98/1000
#  - 0s - loss: 3.4756 - val_loss: 2.4631
# Epoch 99/1000
#  - 0s - loss: 3.4125 - val_loss: 2.4183
# Epoch 100/1000
#  - 0s - loss: 3.3503 - val_loss: 2.3746
# Epoch 101/1000
#  - 0s - loss: 3.2896 - val_loss: 2.3318
# Epoch 102/1000
#  - 0s - loss: 3.2305 - val_loss: 2.2899
# Epoch 103/1000
#  - 0s - loss: 3.1726 - val_loss: 2.2488
# Epoch 104/1000
#  - 0s - loss: 3.1158 - val_loss: 2.2087
# Epoch 105/1000
#  - 0s - loss: 3.0604 - val_loss: 2.1694
# Epoch 106/1000
#  - 0s - loss: 3.0059 - val_loss: 2.1310
# Epoch 107/1000
#  - 0s - loss: 2.9527 - val_loss: 2.0933
# Epoch 108/1000
#  - 0s - loss: 2.9006 - val_loss: 2.0565
# Epoch 109/1000
#  - 0s - loss: 2.8499 - val_loss: 2.0205
# Epoch 110/1000
#  - 0s - loss: 2.8001 - val_loss: 1.9853
# Epoch 111/1000
#  - 0s - loss: 2.7515 - val_loss: 1.9508
# Epoch 112/1000
#  - 0s - loss: 2.7035 - val_loss: 1.9171
# Epoch 113/1000
#  - 0s - loss: 2.6569 - val_loss: 1.8840
# Epoch 114/1000
#  - 0s - loss: 2.6112 - val_loss: 1.8516
# Epoch 115/1000
#  - 0s - loss: 2.5665 - val_loss: 1.8200
# Epoch 116/1000
#  - 0s - loss: 2.5225 - val_loss: 1.7890
# Epoch 117/1000
#  - 0s - loss: 2.4796 - val_loss: 1.7586
# Epoch 118/1000
#  - 0s - loss: 2.4377 - val_loss: 1.7289
# Epoch 119/1000
#  - 0s - loss: 2.3966 - val_loss: 1.6998
# Epoch 120/1000
#  - 0s - loss: 2.3563 - val_loss: 1.6713
# Epoch 121/1000
#  - 0s - loss: 2.3168 - val_loss: 1.6434
# Epoch 122/1000
#  - 0s - loss: 2.2782 - val_loss: 1.6160
# Epoch 123/1000
#  - 0s - loss: 2.2402 - val_loss: 1.5892
# Epoch 124/1000
#  - 0s - loss: 2.2034 - val_loss: 1.5629
# Epoch 125/1000
#  - 0s - loss: 2.1668 - val_loss: 1.5372
# Epoch 126/1000
#  - 0s - loss: 2.1313 - val_loss: 1.5120
# Epoch 127/1000
#  - 0s - loss: 2.0965 - val_loss: 1.4872
# Epoch 128/1000
#  - 0s - loss: 2.0620 - val_loss: 1.4630
# Epoch 129/1000
#  - 0s - loss: 2.0287 - val_loss: 1.4393
# Epoch 130/1000
#  - 0s - loss: 1.9957 - val_loss: 1.4160
# Epoch 131/1000
#  - 0s - loss: 1.9635 - val_loss: 1.3932
# Epoch 132/1000
#  - 0s - loss: 1.9320 - val_loss: 1.3708
# Epoch 133/1000
#  - 0s - loss: 1.9009 - val_loss: 1.3488
# Epoch 134/1000
#  - 0s - loss: 1.8707 - val_loss: 1.3273
# Epoch 135/1000
#  - 0s - loss: 1.8408 - val_loss: 1.3063
# Epoch 136/1000
#  - 0s - loss: 1.8117 - val_loss: 1.2856
# Epoch 137/1000
#  - 0s - loss: 1.7830 - val_loss: 1.2653
# Epoch 138/1000
#  - 0s - loss: 1.7549 - val_loss: 1.2454
# Epoch 139/1000
#  - 0s - loss: 1.7275 - val_loss: 1.2259
# Epoch 140/1000
#  - 0s - loss: 1.7004 - val_loss: 1.2067
# Epoch 141/1000
#  - 0s - loss: 1.6739 - val_loss: 1.1879
# Epoch 142/1000
#  - 0s - loss: 1.6479 - val_loss: 1.1695
# Epoch 143/1000
#  - 0s - loss: 1.6222 - val_loss: 1.1514
# Epoch 144/1000
#  - 0s - loss: 1.5974 - val_loss: 1.1337
# Epoch 145/1000
#  - 0s - loss: 1.5730 - val_loss: 1.1163
# Epoch 146/1000
#  - 0s - loss: 1.5488 - val_loss: 1.0992
# Epoch 147/1000
#  - 0s - loss: 1.5250 - val_loss: 1.0825
# Epoch 148/1000
#  - 0s - loss: 1.5018 - val_loss: 1.0661
# Epoch 149/1000
#  - 0s - loss: 1.4792 - val_loss: 1.0499
# Epoch 150/1000
#  - 0s - loss: 1.4569 - val_loss: 1.0341
# Epoch 151/1000
#  - 0s - loss: 1.4350 - val_loss: 1.0186
# Epoch 152/1000
#  - 0s - loss: 1.4135 - val_loss: 1.0033
# Epoch 153/1000
#  - 0s - loss: 1.3924 - val_loss: 0.9884
# Epoch 154/1000
#  - 0s - loss: 1.3717 - val_loss: 0.9737
# Epoch 155/1000
#  - 0s - loss: 1.3514 - val_loss: 0.9593
# Epoch 156/1000
#  - 0s - loss: 1.3315 - val_loss: 0.9452
# Epoch 157/1000
#  - 0s - loss: 1.3119 - val_loss: 0.9313
# Epoch 158/1000
#  - 0s - loss: 1.2926 - val_loss: 0.9177
# Epoch 159/1000
#  - 0s - loss: 1.2736 - val_loss: 0.9043
# Epoch 160/1000
#  - 0s - loss: 1.2552 - val_loss: 0.8911
# Epoch 161/1000
#  - 0s - loss: 1.2370 - val_loss: 0.8782
# Epoch 162/1000
#  - 0s - loss: 1.2190 - val_loss: 0.8655
# Epoch 163/1000
#  - 0s - loss: 1.2014 - val_loss: 0.8530
# Epoch 164/1000
#  - 0s - loss: 1.1843 - val_loss: 0.8407
# Epoch 165/1000
#  - 0s - loss: 1.1672 - val_loss: 0.8287
# Epoch 166/1000
#  - 0s - loss: 1.1505 - val_loss: 0.8168
# Epoch 167/1000
#  - 0s - loss: 1.1342 - val_loss: 0.8052
# Epoch 168/1000
#  - 0s - loss: 1.1180 - val_loss: 0.7938
# Epoch 169/1000
#  - 0s - loss: 1.1022 - val_loss: 0.7825
# Epoch 170/1000
#  - 0s - loss: 1.0867 - val_loss: 0.7715
# Epoch 171/1000
#  - 0s - loss: 1.0714 - val_loss: 0.7607
# Epoch 172/1000
#  - 0s - loss: 1.0564 - val_loss: 0.7500
# Epoch 173/1000
#  - 0s - loss: 1.0416 - val_loss: 0.7396
# Epoch 174/1000
#  - 0s - loss: 1.0271 - val_loss: 0.7293
# Epoch 175/1000
#  - 0s - loss: 1.0129 - val_loss: 0.7192
# Epoch 176/1000
#  - 0s - loss: 0.9988 - val_loss: 0.7092
# Epoch 177/1000
#  - 0s - loss: 0.9851 - val_loss: 0.6995
# Epoch 178/1000
#  - 0s - loss: 0.9716 - val_loss: 0.6898
# Epoch 179/1000
#  - 0s - loss: 0.9583 - val_loss: 0.6804
# Epoch 180/1000
#  - 0s - loss: 0.9452 - val_loss: 0.6711
# Epoch 181/1000
#  - 0s - loss: 0.9324 - val_loss: 0.6620
# Epoch 182/1000
#  - 0s - loss: 0.9197 - val_loss: 0.6530
# Epoch 183/1000
#  - 0s - loss: 0.9073 - val_loss: 0.6442
# Epoch 184/1000
#  - 0s - loss: 0.8950 - val_loss: 0.6356
# Epoch 185/1000
#  - 0s - loss: 0.8831 - val_loss: 0.6270
# Epoch 186/1000
#  - 0s - loss: 0.8712 - val_loss: 0.6186
# Epoch 187/1000
#  - 0s - loss: 0.8596 - val_loss: 0.6103
# Epoch 188/1000
#  - 0s - loss: 0.8482 - val_loss: 0.6022
# Epoch 189/1000
#  - 0s - loss: 0.8369 - val_loss: 0.5942
# Epoch 190/1000
#  - 0s - loss: 0.8258 - val_loss: 0.5864
# Epoch 191/1000
#  - 0s - loss: 0.8150 - val_loss: 0.5786
# Epoch 192/1000
#  - 0s - loss: 0.8043 - val_loss: 0.5710
# Epoch 193/1000
#  - 0s - loss: 0.7937 - val_loss: 0.5635
# Epoch 194/1000
#  - 0s - loss: 0.7832 - val_loss: 0.5562
# Epoch 195/1000
#  - 0s - loss: 0.7731 - val_loss: 0.5489
# Epoch 196/1000
#  - 0s - loss: 0.7631 - val_loss: 0.5418
# Epoch 197/1000
#  - 0s - loss: 0.7532 - val_loss: 0.5348
# Epoch 198/1000
#  - 0s - loss: 0.7434 - val_loss: 0.5279
# Epoch 199/1000
#  - 0s - loss: 0.7339 - val_loss: 0.5211
# Epoch 200/1000
#  - 0s - loss: 0.7245 - val_loss: 0.5144
# Epoch 201/1000
#  - 0s - loss: 0.7152 - val_loss: 0.5078
# Epoch 202/1000
#  - 0s - loss: 0.7061 - val_loss: 0.5013
# Epoch 203/1000
#  - 0s - loss: 0.6971 - val_loss: 0.4949
# Epoch 204/1000
#  - 0s - loss: 0.6883 - val_loss: 0.4887
# Epoch 205/1000
#  - 0s - loss: 0.6796 - val_loss: 0.4825
# Epoch 206/1000
#  - 0s - loss: 0.6710 - val_loss: 0.4764
# Epoch 207/1000
#  - 0s - loss: 0.6626 - val_loss: 0.4704
# Epoch 208/1000
#  - 0s - loss: 0.6543 - val_loss: 0.4645
# Epoch 209/1000
#  - 0s - loss: 0.6461 - val_loss: 0.4587
# Epoch 210/1000
#  - 0s - loss: 0.6381 - val_loss: 0.4530
# Epoch 211/1000
#  - 0s - loss: 0.6301 - val_loss: 0.4474
# Epoch 212/1000
#  - 0s - loss: 0.6223 - val_loss: 0.4418
# Epoch 213/1000
#  - 0s - loss: 0.6147 - val_loss: 0.4364
# Epoch 214/1000
#  - 0s - loss: 0.6071 - val_loss: 0.4310
# Epoch 215/1000
#  - 0s - loss: 0.5997 - val_loss: 0.4257
# Epoch 216/1000
#  - 0s - loss: 0.5923 - val_loss: 0.4205
# Epoch 217/1000
#  - 0s - loss: 0.5851 - val_loss: 0.4153
# Epoch 218/1000
#  - 0s - loss: 0.5780 - val_loss: 0.4103
# Epoch 219/1000
#  - 0s - loss: 0.5710 - val_loss: 0.4053
# Epoch 220/1000
#  - 0s - loss: 0.5641 - val_loss: 0.4004
# Epoch 221/1000
#  - 0s - loss: 0.5573 - val_loss: 0.3956
# Epoch 222/1000
#  - 0s - loss: 0.5506 - val_loss: 0.3908
# Epoch 223/1000
#  - 0s - loss: 0.5440 - val_loss: 0.3861
# Epoch 224/1000
#  - 0s - loss: 0.5375 - val_loss: 0.3815
# Epoch 225/1000
#  - 0s - loss: 0.5311 - val_loss: 0.3769
# Epoch 226/1000
#  - 0s - loss: 0.5248 - val_loss: 0.3724
# Epoch 227/1000
#  - 0s - loss: 0.5185 - val_loss: 0.3680
# Epoch 228/1000
#  - 0s - loss: 0.5124 - val_loss: 0.3637
# Epoch 229/1000
#  - 0s - loss: 0.5064 - val_loss: 0.3594
# Epoch 230/1000
#  - 0s - loss: 0.5004 - val_loss: 0.3551
# Epoch 231/1000
#  - 0s - loss: 0.4946 - val_loss: 0.3510
# Epoch 232/1000
#  - 0s - loss: 0.4888 - val_loss: 0.3469
# Epoch 233/1000
#  - 0s - loss: 0.4831 - val_loss: 0.3428
# Epoch 234/1000
#  - 0s - loss: 0.4775 - val_loss: 0.3388
# Epoch 235/1000
#  - 0s - loss: 0.4720 - val_loss: 0.3349
# Epoch 236/1000
#  - 0s - loss: 0.4665 - val_loss: 0.3310
# Epoch 237/1000
#  - 0s - loss: 0.4611 - val_loss: 0.3272
# Epoch 238/1000
#  - 0s - loss: 0.4558 - val_loss: 0.3234
# Epoch 239/1000
#  - 0s - loss: 0.4506 - val_loss: 0.3197
# Epoch 240/1000
#  - 0s - loss: 0.4455 - val_loss: 0.3161
# Epoch 241/1000
#  - 0s - loss: 0.4404 - val_loss: 0.3125
# Epoch 242/1000
#  - 0s - loss: 0.4354 - val_loss: 0.3089
# Epoch 243/1000
#  - 0s - loss: 0.4305 - val_loss: 0.3054
# Epoch 244/1000
#  - 0s - loss: 0.4256 - val_loss: 0.3020
# Epoch 245/1000
#  - 0s - loss: 0.4208 - val_loss: 0.2985
# Epoch 246/1000
#  - 0s - loss: 0.4161 - val_loss: 0.2952
# Epoch 247/1000
#  - 0s - loss: 0.4114 - val_loss: 0.2919
# Epoch 248/1000
#  - 0s - loss: 0.4069 - val_loss: 0.2886
# Epoch 249/1000
#  - 0s - loss: 0.4023 - val_loss: 0.2854
# Epoch 250/1000
#  - 0s - loss: 0.3979 - val_loss: 0.2822
# Epoch 251/1000
#  - 0s - loss: 0.3935 - val_loss: 0.2791
# Epoch 252/1000
#  - 0s - loss: 0.3891 - val_loss: 0.2760
# Epoch 253/1000
#  - 0s - loss: 0.3848 - val_loss: 0.2729
# Epoch 254/1000
#  - 0s - loss: 0.3806 - val_loss: 0.2699
# Epoch 255/1000
#  - 0s - loss: 0.3764 - val_loss: 0.2670
# Epoch 256/1000
#  - 0s - loss: 0.3723 - val_loss: 0.2641
# Epoch 257/1000
#  - 0s - loss: 0.3683 - val_loss: 0.2612
# Epoch 258/1000
#  - 0s - loss: 0.3643 - val_loss: 0.2583
# Epoch 259/1000
#  - 0s - loss: 0.3603 - val_loss: 0.2555
# Epoch 260/1000
#  - 0s - loss: 0.3564 - val_loss: 0.2527
# Epoch 261/1000
#  - 0s - loss: 0.3526 - val_loss: 0.2500
# Epoch 262/1000
#  - 0s - loss: 0.3488 - val_loss: 0.2473
# Epoch 263/1000
#  - 0s - loss: 0.3451 - val_loss: 0.2446
# Epoch 264/1000
#  - 0s - loss: 0.3413 - val_loss: 0.2420
# Epoch 265/1000
#  - 0s - loss: 0.3377 - val_loss: 0.2394
# Epoch 266/1000
#  - 0s - loss: 0.3341 - val_loss: 0.2369
# Epoch 267/1000
#  - 0s - loss: 0.3306 - val_loss: 0.2343
# Epoch 268/1000
#  - 0s - loss: 0.3271 - val_loss: 0.2318
# Epoch 269/1000
#  - 0s - loss: 0.3236 - val_loss: 0.2294
# Epoch 270/1000
#  - 0s - loss: 0.3202 - val_loss: 0.2270
# Epoch 271/1000
#  - 0s - loss: 0.3168 - val_loss: 0.2246
# Epoch 272/1000
#  - 0s - loss: 0.3135 - val_loss: 0.2222
# Epoch 273/1000
#  - 0s - loss: 0.3103 - val_loss: 0.2199
# Epoch 274/1000
#  - 0s - loss: 0.3070 - val_loss: 0.2176
# Epoch 275/1000
#  - 0s - loss: 0.3038 - val_loss: 0.2153
# Epoch 276/1000
#  - 0s - loss: 0.3007 - val_loss: 0.2131
# Epoch 277/1000
#  - 0s - loss: 0.2976 - val_loss: 0.2108
# Epoch 278/1000
#  - 0s - loss: 0.2945 - val_loss: 0.2087
# Epoch 279/1000
#  - 0s - loss: 0.2915 - val_loss: 0.2065
# Epoch 280/1000
#  - 0s - loss: 0.2885 - val_loss: 0.2044
# Epoch 281/1000
#  - 0s - loss: 0.2855 - val_loss: 0.2023
# Epoch 282/1000
#  - 0s - loss: 0.2826 - val_loss: 0.2002
# Epoch 283/1000
#  - 0s - loss: 0.2797 - val_loss: 0.1982
# Epoch 284/1000
#  - 0s - loss: 0.2769 - val_loss: 0.1961
# Epoch 285/1000
#  - 0s - loss: 0.2741 - val_loss: 0.1942
# Epoch 286/1000
#  - 0s - loss: 0.2713 - val_loss: 0.1922
# Epoch 287/1000
#  - 0s - loss: 0.2686 - val_loss: 0.1902
# Epoch 288/1000
#  - 0s - loss: 0.2659 - val_loss: 0.1883
# Epoch 289/1000
#  - 0s - loss: 0.2632 - val_loss: 0.1864
# Epoch 290/1000
#  - 0s - loss: 0.2606 - val_loss: 0.1845
# Epoch 291/1000
#  - 0s - loss: 0.2580 - val_loss: 0.1827
# Epoch 292/1000
#  - 0s - loss: 0.2555 - val_loss: 0.1809
# Epoch 293/1000
#  - 0s - loss: 0.2529 - val_loss: 0.1791
# Epoch 294/1000
#  - 0s - loss: 0.2504 - val_loss: 0.1773
# Epoch 295/1000
#  - 0s - loss: 0.2479 - val_loss: 0.1755
# Epoch 296/1000
#  - 0s - loss: 0.2455 - val_loss: 0.1738
# Epoch 297/1000
#  - 0s - loss: 0.2431 - val_loss: 0.1721
# Epoch 298/1000
#  - 0s - loss: 0.2407 - val_loss: 0.1704
# Epoch 299/1000
#  - 0s - loss: 0.2384 - val_loss: 0.1687
# Epoch 300/1000
#  - 0s - loss: 0.2360 - val_loss: 0.1671
# Epoch 301/1000
#  - 0s - loss: 0.2337 - val_loss: 0.1654
# Epoch 302/1000
#  - 0s - loss: 0.2315 - val_loss: 0.1638
# Epoch 303/1000
#  - 0s - loss: 0.2292 - val_loss: 0.1622
# Epoch 304/1000
#  - 0s - loss: 0.2270 - val_loss: 0.1607
# Epoch 305/1000
#  - 0s - loss: 0.2248 - val_loss: 0.1591
# Epoch 306/1000
#  - 0s - loss: 0.2227 - val_loss: 0.1576
# Epoch 307/1000
#  - 0s - loss: 0.2206 - val_loss: 0.1560
# Epoch 308/1000
#  - 0s - loss: 0.2184 - val_loss: 0.1545
# Epoch 309/1000
#  - 0s - loss: 0.2164 - val_loss: 0.1531
# Epoch 310/1000
#  - 0s - loss: 0.2143 - val_loss: 0.1516
# Epoch 311/1000
#  - 0s - loss: 0.2123 - val_loss: 0.1501
# Epoch 312/1000
#  - 0s - loss: 0.2103 - val_loss: 0.1487
# Epoch 313/1000
#  - 0s - loss: 0.2083 - val_loss: 0.1473
# Epoch 314/1000
#  - 0s - loss: 0.2063 - val_loss: 0.1459
# Epoch 315/1000
#  - 0s - loss: 0.2044 - val_loss: 0.1445
# Epoch 316/1000
#  - 0s - loss: 0.2025 - val_loss: 0.1432
# Epoch 317/1000
#  - 0s - loss: 0.2006 - val_loss: 0.1418
# Epoch 318/1000
#  - 0s - loss: 0.1987 - val_loss: 0.1405
# Epoch 319/1000
#  - 0s - loss: 0.1969 - val_loss: 0.1392
# Epoch 320/1000
#  - 0s - loss: 0.1951 - val_loss: 0.1379
# Epoch 321/1000
#  - 0s - loss: 0.1932 - val_loss: 0.1366
# Epoch 322/1000
#  - 0s - loss: 0.1915 - val_loss: 0.1353
# Epoch 323/1000
#  - 0s - loss: 0.1897 - val_loss: 0.1341
# Epoch 324/1000
#  - 0s - loss: 0.1880 - val_loss: 0.1328
# Epoch 325/1000
#  - 0s - loss: 0.1862 - val_loss: 0.1316
# Epoch 326/1000
#  - 0s - loss: 0.1846 - val_loss: 0.1304
# Epoch 327/1000
#  - 0s - loss: 0.1829 - val_loss: 0.1292
# Epoch 328/1000
#  - 0s - loss: 0.1812 - val_loss: 0.1280
# Epoch 329/1000
#  - 0s - loss: 0.1796 - val_loss: 0.1269
# Epoch 330/1000
#  - 0s - loss: 0.1779 - val_loss: 0.1257
# Epoch 331/1000
#  - 0s - loss: 0.1763 - val_loss: 0.1246
# Epoch 332/1000
#  - 0s - loss: 0.1747 - val_loss: 0.1234
# Epoch 333/1000
#  - 0s - loss: 0.1732 - val_loss: 0.1223
# Epoch 334/1000
#  - 0s - loss: 0.1716 - val_loss: 0.1212
# Epoch 335/1000
#  - 0s - loss: 0.1701 - val_loss: 0.1201
# Epoch 336/1000
#  - 0s - loss: 0.1686 - val_loss: 0.1190
# Epoch 337/1000
#  - 0s - loss: 0.1671 - val_loss: 0.1180
# Epoch 338/1000
#  - 0s - loss: 0.1656 - val_loss: 0.1169
# Epoch 339/1000
#  - 0s - loss: 0.1641 - val_loss: 0.1159
# Epoch 340/1000
#  - 0s - loss: 0.1627 - val_loss: 0.1149
# Epoch 341/1000
#  - 0s - loss: 0.1613 - val_loss: 0.1138
# Epoch 342/1000
#  - 0s - loss: 0.1599 - val_loss: 0.1128
# Epoch 343/1000
#  - 0s - loss: 0.1585 - val_loss: 0.1118
# Epoch 344/1000
#  - 0s - loss: 0.1571 - val_loss: 0.1108
# Epoch 345/1000
#  - 0s - loss: 0.1557 - val_loss: 0.1099
# Epoch 346/1000
#  - 0s - loss: 0.1544 - val_loss: 0.1089
# Epoch 347/1000
#  - 0s - loss: 0.1530 - val_loss: 0.1080
# Epoch 348/1000
#  - 0s - loss: 0.1517 - val_loss: 0.1070
# Epoch 349/1000
#  - 0s - loss: 0.1504 - val_loss: 0.1061
# Epoch 350/1000
#  - 0s - loss: 0.1491 - val_loss: 0.1052
# Epoch 351/1000
#  - 0s - loss: 0.1478 - val_loss: 0.1043
# Epoch 352/1000
#  - 0s - loss: 0.1466 - val_loss: 0.1034
# Epoch 353/1000
#  - 0s - loss: 0.1453 - val_loss: 0.1025
# Epoch 354/1000
#  - 0s - loss: 0.1441 - val_loss: 0.1016
# Epoch 355/1000
#  - 0s - loss: 0.1428 - val_loss: 0.1007
# Epoch 356/1000
#  - 0s - loss: 0.1416 - val_loss: 0.0999
# Epoch 357/1000
#  - 0s - loss: 0.1404 - val_loss: 0.0990
# Epoch 358/1000
#  - 0s - loss: 0.1392 - val_loss: 0.0982
# Epoch 359/1000
#  - 0s - loss: 0.1381 - val_loss: 0.0973
# Epoch 360/1000
#  - 0s - loss: 0.1369 - val_loss: 0.0965
# Epoch 361/1000
#  - 0s - loss: 0.1358 - val_loss: 0.0957
# Epoch 362/1000
#  - 0s - loss: 0.1346 - val_loss: 0.0949
# Epoch 363/1000
#  - 0s - loss: 0.1335 - val_loss: 0.0941
# Epoch 364/1000
#  - 0s - loss: 0.1324 - val_loss: 0.0933
# Epoch 365/1000
#  - 0s - loss: 0.1313 - val_loss: 0.0925
# Epoch 366/1000
#  - 0s - loss: 0.1302 - val_loss: 0.0917
# Epoch 367/1000
#  - 0s - loss: 0.1291 - val_loss: 0.0910
# Epoch 368/1000
#  - 0s - loss: 0.1281 - val_loss: 0.0902
# Epoch 369/1000
#  - 0s - loss: 0.1270 - val_loss: 0.0895
# Epoch 370/1000
#  - 0s - loss: 0.1260 - val_loss: 0.0887
# Epoch 371/1000
#  - 0s - loss: 0.1250 - val_loss: 0.0880
# Epoch 372/1000
#  - 0s - loss: 0.1239 - val_loss: 0.0873
# Epoch 373/1000
#  - 0s - loss: 0.1229 - val_loss: 0.0865
# Epoch 374/1000
#  - 0s - loss: 0.1219 - val_loss: 0.0858
# Epoch 375/1000
#  - 0s - loss: 0.1209 - val_loss: 0.0851
# Epoch 376/1000
#  - 0s - loss: 0.1200 - val_loss: 0.0844
# Epoch 377/1000
#  - 0s - loss: 0.1190 - val_loss: 0.0837
# Epoch 378/1000
#  - 0s - loss: 0.1180 - val_loss: 0.0831
# Epoch 379/1000
#  - 0s - loss: 0.1171 - val_loss: 0.0824
# Epoch 380/1000
#  - 0s - loss: 0.1162 - val_loss: 0.0817
# Epoch 381/1000
#  - 0s - loss: 0.1152 - val_loss: 0.0811
# Epoch 382/1000
#  - 0s - loss: 0.1143 - val_loss: 0.0804
# Epoch 383/1000
#  - 0s - loss: 0.1134 - val_loss: 0.0798
# Epoch 384/1000
#  - 0s - loss: 0.1125 - val_loss: 0.0791
# Epoch 385/1000
#  - 0s - loss: 0.1116 - val_loss: 0.0785
# Epoch 386/1000
#  - 0s - loss: 0.1107 - val_loss: 0.0779
# Epoch 387/1000
#  - 0s - loss: 0.1099 - val_loss: 0.0772
# Epoch 388/1000
#  - 0s - loss: 0.1090 - val_loss: 0.0766
# Epoch 389/1000
#  - 0s - loss: 0.1081 - val_loss: 0.0760
# Epoch 390/1000
#  - 0s - loss: 0.1073 - val_loss: 0.0754
# Epoch 391/1000
#  - 0s - loss: 0.1065 - val_loss: 0.0748
# Epoch 392/1000
#  - 0s - loss: 0.1056 - val_loss: 0.0742
# Epoch 393/1000
#  - 0s - loss: 0.1048 - val_loss: 0.0736
# Epoch 394/1000
#  - 0s - loss: 0.1040 - val_loss: 0.0731
# Epoch 395/1000
#  - 0s - loss: 0.1032 - val_loss: 0.0725
# Epoch 396/1000
#  - 0s - loss: 0.1024 - val_loss: 0.0719
# Epoch 397/1000
#  - 0s - loss: 0.1016 - val_loss: 0.0714
# Epoch 398/1000
#  - 0s - loss: 0.1008 - val_loss: 0.0708
# Epoch 399/1000
#  - 0s - loss: 0.1000 - val_loss: 0.0702
# Epoch 400/1000
#  - 0s - loss: 0.0993 - val_loss: 0.0697
# Epoch 401/1000
#  - 0s - loss: 0.0985 - val_loss: 0.0692
# Epoch 402/1000
#  - 0s - loss: 0.0978 - val_loss: 0.0686
# Epoch 403/1000
#  - 0s - loss: 0.0970 - val_loss: 0.0681
# Epoch 404/1000
#  - 0s - loss: 0.0963 - val_loss: 0.0676
# Epoch 405/1000
#  - 0s - loss: 0.0956 - val_loss: 0.0671
# Epoch 406/1000
#  - 0s - loss: 0.0948 - val_loss: 0.0665
# Epoch 407/1000
#  - 0s - loss: 0.0941 - val_loss: 0.0660
# Epoch 408/1000
#  - 0s - loss: 0.0934 - val_loss: 0.0655
# Epoch 409/1000
#  - 0s - loss: 0.0927 - val_loss: 0.0650
# Epoch 410/1000
#  - 0s - loss: 0.0920 - val_loss: 0.0645
# Epoch 411/1000
#  - 0s - loss: 0.0913 - val_loss: 0.0641
# Epoch 412/1000
#  - 0s - loss: 0.0907 - val_loss: 0.0636
# Epoch 413/1000
#  - 0s - loss: 0.0900 - val_loss: 0.0631
# Epoch 414/1000
#  - 0s - loss: 0.0893 - val_loss: 0.0626
# Epoch 415/1000
#  - 0s - loss: 0.0887 - val_loss: 0.0621
# Epoch 416/1000
#  - 0s - loss: 0.0880 - val_loss: 0.0617
# Epoch 417/1000
#  - 0s - loss: 0.0874 - val_loss: 0.0612
# Epoch 418/1000
#  - 0s - loss: 0.0867 - val_loss: 0.0608
# Epoch 419/1000
#  - 0s - loss: 0.0861 - val_loss: 0.0603
# Epoch 420/1000
#  - 0s - loss: 0.0855 - val_loss: 0.0599
# Epoch 421/1000
#  - 0s - loss: 0.0848 - val_loss: 0.0594
# Epoch 422/1000
#  - 0s - loss: 0.0842 - val_loss: 0.0590
# Epoch 423/1000
#  - 0s - loss: 0.0836 - val_loss: 0.0585
# Epoch 424/1000
#  - 0s - loss: 0.0830 - val_loss: 0.0581
# Epoch 425/1000
#  - 0s - loss: 0.0824 - val_loss: 0.0577
# Epoch 426/1000
#  - 0s - loss: 0.0818 - val_loss: 0.0573
# Epoch 427/1000
#  - 0s - loss: 0.0812 - val_loss: 0.0569
# Epoch 428/1000
#  - 0s - loss: 0.0806 - val_loss: 0.0564
# Epoch 429/1000
#  - 0s - loss: 0.0801 - val_loss: 0.0560
# Epoch 430/1000
#  - 0s - loss: 0.0795 - val_loss: 0.0556
# Epoch 431/1000
#  - 0s - loss: 0.0789 - val_loss: 0.0552
# Epoch 432/1000
#  - 0s - loss: 0.0784 - val_loss: 0.0548
# Epoch 433/1000
#  - 0s - loss: 0.0778 - val_loss: 0.0544
# Epoch 434/1000
#  - 0s - loss: 0.0772 - val_loss: 0.0540
# Epoch 435/1000
#  - 0s - loss: 0.0767 - val_loss: 0.0536
# Epoch 436/1000
#  - 0s - loss: 0.0762 - val_loss: 0.0533
# Epoch 437/1000
#  - 0s - loss: 0.0756 - val_loss: 0.0529
# Epoch 438/1000
#  - 0s - loss: 0.0751 - val_loss: 0.0525
# Epoch 439/1000
#  - 0s - loss: 0.0746 - val_loss: 0.0521
# Epoch 440/1000
#  - 0s - loss: 0.0740 - val_loss: 0.0518
# Epoch 441/1000
#  - 0s - loss: 0.0735 - val_loss: 0.0514
# Epoch 442/1000
#  - 0s - loss: 0.0730 - val_loss: 0.0510
# Epoch 443/1000
#  - 0s - loss: 0.0725 - val_loss: 0.0507
# Epoch 444/1000
#  - 0s - loss: 0.0720 - val_loss: 0.0503
# Epoch 445/1000
#  - 0s - loss: 0.0715 - val_loss: 0.0499
# Epoch 446/1000
#  - 0s - loss: 0.0710 - val_loss: 0.0496
# Epoch 447/1000
#  - 0s - loss: 0.0705 - val_loss: 0.0492
# Epoch 448/1000
#  - 0s - loss: 0.0700 - val_loss: 0.0489
# Epoch 449/1000
#  - 0s - loss: 0.0696 - val_loss: 0.0486
# Epoch 450/1000
#  - 0s - loss: 0.0691 - val_loss: 0.0482
# Epoch 451/1000
#  - 0s - loss: 0.0686 - val_loss: 0.0479
# Epoch 452/1000
#  - 0s - loss: 0.0681 - val_loss: 0.0476
# Epoch 453/1000
#  - 0s - loss: 0.0677 - val_loss: 0.0472
# Epoch 454/1000
#  - 0s - loss: 0.0672 - val_loss: 0.0469
# Epoch 455/1000
#  - 0s - loss: 0.0668 - val_loss: 0.0466
# Epoch 456/1000
#  - 0s - loss: 0.0663 - val_loss: 0.0463
# Epoch 457/1000
#  - 0s - loss: 0.0659 - val_loss: 0.0459
# Epoch 458/1000
#  - 0s - loss: 0.0654 - val_loss: 0.0456
# Epoch 459/1000
#  - 0s - loss: 0.0650 - val_loss: 0.0453
# Epoch 460/1000
#  - 0s - loss: 0.0645 - val_loss: 0.0450
# Epoch 461/1000
#  - 0s - loss: 0.0641 - val_loss: 0.0447
# Epoch 462/1000
#  - 0s - loss: 0.0637 - val_loss: 0.0444
# Epoch 463/1000
#  - 0s - loss: 0.0632 - val_loss: 0.0441
# Epoch 464/1000
#  - 0s - loss: 0.0628 - val_loss: 0.0438
# Epoch 465/1000
#  - 0s - loss: 0.0624 - val_loss: 0.0435
# Epoch 466/1000
#  - 0s - loss: 0.0620 - val_loss: 0.0432
# Epoch 467/1000
#  - 0s - loss: 0.0616 - val_loss: 0.0429
# Epoch 468/1000
#  - 0s - loss: 0.0612 - val_loss: 0.0426
# Epoch 469/1000
#  - 0s - loss: 0.0608 - val_loss: 0.0423
# Epoch 470/1000
#  - 0s - loss: 0.0604 - val_loss: 0.0420
# Epoch 471/1000
#  - 0s - loss: 0.0600 - val_loss: 0.0418
# Epoch 472/1000
#  - 0s - loss: 0.0596 - val_loss: 0.0415
# Epoch 473/1000
#  - 0s - loss: 0.0592 - val_loss: 0.0412
# Epoch 474/1000
#  - 0s - loss: 0.0588 - val_loss: 0.0409
# Epoch 475/1000
#  - 0s - loss: 0.0584 - val_loss: 0.0406
# Epoch 476/1000
#  - 0s - loss: 0.0580 - val_loss: 0.0404
# Epoch 477/1000
#  - 0s - loss: 0.0576 - val_loss: 0.0401
# Epoch 478/1000
#  - 0s - loss: 0.0573 - val_loss: 0.0398
# Epoch 479/1000
#  - 0s - loss: 0.0569 - val_loss: 0.0396
# Epoch 480/1000
#  - 0s - loss: 0.0565 - val_loss: 0.0393
# Epoch 481/1000
#  - 0s - loss: 0.0562 - val_loss: 0.0391
# Epoch 482/1000
#  - 0s - loss: 0.0558 - val_loss: 0.0388
# Epoch 483/1000
#  - 0s - loss: 0.0554 - val_loss: 0.0385
# Epoch 484/1000
#  - 0s - loss: 0.0551 - val_loss: 0.0383
# Epoch 485/1000
#  - 0s - loss: 0.0547 - val_loss: 0.0380
# Epoch 486/1000
#  - 0s - loss: 0.0544 - val_loss: 0.0378
# Epoch 487/1000
#  - 0s - loss: 0.0540 - val_loss: 0.0375
# Epoch 488/1000
#  - 0s - loss: 0.0537 - val_loss: 0.0373
# Epoch 489/1000
#  - 0s - loss: 0.0533 - val_loss: 0.0370
# Epoch 490/1000
#  - 0s - loss: 0.0530 - val_loss: 0.0368
# Epoch 491/1000
#  - 0s - loss: 0.0527 - val_loss: 0.0366
# Epoch 492/1000
#  - 0s - loss: 0.0523 - val_loss: 0.0363
# Epoch 493/1000
#  - 0s - loss: 0.0520 - val_loss: 0.0361
# Epoch 494/1000
#  - 0s - loss: 0.0517 - val_loss: 0.0359
# Epoch 495/1000
#  - 0s - loss: 0.0513 - val_loss: 0.0356
# Epoch 496/1000
#  - 0s - loss: 0.0510 - val_loss: 0.0354
# Epoch 497/1000
#  - 0s - loss: 0.0507 - val_loss: 0.0352
# Epoch 498/1000
#  - 0s - loss: 0.0504 - val_loss: 0.0349
# Epoch 499/1000
#  - 0s - loss: 0.0500 - val_loss: 0.0347
# Epoch 500/1000
#  - 0s - loss: 0.0497 - val_loss: 0.0345
# Epoch 501/1000
#  - 0s - loss: 0.0494 - val_loss: 0.0343
# Epoch 502/1000
#  - 0s - loss: 0.0491 - val_loss: 0.0341
# Epoch 503/1000
#  - 0s - loss: 0.0488 - val_loss: 0.0338
# Epoch 504/1000
#  - 0s - loss: 0.0485 - val_loss: 0.0336
# Epoch 505/1000
#  - 0s - loss: 0.0482 - val_loss: 0.0334
# Epoch 506/1000
#  - 0s - loss: 0.0479 - val_loss: 0.0332
# Epoch 507/1000
#  - 0s - loss: 0.0476 - val_loss: 0.0330
# Epoch 508/1000
#  - 0s - loss: 0.0473 - val_loss: 0.0328
# Epoch 509/1000
#  - 0s - loss: 0.0470 - val_loss: 0.0326
# Epoch 510/1000
#  - 0s - loss: 0.0467 - val_loss: 0.0324
# Epoch 511/1000
#  - 0s - loss: 0.0464 - val_loss: 0.0321
# Epoch 512/1000
#  - 0s - loss: 0.0461 - val_loss: 0.0319
# Epoch 513/1000
#  - 0s - loss: 0.0458 - val_loss: 0.0317
# Epoch 514/1000
#  - 0s - loss: 0.0456 - val_loss: 0.0315
# Epoch 515/1000
#  - 0s - loss: 0.0453 - val_loss: 0.0313
# Epoch 516/1000
#  - 0s - loss: 0.0450 - val_loss: 0.0311
# Epoch 517/1000
#  - 0s - loss: 0.0447 - val_loss: 0.0310
# Epoch 518/1000
#  - 0s - loss: 0.0445 - val_loss: 0.0308
# Epoch 519/1000
#  - 0s - loss: 0.0442 - val_loss: 0.0306
# Epoch 520/1000
#  - 0s - loss: 0.0439 - val_loss: 0.0304
# Epoch 521/1000
#  - 0s - loss: 0.0436 - val_loss: 0.0302
# Epoch 522/1000
#  - 0s - loss: 0.0434 - val_loss: 0.0300
# Epoch 523/1000
#  - 0s - loss: 0.0431 - val_loss: 0.0298
# Epoch 524/1000
#  - 0s - loss: 0.0428 - val_loss: 0.0296
# Epoch 525/1000
#  - 0s - loss: 0.0426 - val_loss: 0.0294
# Epoch 526/1000
#  - 0s - loss: 0.0423 - val_loss: 0.0293
# Epoch 527/1000
#  - 0s - loss: 0.0421 - val_loss: 0.0291
# Epoch 528/1000
#  - 0s - loss: 0.0418 - val_loss: 0.0289
# Epoch 529/1000
#  - 0s - loss: 0.0416 - val_loss: 0.0287
# Epoch 530/1000
#  - 0s - loss: 0.0413 - val_loss: 0.0285
# Epoch 531/1000
#  - 0s - loss: 0.0411 - val_loss: 0.0284
# Epoch 532/1000
#  - 0s - loss: 0.0408 - val_loss: 0.0282
# Epoch 533/1000
#  - 0s - loss: 0.0406 - val_loss: 0.0280
# Epoch 534/1000
#  - 0s - loss: 0.0403 - val_loss: 0.0278
# Epoch 535/1000
#  - 0s - loss: 0.0401 - val_loss: 0.0277
# Epoch 536/1000
#  - 0s - loss: 0.0398 - val_loss: 0.0275
# Epoch 537/1000
#  - 0s - loss: 0.0396 - val_loss: 0.0273
# Epoch 538/1000
#  - 0s - loss: 0.0394 - val_loss: 0.0272
# Epoch 539/1000
#  - 0s - loss: 0.0391 - val_loss: 0.0270
# Epoch 540/1000
#  - 0s - loss: 0.0389 - val_loss: 0.0268
# Epoch 541/1000
#  - 0s - loss: 0.0387 - val_loss: 0.0267
# Epoch 542/1000
#  - 0s - loss: 0.0384 - val_loss: 0.0265
# Epoch 543/1000
#  - 0s - loss: 0.0382 - val_loss: 0.0263
# Epoch 544/1000
#  - 0s - loss: 0.0380 - val_loss: 0.0262
# Epoch 545/1000
#  - 0s - loss: 0.0377 - val_loss: 0.0260
# Epoch 546/1000
#  - 0s - loss: 0.0375 - val_loss: 0.0259
# Epoch 547/1000
#  - 0s - loss: 0.0373 - val_loss: 0.0257
# Epoch 548/1000
#  - 0s - loss: 0.0371 - val_loss: 0.0255
# Epoch 549/1000
#  - 0s - loss: 0.0369 - val_loss: 0.0254
# Epoch 550/1000
#  - 0s - loss: 0.0366 - val_loss: 0.0252
# Epoch 551/1000
#  - 0s - loss: 0.0364 - val_loss: 0.0251
# Epoch 552/1000
#  - 0s - loss: 0.0362 - val_loss: 0.0249
# Epoch 553/1000
#  - 0s - loss: 0.0360 - val_loss: 0.0248
# Epoch 554/1000
#  - 0s - loss: 0.0358 - val_loss: 0.0246
# Epoch 555/1000
#  - 0s - loss: 0.0356 - val_loss: 0.0245
# Epoch 556/1000
#  - 0s - loss: 0.0354 - val_loss: 0.0243
# Epoch 557/1000
#  - 0s - loss: 0.0352 - val_loss: 0.0242
# Epoch 558/1000
#  - 0s - loss: 0.0349 - val_loss: 0.0240
# Epoch 559/1000
#  - 0s - loss: 0.0347 - val_loss: 0.0239
# Epoch 560/1000
#  - 0s - loss: 0.0345 - val_loss: 0.0237
# Epoch 561/1000
#  - 0s - loss: 0.0343 - val_loss: 0.0236
# Epoch 562/1000
#  - 0s - loss: 0.0341 - val_loss: 0.0235
# Epoch 563/1000
#  - 0s - loss: 0.0339 - val_loss: 0.0233
# Epoch 564/1000
#  - 0s - loss: 0.0337 - val_loss: 0.0232
# Epoch 565/1000
#  - 0s - loss: 0.0335 - val_loss: 0.0230
# Epoch 566/1000
#  - 0s - loss: 0.0333 - val_loss: 0.0229
# Epoch 567/1000
#  - 0s - loss: 0.0331 - val_loss: 0.0228
# Epoch 568/1000
#  - 0s - loss: 0.0330 - val_loss: 0.0226
# Epoch 569/1000
#  - 0s - loss: 0.0328 - val_loss: 0.0225
# Epoch 570/1000
#  - 0s - loss: 0.0326 - val_loss: 0.0224
# Epoch 571/1000
#  - 0s - loss: 0.0324 - val_loss: 0.0222
# Epoch 572/1000
#  - 0s - loss: 0.0322 - val_loss: 0.0221
# Epoch 573/1000
#  - 0s - loss: 0.0320 - val_loss: 0.0220
# Epoch 574/1000
#  - 0s - loss: 0.0318 - val_loss: 0.0218
# Epoch 575/1000
#  - 0s - loss: 0.0316 - val_loss: 0.0217
# Epoch 576/1000
#  - 0s - loss: 0.0315 - val_loss: 0.0216
# Epoch 577/1000
#  - 0s - loss: 0.0313 - val_loss: 0.0215
# Epoch 578/1000
#  - 0s - loss: 0.0311 - val_loss: 0.0213
# Epoch 579/1000
#  - 0s - loss: 0.0309 - val_loss: 0.0212
# Epoch 580/1000
#  - 0s - loss: 0.0307 - val_loss: 0.0211
# Epoch 581/1000
#  - 0s - loss: 0.0306 - val_loss: 0.0209
# Epoch 582/1000
#  - 0s - loss: 0.0304 - val_loss: 0.0208
# Epoch 583/1000
#  - 0s - loss: 0.0302 - val_loss: 0.0207
# Epoch 584/1000
#  - 0s - loss: 0.0300 - val_loss: 0.0206
# Epoch 585/1000
#  - 0s - loss: 0.0299 - val_loss: 0.0205
# Epoch 586/1000
#  - 0s - loss: 0.0297 - val_loss: 0.0203
# Epoch 587/1000
#  - 0s - loss: 0.0295 - val_loss: 0.0202
# Epoch 588/1000
#  - 0s - loss: 0.0294 - val_loss: 0.0201
# Epoch 589/1000
#  - 0s - loss: 0.0292 - val_loss: 0.0200
# Epoch 590/1000
#  - 0s - loss: 0.0290 - val_loss: 0.0199
# Epoch 591/1000
#  - 0s - loss: 0.0289 - val_loss: 0.0197
# Epoch 592/1000
#  - 0s - loss: 0.0287 - val_loss: 0.0196
# Epoch 593/1000
#  - 0s - loss: 0.0285 - val_loss: 0.0195
# Epoch 594/1000
#  - 0s - loss: 0.0284 - val_loss: 0.0194
# Epoch 595/1000
#  - 0s - loss: 0.0282 - val_loss: 0.0193
# Epoch 596/1000
#  - 0s - loss: 0.0280 - val_loss: 0.0192
# Epoch 597/1000
#  - 0s - loss: 0.0279 - val_loss: 0.0191
# Epoch 598/1000
#  - 0s - loss: 0.0277 - val_loss: 0.0190
# Epoch 599/1000
#  - 0s - loss: 0.0276 - val_loss: 0.0188
# Epoch 600/1000
#  - 0s - loss: 0.0274 - val_loss: 0.0187
# Epoch 601/1000
#  - 0s - loss: 0.0273 - val_loss: 0.0186
# Epoch 602/1000
#  - 0s - loss: 0.0271 - val_loss: 0.0185
# Epoch 603/1000
#  - 0s - loss: 0.0269 - val_loss: 0.0184
# Epoch 604/1000
#  - 0s - loss: 0.0268 - val_loss: 0.0183
# Epoch 605/1000
#  - 0s - loss: 0.0266 - val_loss: 0.0182
# Epoch 606/1000
#  - 0s - loss: 0.0265 - val_loss: 0.0181
# Epoch 607/1000
#  - 0s - loss: 0.0263 - val_loss: 0.0180
# Epoch 608/1000
#  - 0s - loss: 0.0262 - val_loss: 0.0179
# Epoch 609/1000
#  - 0s - loss: 0.0260 - val_loss: 0.0178
# Epoch 610/1000
#  - 0s - loss: 0.0259 - val_loss: 0.0177
# Epoch 611/1000
#  - 0s - loss: 0.0258 - val_loss: 0.0176
# Epoch 612/1000
#  - 0s - loss: 0.0256 - val_loss: 0.0175
# Epoch 613/1000
#  - 0s - loss: 0.0255 - val_loss: 0.0174
# Epoch 614/1000
#  - 0s - loss: 0.0253 - val_loss: 0.0173
# Epoch 615/1000
#  - 0s - loss: 0.0252 - val_loss: 0.0172
# Epoch 616/1000
#  - 0s - loss: 0.0250 - val_loss: 0.0171
# Epoch 617/1000
#  - 0s - loss: 0.0249 - val_loss: 0.0170
# Epoch 618/1000
#  - 0s - loss: 0.0248 - val_loss: 0.0169
# Epoch 619/1000
#  - 0s - loss: 0.0246 - val_loss: 0.0168
# Epoch 620/1000
#  - 0s - loss: 0.0245 - val_loss: 0.0167
# Epoch 621/1000
#  - 0s - loss: 0.0243 - val_loss: 0.0166
# Epoch 622/1000
#  - 0s - loss: 0.0242 - val_loss: 0.0165
# Epoch 623/1000
#  - 0s - loss: 0.0241 - val_loss: 0.0164
# Epoch 624/1000
#  - 0s - loss: 0.0239 - val_loss: 0.0163
# Epoch 625/1000
#  - 0s - loss: 0.0238 - val_loss: 0.0162
# Epoch 626/1000
#  - 0s - loss: 0.0237 - val_loss: 0.0161
# Epoch 627/1000
#  - 0s - loss: 0.0235 - val_loss: 0.0160
# Epoch 628/1000
#  - 0s - loss: 0.0234 - val_loss: 0.0159
# Epoch 629/1000
#  - 0s - loss: 0.0233 - val_loss: 0.0158
# Epoch 630/1000
#  - 0s - loss: 0.0232 - val_loss: 0.0158
# Epoch 631/1000
#  - 0s - loss: 0.0230 - val_loss: 0.0157
# Epoch 632/1000
#  - 0s - loss: 0.0229 - val_loss: 0.0156
# Epoch 633/1000
#  - 0s - loss: 0.0228 - val_loss: 0.0155
# Epoch 634/1000
#  - 0s - loss: 0.0226 - val_loss: 0.0154
# Epoch 635/1000
#  - 0s - loss: 0.0225 - val_loss: 0.0153
# Epoch 636/1000
#  - 0s - loss: 0.0224 - val_loss: 0.0152
# Epoch 637/1000
#  - 0s - loss: 0.0223 - val_loss: 0.0151
# Epoch 638/1000
#  - 0s - loss: 0.0221 - val_loss: 0.0150
# Epoch 639/1000
#  - 0s - loss: 0.0220 - val_loss: 0.0150
# Epoch 640/1000
#  - 0s - loss: 0.0219 - val_loss: 0.0149
# Epoch 641/1000
#  - 0s - loss: 0.0218 - val_loss: 0.0148
# Epoch 642/1000
#  - 0s - loss: 0.0217 - val_loss: 0.0147
# Epoch 643/1000
#  - 0s - loss: 0.0215 - val_loss: 0.0146
# Epoch 644/1000
#  - 0s - loss: 0.0214 - val_loss: 0.0145
# Epoch 645/1000
#  - 0s - loss: 0.0213 - val_loss: 0.0145
# Epoch 646/1000
#  - 0s - loss: 0.0212 - val_loss: 0.0144
# Epoch 647/1000
#  - 0s - loss: 0.0211 - val_loss: 0.0143
# Epoch 648/1000
#  - 0s - loss: 0.0210 - val_loss: 0.0142
# Epoch 649/1000
#  - 0s - loss: 0.0208 - val_loss: 0.0141
# Epoch 650/1000
#  - 0s - loss: 0.0207 - val_loss: 0.0141
# Epoch 651/1000
#  - 0s - loss: 0.0206 - val_loss: 0.0140
# Epoch 652/1000
#  - 0s - loss: 0.0205 - val_loss: 0.0139
# Epoch 653/1000
#  - 0s - loss: 0.0204 - val_loss: 0.0138
# Epoch 654/1000
#  - 0s - loss: 0.0203 - val_loss: 0.0137
# Epoch 655/1000
#  - 0s - loss: 0.0202 - val_loss: 0.0137
# Epoch 656/1000
#  - 0s - loss: 0.0201 - val_loss: 0.0136
# Epoch 657/1000
#  - 0s - loss: 0.0199 - val_loss: 0.0135
# Epoch 658/1000
#  - 0s - loss: 0.0198 - val_loss: 0.0134
# Epoch 659/1000
#  - 0s - loss: 0.0197 - val_loss: 0.0134
# Epoch 660/1000
#  - 0s - loss: 0.0196 - val_loss: 0.0133
# Epoch 661/1000
#  - 0s - loss: 0.0195 - val_loss: 0.0132
# Epoch 662/1000
#  - 0s - loss: 0.0194 - val_loss: 0.0131
# Epoch 663/1000
#  - 0s - loss: 0.0193 - val_loss: 0.0131
# Epoch 664/1000
#  - 0s - loss: 0.0192 - val_loss: 0.0130
# Epoch 665/1000
#  - 0s - loss: 0.0191 - val_loss: 0.0129
# Epoch 666/1000
#  - 0s - loss: 0.0190 - val_loss: 0.0129
# Epoch 667/1000
#  - 0s - loss: 0.0189 - val_loss: 0.0128
# Epoch 668/1000
#  - 0s - loss: 0.0188 - val_loss: 0.0127
# Epoch 669/1000
#  - 0s - loss: 0.0187 - val_loss: 0.0126
# Epoch 670/1000
#  - 0s - loss: 0.0186 - val_loss: 0.0126
# Epoch 671/1000
#  - 0s - loss: 0.0185 - val_loss: 0.0125
# Epoch 672/1000
#  - 0s - loss: 0.0184 - val_loss: 0.0124
# Epoch 673/1000
#  - 0s - loss: 0.0183 - val_loss: 0.0124
# Epoch 674/1000
#  - 0s - loss: 0.0182 - val_loss: 0.0123
# Epoch 675/1000
#  - 0s - loss: 0.0181 - val_loss: 0.0122
# Epoch 676/1000
#  - 0s - loss: 0.0180 - val_loss: 0.0122
# Epoch 677/1000
#  - 0s - loss: 0.0179 - val_loss: 0.0121
# Epoch 678/1000
#  - 0s - loss: 0.0178 - val_loss: 0.0120
# Epoch 679/1000
#  - 0s - loss: 0.0177 - val_loss: 0.0120
# Epoch 680/1000
#  - 0s - loss: 0.0176 - val_loss: 0.0119
# Epoch 681/1000
#  - 0s - loss: 0.0175 - val_loss: 0.0118
# Epoch 682/1000
#  - 0s - loss: 0.0174 - val_loss: 0.0118
# Epoch 683/1000
#  - 0s - loss: 0.0173 - val_loss: 0.0117
# Epoch 684/1000
#  - 0s - loss: 0.0172 - val_loss: 0.0116
# Epoch 685/1000
#  - 0s - loss: 0.0171 - val_loss: 0.0116
# Epoch 686/1000
#  - 0s - loss: 0.0170 - val_loss: 0.0115
# Epoch 687/1000
#  - 0s - loss: 0.0170 - val_loss: 0.0114
# Epoch 688/1000
#  - 0s - loss: 0.0169 - val_loss: 0.0114
# Epoch 689/1000
#  - 0s - loss: 0.0168 - val_loss: 0.0113
# Epoch 690/1000
#  - 0s - loss: 0.0167 - val_loss: 0.0113
# Epoch 691/1000
#  - 0s - loss: 0.0166 - val_loss: 0.0112
# Epoch 692/1000
#  - 0s - loss: 0.0165 - val_loss: 0.0111
# Epoch 693/1000
#  - 0s - loss: 0.0164 - val_loss: 0.0111
# Epoch 694/1000
#  - 0s - loss: 0.0163 - val_loss: 0.0110
# Epoch 695/1000
#  - 0s - loss: 0.0162 - val_loss: 0.0110
# Epoch 696/1000
#  - 0s - loss: 0.0162 - val_loss: 0.0109
# Epoch 697/1000
#  - 0s - loss: 0.0161 - val_loss: 0.0108
# Epoch 698/1000
#  - 0s - loss: 0.0160 - val_loss: 0.0108
# Epoch 699/1000
#  - 0s - loss: 0.0159 - val_loss: 0.0107
# Epoch 700/1000
#  - 0s - loss: 0.0158 - val_loss: 0.0107
# Epoch 701/1000
#  - 0s - loss: 0.0157 - val_loss: 0.0106
# Epoch 702/1000
#  - 0s - loss: 0.0157 - val_loss: 0.0105
# Epoch 703/1000
#  - 0s - loss: 0.0156 - val_loss: 0.0105
# Epoch 704/1000
#  - 0s - loss: 0.0155 - val_loss: 0.0104
# Epoch 705/1000
#  - 0s - loss: 0.0154 - val_loss: 0.0104
# Epoch 706/1000
#  - 0s - loss: 0.0153 - val_loss: 0.0103
# Epoch 707/1000
#  - 0s - loss: 0.0152 - val_loss: 0.0103
# Epoch 708/1000
#  - 0s - loss: 0.0152 - val_loss: 0.0102
# Epoch 709/1000
#  - 0s - loss: 0.0151 - val_loss: 0.0101
# Epoch 710/1000
#  - 0s - loss: 0.0150 - val_loss: 0.0101
# Epoch 711/1000
#  - 0s - loss: 0.0149 - val_loss: 0.0100
# Epoch 712/1000
#  - 0s - loss: 0.0148 - val_loss: 0.0100
# Epoch 713/1000
#  - 0s - loss: 0.0148 - val_loss: 0.0099
# Epoch 714/1000
#  - 0s - loss: 0.0147 - val_loss: 0.0099
# Epoch 715/1000
#  - 0s - loss: 0.0146 - val_loss: 0.0098
# Epoch 716/1000
#  - 0s - loss: 0.0145 - val_loss: 0.0098
# Epoch 717/1000
#  - 0s - loss: 0.0145 - val_loss: 0.0097
# Epoch 718/1000
#  - 0s - loss: 0.0144 - val_loss: 0.0097
# Epoch 719/1000
#  - 0s - loss: 0.0143 - val_loss: 0.0096
# Epoch 720/1000
#  - 0s - loss: 0.0142 - val_loss: 0.0096
# Epoch 721/1000
#  - 0s - loss: 0.0142 - val_loss: 0.0095
# Epoch 722/1000
#  - 0s - loss: 0.0141 - val_loss: 0.0095
# Epoch 723/1000
#  - 0s - loss: 0.0140 - val_loss: 0.0094
# Epoch 724/1000
#  - 0s - loss: 0.0139 - val_loss: 0.0094
# Epoch 725/1000
#  - 0s - loss: 0.0139 - val_loss: 0.0093
# Epoch 726/1000
#  - 0s - loss: 0.0138 - val_loss: 0.0093
# Epoch 727/1000
#  - 0s - loss: 0.0137 - val_loss: 0.0092
# Epoch 728/1000
#  - 0s - loss: 0.0137 - val_loss: 0.0092
# Epoch 729/1000
#  - 0s - loss: 0.0136 - val_loss: 0.0091
# Epoch 730/1000
#  - 0s - loss: 0.0135 - val_loss: 0.0091
# Epoch 731/1000
#  - 0s - loss: 0.0134 - val_loss: 0.0090
# Epoch 732/1000
#  - 0s - loss: 0.0134 - val_loss: 0.0090
# Epoch 733/1000
#  - 0s - loss: 0.0133 - val_loss: 0.0089
# Epoch 734/1000
#  - 0s - loss: 0.0132 - val_loss: 0.0089
# Epoch 735/1000
#  - 0s - loss: 0.0132 - val_loss: 0.0088
# Epoch 736/1000
#  - 0s - loss: 0.0131 - val_loss: 0.0088
# Epoch 737/1000
#  - 0s - loss: 0.0130 - val_loss: 0.0087
# Epoch 738/1000
#  - 0s - loss: 0.0130 - val_loss: 0.0087
# Epoch 739/1000
#  - 0s - loss: 0.0129 - val_loss: 0.0086
# Epoch 740/1000
#  - 0s - loss: 0.0128 - val_loss: 0.0086
# Epoch 741/1000
#  - 0s - loss: 0.0128 - val_loss: 0.0086
# Epoch 742/1000
#  - 0s - loss: 0.0127 - val_loss: 0.0085
# Epoch 743/1000
#  - 0s - loss: 0.0126 - val_loss: 0.0085
# Epoch 744/1000
#  - 0s - loss: 0.0126 - val_loss: 0.0084
# Epoch 745/1000
#  - 0s - loss: 0.0125 - val_loss: 0.0084
# Epoch 746/1000
#  - 0s - loss: 0.0124 - val_loss: 0.0083
# Epoch 747/1000
#  - 0s - loss: 0.0124 - val_loss: 0.0083
# Epoch 748/1000
#  - 0s - loss: 0.0123 - val_loss: 0.0082
# Epoch 749/1000
#  - 0s - loss: 0.0122 - val_loss: 0.0082
# Epoch 750/1000
#  - 0s - loss: 0.0122 - val_loss: 0.0082
# Epoch 751/1000
#  - 0s - loss: 0.0121 - val_loss: 0.0081
# Epoch 752/1000
#  - 0s - loss: 0.0121 - val_loss: 0.0081
# Epoch 753/1000
#  - 0s - loss: 0.0120 - val_loss: 0.0080
# Epoch 754/1000
#  - 0s - loss: 0.0119 - val_loss: 0.0080
# Epoch 755/1000
#  - 0s - loss: 0.0119 - val_loss: 0.0079
# Epoch 756/1000
#  - 0s - loss: 0.0118 - val_loss: 0.0079
# Epoch 757/1000
#  - 0s - loss: 0.0118 - val_loss: 0.0079
# Epoch 758/1000
#  - 0s - loss: 0.0117 - val_loss: 0.0078
# Epoch 759/1000
#  - 0s - loss: 0.0116 - val_loss: 0.0078
# Epoch 760/1000
#  - 0s - loss: 0.0116 - val_loss: 0.0077
# Epoch 761/1000
#  - 0s - loss: 0.0115 - val_loss: 0.0077
# Epoch 762/1000
#  - 0s - loss: 0.0115 - val_loss: 0.0077
# Epoch 763/1000
#  - 0s - loss: 0.0114 - val_loss: 0.0076
# Epoch 764/1000
#  - 0s - loss: 0.0113 - val_loss: 0.0076
# Epoch 765/1000
#  - 0s - loss: 0.0113 - val_loss: 0.0075
# Epoch 766/1000
#  - 0s - loss: 0.0112 - val_loss: 0.0075
# Epoch 767/1000
#  - 0s - loss: 0.0112 - val_loss: 0.0075
# Epoch 768/1000
#  - 0s - loss: 0.0111 - val_loss: 0.0074
# Epoch 769/1000
#  - 0s - loss: 0.0111 - val_loss: 0.0074
# Epoch 770/1000
#  - 0s - loss: 0.0110 - val_loss: 0.0074
# Epoch 771/1000
#  - 0s - loss: 0.0109 - val_loss: 0.0073
# Epoch 772/1000
#  - 0s - loss: 0.0109 - val_loss: 0.0073
# Epoch 773/1000
#  - 0s - loss: 0.0108 - val_loss: 0.0072
# Epoch 774/1000
#  - 0s - loss: 0.0108 - val_loss: 0.0072
# Epoch 775/1000
#  - 0s - loss: 0.0107 - val_loss: 0.0072
# Epoch 776/1000
#  - 0s - loss: 0.0107 - val_loss: 0.0071
# Epoch 777/1000
#  - 0s - loss: 0.0106 - val_loss: 0.0071
# Epoch 778/1000
#  - 0s - loss: 0.0106 - val_loss: 0.0071
# Epoch 779/1000
#  - 0s - loss: 0.0105 - val_loss: 0.0070
# Epoch 780/1000
#  - 0s - loss: 0.0105 - val_loss: 0.0070
# Epoch 781/1000
#  - 0s - loss: 0.0104 - val_loss: 0.0070
# Epoch 782/1000
#  - 0s - loss: 0.0104 - val_loss: 0.0069
# Epoch 783/1000
#  - 0s - loss: 0.0103 - val_loss: 0.0069
# Epoch 784/1000
#  - 0s - loss: 0.0103 - val_loss: 0.0068
# Epoch 785/1000
#  - 0s - loss: 0.0102 - val_loss: 0.0068
# Epoch 786/1000
#  - 0s - loss: 0.0102 - val_loss: 0.0068
# Epoch 787/1000
#  - 0s - loss: 0.0101 - val_loss: 0.0067
# Epoch 788/1000
#  - 0s - loss: 0.0101 - val_loss: 0.0067
# Epoch 789/1000
#  - 0s - loss: 0.0100 - val_loss: 0.0067
# Epoch 790/1000
#  - 0s - loss: 0.0100 - val_loss: 0.0066
# Epoch 791/1000
#  - 0s - loss: 0.0099 - val_loss: 0.0066
# Epoch 792/1000
#  - 0s - loss: 0.0099 - val_loss: 0.0066
# Epoch 793/1000
#  - 0s - loss: 0.0098 - val_loss: 0.0065
# Epoch 794/1000
#  - 0s - loss: 0.0098 - val_loss: 0.0065
# Epoch 795/1000
#  - 0s - loss: 0.0097 - val_loss: 0.0065
# Epoch 796/1000
#  - 0s - loss: 0.0097 - val_loss: 0.0064
# Epoch 797/1000
#  - 0s - loss: 0.0096 - val_loss: 0.0064
# Epoch 798/1000
#  - 0s - loss: 0.0096 - val_loss: 0.0064
# Epoch 799/1000
#  - 0s - loss: 0.0095 - val_loss: 0.0063
# Epoch 800/1000
#  - 0s - loss: 0.0095 - val_loss: 0.0063
# Epoch 801/1000
#  - 0s - loss: 0.0094 - val_loss: 0.0063
# Epoch 802/1000
#  - 0s - loss: 0.0094 - val_loss: 0.0063
# Epoch 803/1000
#  - 0s - loss: 0.0093 - val_loss: 0.0062
# Epoch 804/1000
#  - 0s - loss: 0.0093 - val_loss: 0.0062
# Epoch 805/1000
#  - 0s - loss: 0.0092 - val_loss: 0.0062
# Epoch 806/1000
#  - 0s - loss: 0.0092 - val_loss: 0.0061
# Epoch 807/1000
#  - 0s - loss: 0.0092 - val_loss: 0.0061
# Epoch 808/1000
#  - 0s - loss: 0.0091 - val_loss: 0.0061
# Epoch 809/1000
#  - 0s - loss: 0.0091 - val_loss: 0.0060
# Epoch 810/1000
#  - 0s - loss: 0.0090 - val_loss: 0.0060
# Epoch 811/1000
#  - 0s - loss: 0.0090 - val_loss: 0.0060
# Epoch 812/1000
#  - 0s - loss: 0.0089 - val_loss: 0.0060
# Epoch 813/1000
#  - 0s - loss: 0.0089 - val_loss: 0.0059
# Epoch 814/1000
#  - 0s - loss: 0.0088 - val_loss: 0.0059
# Epoch 815/1000
#  - 0s - loss: 0.0088 - val_loss: 0.0059
# Epoch 816/1000
#  - 0s - loss: 0.0088 - val_loss: 0.0058
# Epoch 817/1000
#  - 0s - loss: 0.0087 - val_loss: 0.0058
# Epoch 818/1000
#  - 0s - loss: 0.0087 - val_loss: 0.0058
# Epoch 819/1000
#  - 0s - loss: 0.0086 - val_loss: 0.0057
# Epoch 820/1000
#  - 0s - loss: 0.0086 - val_loss: 0.0057
# Epoch 821/1000
#  - 0s - loss: 0.0085 - val_loss: 0.0057
# Epoch 822/1000
#  - 0s - loss: 0.0085 - val_loss: 0.0057
# Epoch 823/1000
#  - 0s - loss: 0.0085 - val_loss: 0.0056
# Epoch 824/1000
#  - 0s - loss: 0.0084 - val_loss: 0.0056
# Epoch 825/1000
#  - 0s - loss: 0.0084 - val_loss: 0.0056
# Epoch 826/1000
#  - 0s - loss: 0.0083 - val_loss: 0.0056
# Epoch 827/1000
#  - 0s - loss: 0.0083 - val_loss: 0.0055
# Epoch 828/1000
#  - 0s - loss: 0.0083 - val_loss: 0.0055
# Epoch 829/1000
#  - 0s - loss: 0.0082 - val_loss: 0.0055
# Epoch 830/1000
#  - 0s - loss: 0.0082 - val_loss: 0.0055
# Epoch 831/1000
#  - 0s - loss: 0.0081 - val_loss: 0.0054
# Epoch 832/1000
#  - 0s - loss: 0.0081 - val_loss: 0.0054
# Epoch 833/1000
#  - 0s - loss: 0.0081 - val_loss: 0.0054
# Epoch 834/1000
#  - 0s - loss: 0.0080 - val_loss: 0.0053
# Epoch 835/1000
#  - 0s - loss: 0.0080 - val_loss: 0.0053
# Epoch 836/1000
#  - 0s - loss: 0.0080 - val_loss: 0.0053
# Epoch 837/1000
#  - 0s - loss: 0.0079 - val_loss: 0.0053
# Epoch 838/1000
#  - 0s - loss: 0.0079 - val_loss: 0.0052
# Epoch 839/1000
#  - 0s - loss: 0.0078 - val_loss: 0.0052
# Epoch 840/1000
#  - 0s - loss: 0.0078 - val_loss: 0.0052
# Epoch 841/1000
#  - 0s - loss: 0.0078 - val_loss: 0.0052
# Epoch 842/1000
#  - 0s - loss: 0.0077 - val_loss: 0.0051
# Epoch 843/1000
#  - 0s - loss: 0.0077 - val_loss: 0.0051
# Epoch 844/1000
#  - 0s - loss: 0.0077 - val_loss: 0.0051
# Epoch 845/1000
#  - 0s - loss: 0.0076 - val_loss: 0.0051
# Epoch 846/1000
#  - 0s - loss: 0.0076 - val_loss: 0.0050
# Epoch 847/1000
#  - 0s - loss: 0.0076 - val_loss: 0.0050
# Epoch 848/1000
#  - 0s - loss: 0.0075 - val_loss: 0.0050
# Epoch 849/1000
#  - 0s - loss: 0.0075 - val_loss: 0.0050
# Epoch 850/1000
#  - 0s - loss: 0.0074 - val_loss: 0.0050
# Epoch 851/1000
#  - 0s - loss: 0.0074 - val_loss: 0.0049
# Epoch 852/1000
#  - 0s - loss: 0.0074 - val_loss: 0.0049
# Epoch 853/1000
#  - 0s - loss: 0.0073 - val_loss: 0.0049
# Epoch 854/1000
#  - 0s - loss: 0.0073 - val_loss: 0.0049
# Epoch 855/1000
#  - 0s - loss: 0.0073 - val_loss: 0.0048
# Epoch 856/1000
#  - 0s - loss: 0.0072 - val_loss: 0.0048
# Epoch 857/1000
#  - 0s - loss: 0.0072 - val_loss: 0.0048
# Epoch 858/1000
#  - 0s - loss: 0.0072 - val_loss: 0.0048
# Epoch 859/1000
#  - 0s - loss: 0.0071 - val_loss: 0.0048
# Epoch 860/1000
#  - 0s - loss: 0.0071 - val_loss: 0.0047
# Epoch 861/1000
#  - 0s - loss: 0.0071 - val_loss: 0.0047
# Epoch 862/1000
#  - 0s - loss: 0.0070 - val_loss: 0.0047
# Epoch 863/1000
#  - 0s - loss: 0.0070 - val_loss: 0.0047
# Epoch 864/1000
#  - 0s - loss: 0.0070 - val_loss: 0.0046
# Epoch 865/1000
#  - 0s - loss: 0.0069 - val_loss: 0.0046
# Epoch 866/1000
#  - 0s - loss: 0.0069 - val_loss: 0.0046
# Epoch 867/1000
#  - 0s - loss: 0.0069 - val_loss: 0.0046
# Epoch 868/1000
#  - 0s - loss: 0.0068 - val_loss: 0.0046
# Epoch 869/1000
#  - 0s - loss: 0.0068 - val_loss: 0.0045
# Epoch 870/1000
#  - 0s - loss: 0.0068 - val_loss: 0.0045
# Epoch 871/1000
#  - 0s - loss: 0.0068 - val_loss: 0.0045
# Epoch 872/1000
#  - 0s - loss: 0.0067 - val_loss: 0.0045
# Epoch 873/1000
#  - 0s - loss: 0.0067 - val_loss: 0.0045
# Epoch 874/1000
#  - 0s - loss: 0.0067 - val_loss: 0.0044
# Epoch 875/1000
#  - 0s - loss: 0.0066 - val_loss: 0.0044
# Epoch 876/1000
#  - 0s - loss: 0.0066 - val_loss: 0.0044
# Epoch 877/1000
#  - 0s - loss: 0.0066 - val_loss: 0.0044
# Epoch 878/1000
#  - 0s - loss: 0.0065 - val_loss: 0.0044
# Epoch 879/1000
#  - 0s - loss: 0.0065 - val_loss: 0.0043
# Epoch 880/1000
#  - 0s - loss: 0.0065 - val_loss: 0.0043
# Epoch 881/1000
#  - 0s - loss: 0.0065 - val_loss: 0.0043
# Epoch 882/1000
#  - 0s - loss: 0.0064 - val_loss: 0.0043
# Epoch 883/1000
#  - 0s - loss: 0.0064 - val_loss: 0.0043
# Epoch 884/1000
#  - 0s - loss: 0.0064 - val_loss: 0.0042
# Epoch 885/1000
#  - 0s - loss: 0.0063 - val_loss: 0.0042
# Epoch 886/1000
#  - 0s - loss: 0.0063 - val_loss: 0.0042
# Epoch 887/1000
#  - 0s - loss: 0.0063 - val_loss: 0.0042
# Epoch 888/1000
#  - 0s - loss: 0.0063 - val_loss: 0.0042
# Epoch 889/1000
#  - 0s - loss: 0.0062 - val_loss: 0.0041
# Epoch 890/1000
#  - 0s - loss: 0.0062 - val_loss: 0.0041
# Epoch 891/1000
#  - 0s - loss: 0.0062 - val_loss: 0.0041
# Epoch 892/1000
#  - 0s - loss: 0.0061 - val_loss: 0.0041
# Epoch 893/1000
#  - 0s - loss: 0.0061 - val_loss: 0.0041
# Epoch 894/1000
#  - 0s - loss: 0.0061 - val_loss: 0.0041
# Epoch 895/1000
#  - 0s - loss: 0.0061 - val_loss: 0.0040
# Epoch 896/1000
#  - 0s - loss: 0.0060 - val_loss: 0.0040
# Epoch 897/1000
#  - 0s - loss: 0.0060 - val_loss: 0.0040
# Epoch 898/1000
#  - 0s - loss: 0.0060 - val_loss: 0.0040
# Epoch 899/1000
#  - 0s - loss: 0.0060 - val_loss: 0.0040
# Epoch 900/1000
#  - 0s - loss: 0.0059 - val_loss: 0.0040
# Epoch 901/1000
#  - 0s - loss: 0.0059 - val_loss: 0.0039
# Epoch 902/1000
#  - 0s - loss: 0.0059 - val_loss: 0.0039
# Epoch 903/1000
#  - 0s - loss: 0.0059 - val_loss: 0.0039
# Epoch 904/1000
#  - 0s - loss: 0.0058 - val_loss: 0.0039
# Epoch 905/1000
#  - 0s - loss: 0.0058 - val_loss: 0.0039
# Epoch 906/1000
#  - 0s - loss: 0.0058 - val_loss: 0.0039
# Epoch 907/1000
#  - 0s - loss: 0.0058 - val_loss: 0.0038
# Epoch 908/1000
#  - 0s - loss: 0.0057 - val_loss: 0.0038
# Epoch 909/1000
#  - 0s - loss: 0.0057 - val_loss: 0.0038
# Epoch 910/1000
#  - 0s - loss: 0.0057 - val_loss: 0.0038
# Epoch 911/1000
#  - 0s - loss: 0.0057 - val_loss: 0.0038
# Epoch 912/1000
#  - 0s - loss: 0.0056 - val_loss: 0.0038
# Epoch 913/1000
#  - 0s - loss: 0.0056 - val_loss: 0.0037
# Epoch 914/1000
#  - 0s - loss: 0.0056 - val_loss: 0.0037
# Epoch 915/1000
#  - 0s - loss: 0.0056 - val_loss: 0.0037
# Epoch 916/1000
#  - 0s - loss: 0.0055 - val_loss: 0.0037
# Epoch 917/1000
#  - 0s - loss: 0.0055 - val_loss: 0.0037
# Epoch 918/1000
#  - 0s - loss: 0.0055 - val_loss: 0.0037
# Epoch 919/1000
#  - 0s - loss: 0.0055 - val_loss: 0.0036
# Epoch 920/1000
#  - 0s - loss: 0.0054 - val_loss: 0.0036
# Epoch 921/1000
#  - 0s - loss: 0.0054 - val_loss: 0.0036
# Epoch 922/1000
#  - 0s - loss: 0.0054 - val_loss: 0.0036
# Epoch 923/1000
#  - 0s - loss: 0.0054 - val_loss: 0.0036
# Epoch 924/1000
#  - 0s - loss: 0.0054 - val_loss: 0.0036
# Epoch 925/1000
#  - 0s - loss: 0.0053 - val_loss: 0.0036
# Epoch 926/1000
#  - 0s - loss: 0.0053 - val_loss: 0.0035
# Epoch 927/1000
#  - 0s - loss: 0.0053 - val_loss: 0.0035
# Epoch 928/1000
#  - 0s - loss: 0.0053 - val_loss: 0.0035
# Epoch 929/1000
#  - 0s - loss: 0.0052 - val_loss: 0.0035
# Epoch 930/1000
#  - 0s - loss: 0.0052 - val_loss: 0.0035
# Epoch 931/1000
#  - 0s - loss: 0.0052 - val_loss: 0.0035
# Epoch 932/1000
#  - 0s - loss: 0.0052 - val_loss: 0.0035
# Epoch 933/1000
#  - 0s - loss: 0.0052 - val_loss: 0.0034
# Epoch 934/1000
#  - 0s - loss: 0.0051 - val_loss: 0.0034
# Epoch 935/1000
#  - 0s - loss: 0.0051 - val_loss: 0.0034
# Epoch 936/1000
#  - 0s - loss: 0.0051 - val_loss: 0.0034
# Epoch 937/1000
#  - 0s - loss: 0.0051 - val_loss: 0.0034
# Epoch 938/1000
#  - 0s - loss: 0.0050 - val_loss: 0.0034
# Epoch 939/1000
#  - 0s - loss: 0.0050 - val_loss: 0.0034
# Epoch 940/1000
#  - 0s - loss: 0.0050 - val_loss: 0.0033
# Epoch 941/1000
#  - 0s - loss: 0.0050 - val_loss: 0.0033
# Epoch 942/1000
#  - 0s - loss: 0.0050 - val_loss: 0.0033
# Epoch 943/1000
#  - 0s - loss: 0.0049 - val_loss: 0.0033
# Epoch 944/1000
#  - 0s - loss: 0.0049 - val_loss: 0.0033
# Epoch 945/1000
#  - 0s - loss: 0.0049 - val_loss: 0.0033
# Epoch 946/1000
#  - 0s - loss: 0.0049 - val_loss: 0.0033
# Epoch 947/1000
#  - 0s - loss: 0.0049 - val_loss: 0.0032
# Epoch 948/1000
#  - 0s - loss: 0.0048 - val_loss: 0.0032
# Epoch 949/1000
#  - 0s - loss: 0.0048 - val_loss: 0.0032
# Epoch 950/1000
#  - 0s - loss: 0.0048 - val_loss: 0.0032
# Epoch 951/1000
#  - 0s - loss: 0.0048 - val_loss: 0.0032
# Epoch 952/1000
#  - 0s - loss: 0.0048 - val_loss: 0.0032
# Epoch 953/1000
#  - 0s - loss: 0.0047 - val_loss: 0.0032
# Epoch 954/1000
#  - 0s - loss: 0.0047 - val_loss: 0.0032
# Epoch 955/1000
#  - 0s - loss: 0.0047 - val_loss: 0.0031
# Epoch 956/1000
#  - 0s - loss: 0.0047 - val_loss: 0.0031
# Epoch 957/1000
#  - 0s - loss: 0.0047 - val_loss: 0.0031
# Epoch 958/1000
#  - 0s - loss: 0.0047 - val_loss: 0.0031
# Epoch 959/1000
#  - 0s - loss: 0.0046 - val_loss: 0.0031
# Epoch 960/1000
#  - 0s - loss: 0.0046 - val_loss: 0.0031
# Epoch 961/1000
#  - 0s - loss: 0.0046 - val_loss: 0.0031
# Epoch 962/1000
#  - 0s - loss: 0.0046 - val_loss: 0.0031
# Epoch 963/1000
#  - 0s - loss: 0.0046 - val_loss: 0.0031
# Epoch 964/1000
#  - 0s - loss: 0.0045 - val_loss: 0.0030
# Epoch 965/1000
#  - 0s - loss: 0.0045 - val_loss: 0.0030
# Epoch 966/1000
#  - 0s - loss: 0.0045 - val_loss: 0.0030
# Epoch 967/1000
#  - 0s - loss: 0.0045 - val_loss: 0.0030
# Epoch 968/1000
#  - 0s - loss: 0.0045 - val_loss: 0.0030
# Epoch 969/1000
#  - 0s - loss: 0.0045 - val_loss: 0.0030
# Epoch 970/1000
#  - 0s - loss: 0.0044 - val_loss: 0.0030
# Epoch 971/1000
#  - 0s - loss: 0.0044 - val_loss: 0.0030
# Epoch 972/1000
#  - 0s - loss: 0.0044 - val_loss: 0.0030
# Epoch 973/1000
#  - 0s - loss: 0.0044 - val_loss: 0.0029
# Epoch 974/1000
#  - 0s - loss: 0.0044 - val_loss: 0.0029
# Epoch 975/1000
#  - 0s - loss: 0.0044 - val_loss: 0.0029
# Epoch 976/1000
#  - 0s - loss: 0.0043 - val_loss: 0.0029
# Epoch 977/1000
#  - 0s - loss: 0.0043 - val_loss: 0.0029
# Epoch 978/1000
#  - 0s - loss: 0.0043 - val_loss: 0.0029
# Epoch 979/1000
#  - 0s - loss: 0.0043 - val_loss: 0.0029
# Epoch 980/1000
#  - 0s - loss: 0.0043 - val_loss: 0.0029
# Epoch 981/1000
#  - 0s - loss: 0.0043 - val_loss: 0.0029
# Epoch 982/1000
#  - 0s - loss: 0.0042 - val_loss: 0.0028
# Epoch 983/1000
#  - 0s - loss: 0.0042 - val_loss: 0.0028
# Epoch 984/1000
#  - 0s - loss: 0.0042 - val_loss: 0.0028
# Epoch 985/1000
#  - 0s - loss: 0.0042 - val_loss: 0.0028
# Epoch 986/1000
#  - 0s - loss: 0.0042 - val_loss: 0.0028
# Epoch 987/1000
#  - 0s - loss: 0.0042 - val_loss: 0.0028
# Epoch 988/1000
#  - 0s - loss: 0.0041 - val_loss: 0.0028
# Epoch 989/1000
#  - 0s - loss: 0.0041 - val_loss: 0.0028
# Epoch 990/1000
#  - 0s - loss: 0.0041 - val_loss: 0.0028
# Epoch 991/1000
#  - 0s - loss: 0.0041 - val_loss: 0.0028
# Epoch 992/1000
#  - 0s - loss: 0.0041 - val_loss: 0.0027
# Epoch 993/1000
#  - 0s - loss: 0.0041 - val_loss: 0.0027
# Epoch 994/1000
#  - 0s - loss: 0.0041 - val_loss: 0.0027
# Epoch 995/1000
#  - 0s - loss: 0.0040 - val_loss: 0.0027
# Epoch 996/1000
#  - 0s - loss: 0.0040 - val_loss: 0.0027
# Epoch 997/1000
#  - 0s - loss: 0.0040 - val_loss: 0.0027
# Epoch 998/1000
#  - 0s - loss: 0.0040 - val_loss: 0.0027
# Epoch 999/1000
#  - 0s - loss: 0.0040 - val_loss: 0.0027
# Epoch 1000/1000
#  - 0s - loss: 0.0040 - val_loss: 0.0027

# %%
plot_loss(history)

# %% [markdown]
# ## Training Data

# %%
# Generate predictions

model = load_model("%s.h5" % (model_name))
                
reconstructed = model.predict(np.array(x_train))

error = abs(x_train-reconstructed)/x_train

# %%
error_reformat = []
for i in range(4):
    error_reformat.append([])

for i in range(len(error)):
    for j in range(4):
        if i == len(error)-1:
            for val in error[i][WINDOW*j:WINDOW+WINDOW*j]:
                error_reformat[j].append(val)
        else:
            error_reformat[j].append(error[i][WINDOW*j])
            
inp = []
outp = []
for i in range(4):
    inp.append([])
    outp.append([])
    
for i in range(len(reconstructed)):
    for j in range(4):
        if i == len(reconstructed)-1:
            for val in reconstructed[i][WINDOW*j:WINDOW+WINDOW*j]:
                outp[j].append(val)
            for val in x_train[i][WINDOW*j:WINDOW+WINDOW*j]:
                inp[j].append(val)
        else:
            outp[j].append(reconstructed[i][WINDOW*j])
            inp[j].append(x_train[i][WINDOW*j])

# %%
labels = data['HLT']

#bins = np.linspace(0,1,50)
bins = 50
plt.figure(figsize=[20,10])
for i in range(len(error_reformat)):
    plt.subplot(2,2,i+1)
    plt.hist(error_reformat[i],bins=bins,label=labels[i],alpha=.5)
    plt.legend()

lumi = data[str(runs[0])]['lumiid'] 
#lumi = np.linspace(0,len(error_reformat[0]),len(error_reformat[0]))
plt.figure(figsize=[20,10])
for i in range(0,4):
    plt.subplot(2,2,i+1)
    plt.scatter(lumi,error_reformat[i],label=labels[i],alpha=.5)
    plt.xlabel('lumi id')
    plt.ylabel('error')
    plt.legend()    

plt.show()

# %%
plt.figure(figsize=[10,10])
for i in range(0,4):
    plt.subplot(2,2,i+1)
    plt.plot(outp[i],inp[i],label=labels[i], linestyle='',marker='o', markersize=3, alpha=0.5)
    #plt.scatter(lumi,outp[i],label='output',alpha=.5)
    plt.xlabel('index')
    plt.ylabel('value')
    #plt.xlim(0,1.8)
    #plt.ylim(0,1.8)
    plt.legend()    

plt.show()

# %% [markdown]
# ## Test Data

# %%
# Generate predictions

model = load_model("%s.h5" % (model_name))

x_test_new = []
for l in x_test:
    if not 0 in l:
        x_test_new.append(l)
                
reconstructed = model.predict(np.array(x_test_new))

error = abs(x_test_new-reconstructed)/x_test_new

# %%
error_reformat = []
for i in range(4):
    error_reformat.append([])

for i in range(len(error)):
    for j in range(4):
        if i == len(error)-1:
            for val in error[i][WINDOW*j:WINDOW+WINDOW*j]:
                error_reformat[j].append(val)
        else:
            error_reformat[j].append(error[i][WINDOW*j])
            
inp = []
outp = []
for i in range(4):
    inp.append([])
    outp.append([])
    
for i in range(len(reconstructed)):
    for j in range(4):
        if i == len(reconstructed)-1:
            for val in reconstructed[i][WINDOW*j:WINDOW+WINDOW*j]:
                outp[j].append(val)
            for val in x_test_new[i][WINDOW*j:WINDOW+WINDOW*j]:
                inp[j].append(val)
        else:
            outp[j].append(reconstructed[i][WINDOW*j])
            inp[j].append(x_test_new[i][WINDOW*j])

# %%
labels = data['HLT']

#bins = np.linspace(0,1,50)
bins = 50
plt.figure(figsize=[20,10])
for i in range(len(error_reformat)):
    plt.subplot(2,2,i+1)
    plt.hist(error_reformat[i],bins=bins,label=labels[i],alpha=.5)
    plt.legend()

lumi = data[str(runs[2])]['lumiid'] 
#lumi = np.linspace(0,len(error_reformat[0]),len(error_reformat[0]))
plt.figure(figsize=[20,10])
for i in range(0,4):
    plt.subplot(2,2,i+1)
    plt.scatter(lumi,error_reformat[i],label=labels[i],alpha=.5)
    plt.xlabel('lumi id')
    plt.ylabel('error')
    plt.legend()    

plt.show()

# %%
plt.figure(figsize=[10,10])
for i in range(0,4):
    plt.subplot(2,2,i+1)
    plt.plot(outp[i],inp[i],label=labels[i], linestyle='',marker='o', markersize=3, alpha=0.5)
    #plt.scatter(lumi,outp[i],label='output',alpha=.5)
    plt.xlabel('index')
    plt.ylabel('value')
    #plt.xlim(0,1.8)
    #plt.ylim(0,1.8)
    plt.legend()    

plt.show()

# %%
# plt.figure(figsize=[20,10])
# for i in range(0,4):
#     plt.subplot(2,2,i+1)
#     plt.scatter(lumi,inp[i],label='input',alpha=.5)
#     plt.scatter(lumi,outp[i]/max(outp[i]),label='output',alpha=.5)
#     plt.xlabel('index')
#     plt.ylabel('value')
#     plt.legend()    

# plt.show()

# %%
# for i in range(len(outp)):
#     for j in range(i+1,len(outp)):
#         print(sum(np.array(outp[i]/max(outp[i]))-np.array(outp[j]/max(outp[j]))))

# %% [markdown]
# ## Fake Bad Data

# %%
bad = np.array(data[str(runs[2])]['bad_samples'])

# %%
bad_new = []
for l in bad:
    if not 0 in l:
        bad_new.append(l)
                
reconstructed_bad = model.predict(np.array(bad_new))

error_bad = abs(bad_new-reconstructed_bad)/bad_new

# %%
error_reformat_bad = []
for i in range(4):
    error_reformat_bad.append([])

for i in range(len(error_bad)):
    for j in range(4):
        if i == len(error_bad)-1:
            for val in error_bad[i][WINDOW*j:WINDOW+WINDOW*j]:
                error_reformat_bad[j].append(val)
        else:
            error_reformat_bad[j].append(error_bad[i][WINDOW*j])
            
inp_bad = []
outp_bad = []
for i in range(4):
    inp_bad.append([])
    outp_bad.append([])
    
for i in range(len(reconstructed_bad)):
    for j in range(4):
        if i == len(reconstructed_bad)-1:
            for val in reconstructed_bad[i][WINDOW*j:WINDOW+WINDOW*j]:
                outp_bad[j].append(val)
            for val in bad_new[i][WINDOW*j:WINDOW+WINDOW*j]:
                inp_bad[j].append(val)
        else:
            outp_bad[j].append(reconstructed_bad[i][WINDOW*j])
            inp_bad[j].append(bad_new[i][WINDOW*j])

# %%
labels = data['HLT']

#bins = np.linspace(0,1,50)
bins = 50
plt.figure(figsize=[20,10])
for i in range(len(error_reformat_bad)):
    plt.subplot(2,2,i+1)
    plt.hist(error_reformat[i],bins=bins,label='good',alpha=.5)
    plt.hist(error_reformat_bad[i],bins=bins,label='fake bad',alpha=.5)
    plt.legend()
    plt.title(labels[i])

lumi = data[str(runs[2])]['lumiid'] 
print(len(error_reformat_bad[0]),len(lumi))
#lumi = np.linspace(0,len(error_reformat_bad[0]),len(error_reformat_bad[0]))
plt.figure(figsize=[20,10])
for i in range(0,4):
    plt.subplot(2,2,i+1)
    plt.scatter(lumi,error_reformat[i],label = 'good', alpha =.5)
    plt.scatter(lumi,error_reformat_bad[i],label='fake bad',alpha=.5)
    plt.xlabel('lumi id')
    plt.ylabel('error')
    plt.legend()    
    plt.title(labels[i])

plt.show()
# Out:
# 1224 1224

# %%
plt.figure(figsize=[10,10])
for i in range(0,4):
    plt.subplot(2,2,i+1)
    plt.plot(outp_bad[i],inp_bad[i],label=labels[i], linestyle='',marker='o', markersize=3, alpha=0.5)
    plt.xlabel('index')
    plt.ylabel('value')
    #plt.xlim(0,2)
    #plt.ylim(0,2)
    plt.legend()    

plt.show()

# %%
# plt.figure(figsize=[20,10])
# for i in range(0,4):
#     plt.subplot(2,2,i+1)
#     plt.scatter(lumi,inp_bad[i],label='inp_badut',alpha=.5)
#     plt.scatter(lumi,outp_bad[i]/max(outp_bad[i]),label='outp_badut',alpha=.5)
#     plt.xlabel('index')
#     plt.ylabel('value')
#     plt.legend()    

# plt.show()

# %%
# labels = data['HLT']

# #bins = np.linspace(0,1,50)
# bins = 50
# plt.figure(figsize=[20,10])
# for i in range(len(error_reformat_bad)):
#     plt.subplot(2,2,i+1)
#     plt.hist(error_reformat_bad[i],bins=bins,label='bad',alpha=.5)
#     plt.hist(error_reformat[i],bins=bins,label='good',alpha=.5)
#     plt.legend()

# # lumi = data[str(runs[0])]['lumiid'] 
# # print(len(error_reformat_bad[0]),len(lumi))
# # #lumi = np.linspace(0,len(error_reformat_bad[0]),len(error_reformat_bad[0]))
# # plt.figure(figsize=[20,10])
# # for i in range(0,4):
# #     plt.subplot(2,2,i+1)
# #     plt.scatter(lumi,error_reformat_bad[i],label='bad',alpha=.5)
# #     plt.scatter(lumi,error_reformat[i],label='good',alpha=.5)
# #     plt.xlabel('lumi id')
# #     plt.ylabel('error')
# #     plt.legend()    

# plt.show()

# %% [markdown]
# ## Fake Bad Data - ALL

# %%
bad = np.array(data[str(runs[2])]['all_bad_samples'])

# %%
bad_new = []
for l in bad:
    if not 0 in l:
        bad_new.append(l)
                
reconstructed_bad = model.predict(np.array(bad_new))

error_bad = abs(bad_new-reconstructed_bad)/bad_new

# %%
error_reformat_bad = []
for i in range(4):
    error_reformat_bad.append([])

for i in range(len(error_bad)):
    for j in range(4):
        if i == len(error_bad)-1:
            for val in error_bad[i][WINDOW*j:WINDOW+WINDOW*j]:
                error_reformat_bad[j].append(val)
        else:
            error_reformat_bad[j].append(error_bad[i][WINDOW*j])
            
inp_bad = []
outp_bad = []
for i in range(4):
    inp_bad.append([])
    outp_bad.append([])
    
for i in range(len(reconstructed_bad)):
    for j in range(4):
        if i == len(reconstructed_bad)-1:
            for val in reconstructed_bad[i][WINDOW*j:WINDOW+WINDOW*j]:
                outp_bad[j].append(val)
            for val in bad_new[i][WINDOW*j:WINDOW+WINDOW*j]:
                inp_bad[j].append(val)
        else:
            outp_bad[j].append(reconstructed_bad[i][WINDOW*j])
            inp_bad[j].append(bad_new[i][WINDOW*j])

# %%
labels = data['HLT']

#bins = np.linspace(0,1,50)
bins = 50
plt.figure(figsize=[20,10])
for i in range(len(error_reformat_bad)):
    plt.subplot(2,2,i+1)
    plt.hist(error_reformat[i],bins=bins,label='good',alpha=.5)
    plt.hist(error_reformat_bad[i],bins=bins,label='fake bad',alpha=.5)
    plt.legend()
    plt.title(labels[i])

lumi = data[str(runs[2])]['lumiid'] 
print(len(error_reformat_bad[0]),len(error_reformat[0]),len(lumi))
#lumi = np.linspace(0,len(error_reformat_bad[0]),len(error_reformat_bad[0]))
plt.figure(figsize=[20,10])
for i in range(0,4):
    plt.subplot(2,2,i+1)
    plt.scatter(lumi,error_reformat[i],label = 'good', alpha =.5)
    plt.scatter(lumi,error_reformat_bad[i],label='fake bad',alpha=.5)
    plt.xlabel('lumi id')
    plt.ylabel('error')
    plt.legend()    
    plt.title(labels[i])

plt.show()
# Out:
# 1224 1224 1224

# %%
plt.figure(figsize=[10,10])
for i in range(0,4):
    plt.subplot(2,2,i+1)
    plt.plot(outp_bad[i],inp_bad[i],label=labels[i], linestyle='',marker='o', markersize=3, alpha=0.5)
    plt.xlabel('index')
    plt.ylabel('value')
    #plt.xlim(0,.6)
    #plt.ylim(0,.6)
    plt.legend()    

plt.show()

# %%
# plt.figure(figsize=[20,10])
# for i in range(0,4):
#     plt.subplot(2,2,i+1)
#     plt.scatter(lumi,inp_bad[i],label='input',alpha=.5)
#     plt.scatter(lumi,outp_bad[i]/max(outp_bad[i]),label='output',alpha=.5)
#     plt.xlabel('index')
#     plt.ylabel('value')
#     plt.legend()    

# plt.show()

# %%
# labels = data['HLT']

# #bins = np.linspace(0,1,50)
# bins = 50
# plt.figure(figsize=[20,10])
# for i in range(len(error_reformat_bad)):
#     plt.subplot(2,2,i+1)
#     plt.hist(error_reformat_bad[i],bins=bins,label='bad',alpha=.5)
#     plt.hist(error_reformat[i],bins=bins,label='good',alpha=.5)
#     plt.legend()

# # lumi = data[str(runs[0])]['lumiid'] 
# # print(len(error_reformat_bad[0]),len(lumi))
# # #lumi = np.linspace(0,len(error_reformat_bad[0]),len(error_reformat_bad[0]))
# # plt.figure(figsize=[20,10])
# # for i in range(0,4):
# #     plt.subplot(2,2,i+1)
# #     plt.scatter(lumi,error_reformat_bad[i],label='bad',alpha=.5)
# #     plt.scatter(lumi,error_reformat[i],label='good',alpha=.5)
# #     plt.xlabel('lumi id')
# #     plt.ylabel('error')
# #     plt.legend()    

# plt.show()

# %% [markdown]
# ## Real Bad Data

# %%
bad_runs = [301480]

with open('unscaled_bad_data_WINDOW2.pickle', 'rb') as handle:
    baddata = pickle.load(handle)

x_test = np.array(baddata[str(bad_runs[0])]['samples'])

# %%
bad_new = []
lumi_new = []

lumiBad = baddata[str(bad_runs[0])]['lumiid']

for l in range(len(x_test)):
    if not 0 in x_test[l]:
        bad_new.append(x_test[l])
        for i in range(WINDOW):
            lumi_new.append(lumiBad[l+i])
            
lumiBad = []
for n in lumi_new:
    if n not in lumiBad:
        lumiBad.append(n)
                
reconstructed_bad = model.predict(np.array(bad_new))

error_bad = abs(bad_new-reconstructed_bad)/bad_new

# %%
error_reformat_bad = []
for i in range(4):
    error_reformat_bad.append([])

for i in range(len(error_bad)):
    for j in range(4):
        if i == len(error_bad)-1:
            for val in error_bad[i][WINDOW*j:WINDOW+WINDOW*j]:
                error_reformat_bad[j].append(val)
        else:
            error_reformat_bad[j].append(error_bad[i][WINDOW*j])
            
inp_bad = []
outp_bad = []
for i in range(4):
    inp_bad.append([])
    outp_bad.append([])
    
for i in range(len(reconstructed_bad)):
    for j in range(4):
        if i == len(reconstructed_bad)-1:
            for val in reconstructed_bad[i][WINDOW*j:WINDOW+WINDOW*j]:
                outp_bad[j].append(val)
            for val in bad_new[i][WINDOW*j:WINDOW+WINDOW*j]:
                inp_bad[j].append(val)
        else:
            outp_bad[j].append(reconstructed_bad[i][WINDOW*j])
            inp_bad[j].append(bad_new[i][WINDOW*j])

# %%
labels = data['HLT']

#bins = np.linspace(0,1,50)
bins = 50
plt.figure(figsize=[20,10])
for i in range(len(error_reformat_bad)):
    plt.subplot(2,2,i+1)
    plt.hist(error_reformat[i],bins=bins,label='good',alpha=.5)
    plt.hist(error_reformat_bad[i],bins=bins,label='bad',alpha=.5)
    plt.legend()
    plt.title(labels[i])

print(len(error_reformat_bad[0]),len(lumiBad))
plt.figure(figsize=[20,10])
for i in range(0,4):
    plt.subplot(2,2,i+1)
    plt.scatter(lumi,error_reformat[i],label = 'good', alpha =.5)
    plt.scatter(lumiBad,error_reformat_bad[i],label='bad',alpha=.5)
    plt.xlabel('lumi id')
    plt.ylabel('error')
    plt.legend()    
    plt.title(labels[i])

plt.show()
# Out:
# 154 154

# %%
plt.figure(figsize=[10,10])
for i in range(0,4):
    plt.subplot(2,2,i+1)
    plt.plot(outp_bad[i],inp_bad[i],label=labels[i], linestyle='',marker='o', markersize=3, alpha=0.5)
    plt.xlabel('index')
    plt.ylabel('value')
    #plt.xlim(0,.6)
    #plt.ylim(0,.6)
    plt.legend()    

plt.show()

# %% [markdown]
# ## Real Bad Data

# %%
bad_runs = [305588]

with open('unscaled_bad_data_WINDOW2.pickle', 'rb') as handle:
    baddata = pickle.load(handle)

x_test = np.array(baddata[str(bad_runs[0])]['samples'])

# %%
bad_new = []
lumi_new = []

lumiBad = baddata[str(bad_runs[0])]['lumiid']

for l in range(len(x_test)):
    if not 0 in x_test[l]:
        bad_new.append(x_test[l])
        for i in range(WINDOW):
            lumi_new.append(lumiBad[l+i])
            
lumiBad = []
for n in lumi_new:
    if n not in lumiBad:
        lumiBad.append(n)
                
reconstructed_bad = model.predict(np.array(bad_new))

error_bad = abs(bad_new-reconstructed_bad)/bad_new

# %%
error_reformat_bad = []
for i in range(4):
    error_reformat_bad.append([])

for i in range(len(error_bad)):
    for j in range(4):
        if i == len(error_bad)-1:
            for val in error_bad[i][WINDOW*j:WINDOW+WINDOW*j]:
                error_reformat_bad[j].append(val)
        else:
            error_reformat_bad[j].append(error_bad[i][WINDOW*j])
            
inp_bad = []
outp_bad = []
for i in range(4):
    inp_bad.append([])
    outp_bad.append([])
    
for i in range(len(reconstructed_bad)):
    for j in range(4):
        if i == len(reconstructed_bad)-1:
            for val in reconstructed_bad[i][WINDOW*j:WINDOW+WINDOW*j]:
                outp_bad[j].append(val)
            for val in bad_new[i][WINDOW*j:WINDOW+WINDOW*j]:
                inp_bad[j].append(val)
        else:
            outp_bad[j].append(reconstructed_bad[i][WINDOW*j])
            inp_bad[j].append(bad_new[i][WINDOW*j])

# %%
labels = data['HLT']

#bins = np.linspace(0,1,50)
bins = 50
plt.figure(figsize=[20,10])
for i in range(len(error_reformat_bad)):
    plt.subplot(2,2,i+1)
    plt.hist(error_reformat[i],bins=bins,label='good',alpha=.5)
    plt.hist(error_reformat_bad[i],bins=bins,label='bad',alpha=.5)
    plt.legend()
    plt.title(labels[i])

print(len(error_reformat_bad[0]),len(lumiBad))
plt.figure(figsize=[20,10])
for i in range(0,4):
    plt.subplot(2,2,i+1)
    plt.scatter(lumi,error_reformat[i],label = 'good', alpha =.5)
    plt.scatter(lumiBad,error_reformat_bad[i],label='bad',alpha=.5)
    plt.xlabel('lumi id')
    plt.ylabel('error')
    plt.legend()    
    plt.title(labels[i])

plt.show()
# Out:
# 99 99

# %%
plt.figure(figsize=[10,10])
for i in range(0,4):
    plt.subplot(2,2,i+1)
    plt.plot(outp_bad[i],inp_bad[i],label=labels[i], linestyle='',marker='o', markersize=3, alpha=0.5)
    plt.xlabel('index')
    plt.ylabel('value')
    #plt.xlim(0,.6)
    #plt.ylim(0,.6)
    plt.legend()    

plt.show()
