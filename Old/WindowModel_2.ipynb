# %%
import os
import numpy as np
import matplotlib
import matplotlib.pyplot as plt
import pandas as pd
import keras
import pickle

from keras import backend as K
from keras.callbacks import EarlyStopping, ModelCheckpoint, ReduceLROnPlateau
from keras.initializers import Ones, Zeros, Constant
from keras.models import Model, load_model
from keras.layers import Dense, Input, Lambda, SimpleRNN, Reshape, RepeatVector, PReLU
from keras.losses import mse
from keras.constraints import non_neg
# Out:
# /anaconda3/lib/python3.6/site-packages/h5py/__init__.py:36: FutureWarning: Conversion of the second argument of issubdtype from `float` to `np.floating` is deprecated. In future, it will be treated as `np.float64 == np.dtype(float).type`.
#   from ._conv import register_converters as _register_converters
# Using TensorFlow backend.
# /anaconda3/lib/python3.6/importlib/_bootstrap.py:219: RuntimeWarning: compiletime version 3.5 of module 'tensorflow.python.framework.fast_tensor_util' does not match runtime version 3.6
#   return f(*args, **kwds)

# %%
# Change presentation settings

# %matplotlib inline

matplotlib.rcParams["figure.figsize"] = (16.0, 10.0)

#matplotlib.rcParams['font.family'] = 'sans-serif'
#matplotlib.rcParams['font.sans-serif'] = ['Liberation Sans']

matplotlib.rcParams["axes.spines.left"] = True
matplotlib.rcParams["axes.spines.top"] = True
matplotlib.rcParams["axes.spines.right"] = True
matplotlib.rcParams["axes.spines.bottom"] = True
matplotlib.rcParams["axes.labelsize"] = 18
matplotlib.rcParams["axes.titlesize"] = 12

matplotlib.rcParams["xtick.top"] = True
matplotlib.rcParams["ytick.right"] = True
matplotlib.rcParams["xtick.direction"] = "in"
matplotlib.rcParams["ytick.direction"] = "in"
matplotlib.rcParams["xtick.labelsize"] = 10
matplotlib.rcParams["ytick.labelsize"] = 10
matplotlib.rcParams["xtick.major.size"] = 10
matplotlib.rcParams["ytick.major.size"] = 10
matplotlib.rcParams["xtick.minor.size"] = 5
matplotlib.rcParams["ytick.minor.size"] = 5
matplotlib.rcParams["xtick.minor.visible"] = True

matplotlib.rcParams["lines.linewidth"] = 2

matplotlib.rcParams["legend.fontsize"] = 14

color_palette = {"Indigo": {
                    50: "#E8EAF6",
                    100: "#C5CAE9",
                    200: "#9FA8DA",
                    300: "#7986CB",
                    400: "#5C6BC0",
                    500: "#3F51B5",
                    600: "#3949AB",
                    700: "#303F9F",
                    800: "#283593",
                    900: "#1A237E"},
                 "Orange": {      
                    50: "#FFF3E0",
                    100: "#FFE0B2",
                    200: "#FFCC80",
                    300: "#FFB74D",
                    400: "#FFA726",
                    500: "#FF9800",
                    600: "#FB8C00",
                    700: "#F57C00",
                    800: "#EF6C00",
                    900: "#E65100"}
                }

line_styles = [(0, ()), (0, (1, 2)), (0, (3, 2))]

# %%
def plot_loss(data, save_name=False):
    """Plots the training and validation loss"""
    fig, ax = plt.subplots()

    plt.xlabel("Epoch", horizontalalignment='right', x=1.0)
    plt.ylabel("Cross-entropy", horizontalalignment='right', y=1.0)

    plt.plot(data["loss"], linestyle=line_styles[0], color=color_palette["Indigo"][800])
    plt.plot(data["val_loss"], linestyle=line_styles[2], color=color_palette["Orange"][400])
    plt.legend(["Training data set", "Validation data set"], loc="upper right", frameon=False)
    #plt.yscale("log")
    
    if save_name:
        fig.savefig("%s/%s.eps" % (figure_export_directory, save_name), bbox_inches="tight")

    plt.show();

# %%
def train_nn(model, x, y, batch_size, loss, name, xval):

    adam = keras.optimizers.Adam(lr=0.003,
                                 beta_1=0.9,
                                 beta_2=0.999,
                                 epsilon=None,
                                 decay=0.0,
                                 amsgrad=False)

    early_stopper = EarlyStopping(monitor="val_loss",
                                  patience=32,
                                  verbose=True,
                                  mode="auto")

    reduce_lr = ReduceLROnPlateau(monitor="val_loss",
                                  factor=0.1,
                                  patience=24)
    
    checkpoint_callback = ModelCheckpoint(("%s.h5" % (name)),
                                          monitor="val_loss",
                                          verbose=False,
                                          save_best_only=True,
                                          mode="min")
    
    model.compile(loss=loss, optimizer=adam)
    
    history = model.fit(x, y,
                     batch_size=batch_size,
                     epochs=1000,
                     verbose=2,
                     initial_epoch=0,
                     shuffle=True,
                     validation_data=(xval,xval),
                     callbacks=[early_stopper, checkpoint_callback])
    return history

# %% [markdown]
# ## Data

# %%
runs = [304125,302263,304508]

with open('good_data_WINDOW2.pickle', 'rb') as handle:
    data = pickle.load(handle)

x_train = np.array(data[str(runs[0])]['samples'])
x_val = np.array(data[str(runs[1])]['samples'])
x_test = np.array(data[str(runs[2])]['samples'])

WINDOW = 2

# %%
plots = [x_train,x_val,x_test]
titles = ["train","val","test"]

stuff = [[],[],[]]
lumi = [[],[],[]]
for h in range(3):
    labels = data['HLT'] 
    lumi[h] = data[str(runs[h])]['lumiid']
    stuff[h] = data[str(runs[h])]['rates']
    
plt.figure(figsize=[20,10])
              
for i in range(4):
    plt.subplot(2,2,i+1)
    for k in range(0,3):
        print(len(lumi[k]),len(stuff[k][i]))
        plt.scatter(lumi[k],stuff[k][i],label=titles[k],alpha=.5)
    plt.xlabel('lumi id')
    plt.ylabel('error')
    plt.title(labels[i])
    plt.legend()

plt.tight_layout()
plt.show()
# Out:
# 1669 1669
# 1129 1129
# 1224 1224
# 1669 1669
# 1129 1129
# 1224 1224
# 1669 1669
# 1129 1129
# 1224 1224
# 1669 1669
# 1129 1129
# 1224 1224

# %% [markdown]
# ## Simple Autoencoder

# %%
model_name = "simplest_2"

# %%
# Define the architecture

_input = Input(shape=(4*WINDOW,), name="input")

hidden = Dense(3,
               kernel_initializer=Ones(),
               bias_initializer=Zeros(),
               kernel_constraint=non_neg(),
               bias_constraint=non_neg(),
               activation=None,
               name="encoded")(_input)

output = Dense(4*WINDOW,
               kernel_initializer=Ones(),
               bias_initializer=Zeros(),
               kernel_constraint=non_neg(),
               bias_constraint=non_neg(),
               activation=None,
               name="reconstructed")(hidden)

model = Model(_input, output)
model.summary()
# Out:
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# input (InputLayer)           (None, 8)                 0
# _________________________________________________________________
# encoded (Dense)              (None, 3)                 27
# _________________________________________________________________
# reconstructed (Dense)        (None, 8)                 32
# =================================================================
# Total params: 59
# Trainable params: 59
# Non-trainable params: 0
# _________________________________________________________________

# %%
# Train neural networks
history = train_nn(model, x_train, x_train, 1024, "mse", model_name, x_val).history
plot_loss(history)
# Out:
# Train on 1668 samples, validate on 1128 samples
# Epoch 1/1000
#  - 0s - loss: 223.8974 - val_loss: 220.7403
# Epoch 2/1000
#  - 0s - loss: 218.3455 - val_loss: 215.4016
# Epoch 3/1000
#  - 0s - loss: 213.0892 - val_loss: 210.1178
# Epoch 4/1000
#  - 0s - loss: 207.8178 - val_loss: 204.8279
# Epoch 5/1000
#  - 0s - loss: 202.5772 - val_loss: 199.6635
# Epoch 6/1000
#  - 0s - loss: 197.4746 - val_loss: 194.5980
# Epoch 7/1000
#  - 0s - loss: 192.4562 - val_loss: 189.6517
# Epoch 8/1000
#  - 0s - loss: 187.5639 - val_loss: 184.8029
# Epoch 9/1000
#  - 0s - loss: 182.7715 - val_loss: 180.0667
# Epoch 10/1000
#  - 0s - loss: 178.0793 - val_loss: 175.4455
# Epoch 11/1000
#  - 0s - loss: 173.5001 - val_loss: 170.9144
# Epoch 12/1000
#  - 0s - loss: 169.0276 - val_loss: 166.5476
# Epoch 13/1000
#  - 0s - loss: 164.7094 - val_loss: 162.2939
# Epoch 14/1000
#  - 0s - loss: 160.5030 - val_loss: 158.1275
# Epoch 15/1000
#  - 0s - loss: 156.3876 - val_loss: 154.0982
# Epoch 16/1000
#  - 0s - loss: 152.4025 - val_loss: 150.1551
# Epoch 17/1000
#  - 0s - loss: 148.4962 - val_loss: 146.3198
# Epoch 18/1000
#  - 0s - loss: 144.7095 - val_loss: 142.5910
# Epoch 19/1000
#  - 0s - loss: 141.0178 - val_loss: 138.9653
# Epoch 20/1000
#  - 0s - loss: 137.4363 - val_loss: 135.4227
# Epoch 21/1000
#  - 0s - loss: 133.9305 - val_loss: 131.9987
# Epoch 22/1000
#  - 0s - loss: 130.5481 - val_loss: 128.6712
# Epoch 23/1000
#  - 0s - loss: 127.2581 - val_loss: 125.4382
# Epoch 24/1000
#  - 0s - loss: 124.0718 - val_loss: 122.3118
# Epoch 25/1000
#  - 0s - loss: 120.9828 - val_loss: 119.2739
# Epoch 26/1000
#  - 0s - loss: 117.9774 - val_loss: 116.3094
# Epoch 27/1000
#  - 0s - loss: 115.0482 - val_loss: 113.4414
# Epoch 28/1000
#  - 0s - loss: 112.2113 - val_loss: 110.6546
# Epoch 29/1000
#  - 0s - loss: 109.4541 - val_loss: 107.9351
# Epoch 30/1000
#  - 0s - loss: 106.7674 - val_loss: 105.3034
# Epoch 31/1000
#  - 0s - loss: 104.1651 - val_loss: 102.7355
# Epoch 32/1000
#  - 0s - loss: 101.6321 - val_loss: 100.2404
# Epoch 33/1000
#  - 0s - loss: 99.1603 - val_loss: 97.8075
# Epoch 34/1000
#  - 0s - loss: 96.7604 - val_loss: 95.4598
# Epoch 35/1000
#  - 0s - loss: 94.4392 - val_loss: 93.1779
# Epoch 36/1000
#  - 0s - loss: 92.1836 - val_loss: 90.9597
# Epoch 37/1000
#  - 0s - loss: 89.9880 - val_loss: 88.8033
# Epoch 38/1000
#  - 0s - loss: 87.8590 - val_loss: 86.6996
# Epoch 39/1000
#  - 0s - loss: 85.7779 - val_loss: 84.6545
# Epoch 40/1000
#  - 0s - loss: 83.7580 - val_loss: 82.6716
# Epoch 41/1000
#  - 0s - loss: 81.7967 - val_loss: 80.7379
# Epoch 42/1000
#  - 0s - loss: 79.8840 - val_loss: 78.8626
# Epoch 43/1000
#  - 0s - loss: 78.0309 - val_loss: 77.0382
# Epoch 44/1000
#  - 0s - loss: 76.2255 - val_loss: 75.2635
# Epoch 45/1000
#  - 0s - loss: 74.4746 - val_loss: 73.5319
# Epoch 46/1000
#  - 0s - loss: 72.7600 - val_loss: 71.8476
# Epoch 47/1000
#  - 0s - loss: 71.0972 - val_loss: 70.2131
# Epoch 48/1000
#  - 0s - loss: 69.4809 - val_loss: 68.6227
# Epoch 49/1000
#  - 0s - loss: 67.9058 - val_loss: 67.0714
# Epoch 50/1000
#  - 0s - loss: 66.3718 - val_loss: 65.5612
# Epoch 51/1000
#  - 0s - loss: 64.8802 - val_loss: 64.0942
# Epoch 52/1000
#  - 0s - loss: 63.4287 - val_loss: 62.6662
# Epoch 53/1000
#  - 0s - loss: 62.0148 - val_loss: 61.2725
# Epoch 54/1000
#  - 0s - loss: 60.6389 - val_loss: 59.9183
# Epoch 55/1000
#  - 0s - loss: 59.3001 - val_loss: 58.5995
# Epoch 56/1000
#  - 0s - loss: 57.9961 - val_loss: 57.3151
# Epoch 57/1000
#  - 0s - loss: 56.7254 - val_loss: 56.0642
# Epoch 58/1000
#  - 0s - loss: 55.4872 - val_loss: 54.8432
# Epoch 59/1000
#  - 0s - loss: 54.2811 - val_loss: 53.6558
# Epoch 60/1000
#  - 0s - loss: 53.1078 - val_loss: 52.4988
# Epoch 61/1000
#  - 0s - loss: 51.9619 - val_loss: 51.3696
# Epoch 62/1000
#  - 0s - loss: 50.8470 - val_loss: 50.2713
# Epoch 63/1000
#  - 0s - loss: 49.7595 - val_loss: 49.2011
# Epoch 64/1000
#  - 0s - loss: 48.7021 - val_loss: 48.1579
# Epoch 65/1000
#  - 0s - loss: 47.6700 - val_loss: 47.1411
# Epoch 66/1000
#  - 0s - loss: 46.6626 - val_loss: 46.1482
# Epoch 67/1000
#  - 0s - loss: 45.6811 - val_loss: 45.1800
# Epoch 68/1000
#  - 0s - loss: 44.7241 - val_loss: 44.2375
# Epoch 69/1000
#  - 0s - loss: 43.7918 - val_loss: 43.3185
# Epoch 70/1000
#  - 0s - loss: 42.8822 - val_loss: 42.4207
# Epoch 71/1000
#  - 0s - loss: 41.9939 - val_loss: 41.5450
# Epoch 72/1000
#  - 0s - loss: 41.1294 - val_loss: 40.6921
# Epoch 73/1000
#  - 0s - loss: 40.2843 - val_loss: 39.8577
# Epoch 74/1000
#  - 0s - loss: 39.4591 - val_loss: 39.0462
# Epoch 75/1000
#  - 0s - loss: 38.6574 - val_loss: 38.2531
# Epoch 76/1000
#  - 0s - loss: 37.8728 - val_loss: 37.4805
# Epoch 77/1000
#  - 0s - loss: 37.1077 - val_loss: 36.7254
# Epoch 78/1000
#  - 0s - loss: 36.3613 - val_loss: 35.9897
# Epoch 79/1000
#  - 0s - loss: 35.6315 - val_loss: 35.2705
# Epoch 80/1000
#  - 0s - loss: 34.9211 - val_loss: 34.5693
# Epoch 81/1000
#  - 0s - loss: 34.2281 - val_loss: 33.8837
# Epoch 82/1000
#  - 0s - loss: 33.5491 - val_loss: 33.2154
# Epoch 83/1000
#  - 0s - loss: 32.8884 - val_loss: 32.5627
# Epoch 84/1000
#  - 0s - loss: 32.2430 - val_loss: 31.9254
# Epoch 85/1000
#  - 0s - loss: 31.6119 - val_loss: 31.3031
# Epoch 86/1000
#  - 0s - loss: 30.9962 - val_loss: 30.6944
# Epoch 87/1000
#  - 0s - loss: 30.3945 - val_loss: 30.1007
# Epoch 88/1000
#  - 0s - loss: 29.8070 - val_loss: 29.5208
# Epoch 89/1000
#  - 0s - loss: 29.2326 - val_loss: 28.9544
# Epoch 90/1000
#  - 0s - loss: 28.6725 - val_loss: 28.4008
# Epoch 91/1000
#  - 0s - loss: 28.1247 - val_loss: 27.8599
# Epoch 92/1000
#  - 0s - loss: 27.5889 - val_loss: 27.3301
# Epoch 93/1000
#  - 0s - loss: 27.0653 - val_loss: 26.8129
# Epoch 94/1000
#  - 0s - loss: 26.5535 - val_loss: 26.3080
# Epoch 95/1000
#  - 0s - loss: 26.0534 - val_loss: 25.8145
# Epoch 96/1000
#  - 0s - loss: 25.5655 - val_loss: 25.3315
# Epoch 97/1000
#  - 0s - loss: 25.0871 - val_loss: 24.8593
# Epoch 98/1000
#  - 0s - loss: 24.6200 - val_loss: 24.3977
# Epoch 99/1000
#  - 0s - loss: 24.1632 - val_loss: 23.9468
# Epoch 100/1000
#  - 0s - loss: 23.7172 - val_loss: 23.5058
# Epoch 101/1000
#  - 0s - loss: 23.2811 - val_loss: 23.0747
# Epoch 102/1000
#  - 0s - loss: 22.8538 - val_loss: 22.6526
# Epoch 103/1000
#  - 0s - loss: 22.4367 - val_loss: 22.2402
# Epoch 104/1000
#  - 0s - loss: 22.0280 - val_loss: 21.8369
# Epoch 105/1000
#  - 0s - loss: 21.6290 - val_loss: 21.4419
# Epoch 106/1000
#  - 0s - loss: 21.2386 - val_loss: 21.0559
# Epoch 107/1000
#  - 0s - loss: 20.8559 - val_loss: 20.6779
# Epoch 108/1000
#  - 0s - loss: 20.4823 - val_loss: 20.3080
# Epoch 109/1000
#  - 0s - loss: 20.1157 - val_loss: 19.9461
# Epoch 110/1000
#  - 0s - loss: 19.7577 - val_loss: 19.5923
# Epoch 111/1000
#  - 0s - loss: 19.4071 - val_loss: 19.2453
# Epoch 112/1000
#  - 0s - loss: 19.0642 - val_loss: 18.9059
# Epoch 113/1000
#  - 0s - loss: 18.7285 - val_loss: 18.5741
# Epoch 114/1000
#  - 0s - loss: 18.3999 - val_loss: 18.2493
# Epoch 115/1000
#  - 0s - loss: 18.0780 - val_loss: 17.9314
# Epoch 116/1000
#  - 0s - loss: 17.7639 - val_loss: 17.6200
# Epoch 117/1000
#  - 0s - loss: 17.4553 - val_loss: 17.3153
# Epoch 118/1000
#  - 0s - loss: 17.1539 - val_loss: 17.0168
# Epoch 119/1000
#  - 0s - loss: 16.8580 - val_loss: 16.7243
# Epoch 120/1000
#  - 0s - loss: 16.5685 - val_loss: 16.4380
# Epoch 121/1000
#  - 0s - loss: 16.2852 - val_loss: 16.1573
# Epoch 122/1000
#  - 0s - loss: 16.0074 - val_loss: 15.8824
# Epoch 123/1000
#  - 0s - loss: 15.7351 - val_loss: 15.6133
# Epoch 124/1000
#  - 0s - loss: 15.4689 - val_loss: 15.3497
# Epoch 125/1000
#  - 0s - loss: 15.2076 - val_loss: 15.0915
# Epoch 126/1000
#  - 0s - loss: 14.9522 - val_loss: 14.8381
# Epoch 127/1000
#  - 0s - loss: 14.7013 - val_loss: 14.5901
# Epoch 128/1000
#  - 0s - loss: 14.4555 - val_loss: 14.3471
# Epoch 129/1000
#  - 0s - loss: 14.2152 - val_loss: 14.1088
# Epoch 130/1000
#  - 0s - loss: 13.9792 - val_loss: 13.8752
# Epoch 131/1000
#  - 0s - loss: 13.7478 - val_loss: 13.6461
# Epoch 132/1000
#  - 0s - loss: 13.5209 - val_loss: 13.4214
# Epoch 133/1000
#  - 0s - loss: 13.2987 - val_loss: 13.2013
# Epoch 134/1000
#  - 0s - loss: 13.0809 - val_loss: 12.9858
# Epoch 135/1000
#  - 0s - loss: 12.8674 - val_loss: 12.7744
# Epoch 136/1000
#  - 0s - loss: 12.6582 - val_loss: 12.5672
# Epoch 137/1000
#  - 0s - loss: 12.4530 - val_loss: 12.3639
# Epoch 138/1000
#  - 0s - loss: 12.2516 - val_loss: 12.1645
# Epoch 139/1000
#  - 0s - loss: 12.0540 - val_loss: 11.9689
# Epoch 140/1000
#  - 0s - loss: 11.8605 - val_loss: 11.7771
# Epoch 141/1000
#  - 0s - loss: 11.6704 - val_loss: 11.5891
# Epoch 142/1000
#  - 0s - loss: 11.4844 - val_loss: 11.4047
# Epoch 143/1000
#  - 0s - loss: 11.3016 - val_loss: 11.2239
# Epoch 144/1000
#  - 0s - loss: 11.1227 - val_loss: 11.0464
# Epoch 145/1000
#  - 0s - loss: 10.9468 - val_loss: 10.8721
# Epoch 146/1000
#  - 0s - loss: 10.7742 - val_loss: 10.7012
# Epoch 147/1000
#  - 0s - loss: 10.6051 - val_loss: 10.5336
# Epoch 148/1000
#  - 0s - loss: 10.4388 - val_loss: 10.3691
# Epoch 149/1000
#  - 0s - loss: 10.2763 - val_loss: 10.2075
# Epoch 150/1000
#  - 0s - loss: 10.1162 - val_loss: 10.0490
# Epoch 151/1000
#  - 0s - loss: 9.9593 - val_loss: 9.8936
# Epoch 152/1000
#  - 0s - loss: 9.8052 - val_loss: 9.7409
# Epoch 153/1000
#  - 0s - loss: 9.6541 - val_loss: 9.5909
# Epoch 154/1000
#  - 0s - loss: 9.5056 - val_loss: 9.4440
# Epoch 155/1000
#  - 0s - loss: 9.3599 - val_loss: 9.2996
# Epoch 156/1000
#  - 0s - loss: 9.2169 - val_loss: 9.1578
# Epoch 157/1000
#  - 0s - loss: 9.0766 - val_loss: 9.0188
# Epoch 158/1000
#  - 0s - loss: 8.9387 - val_loss: 8.8822
# Epoch 159/1000
#  - 0s - loss: 8.8036 - val_loss: 8.7480
# Epoch 160/1000
#  - 0s - loss: 8.6708 - val_loss: 8.6163
# Epoch 161/1000
#  - 0s - loss: 8.5402 - val_loss: 8.4869
# Epoch 162/1000
#  - 0s - loss: 8.4121 - val_loss: 8.3598
# Epoch 163/1000
#  - 0s - loss: 8.2861 - val_loss: 8.2351
# Epoch 164/1000
#  - 0s - loss: 8.1627 - val_loss: 8.1126
# Epoch 165/1000
#  - 0s - loss: 8.0412 - val_loss: 7.9921
# Epoch 166/1000
#  - 0s - loss: 7.9219 - val_loss: 7.8739
# Epoch 167/1000
#  - 0s - loss: 7.8049 - val_loss: 7.7578
# Epoch 168/1000
#  - 0s - loss: 7.6900 - val_loss: 7.6437
# Epoch 169/1000
#  - 0s - loss: 7.5769 - val_loss: 7.5316
# Epoch 170/1000
#  - 0s - loss: 7.4659 - val_loss: 7.4215
# Epoch 171/1000
#  - 0s - loss: 7.3567 - val_loss: 7.3131
# Epoch 172/1000
#  - 0s - loss: 7.2495 - val_loss: 7.2068
# Epoch 173/1000
#  - 0s - loss: 7.1443 - val_loss: 7.1024
# Epoch 174/1000
#  - 0s - loss: 7.0408 - val_loss: 6.9997
# Epoch 175/1000
#  - 0s - loss: 6.9390 - val_loss: 6.8988
# Epoch 176/1000
#  - 0s - loss: 6.8392 - val_loss: 6.7996
# Epoch 177/1000
#  - 0s - loss: 6.7408 - val_loss: 6.7022
# Epoch 178/1000
#  - 0s - loss: 6.6442 - val_loss: 6.6063
# Epoch 179/1000
#  - 0s - loss: 6.5492 - val_loss: 6.5121
# Epoch 180/1000
#  - 0s - loss: 6.4559 - val_loss: 6.4195
# Epoch 181/1000
#  - 0s - loss: 6.3641 - val_loss: 6.3284
# Epoch 182/1000
#  - 0s - loss: 6.2739 - val_loss: 6.2389
# Epoch 183/1000
#  - 0s - loss: 6.1852 - val_loss: 6.1509
# Epoch 184/1000
#  - 0s - loss: 6.0981 - val_loss: 6.0644
# Epoch 185/1000
#  - 0s - loss: 6.0125 - val_loss: 5.9793
# Epoch 186/1000
#  - 0s - loss: 5.9282 - val_loss: 5.8957
# Epoch 187/1000
#  - 0s - loss: 5.8452 - val_loss: 5.8134
# Epoch 188/1000
#  - 0s - loss: 5.7638 - val_loss: 5.7326
# Epoch 189/1000
#  - 0s - loss: 5.6836 - val_loss: 5.6530
# Epoch 190/1000
#  - 0s - loss: 5.6049 - val_loss: 5.5747
# Epoch 191/1000
#  - 0s - loss: 5.5273 - val_loss: 5.4977
# Epoch 192/1000
#  - 0s - loss: 5.4510 - val_loss: 5.4220
# Epoch 193/1000
#  - 0s - loss: 5.3759 - val_loss: 5.3475
# Epoch 194/1000
#  - 0s - loss: 5.3022 - val_loss: 5.2742
# Epoch 195/1000
#  - 0s - loss: 5.2296 - val_loss: 5.2022
# Epoch 196/1000
#  - 0s - loss: 5.1582 - val_loss: 5.1313
# Epoch 197/1000
#  - 0s - loss: 5.0879 - val_loss: 5.0615
# Epoch 198/1000
#  - 0s - loss: 5.0187 - val_loss: 4.9928
# Epoch 199/1000
#  - 0s - loss: 4.9507 - val_loss: 4.9252
# Epoch 200/1000
#  - 0s - loss: 4.8837 - val_loss: 4.8587
# Epoch 201/1000
#  - 0s - loss: 4.8178 - val_loss: 4.7933
# Epoch 202/1000
#  - 0s - loss: 4.7530 - val_loss: 4.7290
# Epoch 203/1000
#  - 0s - loss: 4.6892 - val_loss: 4.6656
# Epoch 204/1000
#  - 0s - loss: 4.6265 - val_loss: 4.6032
# Epoch 205/1000
#  - 0s - loss: 4.5646 - val_loss: 4.5418
# Epoch 206/1000
#  - 0s - loss: 4.5038 - val_loss: 4.4814
# Epoch 207/1000
#  - 0s - loss: 4.4439 - val_loss: 4.4219
# Epoch 208/1000
#  - 0s - loss: 4.3850 - val_loss: 4.3634
# Epoch 209/1000
#  - 0s - loss: 4.3270 - val_loss: 4.3058
# Epoch 210/1000
#  - 0s - loss: 4.2700 - val_loss: 4.2490
# Epoch 211/1000
#  - 0s - loss: 4.2137 - val_loss: 4.1932
# Epoch 212/1000
#  - 0s - loss: 4.1584 - val_loss: 4.1383
# Epoch 213/1000
#  - 0s - loss: 4.1039 - val_loss: 4.0841
# Epoch 214/1000
#  - 0s - loss: 4.0503 - val_loss: 4.0309
# Epoch 215/1000
#  - 0s - loss: 3.9975 - val_loss: 3.9784
# Epoch 216/1000
#  - 0s - loss: 3.9455 - val_loss: 3.9267
# Epoch 217/1000
#  - 0s - loss: 3.8944 - val_loss: 3.8759
# Epoch 218/1000
#  - 0s - loss: 3.8439 - val_loss: 3.8257
# Epoch 219/1000
#  - 0s - loss: 3.7943 - val_loss: 3.7764
# Epoch 220/1000
#  - 0s - loss: 3.7454 - val_loss: 3.7278
# Epoch 221/1000
#  - 0s - loss: 3.6972 - val_loss: 3.6800
# Epoch 222/1000
#  - 0s - loss: 3.6497 - val_loss: 3.6329
# Epoch 223/1000
#  - 0s - loss: 3.6031 - val_loss: 3.5864
# Epoch 224/1000
#  - 0s - loss: 3.5570 - val_loss: 3.5407
# Epoch 225/1000
#  - 0s - loss: 3.5117 - val_loss: 3.4956
# Epoch 226/1000
#  - 0s - loss: 3.4671 - val_loss: 3.4513
# Epoch 227/1000
#  - 0s - loss: 3.4232 - val_loss: 3.4076
# Epoch 228/1000
#  - 0s - loss: 3.3798 - val_loss: 3.3645
# Epoch 229/1000
#  - 0s - loss: 3.3371 - val_loss: 3.3221
# Epoch 230/1000
#  - 0s - loss: 3.2952 - val_loss: 3.2803
# Epoch 231/1000
#  - 0s - loss: 3.2537 - val_loss: 3.2392
# Epoch 232/1000
#  - 0s - loss: 3.2129 - val_loss: 3.1987
# Epoch 233/1000
#  - 0s - loss: 3.1727 - val_loss: 3.1587
# Epoch 234/1000
#  - 0s - loss: 3.1332 - val_loss: 3.1193
# Epoch 235/1000
#  - 0s - loss: 3.0941 - val_loss: 3.0805
# Epoch 236/1000
#  - 0s - loss: 3.0557 - val_loss: 3.0423
# Epoch 237/1000
#  - 0s - loss: 3.0177 - val_loss: 3.0046
# Epoch 238/1000
#  - 0s - loss: 2.9804 - val_loss: 2.9675
# Epoch 239/1000
#  - 0s - loss: 2.9436 - val_loss: 2.9309
# Epoch 240/1000
#  - 0s - loss: 2.9073 - val_loss: 2.8948
# Epoch 241/1000
#  - 0s - loss: 2.8715 - val_loss: 2.8592
# Epoch 242/1000
#  - 0s - loss: 2.8362 - val_loss: 2.8241
# Epoch 243/1000
#  - 0s - loss: 2.8015 - val_loss: 2.7895
# Epoch 244/1000
#  - 0s - loss: 2.7672 - val_loss: 2.7555
# Epoch 245/1000
#  - 0s - loss: 2.7334 - val_loss: 2.7219
# Epoch 246/1000
#  - 0s - loss: 2.7002 - val_loss: 2.6888
# Epoch 247/1000
#  - 0s - loss: 2.6674 - val_loss: 2.6561
# Epoch 248/1000
#  - 0s - loss: 2.6350 - val_loss: 2.6239
# Epoch 249/1000
#  - 0s - loss: 2.6031 - val_loss: 2.5922
# Epoch 250/1000
#  - 0s - loss: 2.5717 - val_loss: 2.5609
# Epoch 251/1000
#  - 0s - loss: 2.5407 - val_loss: 2.5301
# Epoch 252/1000
#  - 0s - loss: 2.5101 - val_loss: 2.4997
# Epoch 253/1000
#  - 0s - loss: 2.4799 - val_loss: 2.4697
# Epoch 254/1000
#  - 0s - loss: 2.4502 - val_loss: 2.4402
# Epoch 255/1000
#  - 0s - loss: 2.4209 - val_loss: 2.4110
# Epoch 256/1000
#  - 0s - loss: 2.3920 - val_loss: 2.3823
# Epoch 257/1000
#  - 0s - loss: 2.3635 - val_loss: 2.3540
# Epoch 258/1000
#  - 0s - loss: 2.3355 - val_loss: 2.3260
# Epoch 259/1000
#  - 0s - loss: 2.3078 - val_loss: 2.2984
# Epoch 260/1000
#  - 0s - loss: 2.2804 - val_loss: 2.2713
# Epoch 261/1000
#  - 0s - loss: 2.2535 - val_loss: 2.2445
# Epoch 262/1000
#  - 0s - loss: 2.2269 - val_loss: 2.2180
# Epoch 263/1000
#  - 0s - loss: 2.2007 - val_loss: 2.1919
# Epoch 264/1000
#  - 0s - loss: 2.1748 - val_loss: 2.1662
# Epoch 265/1000
#  - 0s - loss: 2.1493 - val_loss: 2.1408
# Epoch 266/1000
#  - 0s - loss: 2.1242 - val_loss: 2.1158
# Epoch 267/1000
#  - 0s - loss: 2.0993 - val_loss: 2.0911
# Epoch 268/1000
#  - 0s - loss: 2.0748 - val_loss: 2.0667
# Epoch 269/1000
#  - 0s - loss: 2.0507 - val_loss: 2.0427
# Epoch 270/1000
#  - 0s - loss: 2.0269 - val_loss: 2.0189
# Epoch 271/1000
#  - 0s - loss: 2.0033 - val_loss: 1.9956
# Epoch 272/1000
#  - 0s - loss: 1.9801 - val_loss: 1.9725
# Epoch 273/1000
#  - 0s - loss: 1.9573 - val_loss: 1.9497
# Epoch 274/1000
#  - 0s - loss: 1.9347 - val_loss: 1.9272
# Epoch 275/1000
#  - 0s - loss: 1.9124 - val_loss: 1.9050
# Epoch 276/1000
#  - 0s - loss: 1.8904 - val_loss: 1.8832
# Epoch 277/1000
#  - 0s - loss: 1.8687 - val_loss: 1.8616
# Epoch 278/1000
#  - 0s - loss: 1.8473 - val_loss: 1.8403
# Epoch 279/1000
#  - 0s - loss: 1.8262 - val_loss: 1.8192
# Epoch 280/1000
#  - 0s - loss: 1.8053 - val_loss: 1.7985
# Epoch 281/1000
#  - 0s - loss: 1.7848 - val_loss: 1.7780
# Epoch 282/1000
#  - 0s - loss: 1.7645 - val_loss: 1.7578
# Epoch 283/1000
#  - 0s - loss: 1.7444 - val_loss: 1.7379
# Epoch 284/1000
#  - 0s - loss: 1.7247 - val_loss: 1.7182
# Epoch 285/1000
#  - 0s - loss: 1.7052 - val_loss: 1.6988
# Epoch 286/1000
#  - 0s - loss: 1.6859 - val_loss: 1.6796
# Epoch 287/1000
#  - 0s - loss: 1.6669 - val_loss: 1.6607
# Epoch 288/1000
#  - 0s - loss: 1.6481 - val_loss: 1.6420
# Epoch 289/1000
#  - 0s - loss: 1.6296 - val_loss: 1.6236
# Epoch 290/1000
#  - 0s - loss: 1.6114 - val_loss: 1.6054
# Epoch 291/1000
#  - 0s - loss: 1.5933 - val_loss: 1.5874
# Epoch 292/1000
#  - 0s - loss: 1.5755 - val_loss: 1.5697
# Epoch 293/1000
#  - 0s - loss: 1.5579 - val_loss: 1.5522
# Epoch 294/1000
#  - 0s - loss: 1.5406 - val_loss: 1.5349
# Epoch 295/1000
#  - 0s - loss: 1.5234 - val_loss: 1.5178
# Epoch 296/1000
#  - 0s - loss: 1.5065 - val_loss: 1.5010
# Epoch 297/1000
#  - 0s - loss: 1.4898 - val_loss: 1.4844
# Epoch 298/1000
#  - 0s - loss: 1.4733 - val_loss: 1.4680
# Epoch 299/1000
#  - 0s - loss: 1.4571 - val_loss: 1.4517
# Epoch 300/1000
#  - 0s - loss: 1.4410 - val_loss: 1.4357
# Epoch 301/1000
#  - 0s - loss: 1.4251 - val_loss: 1.4199
# Epoch 302/1000
#  - 0s - loss: 1.4095 - val_loss: 1.4043
# Epoch 303/1000
#  - 0s - loss: 1.3940 - val_loss: 1.3889
# Epoch 304/1000
#  - 0s - loss: 1.3787 - val_loss: 1.3737
# Epoch 305/1000
#  - 0s - loss: 1.3636 - val_loss: 1.3587
# Epoch 306/1000
#  - 0s - loss: 1.3487 - val_loss: 1.3439
# Epoch 307/1000
#  - 0s - loss: 1.3340 - val_loss: 1.3292
# Epoch 308/1000
#  - 0s - loss: 1.3195 - val_loss: 1.3148
# Epoch 309/1000
#  - 0s - loss: 1.3052 - val_loss: 1.3005
# Epoch 310/1000
#  - 0s - loss: 1.2910 - val_loss: 1.2864
# Epoch 311/1000
#  - 0s - loss: 1.2770 - val_loss: 1.2724
# Epoch 312/1000
#  - 0s - loss: 1.2632 - val_loss: 1.2587
# Epoch 313/1000
#  - 0s - loss: 1.2495 - val_loss: 1.2451
# Epoch 314/1000
#  - 0s - loss: 1.2361 - val_loss: 1.2317
# Epoch 315/1000
#  - 0s - loss: 1.2227 - val_loss: 1.2184
# Epoch 316/1000
#  - 0s - loss: 1.2096 - val_loss: 1.2053
# Epoch 317/1000
#  - 0s - loss: 1.1966 - val_loss: 1.1924
# Epoch 318/1000
#  - 0s - loss: 1.1838 - val_loss: 1.1796
# Epoch 319/1000
#  - 0s - loss: 1.1711 - val_loss: 1.1670
# Epoch 320/1000
#  - 0s - loss: 1.1586 - val_loss: 1.1545
# Epoch 321/1000
#  - 0s - loss: 1.1462 - val_loss: 1.1422
# Epoch 322/1000
#  - 0s - loss: 1.1340 - val_loss: 1.1300
# Epoch 323/1000
#  - 0s - loss: 1.1219 - val_loss: 1.1180
# Epoch 324/1000
#  - 0s - loss: 1.1100 - val_loss: 1.1061
# Epoch 325/1000
#  - 0s - loss: 1.0983 - val_loss: 1.0944
# Epoch 326/1000
#  - 0s - loss: 1.0866 - val_loss: 1.0828
# Epoch 327/1000
#  - 0s - loss: 1.0751 - val_loss: 1.0713
# Epoch 328/1000
#  - 0s - loss: 1.0638 - val_loss: 1.0600
# Epoch 329/1000
#  - 0s - loss: 1.0526 - val_loss: 1.0489
# Epoch 330/1000
#  - 0s - loss: 1.0415 - val_loss: 1.0378
# Epoch 331/1000
#  - 0s - loss: 1.0305 - val_loss: 1.0269
# Epoch 332/1000
#  - 0s - loss: 1.0197 - val_loss: 1.0161
# Epoch 333/1000
#  - 0s - loss: 1.0090 - val_loss: 1.0055
# Epoch 334/1000
#  - 0s - loss: 0.9985 - val_loss: 0.9950
# Epoch 335/1000
#  - 0s - loss: 0.9880 - val_loss: 0.9846
# Epoch 336/1000
#  - 0s - loss: 0.9777 - val_loss: 0.9743
# Epoch 337/1000
#  - 0s - loss: 0.9675 - val_loss: 0.9641
# Epoch 338/1000
#  - 0s - loss: 0.9574 - val_loss: 0.9541
# Epoch 339/1000
#  - 0s - loss: 0.9475 - val_loss: 0.9442
# Epoch 340/1000
#  - 0s - loss: 0.9377 - val_loss: 0.9344
# Epoch 341/1000
#  - 0s - loss: 0.9279 - val_loss: 0.9247
# Epoch 342/1000
#  - 0s - loss: 0.9183 - val_loss: 0.9151
# Epoch 343/1000
#  - 0s - loss: 0.9088 - val_loss: 0.9057
# Epoch 344/1000
#  - 0s - loss: 0.8994 - val_loss: 0.8963
# Epoch 345/1000
#  - 0s - loss: 0.8902 - val_loss: 0.8871
# Epoch 346/1000
#  - 0s - loss: 0.8810 - val_loss: 0.8779
# Epoch 347/1000
#  - 0s - loss: 0.8719 - val_loss: 0.8689
# Epoch 348/1000
#  - 0s - loss: 0.8630 - val_loss: 0.8600
# Epoch 349/1000
#  - 0s - loss: 0.8541 - val_loss: 0.8512
# Epoch 350/1000
#  - 0s - loss: 0.8454 - val_loss: 0.8424
# Epoch 351/1000
#  - 0s - loss: 0.8368 - val_loss: 0.8338
# Epoch 352/1000
#  - 0s - loss: 0.8282 - val_loss: 0.8253
# Epoch 353/1000
#  - 0s - loss: 0.8197 - val_loss: 0.8169
# Epoch 354/1000
#  - 0s - loss: 0.8114 - val_loss: 0.8086
# Epoch 355/1000
#  - 0s - loss: 0.8031 - val_loss: 0.8003
# Epoch 356/1000
#  - 0s - loss: 0.7950 - val_loss: 0.7922
# Epoch 357/1000
#  - 0s - loss: 0.7869 - val_loss: 0.7842
# Epoch 358/1000
#  - 0s - loss: 0.7789 - val_loss: 0.7762
# Epoch 359/1000
#  - 0s - loss: 0.7711 - val_loss: 0.7683
# Epoch 360/1000
#  - 0s - loss: 0.7633 - val_loss: 0.7606
# Epoch 361/1000
#  - 0s - loss: 0.7555 - val_loss: 0.7529
# Epoch 362/1000
#  - 0s - loss: 0.7479 - val_loss: 0.7453
# Epoch 363/1000
#  - 0s - loss: 0.7404 - val_loss: 0.7378
# Epoch 364/1000
#  - 0s - loss: 0.7330 - val_loss: 0.7304
# Epoch 365/1000
#  - 0s - loss: 0.7256 - val_loss: 0.7230
# Epoch 366/1000
#  - 0s - loss: 0.7183 - val_loss: 0.7158
# Epoch 367/1000
#  - 0s - loss: 0.7111 - val_loss: 0.7086
# Epoch 368/1000
#  - 0s - loss: 0.7040 - val_loss: 0.7015
# Epoch 369/1000
#  - 0s - loss: 0.6970 - val_loss: 0.6945
# Epoch 370/1000
#  - 0s - loss: 0.6900 - val_loss: 0.6875
# Epoch 371/1000
#  - 0s - loss: 0.6831 - val_loss: 0.6807
# Epoch 372/1000
#  - 0s - loss: 0.6763 - val_loss: 0.6739
# Epoch 373/1000
#  - 0s - loss: 0.6696 - val_loss: 0.6672
# Epoch 374/1000
#  - 0s - loss: 0.6629 - val_loss: 0.6606
# Epoch 375/1000
#  - 0s - loss: 0.6564 - val_loss: 0.6540
# Epoch 376/1000
#  - 0s - loss: 0.6499 - val_loss: 0.6475
# Epoch 377/1000
#  - 0s - loss: 0.6434 - val_loss: 0.6411
# Epoch 378/1000
#  - 0s - loss: 0.6371 - val_loss: 0.6348
# Epoch 379/1000
#  - 0s - loss: 0.6308 - val_loss: 0.6285
# Epoch 380/1000
#  - 0s - loss: 0.6246 - val_loss: 0.6223
# Epoch 381/1000
#  - 0s - loss: 0.6184 - val_loss: 0.6162
# Epoch 382/1000
#  - 0s - loss: 0.6123 - val_loss: 0.6101
# Epoch 383/1000
#  - 0s - loss: 0.6063 - val_loss: 0.6041
# Epoch 384/1000
#  - 0s - loss: 0.6003 - val_loss: 0.5982
# Epoch 385/1000
#  - 0s - loss: 0.5945 - val_loss: 0.5923
# Epoch 386/1000
#  - 0s - loss: 0.5886 - val_loss: 0.5865
# Epoch 387/1000
#  - 0s - loss: 0.5829 - val_loss: 0.5808
# Epoch 388/1000
#  - 0s - loss: 0.5772 - val_loss: 0.5751
# Epoch 389/1000
#  - 0s - loss: 0.5716 - val_loss: 0.5695
# Epoch 390/1000
#  - 0s - loss: 0.5660 - val_loss: 0.5639
# Epoch 391/1000
#  - 0s - loss: 0.5605 - val_loss: 0.5584
# Epoch 392/1000
#  - 0s - loss: 0.5550 - val_loss: 0.5530
# Epoch 393/1000
#  - 0s - loss: 0.5496 - val_loss: 0.5476
# Epoch 394/1000
#  - 0s - loss: 0.5443 - val_loss: 0.5423
# Epoch 395/1000
#  - 0s - loss: 0.5390 - val_loss: 0.5370
# Epoch 396/1000
#  - 0s - loss: 0.5338 - val_loss: 0.5318
# Epoch 397/1000
#  - 0s - loss: 0.5286 - val_loss: 0.5267
# Epoch 398/1000
#  - 0s - loss: 0.5235 - val_loss: 0.5216
# Epoch 399/1000
#  - 0s - loss: 0.5185 - val_loss: 0.5166
# Epoch 400/1000
#  - 0s - loss: 0.5135 - val_loss: 0.5116
# Epoch 401/1000
#  - 0s - loss: 0.5085 - val_loss: 0.5066
# Epoch 402/1000
#  - 0s - loss: 0.5037 - val_loss: 0.5018
# Epoch 403/1000
#  - 0s - loss: 0.4988 - val_loss: 0.4969
# Epoch 404/1000
#  - 0s - loss: 0.4940 - val_loss: 0.4922
# Epoch 405/1000
#  - 0s - loss: 0.4893 - val_loss: 0.4874
# Epoch 406/1000
#  - 0s - loss: 0.4846 - val_loss: 0.4828
# Epoch 407/1000
#  - 0s - loss: 0.4800 - val_loss: 0.4782
# Epoch 408/1000
#  - 0s - loss: 0.4754 - val_loss: 0.4736
# Epoch 409/1000
#  - 0s - loss: 0.4709 - val_loss: 0.4691
# Epoch 410/1000
#  - 0s - loss: 0.4664 - val_loss: 0.4646
# Epoch 411/1000
#  - 0s - loss: 0.4619 - val_loss: 0.4602
# Epoch 412/1000
#  - 0s - loss: 0.4575 - val_loss: 0.4558
# Epoch 413/1000
#  - 0s - loss: 0.4532 - val_loss: 0.4514
# Epoch 414/1000
#  - 0s - loss: 0.4489 - val_loss: 0.4472
# Epoch 415/1000
#  - 0s - loss: 0.4446 - val_loss: 0.4429
# Epoch 416/1000
#  - 0s - loss: 0.4404 - val_loss: 0.4387
# Epoch 417/1000
#  - 0s - loss: 0.4363 - val_loss: 0.4346
# Epoch 418/1000
#  - 0s - loss: 0.4321 - val_loss: 0.4305
# Epoch 419/1000
#  - 0s - loss: 0.4281 - val_loss: 0.4264
# Epoch 420/1000
#  - 0s - loss: 0.4240 - val_loss: 0.4224
# Epoch 421/1000
#  - 0s - loss: 0.4200 - val_loss: 0.4184
# Epoch 422/1000
#  - 0s - loss: 0.4161 - val_loss: 0.4144
# Epoch 423/1000
#  - 0s - loss: 0.4122 - val_loss: 0.4105
# Epoch 424/1000
#  - 0s - loss: 0.4083 - val_loss: 0.4067
# Epoch 425/1000
#  - 0s - loss: 0.4045 - val_loss: 0.4029
# Epoch 426/1000
#  - 0s - loss: 0.4007 - val_loss: 0.3991
# Epoch 427/1000
#  - 0s - loss: 0.3969 - val_loss: 0.3953
# Epoch 428/1000
#  - 0s - loss: 0.3932 - val_loss: 0.3916
# Epoch 429/1000
#  - 0s - loss: 0.3895 - val_loss: 0.3880
# Epoch 430/1000
#  - 0s - loss: 0.3859 - val_loss: 0.3843
# Epoch 431/1000
#  - 0s - loss: 0.3823 - val_loss: 0.3808
# Epoch 432/1000
#  - 0s - loss: 0.3788 - val_loss: 0.3772
# Epoch 433/1000
#  - 0s - loss: 0.3752 - val_loss: 0.3737
# Epoch 434/1000
#  - 0s - loss: 0.3717 - val_loss: 0.3702
# Epoch 435/1000
#  - 0s - loss: 0.3683 - val_loss: 0.3668
# Epoch 436/1000
#  - 0s - loss: 0.3649 - val_loss: 0.3634
# Epoch 437/1000
#  - 0s - loss: 0.3615 - val_loss: 0.3600
# Epoch 438/1000
#  - 0s - loss: 0.3581 - val_loss: 0.3567
# Epoch 439/1000
#  - 0s - loss: 0.3548 - val_loss: 0.3533
# Epoch 440/1000
#  - 0s - loss: 0.3516 - val_loss: 0.3501
# Epoch 441/1000
#  - 0s - loss: 0.3483 - val_loss: 0.3468
# Epoch 442/1000
#  - 0s - loss: 0.3451 - val_loss: 0.3436
# Epoch 443/1000
#  - 0s - loss: 0.3419 - val_loss: 0.3405
# Epoch 444/1000
#  - 0s - loss: 0.3388 - val_loss: 0.3373
# Epoch 445/1000
#  - 0s - loss: 0.3357 - val_loss: 0.3342
# Epoch 446/1000
#  - 0s - loss: 0.3326 - val_loss: 0.3311
# Epoch 447/1000
#  - 0s - loss: 0.3295 - val_loss: 0.3281
# Epoch 448/1000
#  - 0s - loss: 0.3265 - val_loss: 0.3251
# Epoch 449/1000
#  - 0s - loss: 0.3235 - val_loss: 0.3221
# Epoch 450/1000
#  - 0s - loss: 0.3206 - val_loss: 0.3192
# Epoch 451/1000
#  - 0s - loss: 0.3176 - val_loss: 0.3162
# Epoch 452/1000
#  - 0s - loss: 0.3147 - val_loss: 0.3133
# Epoch 453/1000
#  - 0s - loss: 0.3119 - val_loss: 0.3105
# Epoch 454/1000
#  - 0s - loss: 0.3090 - val_loss: 0.3076
# Epoch 455/1000
#  - 0s - loss: 0.3062 - val_loss: 0.3048
# Epoch 456/1000
#  - 0s - loss: 0.3034 - val_loss: 0.3021
# Epoch 457/1000
#  - 0s - loss: 0.3007 - val_loss: 0.2993
# Epoch 458/1000
#  - 0s - loss: 0.2979 - val_loss: 0.2966
# Epoch 459/1000
#  - 0s - loss: 0.2952 - val_loss: 0.2939
# Epoch 460/1000
#  - 0s - loss: 0.2926 - val_loss: 0.2912
# Epoch 461/1000
#  - 0s - loss: 0.2899 - val_loss: 0.2886
# Epoch 462/1000
#  - 0s - loss: 0.2873 - val_loss: 0.2860
# Epoch 463/1000
#  - 0s - loss: 0.2847 - val_loss: 0.2834
# Epoch 464/1000
#  - 0s - loss: 0.2821 - val_loss: 0.2808
# Epoch 465/1000
#  - 0s - loss: 0.2796 - val_loss: 0.2783
# Epoch 466/1000
#  - 0s - loss: 0.2771 - val_loss: 0.2758
# Epoch 467/1000
#  - 0s - loss: 0.2746 - val_loss: 0.2733
# Epoch 468/1000
#  - 0s - loss: 0.2721 - val_loss: 0.2708
# Epoch 469/1000
#  - 0s - loss: 0.2697 - val_loss: 0.2684
# Epoch 470/1000
#  - 0s - loss: 0.2672 - val_loss: 0.2660
# Epoch 471/1000
#  - 0s - loss: 0.2648 - val_loss: 0.2636
# Epoch 472/1000
#  - 0s - loss: 0.2625 - val_loss: 0.2612
# Epoch 473/1000
#  - 0s - loss: 0.2601 - val_loss: 0.2589
# Epoch 474/1000
#  - 0s - loss: 0.2578 - val_loss: 0.2566
# Epoch 475/1000
#  - 0s - loss: 0.2555 - val_loss: 0.2543
# Epoch 476/1000
#  - 0s - loss: 0.2532 - val_loss: 0.2520
# Epoch 477/1000
#  - 0s - loss: 0.2510 - val_loss: 0.2497
# Epoch 478/1000
#  - 0s - loss: 0.2487 - val_loss: 0.2475
# Epoch 479/1000
#  - 0s - loss: 0.2465 - val_loss: 0.2453
# Epoch 480/1000
#  - 0s - loss: 0.2443 - val_loss: 0.2431
# Epoch 481/1000
#  - 0s - loss: 0.2422 - val_loss: 0.2410
# Epoch 482/1000
#  - 0s - loss: 0.2400 - val_loss: 0.2388
# Epoch 483/1000
#  - 0s - loss: 0.2379 - val_loss: 0.2367
# Epoch 484/1000
#  - 0s - loss: 0.2358 - val_loss: 0.2346
# Epoch 485/1000
#  - 0s - loss: 0.2337 - val_loss: 0.2325
# Epoch 486/1000
#  - 0s - loss: 0.2316 - val_loss: 0.2305
# Epoch 487/1000
#  - 0s - loss: 0.2296 - val_loss: 0.2284
# Epoch 488/1000
#  - 0s - loss: 0.2276 - val_loss: 0.2264
# Epoch 489/1000
#  - 0s - loss: 0.2256 - val_loss: 0.2244
# Epoch 490/1000
#  - 0s - loss: 0.2236 - val_loss: 0.2224
# Epoch 491/1000
#  - 0s - loss: 0.2216 - val_loss: 0.2204
# Epoch 492/1000
#  - 0s - loss: 0.2197 - val_loss: 0.2185
# Epoch 493/1000
#  - 0s - loss: 0.2177 - val_loss: 0.2166
# Epoch 494/1000
#  - 0s - loss: 0.2158 - val_loss: 0.2147
# Epoch 495/1000
#  - 0s - loss: 0.2139 - val_loss: 0.2128
# Epoch 496/1000
#  - 0s - loss: 0.2121 - val_loss: 0.2109
# Epoch 497/1000
#  - 0s - loss: 0.2102 - val_loss: 0.2091
# Epoch 498/1000
#  - 0s - loss: 0.2084 - val_loss: 0.2072
# Epoch 499/1000
#  - 0s - loss: 0.2066 - val_loss: 0.2054
# Epoch 500/1000
#  - 0s - loss: 0.2047 - val_loss: 0.2036
# Epoch 501/1000
#  - 0s - loss: 0.2030 - val_loss: 0.2018
# Epoch 502/1000
#  - 0s - loss: 0.2012 - val_loss: 0.2001
# Epoch 503/1000
#  - 0s - loss: 0.1994 - val_loss: 0.1983
# Epoch 504/1000
#  - 0s - loss: 0.1977 - val_loss: 0.1966
# Epoch 505/1000
#  - 0s - loss: 0.1960 - val_loss: 0.1949
# Epoch 506/1000
#  - 0s - loss: 0.1943 - val_loss: 0.1932
# Epoch 507/1000
#  - 0s - loss: 0.1926 - val_loss: 0.1915
# Epoch 508/1000
#  - 0s - loss: 0.1910 - val_loss: 0.1899
# Epoch 509/1000
#  - 0s - loss: 0.1893 - val_loss: 0.1882
# Epoch 510/1000
#  - 0s - loss: 0.1877 - val_loss: 0.1866
# Epoch 511/1000
#  - 0s - loss: 0.1861 - val_loss: 0.1850
# Epoch 512/1000
#  - 0s - loss: 0.1844 - val_loss: 0.1834
# Epoch 513/1000
#  - 0s - loss: 0.1829 - val_loss: 0.1818
# Epoch 514/1000
#  - 0s - loss: 0.1813 - val_loss: 0.1802
# Epoch 515/1000
#  - 0s - loss: 0.1797 - val_loss: 0.1787
# Epoch 516/1000
#  - 0s - loss: 0.1782 - val_loss: 0.1771
# Epoch 517/1000
#  - 0s - loss: 0.1767 - val_loss: 0.1756
# Epoch 518/1000
#  - 0s - loss: 0.1751 - val_loss: 0.1741
# Epoch 519/1000
#  - 0s - loss: 0.1736 - val_loss: 0.1726
# Epoch 520/1000
#  - 0s - loss: 0.1722 - val_loss: 0.1711
# Epoch 521/1000
#  - 0s - loss: 0.1707 - val_loss: 0.1696
# Epoch 522/1000
#  - 0s - loss: 0.1692 - val_loss: 0.1682
# Epoch 523/1000
#  - 0s - loss: 0.1678 - val_loss: 0.1668
# Epoch 524/1000
#  - 0s - loss: 0.1664 - val_loss: 0.1653
# Epoch 525/1000
#  - 0s - loss: 0.1649 - val_loss: 0.1639
# Epoch 526/1000
#  - 0s - loss: 0.1635 - val_loss: 0.1625
# Epoch 527/1000
#  - 0s - loss: 0.1621 - val_loss: 0.1611
# Epoch 528/1000
#  - 0s - loss: 0.1608 - val_loss: 0.1598
# Epoch 529/1000
#  - 0s - loss: 0.1594 - val_loss: 0.1584
# Epoch 530/1000
#  - 0s - loss: 0.1581 - val_loss: 0.1570
# Epoch 531/1000
#  - 0s - loss: 0.1567 - val_loss: 0.1557
# Epoch 532/1000
#  - 0s - loss: 0.1554 - val_loss: 0.1544
# Epoch 533/1000
#  - 0s - loss: 0.1541 - val_loss: 0.1531
# Epoch 534/1000
#  - 0s - loss: 0.1528 - val_loss: 0.1518
# Epoch 535/1000
#  - 0s - loss: 0.1515 - val_loss: 0.1505
# Epoch 536/1000
#  - 0s - loss: 0.1502 - val_loss: 0.1492
# Epoch 537/1000
#  - 0s - loss: 0.1490 - val_loss: 0.1480
# Epoch 538/1000
#  - 0s - loss: 0.1477 - val_loss: 0.1467
# Epoch 539/1000
#  - 0s - loss: 0.1465 - val_loss: 0.1455
# Epoch 540/1000
#  - 0s - loss: 0.1452 - val_loss: 0.1443
# Epoch 541/1000
#  - 0s - loss: 0.1440 - val_loss: 0.1430
# Epoch 542/1000
#  - 0s - loss: 0.1428 - val_loss: 0.1418
# Epoch 543/1000
#  - 0s - loss: 0.1416 - val_loss: 0.1406
# Epoch 544/1000
#  - 0s - loss: 0.1404 - val_loss: 0.1395
# Epoch 545/1000
#  - 0s - loss: 0.1393 - val_loss: 0.1383
# Epoch 546/1000
#  - 0s - loss: 0.1381 - val_loss: 0.1371
# Epoch 547/1000
#  - 0s - loss: 0.1370 - val_loss: 0.1360
# Epoch 548/1000
#  - 0s - loss: 0.1358 - val_loss: 0.1349
# Epoch 549/1000
#  - 0s - loss: 0.1347 - val_loss: 0.1337
# Epoch 550/1000
#  - 0s - loss: 0.1336 - val_loss: 0.1326
# Epoch 551/1000
#  - 0s - loss: 0.1325 - val_loss: 0.1315
# Epoch 552/1000
#  - 0s - loss: 0.1314 - val_loss: 0.1304
# Epoch 553/1000
#  - 0s - loss: 0.1303 - val_loss: 0.1293
# Epoch 554/1000
#  - 0s - loss: 0.1292 - val_loss: 0.1283
# Epoch 555/1000
#  - 0s - loss: 0.1281 - val_loss: 0.1272
# Epoch 556/1000
#  - 0s - loss: 0.1271 - val_loss: 0.1261
# Epoch 557/1000
#  - 0s - loss: 0.1260 - val_loss: 0.1251
# Epoch 558/1000
#  - 0s - loss: 0.1250 - val_loss: 0.1241
# Epoch 559/1000
#  - 0s - loss: 0.1240 - val_loss: 0.1230
# Epoch 560/1000
#  - 0s - loss: 0.1229 - val_loss: 0.1220
# Epoch 561/1000
#  - 0s - loss: 0.1219 - val_loss: 0.1210
# Epoch 562/1000
#  - 0s - loss: 0.1209 - val_loss: 0.1200
# Epoch 563/1000
#  - 0s - loss: 0.1199 - val_loss: 0.1190
# Epoch 564/1000
#  - 0s - loss: 0.1190 - val_loss: 0.1180
# Epoch 565/1000
#  - 0s - loss: 0.1180 - val_loss: 0.1171
# Epoch 566/1000
#  - 0s - loss: 0.1170 - val_loss: 0.1161
# Epoch 567/1000
#  - 0s - loss: 0.1161 - val_loss: 0.1152
# Epoch 568/1000
#  - 0s - loss: 0.1151 - val_loss: 0.1142
# Epoch 569/1000
#  - 0s - loss: 0.1142 - val_loss: 0.1133
# Epoch 570/1000
#  - 0s - loss: 0.1133 - val_loss: 0.1124
# Epoch 571/1000
#  - 0s - loss: 0.1123 - val_loss: 0.1114
# Epoch 572/1000
#  - 0s - loss: 0.1114 - val_loss: 0.1105
# Epoch 573/1000
#  - 0s - loss: 0.1105 - val_loss: 0.1096
# Epoch 574/1000
#  - 0s - loss: 0.1096 - val_loss: 0.1087
# Epoch 575/1000
#  - 0s - loss: 0.1087 - val_loss: 0.1079
# Epoch 576/1000
#  - 0s - loss: 0.1079 - val_loss: 0.1070
# Epoch 577/1000
#  - 0s - loss: 0.1070 - val_loss: 0.1061
# Epoch 578/1000
#  - 0s - loss: 0.1061 - val_loss: 0.1052
# Epoch 579/1000
#  - 0s - loss: 0.1053 - val_loss: 0.1044
# Epoch 580/1000
#  - 0s - loss: 0.1044 - val_loss: 0.1035
# Epoch 581/1000
#  - 0s - loss: 0.1036 - val_loss: 0.1027
# Epoch 582/1000
#  - 0s - loss: 0.1028 - val_loss: 0.1019
# Epoch 583/1000
#  - 0s - loss: 0.1019 - val_loss: 0.1011
# Epoch 584/1000
#  - 0s - loss: 0.1011 - val_loss: 0.1002
# Epoch 585/1000
#  - 0s - loss: 0.1003 - val_loss: 0.0994
# Epoch 586/1000
#  - 0s - loss: 0.0995 - val_loss: 0.0986
# Epoch 587/1000
#  - 0s - loss: 0.0987 - val_loss: 0.0979
# Epoch 588/1000
#  - 0s - loss: 0.0979 - val_loss: 0.0971
# Epoch 589/1000
#  - 0s - loss: 0.0971 - val_loss: 0.0963
# Epoch 590/1000
#  - 0s - loss: 0.0964 - val_loss: 0.0955
# Epoch 591/1000
#  - 0s - loss: 0.0956 - val_loss: 0.0948
# Epoch 592/1000
#  - 0s - loss: 0.0949 - val_loss: 0.0940
# Epoch 593/1000
#  - 0s - loss: 0.0941 - val_loss: 0.0933
# Epoch 594/1000
#  - 0s - loss: 0.0934 - val_loss: 0.0925
# Epoch 595/1000
#  - 0s - loss: 0.0926 - val_loss: 0.0918
# Epoch 596/1000
#  - 0s - loss: 0.0919 - val_loss: 0.0910
# Epoch 597/1000
#  - 0s - loss: 0.0912 - val_loss: 0.0903
# Epoch 598/1000
#  - 0s - loss: 0.0904 - val_loss: 0.0896
# Epoch 599/1000
#  - 0s - loss: 0.0897 - val_loss: 0.0889
# Epoch 600/1000
#  - 0s - loss: 0.0890 - val_loss: 0.0882
# Epoch 601/1000
#  - 0s - loss: 0.0883 - val_loss: 0.0875
# Epoch 602/1000
#  - 0s - loss: 0.0876 - val_loss: 0.0868
# Epoch 603/1000
#  - 0s - loss: 0.0870 - val_loss: 0.0861
# Epoch 604/1000
#  - 0s - loss: 0.0863 - val_loss: 0.0854
# Epoch 605/1000
#  - 0s - loss: 0.0856 - val_loss: 0.0848
# Epoch 606/1000
#  - 0s - loss: 0.0849 - val_loss: 0.0841
# Epoch 607/1000
#  - 0s - loss: 0.0843 - val_loss: 0.0834
# Epoch 608/1000
#  - 0s - loss: 0.0836 - val_loss: 0.0828
# Epoch 609/1000
#  - 0s - loss: 0.0830 - val_loss: 0.0821
# Epoch 610/1000
#  - 0s - loss: 0.0823 - val_loss: 0.0815
# Epoch 611/1000
#  - 0s - loss: 0.0817 - val_loss: 0.0809
# Epoch 612/1000
#  - 0s - loss: 0.0811 - val_loss: 0.0802
# Epoch 613/1000
#  - 0s - loss: 0.0804 - val_loss: 0.0796
# Epoch 614/1000
#  - 0s - loss: 0.0798 - val_loss: 0.0790
# Epoch 615/1000
#  - 0s - loss: 0.0792 - val_loss: 0.0784
# Epoch 616/1000
#  - 0s - loss: 0.0786 - val_loss: 0.0778
# Epoch 617/1000
#  - 0s - loss: 0.0780 - val_loss: 0.0772
# Epoch 618/1000
#  - 0s - loss: 0.0774 - val_loss: 0.0766
# Epoch 619/1000
#  - 0s - loss: 0.0768 - val_loss: 0.0760
# Epoch 620/1000
#  - 0s - loss: 0.0762 - val_loss: 0.0754
# Epoch 621/1000
#  - 0s - loss: 0.0756 - val_loss: 0.0748
# Epoch 622/1000
#  - 0s - loss: 0.0750 - val_loss: 0.0742
# Epoch 623/1000
#  - 0s - loss: 0.0745 - val_loss: 0.0737
# Epoch 624/1000
#  - 0s - loss: 0.0739 - val_loss: 0.0731
# Epoch 625/1000
#  - 0s - loss: 0.0733 - val_loss: 0.0725
# Epoch 626/1000
#  - 0s - loss: 0.0728 - val_loss: 0.0720
# Epoch 627/1000
#  - 0s - loss: 0.0722 - val_loss: 0.0714
# Epoch 628/1000
#  - 0s - loss: 0.0717 - val_loss: 0.0709
# Epoch 629/1000
#  - 0s - loss: 0.0711 - val_loss: 0.0704
# Epoch 630/1000
#  - 0s - loss: 0.0706 - val_loss: 0.0698
# Epoch 631/1000
#  - 0s - loss: 0.0701 - val_loss: 0.0693
# Epoch 632/1000
#  - 0s - loss: 0.0695 - val_loss: 0.0688
# Epoch 633/1000
#  - 0s - loss: 0.0690 - val_loss: 0.0682
# Epoch 634/1000
#  - 0s - loss: 0.0685 - val_loss: 0.0677
# Epoch 635/1000
#  - 0s - loss: 0.0680 - val_loss: 0.0672
# Epoch 636/1000
#  - 0s - loss: 0.0675 - val_loss: 0.0667
# Epoch 637/1000
#  - 0s - loss: 0.0670 - val_loss: 0.0662
# Epoch 638/1000
#  - 0s - loss: 0.0665 - val_loss: 0.0657
# Epoch 639/1000
#  - 0s - loss: 0.0660 - val_loss: 0.0652
# Epoch 640/1000
#  - 0s - loss: 0.0655 - val_loss: 0.0647
# Epoch 641/1000
#  - 0s - loss: 0.0650 - val_loss: 0.0642
# Epoch 642/1000
#  - 0s - loss: 0.0645 - val_loss: 0.0638
# Epoch 643/1000
#  - 0s - loss: 0.0640 - val_loss: 0.0633
# Epoch 644/1000
#  - 0s - loss: 0.0636 - val_loss: 0.0628
# Epoch 645/1000
#  - 0s - loss: 0.0631 - val_loss: 0.0623
# Epoch 646/1000
#  - 0s - loss: 0.0626 - val_loss: 0.0619
# Epoch 647/1000
#  - 0s - loss: 0.0622 - val_loss: 0.0614
# Epoch 648/1000
#  - 0s - loss: 0.0617 - val_loss: 0.0610
# Epoch 649/1000
#  - 0s - loss: 0.0613 - val_loss: 0.0605
# Epoch 650/1000
#  - 0s - loss: 0.0608 - val_loss: 0.0601
# Epoch 651/1000
#  - 0s - loss: 0.0604 - val_loss: 0.0596
# Epoch 652/1000
#  - 0s - loss: 0.0599 - val_loss: 0.0592
# Epoch 653/1000
#  - 0s - loss: 0.0595 - val_loss: 0.0587
# Epoch 654/1000
#  - 0s - loss: 0.0591 - val_loss: 0.0583
# Epoch 655/1000
#  - 0s - loss: 0.0586 - val_loss: 0.0579
# Epoch 656/1000
#  - 0s - loss: 0.0582 - val_loss: 0.0575
# Epoch 657/1000
#  - 0s - loss: 0.0578 - val_loss: 0.0570
# Epoch 658/1000
#  - 0s - loss: 0.0574 - val_loss: 0.0566
# Epoch 659/1000
#  - 0s - loss: 0.0569 - val_loss: 0.0562
# Epoch 660/1000
#  - 0s - loss: 0.0565 - val_loss: 0.0558
# Epoch 661/1000
#  - 0s - loss: 0.0561 - val_loss: 0.0554
# Epoch 662/1000
#  - 0s - loss: 0.0557 - val_loss: 0.0550
# Epoch 663/1000
#  - 0s - loss: 0.0553 - val_loss: 0.0546
# Epoch 664/1000
#  - 0s - loss: 0.0549 - val_loss: 0.0542
# Epoch 665/1000
#  - 0s - loss: 0.0545 - val_loss: 0.0538
# Epoch 666/1000
#  - 0s - loss: 0.0541 - val_loss: 0.0534
# Epoch 667/1000
#  - 0s - loss: 0.0538 - val_loss: 0.0530
# Epoch 668/1000
#  - 0s - loss: 0.0534 - val_loss: 0.0527
# Epoch 669/1000
#  - 0s - loss: 0.0530 - val_loss: 0.0523
# Epoch 670/1000
#  - 0s - loss: 0.0526 - val_loss: 0.0519
# Epoch 671/1000
#  - 0s - loss: 0.0523 - val_loss: 0.0515
# Epoch 672/1000
#  - 0s - loss: 0.0519 - val_loss: 0.0512
# Epoch 673/1000
#  - 0s - loss: 0.0515 - val_loss: 0.0508
# Epoch 674/1000
#  - 0s - loss: 0.0512 - val_loss: 0.0504
# Epoch 675/1000
#  - 0s - loss: 0.0508 - val_loss: 0.0501
# Epoch 676/1000
#  - 0s - loss: 0.0504 - val_loss: 0.0497
# Epoch 677/1000
#  - 0s - loss: 0.0501 - val_loss: 0.0494
# Epoch 678/1000
#  - 0s - loss: 0.0497 - val_loss: 0.0490
# Epoch 679/1000
#  - 0s - loss: 0.0494 - val_loss: 0.0487
# Epoch 680/1000
#  - 0s - loss: 0.0490 - val_loss: 0.0483
# Epoch 681/1000
#  - 0s - loss: 0.0487 - val_loss: 0.0480
# Epoch 682/1000
#  - 0s - loss: 0.0484 - val_loss: 0.0477
# Epoch 683/1000
#  - 0s - loss: 0.0480 - val_loss: 0.0473
# Epoch 684/1000
#  - 0s - loss: 0.0477 - val_loss: 0.0470
# Epoch 685/1000
#  - 0s - loss: 0.0474 - val_loss: 0.0467
# Epoch 686/1000
#  - 0s - loss: 0.0470 - val_loss: 0.0463
# Epoch 687/1000
#  - 0s - loss: 0.0467 - val_loss: 0.0460
# Epoch 688/1000
#  - 0s - loss: 0.0464 - val_loss: 0.0457
# Epoch 689/1000
#  - 0s - loss: 0.0461 - val_loss: 0.0454
# Epoch 690/1000
#  - 0s - loss: 0.0458 - val_loss: 0.0451
# Epoch 691/1000
#  - 0s - loss: 0.0455 - val_loss: 0.0448
# Epoch 692/1000
#  - 0s - loss: 0.0452 - val_loss: 0.0445
# Epoch 693/1000
#  - 0s - loss: 0.0448 - val_loss: 0.0442
# Epoch 694/1000
#  - 0s - loss: 0.0445 - val_loss: 0.0439
# Epoch 695/1000
#  - 0s - loss: 0.0442 - val_loss: 0.0436
# Epoch 696/1000
#  - 0s - loss: 0.0439 - val_loss: 0.0433
# Epoch 697/1000
#  - 0s - loss: 0.0436 - val_loss: 0.0430
# Epoch 698/1000
#  - 0s - loss: 0.0434 - val_loss: 0.0427
# Epoch 699/1000
#  - 0s - loss: 0.0431 - val_loss: 0.0424
# Epoch 700/1000
#  - 0s - loss: 0.0428 - val_loss: 0.0421
# Epoch 701/1000
#  - 0s - loss: 0.0425 - val_loss: 0.0418
# Epoch 702/1000
#  - 0s - loss: 0.0422 - val_loss: 0.0415
# Epoch 703/1000
#  - 0s - loss: 0.0419 - val_loss: 0.0413
# Epoch 704/1000
#  - 0s - loss: 0.0416 - val_loss: 0.0410
# Epoch 705/1000
#  - 0s - loss: 0.0414 - val_loss: 0.0407
# Epoch 706/1000
#  - 0s - loss: 0.0411 - val_loss: 0.0404
# Epoch 707/1000
#  - 0s - loss: 0.0408 - val_loss: 0.0402
# Epoch 708/1000
#  - 0s - loss: 0.0406 - val_loss: 0.0399
# Epoch 709/1000
#  - 0s - loss: 0.0403 - val_loss: 0.0396
# Epoch 710/1000
#  - 0s - loss: 0.0400 - val_loss: 0.0394
# Epoch 711/1000
#  - 0s - loss: 0.0398 - val_loss: 0.0391
# Epoch 712/1000
#  - 0s - loss: 0.0395 - val_loss: 0.0388
# Epoch 713/1000
#  - 0s - loss: 0.0393 - val_loss: 0.0386
# Epoch 714/1000
#  - 0s - loss: 0.0390 - val_loss: 0.0383
# Epoch 715/1000
#  - 0s - loss: 0.0387 - val_loss: 0.0381
# Epoch 716/1000
#  - 0s - loss: 0.0385 - val_loss: 0.0378
# Epoch 717/1000
#  - 0s - loss: 0.0383 - val_loss: 0.0376
# Epoch 718/1000
#  - 0s - loss: 0.0380 - val_loss: 0.0373
# Epoch 719/1000
#  - 0s - loss: 0.0378 - val_loss: 0.0371
# Epoch 720/1000
#  - 0s - loss: 0.0375 - val_loss: 0.0369
# Epoch 721/1000
#  - 0s - loss: 0.0373 - val_loss: 0.0366
# Epoch 722/1000
#  - 0s - loss: 0.0370 - val_loss: 0.0364
# Epoch 723/1000
#  - 0s - loss: 0.0368 - val_loss: 0.0362
# Epoch 724/1000
#  - 0s - loss: 0.0366 - val_loss: 0.0359
# Epoch 725/1000
#  - 0s - loss: 0.0363 - val_loss: 0.0357
# Epoch 726/1000
#  - 0s - loss: 0.0361 - val_loss: 0.0355
# Epoch 727/1000
#  - 0s - loss: 0.0359 - val_loss: 0.0352
# Epoch 728/1000
#  - 0s - loss: 0.0357 - val_loss: 0.0350
# Epoch 729/1000
#  - 0s - loss: 0.0354 - val_loss: 0.0348
# Epoch 730/1000
#  - 0s - loss: 0.0352 - val_loss: 0.0346
# Epoch 731/1000
#  - 0s - loss: 0.0350 - val_loss: 0.0344
# Epoch 732/1000
#  - 0s - loss: 0.0348 - val_loss: 0.0341
# Epoch 733/1000
#  - 0s - loss: 0.0346 - val_loss: 0.0339
# Epoch 734/1000
#  - 0s - loss: 0.0344 - val_loss: 0.0337
# Epoch 735/1000
#  - 0s - loss: 0.0341 - val_loss: 0.0335
# Epoch 736/1000
#  - 0s - loss: 0.0339 - val_loss: 0.0333
# Epoch 737/1000
#  - 0s - loss: 0.0337 - val_loss: 0.0331
# Epoch 738/1000
#  - 0s - loss: 0.0335 - val_loss: 0.0329
# Epoch 739/1000
#  - 0s - loss: 0.0333 - val_loss: 0.0327
# Epoch 740/1000
#  - 0s - loss: 0.0331 - val_loss: 0.0325
# Epoch 741/1000
#  - 0s - loss: 0.0329 - val_loss: 0.0323
# Epoch 742/1000
#  - 0s - loss: 0.0327 - val_loss: 0.0321
# Epoch 743/1000
#  - 0s - loss: 0.0325 - val_loss: 0.0319
# Epoch 744/1000
#  - 0s - loss: 0.0323 - val_loss: 0.0317
# Epoch 745/1000
#  - 0s - loss: 0.0321 - val_loss: 0.0315
# Epoch 746/1000
#  - 0s - loss: 0.0319 - val_loss: 0.0313
# Epoch 747/1000
#  - 0s - loss: 0.0317 - val_loss: 0.0311
# Epoch 748/1000
#  - 0s - loss: 0.0316 - val_loss: 0.0309
# Epoch 749/1000
#  - 0s - loss: 0.0314 - val_loss: 0.0308
# Epoch 750/1000
#  - 0s - loss: 0.0312 - val_loss: 0.0306
# Epoch 751/1000
#  - 0s - loss: 0.0310 - val_loss: 0.0304
# Epoch 752/1000
#  - 0s - loss: 0.0308 - val_loss: 0.0302
# Epoch 753/1000
#  - 0s - loss: 0.0306 - val_loss: 0.0300
# Epoch 754/1000
#  - 0s - loss: 0.0305 - val_loss: 0.0298
# Epoch 755/1000
#  - 0s - loss: 0.0303 - val_loss: 0.0297
# Epoch 756/1000
#  - 0s - loss: 0.0301 - val_loss: 0.0295
# Epoch 757/1000
#  - 0s - loss: 0.0299 - val_loss: 0.0293
# Epoch 758/1000
#  - 0s - loss: 0.0298 - val_loss: 0.0292
# Epoch 759/1000
#  - 0s - loss: 0.0296 - val_loss: 0.0290
# Epoch 760/1000
#  - 0s - loss: 0.0294 - val_loss: 0.0288
# Epoch 761/1000
#  - 0s - loss: 0.0292 - val_loss: 0.0286
# Epoch 762/1000
#  - 0s - loss: 0.0291 - val_loss: 0.0285
# Epoch 763/1000
#  - 0s - loss: 0.0289 - val_loss: 0.0283
# Epoch 764/1000
#  - 0s - loss: 0.0287 - val_loss: 0.0282
# Epoch 765/1000
#  - 0s - loss: 0.0286 - val_loss: 0.0280
# Epoch 766/1000
#  - 0s - loss: 0.0284 - val_loss: 0.0278
# Epoch 767/1000
#  - 0s - loss: 0.0283 - val_loss: 0.0277
# Epoch 768/1000
#  - 0s - loss: 0.0281 - val_loss: 0.0275
# Epoch 769/1000
#  - 0s - loss: 0.0279 - val_loss: 0.0274
# Epoch 770/1000
#  - 0s - loss: 0.0278 - val_loss: 0.0272
# Epoch 771/1000
#  - 0s - loss: 0.0276 - val_loss: 0.0271
# Epoch 772/1000
#  - 0s - loss: 0.0275 - val_loss: 0.0269
# Epoch 773/1000
#  - 0s - loss: 0.0273 - val_loss: 0.0267
# Epoch 774/1000
#  - 0s - loss: 0.0272 - val_loss: 0.0266
# Epoch 775/1000
#  - 0s - loss: 0.0270 - val_loss: 0.0265
# Epoch 776/1000
#  - 0s - loss: 0.0269 - val_loss: 0.0263
# Epoch 777/1000
#  - 0s - loss: 0.0267 - val_loss: 0.0262
# Epoch 778/1000
#  - 0s - loss: 0.0266 - val_loss: 0.0260
# Epoch 779/1000
#  - 0s - loss: 0.0265 - val_loss: 0.0259
# Epoch 780/1000
#  - 0s - loss: 0.0263 - val_loss: 0.0257
# Epoch 781/1000
#  - 0s - loss: 0.0262 - val_loss: 0.0256
# Epoch 782/1000
#  - 0s - loss: 0.0260 - val_loss: 0.0255
# Epoch 783/1000
#  - 0s - loss: 0.0259 - val_loss: 0.0253
# Epoch 784/1000
#  - 0s - loss: 0.0258 - val_loss: 0.0252
# Epoch 785/1000
#  - 0s - loss: 0.0256 - val_loss: 0.0250
# Epoch 786/1000
#  - 0s - loss: 0.0255 - val_loss: 0.0249
# Epoch 787/1000
#  - 0s - loss: 0.0253 - val_loss: 0.0248
# Epoch 788/1000
#  - 0s - loss: 0.0252 - val_loss: 0.0246
# Epoch 789/1000
#  - 0s - loss: 0.0251 - val_loss: 0.0245
# Epoch 790/1000
#  - 0s - loss: 0.0249 - val_loss: 0.0244
# Epoch 791/1000
#  - 0s - loss: 0.0248 - val_loss: 0.0243
# Epoch 792/1000
#  - 0s - loss: 0.0247 - val_loss: 0.0241
# Epoch 793/1000
#  - 0s - loss: 0.0246 - val_loss: 0.0240
# Epoch 794/1000
#  - 0s - loss: 0.0244 - val_loss: 0.0239
# Epoch 795/1000
#  - 0s - loss: 0.0243 - val_loss: 0.0238
# Epoch 796/1000
#  - 0s - loss: 0.0242 - val_loss: 0.0236
# Epoch 797/1000
#  - 0s - loss: 0.0241 - val_loss: 0.0235
# Epoch 798/1000
#  - 0s - loss: 0.0239 - val_loss: 0.0234
# Epoch 799/1000
#  - 0s - loss: 0.0238 - val_loss: 0.0233
# Epoch 800/1000
#  - 0s - loss: 0.0237 - val_loss: 0.0231
# Epoch 801/1000
#  - 0s - loss: 0.0236 - val_loss: 0.0230
# Epoch 802/1000
#  - 0s - loss: 0.0235 - val_loss: 0.0229
# Epoch 803/1000
#  - 0s - loss: 0.0233 - val_loss: 0.0228
# Epoch 804/1000
#  - 0s - loss: 0.0232 - val_loss: 0.0227
# Epoch 805/1000
#  - 0s - loss: 0.0231 - val_loss: 0.0226
# Epoch 806/1000
#  - 0s - loss: 0.0230 - val_loss: 0.0225
# Epoch 807/1000
#  - 0s - loss: 0.0229 - val_loss: 0.0223
# Epoch 808/1000
#  - 0s - loss: 0.0228 - val_loss: 0.0222
# Epoch 809/1000
#  - 0s - loss: 0.0227 - val_loss: 0.0221
# Epoch 810/1000
#  - 0s - loss: 0.0226 - val_loss: 0.0220
# Epoch 811/1000
#  - 0s - loss: 0.0224 - val_loss: 0.0219
# Epoch 812/1000
#  - 0s - loss: 0.0223 - val_loss: 0.0218
# Epoch 813/1000
#  - 0s - loss: 0.0222 - val_loss: 0.0217
# Epoch 814/1000
#  - 0s - loss: 0.0221 - val_loss: 0.0216
# Epoch 815/1000
#  - 0s - loss: 0.0220 - val_loss: 0.0215
# Epoch 816/1000
#  - 0s - loss: 0.0219 - val_loss: 0.0214
# Epoch 817/1000
#  - 0s - loss: 0.0218 - val_loss: 0.0213
# Epoch 818/1000
#  - 0s - loss: 0.0217 - val_loss: 0.0212
# Epoch 819/1000
#  - 0s - loss: 0.0216 - val_loss: 0.0211
# Epoch 820/1000
#  - 0s - loss: 0.0215 - val_loss: 0.0210
# Epoch 821/1000
#  - 0s - loss: 0.0214 - val_loss: 0.0209
# Epoch 822/1000
#  - 0s - loss: 0.0213 - val_loss: 0.0208
# Epoch 823/1000
#  - 0s - loss: 0.0212 - val_loss: 0.0207
# Epoch 824/1000
#  - 0s - loss: 0.0211 - val_loss: 0.0206
# Epoch 825/1000
#  - 0s - loss: 0.0210 - val_loss: 0.0205
# Epoch 826/1000
#  - 0s - loss: 0.0209 - val_loss: 0.0204
# Epoch 827/1000
#  - 0s - loss: 0.0208 - val_loss: 0.0203
# Epoch 828/1000
#  - 0s - loss: 0.0207 - val_loss: 0.0202
# Epoch 829/1000
#  - 0s - loss: 0.0206 - val_loss: 0.0201
# Epoch 830/1000
#  - 0s - loss: 0.0206 - val_loss: 0.0200
# Epoch 831/1000
#  - 0s - loss: 0.0205 - val_loss: 0.0199
# Epoch 832/1000
#  - 0s - loss: 0.0204 - val_loss: 0.0198
# Epoch 833/1000
#  - 0s - loss: 0.0203 - val_loss: 0.0198
# Epoch 834/1000
#  - 0s - loss: 0.0202 - val_loss: 0.0197
# Epoch 835/1000
#  - 0s - loss: 0.0201 - val_loss: 0.0196
# Epoch 836/1000
#  - 0s - loss: 0.0200 - val_loss: 0.0195
# Epoch 837/1000
#  - 0s - loss: 0.0199 - val_loss: 0.0194
# Epoch 838/1000
#  - 0s - loss: 0.0198 - val_loss: 0.0193
# Epoch 839/1000
#  - 0s - loss: 0.0198 - val_loss: 0.0192
# Epoch 840/1000
#  - 0s - loss: 0.0197 - val_loss: 0.0192
# Epoch 841/1000
#  - 0s - loss: 0.0196 - val_loss: 0.0191
# Epoch 842/1000
#  - 0s - loss: 0.0195 - val_loss: 0.0190
# Epoch 843/1000
#  - 0s - loss: 0.0194 - val_loss: 0.0189
# Epoch 844/1000
#  - 0s - loss: 0.0193 - val_loss: 0.0188
# Epoch 845/1000
#  - 0s - loss: 0.0193 - val_loss: 0.0188
# Epoch 846/1000
#  - 0s - loss: 0.0192 - val_loss: 0.0187
# Epoch 847/1000
#  - 0s - loss: 0.0191 - val_loss: 0.0186
# Epoch 848/1000
#  - 0s - loss: 0.0190 - val_loss: 0.0185
# Epoch 849/1000
#  - 0s - loss: 0.0189 - val_loss: 0.0184
# Epoch 850/1000
#  - 0s - loss: 0.0189 - val_loss: 0.0184
# Epoch 851/1000
#  - 0s - loss: 0.0188 - val_loss: 0.0183
# Epoch 852/1000
#  - 0s - loss: 0.0187 - val_loss: 0.0182
# Epoch 853/1000
#  - 0s - loss: 0.0186 - val_loss: 0.0181
# Epoch 854/1000
#  - 0s - loss: 0.0186 - val_loss: 0.0181
# Epoch 855/1000
#  - 0s - loss: 0.0185 - val_loss: 0.0180
# Epoch 856/1000
#  - 0s - loss: 0.0184 - val_loss: 0.0179
# Epoch 857/1000
#  - 0s - loss: 0.0183 - val_loss: 0.0178
# Epoch 858/1000
#  - 0s - loss: 0.0183 - val_loss: 0.0178
# Epoch 859/1000
#  - 0s - loss: 0.0182 - val_loss: 0.0177
# Epoch 860/1000
#  - 0s - loss: 0.0181 - val_loss: 0.0176
# Epoch 861/1000
#  - 0s - loss: 0.0181 - val_loss: 0.0176
# Epoch 862/1000
#  - 0s - loss: 0.0180 - val_loss: 0.0175
# Epoch 863/1000
#  - 0s - loss: 0.0179 - val_loss: 0.0174
# Epoch 864/1000
#  - 0s - loss: 0.0178 - val_loss: 0.0174
# Epoch 865/1000
#  - 0s - loss: 0.0178 - val_loss: 0.0173
# Epoch 866/1000
#  - 0s - loss: 0.0177 - val_loss: 0.0172
# Epoch 867/1000
#  - 0s - loss: 0.0176 - val_loss: 0.0172
# Epoch 868/1000
#  - 0s - loss: 0.0176 - val_loss: 0.0171
# Epoch 869/1000
#  - 0s - loss: 0.0175 - val_loss: 0.0170
# Epoch 870/1000
#  - 0s - loss: 0.0174 - val_loss: 0.0170
# Epoch 871/1000
#  - 0s - loss: 0.0174 - val_loss: 0.0169
# Epoch 872/1000
#  - 0s - loss: 0.0173 - val_loss: 0.0168
# Epoch 873/1000
#  - 0s - loss: 0.0173 - val_loss: 0.0168
# Epoch 874/1000
#  - 0s - loss: 0.0172 - val_loss: 0.0167
# Epoch 875/1000
#  - 0s - loss: 0.0171 - val_loss: 0.0167
# Epoch 876/1000
#  - 0s - loss: 0.0171 - val_loss: 0.0166
# Epoch 877/1000
#  - 0s - loss: 0.0170 - val_loss: 0.0165
# Epoch 878/1000
#  - 0s - loss: 0.0169 - val_loss: 0.0165
# Epoch 879/1000
#  - 0s - loss: 0.0169 - val_loss: 0.0164
# Epoch 880/1000
#  - 0s - loss: 0.0168 - val_loss: 0.0164
# Epoch 881/1000
#  - 0s - loss: 0.0168 - val_loss: 0.0163
# Epoch 882/1000
#  - 0s - loss: 0.0167 - val_loss: 0.0162
# Epoch 883/1000
#  - 0s - loss: 0.0166 - val_loss: 0.0162
# Epoch 884/1000
#  - 0s - loss: 0.0166 - val_loss: 0.0161
# Epoch 885/1000
#  - 0s - loss: 0.0165 - val_loss: 0.0161
# Epoch 886/1000
#  - 0s - loss: 0.0165 - val_loss: 0.0160
# Epoch 887/1000
#  - 0s - loss: 0.0164 - val_loss: 0.0160
# Epoch 888/1000
#  - 0s - loss: 0.0164 - val_loss: 0.0159
# Epoch 889/1000
#  - 0s - loss: 0.0163 - val_loss: 0.0158
# Epoch 890/1000
#  - 0s - loss: 0.0163 - val_loss: 0.0158
# Epoch 891/1000
#  - 0s - loss: 0.0162 - val_loss: 0.0157
# Epoch 892/1000
#  - 0s - loss: 0.0161 - val_loss: 0.0157
# Epoch 893/1000
#  - 0s - loss: 0.0161 - val_loss: 0.0156
# Epoch 894/1000
#  - 0s - loss: 0.0160 - val_loss: 0.0156
# Epoch 895/1000
#  - 0s - loss: 0.0160 - val_loss: 0.0155
# Epoch 896/1000
#  - 0s - loss: 0.0159 - val_loss: 0.0155
# Epoch 897/1000
#  - 0s - loss: 0.0159 - val_loss: 0.0154
# Epoch 898/1000
#  - 0s - loss: 0.0158 - val_loss: 0.0154
# Epoch 899/1000
#  - 0s - loss: 0.0158 - val_loss: 0.0153
# Epoch 900/1000
#  - 0s - loss: 0.0157 - val_loss: 0.0153
# Epoch 901/1000
#  - 0s - loss: 0.0157 - val_loss: 0.0152
# Epoch 902/1000
#  - 0s - loss: 0.0156 - val_loss: 0.0152
# Epoch 903/1000
#  - 0s - loss: 0.0156 - val_loss: 0.0151
# Epoch 904/1000
#  - 0s - loss: 0.0155 - val_loss: 0.0151
# Epoch 905/1000
#  - 0s - loss: 0.0155 - val_loss: 0.0150
# Epoch 906/1000
#  - 0s - loss: 0.0154 - val_loss: 0.0150
# Epoch 907/1000
#  - 0s - loss: 0.0154 - val_loss: 0.0149
# Epoch 908/1000
#  - 0s - loss: 0.0153 - val_loss: 0.0149
# Epoch 909/1000
#  - 0s - loss: 0.0153 - val_loss: 0.0149
# Epoch 910/1000
#  - 0s - loss: 0.0152 - val_loss: 0.0148
# Epoch 911/1000
#  - 0s - loss: 0.0152 - val_loss: 0.0148
# Epoch 912/1000
#  - 0s - loss: 0.0152 - val_loss: 0.0147
# Epoch 913/1000
#  - 0s - loss: 0.0151 - val_loss: 0.0147
# Epoch 914/1000
#  - 0s - loss: 0.0151 - val_loss: 0.0146
# Epoch 915/1000
#  - 0s - loss: 0.0150 - val_loss: 0.0146
# Epoch 916/1000
#  - 0s - loss: 0.0150 - val_loss: 0.0145
# Epoch 917/1000
#  - 0s - loss: 0.0149 - val_loss: 0.0145
# Epoch 918/1000
#  - 0s - loss: 0.0149 - val_loss: 0.0145
# Epoch 919/1000
#  - 0s - loss: 0.0148 - val_loss: 0.0144
# Epoch 920/1000
#  - 0s - loss: 0.0148 - val_loss: 0.0144
# Epoch 921/1000
#  - 0s - loss: 0.0148 - val_loss: 0.0143
# Epoch 922/1000
#  - 0s - loss: 0.0147 - val_loss: 0.0143
# Epoch 923/1000
#  - 0s - loss: 0.0147 - val_loss: 0.0143
# Epoch 924/1000
#  - 0s - loss: 0.0146 - val_loss: 0.0142
# Epoch 925/1000
#  - 0s - loss: 0.0146 - val_loss: 0.0142
# Epoch 926/1000
#  - 0s - loss: 0.0146 - val_loss: 0.0141
# Epoch 927/1000
#  - 0s - loss: 0.0145 - val_loss: 0.0141
# Epoch 928/1000
#  - 0s - loss: 0.0145 - val_loss: 0.0141
# Epoch 929/1000
#  - 0s - loss: 0.0144 - val_loss: 0.0140
# Epoch 930/1000
#  - 0s - loss: 0.0144 - val_loss: 0.0140
# Epoch 931/1000
#  - 0s - loss: 0.0144 - val_loss: 0.0139
# Epoch 932/1000
#  - 0s - loss: 0.0143 - val_loss: 0.0139
# Epoch 933/1000
#  - 0s - loss: 0.0143 - val_loss: 0.0139
# Epoch 934/1000
#  - 0s - loss: 0.0143 - val_loss: 0.0138
# Epoch 935/1000
#  - 0s - loss: 0.0142 - val_loss: 0.0138
# Epoch 936/1000
#  - 0s - loss: 0.0142 - val_loss: 0.0138
# Epoch 937/1000
#  - 0s - loss: 0.0141 - val_loss: 0.0137
# Epoch 938/1000
#  - 0s - loss: 0.0141 - val_loss: 0.0137
# Epoch 939/1000
#  - 0s - loss: 0.0141 - val_loss: 0.0137
# Epoch 940/1000
#  - 0s - loss: 0.0140 - val_loss: 0.0136
# Epoch 941/1000
#  - 0s - loss: 0.0140 - val_loss: 0.0136
# Epoch 942/1000
#  - 0s - loss: 0.0140 - val_loss: 0.0136
# Epoch 943/1000
#  - 0s - loss: 0.0139 - val_loss: 0.0135
# Epoch 944/1000
#  - 0s - loss: 0.0139 - val_loss: 0.0135
# Epoch 945/1000
#  - 0s - loss: 0.0139 - val_loss: 0.0135
# Epoch 946/1000
#  - 0s - loss: 0.0138 - val_loss: 0.0134
# Epoch 947/1000
#  - 0s - loss: 0.0138 - val_loss: 0.0134
# Epoch 948/1000
#  - 0s - loss: 0.0138 - val_loss: 0.0134
# Epoch 949/1000
#  - 0s - loss: 0.0137 - val_loss: 0.0133
# Epoch 950/1000
#  - 0s - loss: 0.0137 - val_loss: 0.0133
# Epoch 951/1000
#  - 0s - loss: 0.0137 - val_loss: 0.0133
# Epoch 952/1000
#  - 0s - loss: 0.0136 - val_loss: 0.0132
# Epoch 953/1000
#  - 0s - loss: 0.0136 - val_loss: 0.0132
# Epoch 954/1000
#  - 0s - loss: 0.0136 - val_loss: 0.0132
# Epoch 955/1000
#  - 0s - loss: 0.0135 - val_loss: 0.0131
# Epoch 956/1000
#  - 0s - loss: 0.0135 - val_loss: 0.0131
# Epoch 957/1000
#  - 0s - loss: 0.0135 - val_loss: 0.0131
# Epoch 958/1000
#  - 0s - loss: 0.0134 - val_loss: 0.0130
# Epoch 959/1000
#  - 0s - loss: 0.0134 - val_loss: 0.0130
# Epoch 960/1000
#  - 0s - loss: 0.0134 - val_loss: 0.0130
# Epoch 961/1000
#  - 0s - loss: 0.0133 - val_loss: 0.0130
# Epoch 962/1000
#  - 0s - loss: 0.0133 - val_loss: 0.0129
# Epoch 963/1000
#  - 0s - loss: 0.0133 - val_loss: 0.0129
# Epoch 964/1000
#  - 0s - loss: 0.0133 - val_loss: 0.0129
# Epoch 965/1000
#  - 0s - loss: 0.0132 - val_loss: 0.0128
# Epoch 966/1000
#  - 0s - loss: 0.0132 - val_loss: 0.0128
# Epoch 967/1000
#  - 0s - loss: 0.0132 - val_loss: 0.0128
# Epoch 968/1000
#  - 0s - loss: 0.0131 - val_loss: 0.0128
# Epoch 969/1000
#  - 0s - loss: 0.0131 - val_loss: 0.0127
# Epoch 970/1000
#  - 0s - loss: 0.0131 - val_loss: 0.0127
# Epoch 971/1000
#  - 0s - loss: 0.0131 - val_loss: 0.0127
# Epoch 972/1000
#  - 0s - loss: 0.0130 - val_loss: 0.0127
# Epoch 973/1000
#  - 0s - loss: 0.0130 - val_loss: 0.0126
# Epoch 974/1000
#  - 0s - loss: 0.0130 - val_loss: 0.0126
# Epoch 975/1000
#  - 0s - loss: 0.0130 - val_loss: 0.0126
# Epoch 976/1000
#  - 0s - loss: 0.0129 - val_loss: 0.0126
# Epoch 977/1000
#  - 0s - loss: 0.0129 - val_loss: 0.0125
# Epoch 978/1000
#  - 0s - loss: 0.0129 - val_loss: 0.0125
# Epoch 979/1000
#  - 0s - loss: 0.0128 - val_loss: 0.0125
# Epoch 980/1000
#  - 0s - loss: 0.0128 - val_loss: 0.0125
# Epoch 981/1000
#  - 0s - loss: 0.0128 - val_loss: 0.0124
# Epoch 982/1000
#  - 0s - loss: 0.0128 - val_loss: 0.0124
# Epoch 983/1000
#  - 0s - loss: 0.0127 - val_loss: 0.0124
# Epoch 984/1000
#  - 0s - loss: 0.0127 - val_loss: 0.0124
# Epoch 985/1000
#  - 0s - loss: 0.0127 - val_loss: 0.0123
# Epoch 986/1000
#  - 0s - loss: 0.0127 - val_loss: 0.0123
# Epoch 987/1000
#  - 0s - loss: 0.0126 - val_loss: 0.0123
# Epoch 988/1000
#  - 0s - loss: 0.0126 - val_loss: 0.0123
# Epoch 989/1000
#  - 0s - loss: 0.0126 - val_loss: 0.0122
# Epoch 990/1000
#  - 0s - loss: 0.0126 - val_loss: 0.0122
# Epoch 991/1000
#  - 0s - loss: 0.0126 - val_loss: 0.0122
# Epoch 992/1000
#  - 0s - loss: 0.0125 - val_loss: 0.0122
# Epoch 993/1000
#  - 0s - loss: 0.0125 - val_loss: 0.0122
# Epoch 994/1000
#  - 0s - loss: 0.0125 - val_loss: 0.0121
# Epoch 995/1000
#  - 0s - loss: 0.0125 - val_loss: 0.0121
# Epoch 996/1000
#  - 0s - loss: 0.0124 - val_loss: 0.0121
# Epoch 997/1000
#  - 0s - loss: 0.0124 - val_loss: 0.0121
# Epoch 998/1000
#  - 0s - loss: 0.0124 - val_loss: 0.0121
# Epoch 999/1000
#  - 0s - loss: 0.0124 - val_loss: 0.0120
# Epoch 1000/1000
#  - 0s - loss: 0.0124 - val_loss: 0.0120

# %%
plot_loss(history)

# %%
# Generate predictions

model = load_model("%s.h5" % (model_name))

x_test_new = []
for l in x_test:
    if not 0 in l:
        x_test_new.append(l)
                
reconstructed = model.predict(np.array(x_test_new))

error = abs(x_test_new-reconstructed)/x_test_new

# %%
error_reformat = []
for i in range(4):
    error_reformat.append([])

for i in range(len(error)):
    for j in range(4):
        if i == len(error)-1:
            for val in error[i][WINDOW*j:WINDOW+WINDOW*j]:
                error_reformat[j].append(val)
        else:
            error_reformat[j].append(error[i][WINDOW*j])
            
inp = []
outp = []
for i in range(4):
    inp.append([])
    outp.append([])
    
for i in range(len(reconstructed)):
    for j in range(4):
        if i == len(reconstructed)-1:
            for val in reconstructed[i][WINDOW*j:WINDOW+WINDOW*j]:
                outp[j].append(val)
            for val in x_test_new[i][WINDOW*j:WINDOW+WINDOW*j]:
                inp[j].append(val)
        else:
            outp[j].append(reconstructed[i][WINDOW*j])
            inp[j].append(x_test_new[i][WINDOW*j])

# %%
labels = data['HLT']

#bins = np.linspace(0,1,50)
bins = 50
plt.figure(figsize=[20,10])
for i in range(len(error_reformat)):
    plt.subplot(2,2,i+1)
    plt.hist(error_reformat[i],bins=bins,label=labels[i],alpha=.5)
    plt.legend()

lumi = data[str(runs[2])]['lumiid'] 
#lumi = np.linspace(0,len(error_reformat[0]),len(error_reformat[0]))
plt.figure(figsize=[20,10])
for i in range(0,4):
    plt.subplot(2,2,i+1)
    plt.scatter(lumi,error_reformat[i],label=labels[i],alpha=.5)
    plt.xlabel('lumi id')
    plt.ylabel('error')
    plt.legend()    

plt.show()

# %%
plt.figure(figsize=[10,10])
for i in range(0,4):
    plt.subplot(2,2,i+1)
    plt.plot(outp[i],inp[i],label=labels[i], linestyle='',marker='o', markersize=3, alpha=0.5)
    #plt.scatter(lumi,outp[i],label='output',alpha=.5)
    plt.xlabel('index')
    plt.ylabel('value')
    plt.xlim(0,1)
    plt.ylim(0,1)
    plt.legend()    

plt.show()

# %%
# plt.figure(figsize=[20,10])
# for i in range(0,4):
#     plt.subplot(2,2,i+1)
#     plt.scatter(lumi,inp[i],label='input',alpha=.5)
#     plt.scatter(lumi,outp[i]/max(outp[i]),label='output',alpha=.5)
#     plt.xlabel('index')
#     plt.ylabel('value')
#     plt.legend()    

# plt.show()

# %%
# for i in range(len(outp)):
#     for j in range(i+1,len(outp)):
#         print(sum(np.array(outp[i]/max(outp[i]))-np.array(outp[j]/max(outp[j]))))

# %% [markdown]
# ## Fake Bad Data

# %%
bad = np.array(data[str(runs[2])]['bad_samples'])

# %%
bad_new = []
for l in bad:
    if not 0 in l:
        bad_new.append(l)
                
reconstructed_bad = model.predict(np.array(bad_new))

error_bad = abs(bad_new-reconstructed_bad)/bad_new

# %%
error_reformat_bad = []
for i in range(4):
    error_reformat_bad.append([])

for i in range(len(error_bad)):
    for j in range(4):
        if i == len(error_bad)-1:
            for val in error_bad[i][WINDOW*j:WINDOW+WINDOW*j]:
                error_reformat_bad[j].append(val)
        else:
            error_reformat_bad[j].append(error_bad[i][WINDOW*j])
            
inp_bad = []
outp_bad = []
for i in range(4):
    inp_bad.append([])
    outp_bad.append([])
    
for i in range(len(reconstructed_bad)):
    for j in range(4):
        if i == len(reconstructed_bad)-1:
            for val in reconstructed_bad[i][WINDOW*j:WINDOW+WINDOW*j]:
                outp_bad[j].append(val)
            for val in bad_new[i][WINDOW*j:WINDOW+WINDOW*j]:
                inp_bad[j].append(val)
        else:
            outp_bad[j].append(reconstructed_bad[i][WINDOW*j])
            inp_bad[j].append(bad_new[i][WINDOW*j])

# %%
labels = data['HLT']

#bins = np.linspace(0,1,50)
bins = 50
plt.figure(figsize=[20,10])
for i in range(len(error_reformat_bad)):
    plt.subplot(2,2,i+1)
    plt.hist(error_reformat[i],bins=bins,label='good',alpha=.5)
    plt.hist(error_reformat_bad[i],bins=bins,label='fake bad',alpha=.5)
    plt.legend()
    plt.title(labels[i])

lumi = data[str(runs[2])]['lumiid'] 
print(len(error_reformat_bad[0]),len(lumi))
#lumi = np.linspace(0,len(error_reformat_bad[0]),len(error_reformat_bad[0]))
plt.figure(figsize=[20,10])
for i in range(0,4):
    plt.subplot(2,2,i+1)
    plt.scatter(lumi,error_reformat[i],label = 'good', alpha =.5)
    plt.scatter(lumi,error_reformat_bad[i],label='fake bad',alpha=.5)
    plt.xlabel('lumi id')
    plt.ylabel('error')
    plt.legend()    
    plt.title(labels[i])

plt.show()
# Out:
# 1224 1224

# %%
plt.figure(figsize=[10,10])
for i in range(0,4):
    plt.subplot(2,2,i+1)
    plt.plot(outp_bad[i],inp_bad[i],label=labels[i], linestyle='',marker='o', markersize=3, alpha=0.5)
    plt.xlabel('index')
    plt.ylabel('value')
    plt.xlim(0,1)
    plt.ylim(0,1)
    plt.legend()    

plt.show()

# %%
# plt.figure(figsize=[20,10])
# for i in range(0,4):
#     plt.subplot(2,2,i+1)
#     plt.scatter(lumi,inp_bad[i],label='inp_badut',alpha=.5)
#     plt.scatter(lumi,outp_bad[i]/max(outp_bad[i]),label='outp_badut',alpha=.5)
#     plt.xlabel('index')
#     plt.ylabel('value')
#     plt.legend()    

# plt.show()

# %%
# labels = data['HLT']

# #bins = np.linspace(0,1,50)
# bins = 50
# plt.figure(figsize=[20,10])
# for i in range(len(error_reformat_bad)):
#     plt.subplot(2,2,i+1)
#     plt.hist(error_reformat_bad[i],bins=bins,label='bad',alpha=.5)
#     plt.hist(error_reformat[i],bins=bins,label='good',alpha=.5)
#     plt.legend()

# # lumi = data[str(runs[0])]['lumiid'] 
# # print(len(error_reformat_bad[0]),len(lumi))
# # #lumi = np.linspace(0,len(error_reformat_bad[0]),len(error_reformat_bad[0]))
# # plt.figure(figsize=[20,10])
# # for i in range(0,4):
# #     plt.subplot(2,2,i+1)
# #     plt.scatter(lumi,error_reformat_bad[i],label='bad',alpha=.5)
# #     plt.scatter(lumi,error_reformat[i],label='good',alpha=.5)
# #     plt.xlabel('lumi id')
# #     plt.ylabel('error')
# #     plt.legend()    

# plt.show()

# %% [markdown]
# ## Fake Bad Data - ALL

# %%
bad = np.array(data[str(runs[2])]['all_bad_samples'])

# %%
bad_new = []
for l in bad:
    if not 0 in l:
        bad_new.append(l)
                
reconstructed_bad = model.predict(np.array(bad_new))

error_bad = abs(bad_new-reconstructed_bad)/bad_new

# %%
error_reformat_bad = []
for i in range(4):
    error_reformat_bad.append([])

for i in range(len(error_bad)):
    for j in range(4):
        if i == len(error_bad)-1:
            for val in error_bad[i][WINDOW*j:WINDOW+WINDOW*j]:
                error_reformat_bad[j].append(val)
        else:
            error_reformat_bad[j].append(error_bad[i][WINDOW*j])
            
inp_bad = []
outp_bad = []
for i in range(4):
    inp_bad.append([])
    outp_bad.append([])
    
for i in range(len(reconstructed_bad)):
    for j in range(4):
        if i == len(reconstructed_bad)-1:
            for val in reconstructed_bad[i][WINDOW*j:WINDOW+WINDOW*j]:
                outp_bad[j].append(val)
            for val in bad_new[i][WINDOW*j:WINDOW+WINDOW*j]:
                inp_bad[j].append(val)
        else:
            outp_bad[j].append(reconstructed_bad[i][WINDOW*j])
            inp_bad[j].append(bad_new[i][WINDOW*j])

# %%
labels = data['HLT']

#bins = np.linspace(0,1,50)
bins = 50
plt.figure(figsize=[20,10])
for i in range(len(error_reformat_bad)):
    plt.subplot(2,2,i+1)
    plt.hist(error_reformat[i],bins=bins,label='good',alpha=.5)
    plt.hist(error_reformat_bad[i],bins=bins,label='fake bad',alpha=.5)
    plt.legend()
    plt.title(labels[i])

lumi = data[str(runs[2])]['lumiid'] 
print(len(error_reformat_bad[0]),len(lumi))
#lumi = np.linspace(0,len(error_reformat_bad[0]),len(error_reformat_bad[0]))
plt.figure(figsize=[20,10])
for i in range(0,4):
    plt.subplot(2,2,i+1)
    plt.scatter(lumi,error_reformat[i],label = 'good', alpha =.5)
    plt.scatter(lumi,error_reformat_bad[i],label='fake bad',alpha=.5)
    plt.xlabel('lumi id')
    plt.ylabel('error')
    plt.legend()    
    plt.title(labels[i])

plt.show()
# Out:
# 1224 1224

# %%
plt.figure(figsize=[10,10])
for i in range(0,4):
    plt.subplot(2,2,i+1)
    plt.plot(outp_bad[i],inp_bad[i],label=labels[i], linestyle='',marker='o', markersize=3, alpha=0.5)
    plt.xlabel('index')
    plt.ylabel('value')
    plt.xlim(0,.5)
    plt.ylim(0,.5)
    plt.legend()    

plt.show()

# %%
# plt.figure(figsize=[20,10])
# for i in range(0,4):
#     plt.subplot(2,2,i+1)
#     plt.scatter(lumi,inp_bad[i],label='input',alpha=.5)
#     plt.scatter(lumi,outp_bad[i]/max(outp_bad[i]),label='output',alpha=.5)
#     plt.xlabel('index')
#     plt.ylabel('value')
#     plt.legend()    

# plt.show()

# %%
# labels = data['HLT']

# #bins = np.linspace(0,1,50)
# bins = 50
# plt.figure(figsize=[20,10])
# for i in range(len(error_reformat_bad)):
#     plt.subplot(2,2,i+1)
#     plt.hist(error_reformat_bad[i],bins=bins,label='bad',alpha=.5)
#     plt.hist(error_reformat[i],bins=bins,label='good',alpha=.5)
#     plt.legend()

# # lumi = data[str(runs[0])]['lumiid'] 
# # print(len(error_reformat_bad[0]),len(lumi))
# # #lumi = np.linspace(0,len(error_reformat_bad[0]),len(error_reformat_bad[0]))
# # plt.figure(figsize=[20,10])
# # for i in range(0,4):
# #     plt.subplot(2,2,i+1)
# #     plt.scatter(lumi,error_reformat_bad[i],label='bad',alpha=.5)
# #     plt.scatter(lumi,error_reformat[i],label='good',alpha=.5)
# #     plt.xlabel('lumi id')
# #     plt.ylabel('error')
# #     plt.legend()    

# plt.show()
