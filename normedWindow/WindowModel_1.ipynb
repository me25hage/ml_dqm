# %%
import os
import numpy as np
import matplotlib
import matplotlib.pyplot as plt
import pandas as pd
import keras
import pickle

from keras import backend as K
from keras.callbacks import EarlyStopping, ModelCheckpoint, ReduceLROnPlateau
from keras.initializers import Ones, Zeros, Constant
from keras.models import Model, load_model
from keras.layers import Dense, Input, Lambda, SimpleRNN, Reshape, RepeatVector, PReLU
from keras.losses import mse
from keras.constraints import non_neg
# Out:
# /anaconda3/lib/python3.6/site-packages/h5py/__init__.py:36: FutureWarning: Conversion of the second argument of issubdtype from `float` to `np.floating` is deprecated. In future, it will be treated as `np.float64 == np.dtype(float).type`.
#   from ._conv import register_converters as _register_converters
# Using TensorFlow backend.
# /anaconda3/lib/python3.6/importlib/_bootstrap.py:219: RuntimeWarning: compiletime version 3.5 of module 'tensorflow.python.framework.fast_tensor_util' does not match runtime version 3.6
#   return f(*args, **kwds)

# %%
# Change presentation settings

# %matplotlib inline

matplotlib.rcParams["figure.figsize"] = (16.0, 10.0)

#matplotlib.rcParams['font.family'] = 'sans-serif'
#matplotlib.rcParams['font.sans-serif'] = ['Liberation Sans']

matplotlib.rcParams["axes.spines.left"] = True
matplotlib.rcParams["axes.spines.top"] = True
matplotlib.rcParams["axes.spines.right"] = True
matplotlib.rcParams["axes.spines.bottom"] = True
matplotlib.rcParams["axes.labelsize"] = 18
matplotlib.rcParams["axes.titlesize"] = 12

matplotlib.rcParams["xtick.top"] = True
matplotlib.rcParams["ytick.right"] = True
matplotlib.rcParams["xtick.direction"] = "in"
matplotlib.rcParams["ytick.direction"] = "in"
matplotlib.rcParams["xtick.labelsize"] = 10
matplotlib.rcParams["ytick.labelsize"] = 10
matplotlib.rcParams["xtick.major.size"] = 10
matplotlib.rcParams["ytick.major.size"] = 10
matplotlib.rcParams["xtick.minor.size"] = 5
matplotlib.rcParams["ytick.minor.size"] = 5
matplotlib.rcParams["xtick.minor.visible"] = True

matplotlib.rcParams["lines.linewidth"] = 2

matplotlib.rcParams["legend.fontsize"] = 14

color_palette = {"Indigo": {
                    50: "#E8EAF6",
                    100: "#C5CAE9",
                    200: "#9FA8DA",
                    300: "#7986CB",
                    400: "#5C6BC0",
                    500: "#3F51B5",
                    600: "#3949AB",
                    700: "#303F9F",
                    800: "#283593",
                    900: "#1A237E"},
                 "Orange": {      
                    50: "#FFF3E0",
                    100: "#FFE0B2",
                    200: "#FFCC80",
                    300: "#FFB74D",
                    400: "#FFA726",
                    500: "#FF9800",
                    600: "#FB8C00",
                    700: "#F57C00",
                    800: "#EF6C00",
                    900: "#E65100"}
                }

line_styles = [(0, ()), (0, (1, 2)), (0, (3, 2))]

# %%
def plot_loss(data, save_name=False):
    """Plots the training and validation loss"""
    fig, ax = plt.subplots()

    plt.xlabel("Epoch", horizontalalignment='right', x=1.0)
    plt.ylabel("Cross-entropy", horizontalalignment='right', y=1.0)

    plt.plot(data["loss"], linestyle=line_styles[0], color=color_palette["Indigo"][800])
    plt.plot(data["val_loss"], linestyle=line_styles[2], color=color_palette["Orange"][400])
    plt.legend(["Training data set", "Validation data set"], loc="upper right", frameon=False)
    #plt.yscale("log")
    
    if save_name:
        fig.savefig("%s/%s.eps" % (figure_export_directory, save_name), bbox_inches="tight")

    plt.show();

# %%
def train_nn(model, x, y, batch_size, loss, name, xval):

    adam = keras.optimizers.Adam(lr=0.003,
                                 beta_1=0.9,
                                 beta_2=0.999,
                                 epsilon=None,
                                 decay=0.0,
                                 amsgrad=False)

    early_stopper = EarlyStopping(monitor="val_loss",
                                  patience=32,
                                  verbose=True,
                                  mode="auto")

    reduce_lr = ReduceLROnPlateau(monitor="val_loss",
                                  factor=0.1,
                                  patience=24)
    
    checkpoint_callback = ModelCheckpoint(("%s.h5" % (name)),
                                          monitor="val_loss",
                                          verbose=False,
                                          save_best_only=True,
                                          mode="min")
    
    model.compile(loss=loss, optimizer=adam)
    
    history = model.fit(x, y,
                     batch_size=batch_size,
                     epochs=1000,
                     verbose=2,
                     initial_epoch=0,
                     shuffle=True,
                     validation_data=(xval,xval),
                     callbacks=[early_stopper, checkpoint_callback])
    return history

# %% [markdown]
# ## Data

# %%
runs = [304125,302263,304508]

with open('good_data_WINDOW1.pickle', 'rb') as handle:
    data = pickle.load(handle)

x_train = np.array(data[str(runs[0])]['samples'])
x_val = np.array(data[str(runs[1])]['samples'])
x_test = np.array(data[str(runs[2])]['samples'])

WINDOW = 1

# %%
plots = [x_train,x_val,x_test]
titles = ["train","val","test"]

stuff = [[],[],[]]
lumi = [[],[],[]]
for h in range(3):
    labels = data['HLT'] 
    lumi[h] = data[str(runs[h])]['lumiid']
    stuff[h] = data[str(runs[h])]['rates']
    
plt.figure(figsize=[20,10])
              
for i in range(4):
    plt.subplot(2,2,i+1)
    for k in range(0,3):
        print(len(lumi[k]),len(stuff[k][i]))
        plt.scatter(lumi[k],stuff[k][i],label=titles[k],alpha=.5)
    plt.xlabel('lumi id')
    plt.ylabel('error')
    plt.title(labels[i])
    plt.legend()

plt.tight_layout()
plt.show()
# Out:
# 1669 1669
# 1129 1129
# 1224 1224
# 1669 1669
# 1129 1129
# 1224 1224
# 1669 1669
# 1129 1129
# 1224 1224
# 1669 1669
# 1129 1129
# 1224 1224

# %% [markdown]
# ## Simple Autoencoder

# %%
model_name = "simplest_1"

# %%
# Define the architecture

_input = Input(shape=(4*WINDOW,), name="input")

hidden = Dense(3,
               kernel_initializer=Ones(),
               bias_initializer=Zeros(),
               kernel_constraint=non_neg(),
               bias_constraint=non_neg(),
               activation=None,
               name="encoded")(_input)

output = Dense(4*WINDOW,
               kernel_initializer=Ones(),
               bias_initializer=Zeros(),
               kernel_constraint=non_neg(),
               bias_constraint=non_neg(),
               activation=None,
               name="reconstructed")(hidden)

model = Model(_input, output)
model.summary()
# Out:
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# input (InputLayer)           (None, 4)                 0
# _________________________________________________________________
# encoded (Dense)              (None, 3)                 15
# _________________________________________________________________
# reconstructed (Dense)        (None, 4)                 16
# =================================================================
# Total params: 31
# Trainable params: 31
# Non-trainable params: 0
# _________________________________________________________________

# %%
# Train neural networks
history = train_nn(model, x_train, x_train, 1024, "mse", model_name, x_val).history
plot_loss(history)
# Out:
# Train on 1669 samples, validate on 1129 samples
# Epoch 1/1000
#  - 0s - loss: 51.3705 - val_loss: 50.5756
# Epoch 2/1000
#  - 0s - loss: 50.0370 - val_loss: 49.2969
# Epoch 3/1000
#  - 0s - loss: 48.7807 - val_loss: 48.0514
# Epoch 4/1000
#  - 0s - loss: 47.5370 - val_loss: 46.7857
# Epoch 5/1000
#  - 0s - loss: 46.2846 - val_loss: 45.5534
# Epoch 6/1000
#  - 0s - loss: 45.0631 - val_loss: 44.3438
# Epoch 7/1000
#  - 0s - loss: 43.8667 - val_loss: 43.1626
# Epoch 8/1000
#  - 0s - loss: 42.6980 - val_loss: 42.0101
# Epoch 9/1000
#  - 0s - loss: 41.5586 - val_loss: 40.8863
# Epoch 10/1000
#  - 0s - loss: 40.4456 - val_loss: 39.7913
# Epoch 11/1000
#  - 0s - loss: 39.3628 - val_loss: 38.7246
# Epoch 12/1000
#  - 0s - loss: 38.3047 - val_loss: 37.6804
# Epoch 13/1000
#  - 0s - loss: 37.2745 - val_loss: 36.6697
# Epoch 14/1000
#  - 0s - loss: 36.2722 - val_loss: 35.6867
# Epoch 15/1000
#  - 0s - loss: 35.2999 - val_loss: 34.7194
# Epoch 16/1000
#  - 0s - loss: 34.3416 - val_loss: 33.7795
# Epoch 17/1000
#  - 0s - loss: 33.4150 - val_loss: 32.8767
# Epoch 18/1000
#  - 0s - loss: 32.5229 - val_loss: 31.9995
# Epoch 19/1000
#  - 0s - loss: 31.6531 - val_loss: 31.1383
# Epoch 20/1000
#  - 0s - loss: 30.8043 - val_loss: 30.3110
# Epoch 21/1000
#  - 0s - loss: 29.9854 - val_loss: 29.5079
# Epoch 22/1000
#  - 0s - loss: 29.1917 - val_loss: 28.7240
# Epoch 23/1000
#  - 0s - loss: 28.4168 - val_loss: 27.9672
# Epoch 24/1000
#  - 0s - loss: 27.6690 - val_loss: 27.2325
# Epoch 25/1000
#  - 0s - loss: 26.9424 - val_loss: 26.5194
# Epoch 26/1000
#  - 0s - loss: 26.2364 - val_loss: 25.8272
# Epoch 27/1000
#  - 0s - loss: 25.5521 - val_loss: 25.1551
# Epoch 28/1000
#  - 0s - loss: 24.8885 - val_loss: 24.5025
# Epoch 29/1000
#  - 0s - loss: 24.2423 - val_loss: 23.8667
# Epoch 30/1000
#  - 0s - loss: 23.6144 - val_loss: 23.2518
# Epoch 31/1000
#  - 0s - loss: 23.0051 - val_loss: 22.6549
# Epoch 32/1000
#  - 0s - loss: 22.4168 - val_loss: 22.0752
# Epoch 33/1000
#  - 0s - loss: 21.8422 - val_loss: 21.5126
# Epoch 34/1000
#  - 0s - loss: 21.2857 - val_loss: 20.9643
# Epoch 35/1000
#  - 0s - loss: 20.7438 - val_loss: 20.4338
# Epoch 36/1000
#  - 0s - loss: 20.2199 - val_loss: 19.9167
# Epoch 37/1000
#  - 0s - loss: 19.7091 - val_loss: 19.4165
# Epoch 38/1000
#  - 0s - loss: 19.2139 - val_loss: 18.9308
# Epoch 39/1000
#  - 0s - loss: 18.7347 - val_loss: 18.4590
# Epoch 40/1000
#  - 0s - loss: 18.2672 - val_loss: 18.0008
# Epoch 41/1000
#  - 0s - loss: 17.8144 - val_loss: 17.5557
# Epoch 42/1000
#  - 0s - loss: 17.3734 - val_loss: 17.1208
# Epoch 43/1000
#  - 0s - loss: 16.9443 - val_loss: 16.7006
# Epoch 44/1000
#  - 0s - loss: 16.5292 - val_loss: 16.2923
# Epoch 45/1000
#  - 0s - loss: 16.1249 - val_loss: 15.8956
# Epoch 46/1000
#  - 0s - loss: 15.7323 - val_loss: 15.5101
# Epoch 47/1000
#  - 0s - loss: 15.3517 - val_loss: 15.1353
# Epoch 48/1000
#  - 0s - loss: 14.9806 - val_loss: 14.7710
# Epoch 49/1000
#  - 0s - loss: 14.6208 - val_loss: 14.4168
# Epoch 50/1000
#  - 0s - loss: 14.2704 - val_loss: 14.0725
# Epoch 51/1000
#  - 0s - loss: 13.9296 - val_loss: 13.7370
# Epoch 52/1000
#  - 0s - loss: 13.5979 - val_loss: 13.4107
# Epoch 53/1000
#  - 0s - loss: 13.2750 - val_loss: 13.0941
# Epoch 54/1000
#  - 0s - loss: 12.9622 - val_loss: 12.7854
# Epoch 55/1000
#  - 0s - loss: 12.6569 - val_loss: 12.4852
# Epoch 56/1000
#  - 0s - loss: 12.3600 - val_loss: 12.1932
# Epoch 57/1000
#  - 0s - loss: 12.0713 - val_loss: 11.9098
# Epoch 58/1000
#  - 0s - loss: 11.7909 - val_loss: 11.6340
# Epoch 59/1000
#  - 0s - loss: 11.5178 - val_loss: 11.3651
# Epoch 60/1000
#  - 0s - loss: 11.2521 - val_loss: 11.1040
# Epoch 61/1000
#  - 0s - loss: 10.9938 - val_loss: 10.8493
# Epoch 62/1000
#  - 0s - loss: 10.7415 - val_loss: 10.6015
# Epoch 63/1000
#  - 0s - loss: 10.4961 - val_loss: 10.3602
# Epoch 64/1000
#  - 0s - loss: 10.2578 - val_loss: 10.1252
# Epoch 65/1000
#  - 0s - loss: 10.0255 - val_loss: 9.8965
# Epoch 66/1000
#  - 0s - loss: 9.7991 - val_loss: 9.6738
# Epoch 67/1000
#  - 0s - loss: 9.5783 - val_loss: 9.4565
# Epoch 68/1000
#  - 0s - loss: 9.3641 - val_loss: 9.2452
# Epoch 69/1000
#  - 0s - loss: 9.1547 - val_loss: 9.0398
# Epoch 70/1000
#  - 0s - loss: 8.9516 - val_loss: 8.8397
# Epoch 71/1000
#  - 0s - loss: 8.7534 - val_loss: 8.6448
# Epoch 72/1000
#  - 0s - loss: 8.5610 - val_loss: 8.4548
# Epoch 73/1000
#  - 0s - loss: 8.3728 - val_loss: 8.2691
# Epoch 74/1000
#  - 0s - loss: 8.1893 - val_loss: 8.0888
# Epoch 75/1000
#  - 0s - loss: 8.0105 - val_loss: 7.9131
# Epoch 76/1000
#  - 0s - loss: 7.8368 - val_loss: 7.7418
# Epoch 77/1000
#  - 0s - loss: 7.6674 - val_loss: 7.5748
# Epoch 78/1000
#  - 0s - loss: 7.5020 - val_loss: 7.4117
# Epoch 79/1000
#  - 0s - loss: 7.3407 - val_loss: 7.2530
# Epoch 80/1000
#  - 0s - loss: 7.1834 - val_loss: 7.0980
# Epoch 81/1000
#  - 0s - loss: 7.0304 - val_loss: 6.9471
# Epoch 82/1000
#  - 0s - loss: 6.8809 - val_loss: 6.7997
# Epoch 83/1000
#  - 0s - loss: 6.7348 - val_loss: 6.6559
# Epoch 84/1000
#  - 0s - loss: 6.5927 - val_loss: 6.5157
# Epoch 85/1000
#  - 0s - loss: 6.4540 - val_loss: 6.3790
# Epoch 86/1000
#  - 0s - loss: 6.3189 - val_loss: 6.2458
# Epoch 87/1000
#  - 0s - loss: 6.1869 - val_loss: 6.1156
# Epoch 88/1000
#  - 0s - loss: 6.0578 - val_loss: 5.9887
# Epoch 89/1000
#  - 0s - loss: 5.9323 - val_loss: 5.8648
# Epoch 90/1000
#  - 0s - loss: 5.8097 - val_loss: 5.7439
# Epoch 91/1000
#  - 0s - loss: 5.6901 - val_loss: 5.6259
# Epoch 92/1000
#  - 0s - loss: 5.5732 - val_loss: 5.5107
# Epoch 93/1000
#  - 0s - loss: 5.4591 - val_loss: 5.3983
# Epoch 94/1000
#  - 0s - loss: 5.3479 - val_loss: 5.2885
# Epoch 95/1000
#  - 0s - loss: 5.2392 - val_loss: 5.1812
# Epoch 96/1000
#  - 0s - loss: 5.1331 - val_loss: 5.0765
# Epoch 97/1000
#  - 0s - loss: 5.0295 - val_loss: 4.9743
# Epoch 98/1000
#  - 0s - loss: 4.9282 - val_loss: 4.8745
# Epoch 99/1000
#  - 0s - loss: 4.8296 - val_loss: 4.7769
# Epoch 100/1000
#  - 0s - loss: 4.7329 - val_loss: 4.6816
# Epoch 101/1000
#  - 0s - loss: 4.6386 - val_loss: 4.5886
# Epoch 102/1000
#  - 0s - loss: 4.5466 - val_loss: 4.4977
# Epoch 103/1000
#  - 0s - loss: 4.4566 - val_loss: 4.4089
# Epoch 104/1000
#  - 0s - loss: 4.3686 - val_loss: 4.3222
# Epoch 105/1000
#  - 0s - loss: 4.2827 - val_loss: 4.2375
# Epoch 106/1000
#  - 0s - loss: 4.1990 - val_loss: 4.1547
# Epoch 107/1000
#  - 0s - loss: 4.1170 - val_loss: 4.0737
# Epoch 108/1000
#  - 0s - loss: 4.0369 - val_loss: 3.9946
# Epoch 109/1000
#  - 0s - loss: 3.9585 - val_loss: 3.9173
# Epoch 110/1000
#  - 0s - loss: 3.8820 - val_loss: 3.8417
# Epoch 111/1000
#  - 0s - loss: 3.8072 - val_loss: 3.7679
# Epoch 112/1000
#  - 0s - loss: 3.7340 - val_loss: 3.6957
# Epoch 113/1000
#  - 0s - loss: 3.6625 - val_loss: 3.6251
# Epoch 114/1000
#  - 0s - loss: 3.5927 - val_loss: 3.5561
# Epoch 115/1000
#  - 0s - loss: 3.5245 - val_loss: 3.4884
# Epoch 116/1000
#  - 0s - loss: 3.4572 - val_loss: 3.4224
# Epoch 117/1000
#  - 0s - loss: 3.3920 - val_loss: 3.3578
# Epoch 118/1000
#  - 0s - loss: 3.3280 - val_loss: 3.2946
# Epoch 119/1000
#  - 0s - loss: 3.2654 - val_loss: 3.2328
# Epoch 120/1000
#  - 0s - loss: 3.2042 - val_loss: 3.1723
# Epoch 121/1000
#  - 0s - loss: 3.1444 - val_loss: 3.1132
# Epoch 122/1000
#  - 0s - loss: 3.0857 - val_loss: 3.0553
# Epoch 123/1000
#  - 0s - loss: 3.0285 - val_loss: 2.9986
# Epoch 124/1000
#  - 0s - loss: 2.9722 - val_loss: 2.9431
# Epoch 125/1000
#  - 0s - loss: 2.9173 - val_loss: 2.8888
# Epoch 126/1000
#  - 0s - loss: 2.8636 - val_loss: 2.8358
# Epoch 127/1000
#  - 0s - loss: 2.8111 - val_loss: 2.7838
# Epoch 128/1000
#  - 0s - loss: 2.7596 - val_loss: 2.7330
# Epoch 129/1000
#  - 0s - loss: 2.7092 - val_loss: 2.6833
# Epoch 130/1000
#  - 0s - loss: 2.6601 - val_loss: 2.6345
# Epoch 131/1000
#  - 0s - loss: 2.6118 - val_loss: 2.5868
# Epoch 132/1000
#  - 0s - loss: 2.5645 - val_loss: 2.5400
# Epoch 133/1000
#  - 0s - loss: 2.5182 - val_loss: 2.4943
# Epoch 134/1000
#  - 0s - loss: 2.4729 - val_loss: 2.4495
# Epoch 135/1000
#  - 0s - loss: 2.4286 - val_loss: 2.4057
# Epoch 136/1000
#  - 0s - loss: 2.3851 - val_loss: 2.3627
# Epoch 137/1000
#  - 0s - loss: 2.3425 - val_loss: 2.3206
# Epoch 138/1000
#  - 0s - loss: 2.3008 - val_loss: 2.2794
# Epoch 139/1000
#  - 0s - loss: 2.2601 - val_loss: 2.2390
# Epoch 140/1000
#  - 0s - loss: 2.2201 - val_loss: 2.1995
# Epoch 141/1000
#  - 0s - loss: 2.1810 - val_loss: 2.1608
# Epoch 142/1000
#  - 0s - loss: 2.1426 - val_loss: 2.1229
# Epoch 143/1000
#  - 0s - loss: 2.1049 - val_loss: 2.0857
# Epoch 144/1000
#  - 0s - loss: 2.0681 - val_loss: 2.0493
# Epoch 145/1000
#  - 0s - loss: 2.0321 - val_loss: 2.0135
# Epoch 146/1000
#  - 0s - loss: 1.9967 - val_loss: 1.9786
# Epoch 147/1000
#  - 0s - loss: 1.9620 - val_loss: 1.9443
# Epoch 148/1000
#  - 0s - loss: 1.9281 - val_loss: 1.9107
# Epoch 149/1000
#  - 0s - loss: 1.8948 - val_loss: 1.8778
# Epoch 150/1000
#  - 0s - loss: 1.8622 - val_loss: 1.8455
# Epoch 151/1000
#  - 0s - loss: 1.8302 - val_loss: 1.8139
# Epoch 152/1000
#  - 0s - loss: 1.7988 - val_loss: 1.7828
# Epoch 153/1000
#  - 0s - loss: 1.7682 - val_loss: 1.7524
# Epoch 154/1000
#  - 0s - loss: 1.7380 - val_loss: 1.7226
# Epoch 155/1000
#  - 0s - loss: 1.7085 - val_loss: 1.6934
# Epoch 156/1000
#  - 0s - loss: 1.6795 - val_loss: 1.6647
# Epoch 157/1000
#  - 0s - loss: 1.6512 - val_loss: 1.6366
# Epoch 158/1000
#  - 0s - loss: 1.6233 - val_loss: 1.6091
# Epoch 159/1000
#  - 0s - loss: 1.5960 - val_loss: 1.5820
# Epoch 160/1000
#  - 0s - loss: 1.5692 - val_loss: 1.5555
# Epoch 161/1000
#  - 0s - loss: 1.5429 - val_loss: 1.5295
# Epoch 162/1000
#  - 0s - loss: 1.5172 - val_loss: 1.5040
# Epoch 163/1000
#  - 0s - loss: 1.4919 - val_loss: 1.4790
# Epoch 164/1000
#  - 0s - loss: 1.4671 - val_loss: 1.4544
# Epoch 165/1000
#  - 0s - loss: 1.4428 - val_loss: 1.4304
# Epoch 166/1000
#  - 0s - loss: 1.4189 - val_loss: 1.4067
# Epoch 167/1000
#  - 0s - loss: 1.3955 - val_loss: 1.3836
# Epoch 168/1000
#  - 0s - loss: 1.3725 - val_loss: 1.3608
# Epoch 169/1000
#  - 0s - loss: 1.3500 - val_loss: 1.3385
# Epoch 170/1000
#  - 0s - loss: 1.3279 - val_loss: 1.3166
# Epoch 171/1000
#  - 0s - loss: 1.3062 - val_loss: 1.2951
# Epoch 172/1000
#  - 0s - loss: 1.2849 - val_loss: 1.2740
# Epoch 173/1000
#  - 0s - loss: 1.2640 - val_loss: 1.2533
# Epoch 174/1000
#  - 0s - loss: 1.2435 - val_loss: 1.2330
# Epoch 175/1000
#  - 0s - loss: 1.2234 - val_loss: 1.2130
# Epoch 176/1000
#  - 0s - loss: 1.2036 - val_loss: 1.1934
# Epoch 177/1000
#  - 0s - loss: 1.1842 - val_loss: 1.1742
# Epoch 178/1000
#  - 0s - loss: 1.1652 - val_loss: 1.1554
# Epoch 179/1000
#  - 0s - loss: 1.1464 - val_loss: 1.1368
# Epoch 180/1000
#  - 0s - loss: 1.1281 - val_loss: 1.1187
# Epoch 181/1000
#  - 0s - loss: 1.1101 - val_loss: 1.1008
# Epoch 182/1000
#  - 0s - loss: 1.0924 - val_loss: 1.0833
# Epoch 183/1000
#  - 0s - loss: 1.0750 - val_loss: 1.0661
# Epoch 184/1000
#  - 0s - loss: 1.0580 - val_loss: 1.0492
# Epoch 185/1000
#  - 0s - loss: 1.0412 - val_loss: 1.0326
# Epoch 186/1000
#  - 0s - loss: 1.0248 - val_loss: 1.0163
# Epoch 187/1000
#  - 0s - loss: 1.0086 - val_loss: 1.0003
# Epoch 188/1000
#  - 0s - loss: 0.9928 - val_loss: 0.9846
# Epoch 189/1000
#  - 0s - loss: 0.9772 - val_loss: 0.9692
# Epoch 190/1000
#  - 0s - loss: 0.9619 - val_loss: 0.9540
# Epoch 191/1000
#  - 0s - loss: 0.9469 - val_loss: 0.9391
# Epoch 192/1000
#  - 0s - loss: 0.9322 - val_loss: 0.9245
# Epoch 193/1000
#  - 0s - loss: 0.9177 - val_loss: 0.9101
# Epoch 194/1000
#  - 0s - loss: 0.9034 - val_loss: 0.8960
# Epoch 195/1000
#  - 0s - loss: 0.8894 - val_loss: 0.8822
# Epoch 196/1000
#  - 0s - loss: 0.8757 - val_loss: 0.8686
# Epoch 197/1000
#  - 0s - loss: 0.8622 - val_loss: 0.8552
# Epoch 198/1000
#  - 0s - loss: 0.8489 - val_loss: 0.8420
# Epoch 199/1000
#  - 0s - loss: 0.8359 - val_loss: 0.8291
# Epoch 200/1000
#  - 0s - loss: 0.8231 - val_loss: 0.8164
# Epoch 201/1000
#  - 0s - loss: 0.8105 - val_loss: 0.8039
# Epoch 202/1000
#  - 0s - loss: 0.7981 - val_loss: 0.7917
# Epoch 203/1000
#  - 0s - loss: 0.7860 - val_loss: 0.7796
# Epoch 204/1000
#  - 0s - loss: 0.7740 - val_loss: 0.7677
# Epoch 205/1000
#  - 0s - loss: 0.7623 - val_loss: 0.7561
# Epoch 206/1000
#  - 0s - loss: 0.7507 - val_loss: 0.7446
# Epoch 207/1000
#  - 0s - loss: 0.7394 - val_loss: 0.7334
# Epoch 208/1000
#  - 0s - loss: 0.7282 - val_loss: 0.7223
# Epoch 209/1000
#  - 0s - loss: 0.7173 - val_loss: 0.7115
# Epoch 210/1000
#  - 0s - loss: 0.7065 - val_loss: 0.7008
# Epoch 211/1000
#  - 0s - loss: 0.6959 - val_loss: 0.6903
# Epoch 212/1000
#  - 0s - loss: 0.6855 - val_loss: 0.6799
# Epoch 213/1000
#  - 0s - loss: 0.6752 - val_loss: 0.6698
# Epoch 214/1000
#  - 0s - loss: 0.6652 - val_loss: 0.6598
# Epoch 215/1000
#  - 0s - loss: 0.6553 - val_loss: 0.6500
# Epoch 216/1000
#  - 0s - loss: 0.6456 - val_loss: 0.6403
# Epoch 217/1000
#  - 0s - loss: 0.6360 - val_loss: 0.6309
# Epoch 218/1000
#  - 0s - loss: 0.6266 - val_loss: 0.6215
# Epoch 219/1000
#  - 0s - loss: 0.6173 - val_loss: 0.6123
# Epoch 220/1000
#  - 0s - loss: 0.6082 - val_loss: 0.6033
# Epoch 221/1000
#  - 0s - loss: 0.5993 - val_loss: 0.5944
# Epoch 222/1000
#  - 0s - loss: 0.5905 - val_loss: 0.5857
# Epoch 223/1000
#  - 0s - loss: 0.5818 - val_loss: 0.5771
# Epoch 224/1000
#  - 0s - loss: 0.5733 - val_loss: 0.5687
# Epoch 225/1000
#  - 0s - loss: 0.5649 - val_loss: 0.5604
# Epoch 226/1000
#  - 0s - loss: 0.5567 - val_loss: 0.5522
# Epoch 227/1000
#  - 0s - loss: 0.5486 - val_loss: 0.5442
# Epoch 228/1000
#  - 0s - loss: 0.5406 - val_loss: 0.5363
# Epoch 229/1000
#  - 0s - loss: 0.5328 - val_loss: 0.5285
# Epoch 230/1000
#  - 0s - loss: 0.5251 - val_loss: 0.5208
# Epoch 231/1000
#  - 0s - loss: 0.5175 - val_loss: 0.5133
# Epoch 232/1000
#  - 0s - loss: 0.5100 - val_loss: 0.5059
# Epoch 233/1000
#  - 0s - loss: 0.5027 - val_loss: 0.4986
# Epoch 234/1000
#  - 0s - loss: 0.4955 - val_loss: 0.4914
# Epoch 235/1000
#  - 0s - loss: 0.4883 - val_loss: 0.4844
# Epoch 236/1000
#  - 0s - loss: 0.4814 - val_loss: 0.4774
# Epoch 237/1000
#  - 0s - loss: 0.4745 - val_loss: 0.4706
# Epoch 238/1000
#  - 0s - loss: 0.4677 - val_loss: 0.4639
# Epoch 239/1000
#  - 0s - loss: 0.4610 - val_loss: 0.4573
# Epoch 240/1000
#  - 0s - loss: 0.4545 - val_loss: 0.4508
# Epoch 241/1000
#  - 0s - loss: 0.4480 - val_loss: 0.4444
# Epoch 242/1000
#  - 0s - loss: 0.4417 - val_loss: 0.4381
# Epoch 243/1000
#  - 0s - loss: 0.4354 - val_loss: 0.4319
# Epoch 244/1000
#  - 0s - loss: 0.4293 - val_loss: 0.4258
# Epoch 245/1000
#  - 0s - loss: 0.4232 - val_loss: 0.4198
# Epoch 246/1000
#  - 0s - loss: 0.4173 - val_loss: 0.4139
# Epoch 247/1000
#  - 0s - loss: 0.4114 - val_loss: 0.4080
# Epoch 248/1000
#  - 0s - loss: 0.4057 - val_loss: 0.4023
# Epoch 249/1000
#  - 0s - loss: 0.4000 - val_loss: 0.3967
# Epoch 250/1000
#  - 0s - loss: 0.3944 - val_loss: 0.3911
# Epoch 251/1000
#  - 0s - loss: 0.3889 - val_loss: 0.3857
# Epoch 252/1000
#  - 0s - loss: 0.3835 - val_loss: 0.3803
# Epoch 253/1000
#  - 0s - loss: 0.3781 - val_loss: 0.3750
# Epoch 254/1000
#  - 0s - loss: 0.3729 - val_loss: 0.3698
# Epoch 255/1000
#  - 0s - loss: 0.3677 - val_loss: 0.3647
# Epoch 256/1000
#  - 0s - loss: 0.3626 - val_loss: 0.3596
# Epoch 257/1000
#  - 0s - loss: 0.3576 - val_loss: 0.3547
# Epoch 258/1000
#  - 0s - loss: 0.3527 - val_loss: 0.3498
# Epoch 259/1000
#  - 0s - loss: 0.3479 - val_loss: 0.3449
# Epoch 260/1000
#  - 0s - loss: 0.3431 - val_loss: 0.3402
# Epoch 261/1000
#  - 0s - loss: 0.3384 - val_loss: 0.3355
# Epoch 262/1000
#  - 0s - loss: 0.3337 - val_loss: 0.3309
# Epoch 263/1000
#  - 0s - loss: 0.3292 - val_loss: 0.3264
# Epoch 264/1000
#  - 0s - loss: 0.3247 - val_loss: 0.3219
# Epoch 265/1000
#  - 0s - loss: 0.3203 - val_loss: 0.3175
# Epoch 266/1000
#  - 0s - loss: 0.3159 - val_loss: 0.3132
# Epoch 267/1000
#  - 0s - loss: 0.3116 - val_loss: 0.3090
# Epoch 268/1000
#  - 0s - loss: 0.3074 - val_loss: 0.3048
# Epoch 269/1000
#  - 0s - loss: 0.3032 - val_loss: 0.3006
# Epoch 270/1000
#  - 0s - loss: 0.2991 - val_loss: 0.2966
# Epoch 271/1000
#  - 0s - loss: 0.2951 - val_loss: 0.2925
# Epoch 272/1000
#  - 0s - loss: 0.2911 - val_loss: 0.2886
# Epoch 273/1000
#  - 0s - loss: 0.2872 - val_loss: 0.2847
# Epoch 274/1000
#  - 0s - loss: 0.2833 - val_loss: 0.2809
# Epoch 275/1000
#  - 0s - loss: 0.2795 - val_loss: 0.2771
# Epoch 276/1000
#  - 0s - loss: 0.2758 - val_loss: 0.2734
# Epoch 277/1000
#  - 0s - loss: 0.2721 - val_loss: 0.2697
# Epoch 278/1000
#  - 0s - loss: 0.2684 - val_loss: 0.2661
# Epoch 279/1000
#  - 0s - loss: 0.2649 - val_loss: 0.2626
# Epoch 280/1000
#  - 0s - loss: 0.2613 - val_loss: 0.2591
# Epoch 281/1000
#  - 0s - loss: 0.2579 - val_loss: 0.2556
# Epoch 282/1000
#  - 0s - loss: 0.2545 - val_loss: 0.2522
# Epoch 283/1000
#  - 0s - loss: 0.2511 - val_loss: 0.2489
# Epoch 284/1000
#  - 0s - loss: 0.2478 - val_loss: 0.2456
# Epoch 285/1000
#  - 0s - loss: 0.2445 - val_loss: 0.2423
# Epoch 286/1000
#  - 0s - loss: 0.2413 - val_loss: 0.2391
# Epoch 287/1000
#  - 0s - loss: 0.2381 - val_loss: 0.2360
# Epoch 288/1000
#  - 0s - loss: 0.2350 - val_loss: 0.2329
# Epoch 289/1000
#  - 0s - loss: 0.2319 - val_loss: 0.2298
# Epoch 290/1000
#  - 0s - loss: 0.2288 - val_loss: 0.2268
# Epoch 291/1000
#  - 0s - loss: 0.2259 - val_loss: 0.2238
# Epoch 292/1000
#  - 0s - loss: 0.2229 - val_loss: 0.2209
# Epoch 293/1000
#  - 0s - loss: 0.2200 - val_loss: 0.2180
# Epoch 294/1000
#  - 0s - loss: 0.2171 - val_loss: 0.2152
# Epoch 295/1000
#  - 0s - loss: 0.2143 - val_loss: 0.2124
# Epoch 296/1000
#  - 0s - loss: 0.2115 - val_loss: 0.2096
# Epoch 297/1000
#  - 0s - loss: 0.2088 - val_loss: 0.2069
# Epoch 298/1000
#  - 0s - loss: 0.2061 - val_loss: 0.2042
# Epoch 299/1000
#  - 0s - loss: 0.2034 - val_loss: 0.2015
# Epoch 300/1000
#  - 0s - loss: 0.2008 - val_loss: 0.1989
# Epoch 301/1000
#  - 0s - loss: 0.1982 - val_loss: 0.1964
# Epoch 302/1000
#  - 0s - loss: 0.1957 - val_loss: 0.1938
# Epoch 303/1000
#  - 0s - loss: 0.1932 - val_loss: 0.1913
# Epoch 304/1000
#  - 0s - loss: 0.1907 - val_loss: 0.1889
# Epoch 305/1000
#  - 0s - loss: 0.1883 - val_loss: 0.1865
# Epoch 306/1000
#  - 0s - loss: 0.1858 - val_loss: 0.1841
# Epoch 307/1000
#  - 0s - loss: 0.1835 - val_loss: 0.1817
# Epoch 308/1000
#  - 0s - loss: 0.1811 - val_loss: 0.1794
# Epoch 309/1000
#  - 0s - loss: 0.1788 - val_loss: 0.1771
# Epoch 310/1000
#  - 0s - loss: 0.1766 - val_loss: 0.1749
# Epoch 311/1000
#  - 0s - loss: 0.1743 - val_loss: 0.1726
# Epoch 312/1000
#  - 0s - loss: 0.1721 - val_loss: 0.1705
# Epoch 313/1000
#  - 0s - loss: 0.1700 - val_loss: 0.1683
# Epoch 314/1000
#  - 0s - loss: 0.1678 - val_loss: 0.1662
# Epoch 315/1000
#  - 0s - loss: 0.1657 - val_loss: 0.1641
# Epoch 316/1000
#  - 0s - loss: 0.1636 - val_loss: 0.1620
# Epoch 317/1000
#  - 0s - loss: 0.1616 - val_loss: 0.1600
# Epoch 318/1000
#  - 0s - loss: 0.1595 - val_loss: 0.1580
# Epoch 319/1000
#  - 0s - loss: 0.1575 - val_loss: 0.1560
# Epoch 320/1000
#  - 0s - loss: 0.1556 - val_loss: 0.1540
# Epoch 321/1000
#  - 0s - loss: 0.1536 - val_loss: 0.1521
# Epoch 322/1000
#  - 0s - loss: 0.1517 - val_loss: 0.1502
# Epoch 323/1000
#  - 0s - loss: 0.1498 - val_loss: 0.1483
# Epoch 324/1000
#  - 0s - loss: 0.1480 - val_loss: 0.1465
# Epoch 325/1000
#  - 0s - loss: 0.1462 - val_loss: 0.1447
# Epoch 326/1000
#  - 0s - loss: 0.1443 - val_loss: 0.1429
# Epoch 327/1000
#  - 0s - loss: 0.1426 - val_loss: 0.1411
# Epoch 328/1000
#  - 0s - loss: 0.1408 - val_loss: 0.1393
# Epoch 329/1000
#  - 0s - loss: 0.1391 - val_loss: 0.1376
# Epoch 330/1000
#  - 0s - loss: 0.1374 - val_loss: 0.1359
# Epoch 331/1000
#  - 0s - loss: 0.1357 - val_loss: 0.1343
# Epoch 332/1000
#  - 0s - loss: 0.1340 - val_loss: 0.1326
# Epoch 333/1000
#  - 0s - loss: 0.1324 - val_loss: 0.1310
# Epoch 334/1000
#  - 0s - loss: 0.1308 - val_loss: 0.1294
# Epoch 335/1000
#  - 0s - loss: 0.1292 - val_loss: 0.1278
# Epoch 336/1000
#  - 0s - loss: 0.1276 - val_loss: 0.1262
# Epoch 337/1000
#  - 0s - loss: 0.1260 - val_loss: 0.1247
# Epoch 338/1000
#  - 0s - loss: 0.1245 - val_loss: 0.1232
# Epoch 339/1000
#  - 0s - loss: 0.1230 - val_loss: 0.1217
# Epoch 340/1000
#  - 0s - loss: 0.1215 - val_loss: 0.1202
# Epoch 341/1000
#  - 0s - loss: 0.1201 - val_loss: 0.1187
# Epoch 342/1000
#  - 0s - loss: 0.1186 - val_loss: 0.1173
# Epoch 343/1000
#  - 0s - loss: 0.1172 - val_loss: 0.1159
# Epoch 344/1000
#  - 0s - loss: 0.1158 - val_loss: 0.1145
# Epoch 345/1000
#  - 0s - loss: 0.1144 - val_loss: 0.1131
# Epoch 346/1000
#  - 0s - loss: 0.1130 - val_loss: 0.1118
# Epoch 347/1000
#  - 0s - loss: 0.1117 - val_loss: 0.1104
# Epoch 348/1000
#  - 0s - loss: 0.1104 - val_loss: 0.1091
# Epoch 349/1000
#  - 0s - loss: 0.1090 - val_loss: 0.1078
# Epoch 350/1000
#  - 0s - loss: 0.1078 - val_loss: 0.1065
# Epoch 351/1000
#  - 0s - loss: 0.1065 - val_loss: 0.1052
# Epoch 352/1000
#  - 0s - loss: 0.1052 - val_loss: 0.1040
# Epoch 353/1000
#  - 0s - loss: 0.1040 - val_loss: 0.1028
# Epoch 354/1000
#  - 0s - loss: 0.1028 - val_loss: 0.1015
# Epoch 355/1000
#  - 0s - loss: 0.1015 - val_loss: 0.1003
# Epoch 356/1000
#  - 0s - loss: 0.1004 - val_loss: 0.0992
# Epoch 357/1000
#  - 0s - loss: 0.0992 - val_loss: 0.0980
# Epoch 358/1000
#  - 0s - loss: 0.0980 - val_loss: 0.0968
# Epoch 359/1000
#  - 0s - loss: 0.0969 - val_loss: 0.0957
# Epoch 360/1000
#  - 0s - loss: 0.0957 - val_loss: 0.0946
# Epoch 361/1000
#  - 0s - loss: 0.0946 - val_loss: 0.0935
# Epoch 362/1000
#  - 0s - loss: 0.0935 - val_loss: 0.0924
# Epoch 363/1000
#  - 0s - loss: 0.0924 - val_loss: 0.0913
# Epoch 364/1000
#  - 0s - loss: 0.0914 - val_loss: 0.0903
# Epoch 365/1000
#  - 0s - loss: 0.0903 - val_loss: 0.0892
# Epoch 366/1000
#  - 0s - loss: 0.0893 - val_loss: 0.0882
# Epoch 367/1000
#  - 0s - loss: 0.0883 - val_loss: 0.0872
# Epoch 368/1000
#  - 0s - loss: 0.0872 - val_loss: 0.0862
# Epoch 369/1000
#  - 0s - loss: 0.0862 - val_loss: 0.0852
# Epoch 370/1000
#  - 0s - loss: 0.0853 - val_loss: 0.0842
# Epoch 371/1000
#  - 0s - loss: 0.0843 - val_loss: 0.0832
# Epoch 372/1000
#  - 0s - loss: 0.0833 - val_loss: 0.0823
# Epoch 373/1000
#  - 0s - loss: 0.0824 - val_loss: 0.0813
# Epoch 374/1000
#  - 0s - loss: 0.0814 - val_loss: 0.0804
# Epoch 375/1000
#  - 0s - loss: 0.0805 - val_loss: 0.0795
# Epoch 376/1000
#  - 0s - loss: 0.0796 - val_loss: 0.0786
# Epoch 377/1000
#  - 0s - loss: 0.0787 - val_loss: 0.0777
# Epoch 378/1000
#  - 0s - loss: 0.0778 - val_loss: 0.0768
# Epoch 379/1000
#  - 0s - loss: 0.0770 - val_loss: 0.0759
# Epoch 380/1000
#  - 0s - loss: 0.0761 - val_loss: 0.0751
# Epoch 381/1000
#  - 0s - loss: 0.0753 - val_loss: 0.0742
# Epoch 382/1000
#  - 0s - loss: 0.0744 - val_loss: 0.0734
# Epoch 383/1000
#  - 0s - loss: 0.0736 - val_loss: 0.0726
# Epoch 384/1000
#  - 0s - loss: 0.0728 - val_loss: 0.0718
# Epoch 385/1000
#  - 0s - loss: 0.0720 - val_loss: 0.0710
# Epoch 386/1000
#  - 0s - loss: 0.0712 - val_loss: 0.0702
# Epoch 387/1000
#  - 0s - loss: 0.0704 - val_loss: 0.0694
# Epoch 388/1000
#  - 0s - loss: 0.0696 - val_loss: 0.0686
# Epoch 389/1000
#  - 0s - loss: 0.0688 - val_loss: 0.0679
# Epoch 390/1000
#  - 0s - loss: 0.0681 - val_loss: 0.0671
# Epoch 391/1000
#  - 0s - loss: 0.0673 - val_loss: 0.0664
# Epoch 392/1000
#  - 0s - loss: 0.0666 - val_loss: 0.0657
# Epoch 393/1000
#  - 0s - loss: 0.0659 - val_loss: 0.0650
# Epoch 394/1000
#  - 0s - loss: 0.0652 - val_loss: 0.0642
# Epoch 395/1000
#  - 0s - loss: 0.0645 - val_loss: 0.0635
# Epoch 396/1000
#  - 0s - loss: 0.0638 - val_loss: 0.0629
# Epoch 397/1000
#  - 0s - loss: 0.0631 - val_loss: 0.0622
# Epoch 398/1000
#  - 0s - loss: 0.0624 - val_loss: 0.0615
# Epoch 399/1000
#  - 0s - loss: 0.0617 - val_loss: 0.0608
# Epoch 400/1000
#  - 0s - loss: 0.0611 - val_loss: 0.0602
# Epoch 401/1000
#  - 0s - loss: 0.0604 - val_loss: 0.0595
# Epoch 402/1000
#  - 0s - loss: 0.0598 - val_loss: 0.0589
# Epoch 403/1000
#  - 0s - loss: 0.0591 - val_loss: 0.0583
# Epoch 404/1000
#  - 0s - loss: 0.0585 - val_loss: 0.0576
# Epoch 405/1000
#  - 0s - loss: 0.0579 - val_loss: 0.0570
# Epoch 406/1000
#  - 0s - loss: 0.0573 - val_loss: 0.0564
# Epoch 407/1000
#  - 0s - loss: 0.0567 - val_loss: 0.0558
# Epoch 408/1000
#  - 0s - loss: 0.0561 - val_loss: 0.0552
# Epoch 409/1000
#  - 0s - loss: 0.0555 - val_loss: 0.0547
# Epoch 410/1000
#  - 0s - loss: 0.0549 - val_loss: 0.0541
# Epoch 411/1000
#  - 0s - loss: 0.0544 - val_loss: 0.0535
# Epoch 412/1000
#  - 0s - loss: 0.0538 - val_loss: 0.0530
# Epoch 413/1000
#  - 0s - loss: 0.0532 - val_loss: 0.0524
# Epoch 414/1000
#  - 0s - loss: 0.0527 - val_loss: 0.0519
# Epoch 415/1000
#  - 0s - loss: 0.0521 - val_loss: 0.0513
# Epoch 416/1000
#  - 0s - loss: 0.0516 - val_loss: 0.0508
# Epoch 417/1000
#  - 0s - loss: 0.0511 - val_loss: 0.0503
# Epoch 418/1000
#  - 0s - loss: 0.0506 - val_loss: 0.0497
# Epoch 419/1000
#  - 0s - loss: 0.0500 - val_loss: 0.0492
# Epoch 420/1000
#  - 0s - loss: 0.0495 - val_loss: 0.0487
# Epoch 421/1000
#  - 0s - loss: 0.0490 - val_loss: 0.0482
# Epoch 422/1000
#  - 0s - loss: 0.0485 - val_loss: 0.0477
# Epoch 423/1000
#  - 0s - loss: 0.0481 - val_loss: 0.0473
# Epoch 424/1000
#  - 0s - loss: 0.0476 - val_loss: 0.0468
# Epoch 425/1000
#  - 0s - loss: 0.0471 - val_loss: 0.0463
# Epoch 426/1000
#  - 0s - loss: 0.0466 - val_loss: 0.0458
# Epoch 427/1000
#  - 0s - loss: 0.0462 - val_loss: 0.0454
# Epoch 428/1000
#  - 0s - loss: 0.0457 - val_loss: 0.0449
# Epoch 429/1000
#  - 0s - loss: 0.0453 - val_loss: 0.0445
# Epoch 430/1000
#  - 0s - loss: 0.0448 - val_loss: 0.0440
# Epoch 431/1000
#  - 0s - loss: 0.0444 - val_loss: 0.0436
# Epoch 432/1000
#  - 0s - loss: 0.0439 - val_loss: 0.0432
# Epoch 433/1000
#  - 0s - loss: 0.0435 - val_loss: 0.0427
# Epoch 434/1000
#  - 0s - loss: 0.0431 - val_loss: 0.0423
# Epoch 435/1000
#  - 0s - loss: 0.0427 - val_loss: 0.0419
# Epoch 436/1000
#  - 0s - loss: 0.0422 - val_loss: 0.0415
# Epoch 437/1000
#  - 0s - loss: 0.0418 - val_loss: 0.0411
# Epoch 438/1000
#  - 0s - loss: 0.0414 - val_loss: 0.0407
# Epoch 439/1000
#  - 0s - loss: 0.0410 - val_loss: 0.0403
# Epoch 440/1000
#  - 0s - loss: 0.0406 - val_loss: 0.0399
# Epoch 441/1000
#  - 0s - loss: 0.0403 - val_loss: 0.0395
# Epoch 442/1000
#  - 0s - loss: 0.0399 - val_loss: 0.0392
# Epoch 443/1000
#  - 0s - loss: 0.0395 - val_loss: 0.0388
# Epoch 444/1000
#  - 0s - loss: 0.0391 - val_loss: 0.0384
# Epoch 445/1000
#  - 0s - loss: 0.0388 - val_loss: 0.0380
# Epoch 446/1000
#  - 0s - loss: 0.0384 - val_loss: 0.0377
# Epoch 447/1000
#  - 0s - loss: 0.0380 - val_loss: 0.0373
# Epoch 448/1000
#  - 0s - loss: 0.0377 - val_loss: 0.0370
# Epoch 449/1000
#  - 0s - loss: 0.0373 - val_loss: 0.0366
# Epoch 450/1000
#  - 0s - loss: 0.0370 - val_loss: 0.0363
# Epoch 451/1000
#  - 0s - loss: 0.0366 - val_loss: 0.0360
# Epoch 452/1000
#  - 0s - loss: 0.0363 - val_loss: 0.0356
# Epoch 453/1000
#  - 0s - loss: 0.0360 - val_loss: 0.0353
# Epoch 454/1000
#  - 0s - loss: 0.0356 - val_loss: 0.0350
# Epoch 455/1000
#  - 0s - loss: 0.0353 - val_loss: 0.0346
# Epoch 456/1000
#  - 0s - loss: 0.0350 - val_loss: 0.0343
# Epoch 457/1000
#  - 0s - loss: 0.0347 - val_loss: 0.0340
# Epoch 458/1000
#  - 0s - loss: 0.0344 - val_loss: 0.0337
# Epoch 459/1000
#  - 0s - loss: 0.0341 - val_loss: 0.0334
# Epoch 460/1000
#  - 0s - loss: 0.0338 - val_loss: 0.0331
# Epoch 461/1000
#  - 0s - loss: 0.0335 - val_loss: 0.0328
# Epoch 462/1000
#  - 0s - loss: 0.0332 - val_loss: 0.0325
# Epoch 463/1000
#  - 0s - loss: 0.0329 - val_loss: 0.0322
# Epoch 464/1000
#  - 0s - loss: 0.0326 - val_loss: 0.0319
# Epoch 465/1000
#  - 0s - loss: 0.0323 - val_loss: 0.0317
# Epoch 466/1000
#  - 0s - loss: 0.0320 - val_loss: 0.0314
# Epoch 467/1000
#  - 0s - loss: 0.0317 - val_loss: 0.0311
# Epoch 468/1000
#  - 0s - loss: 0.0315 - val_loss: 0.0308
# Epoch 469/1000
#  - 0s - loss: 0.0312 - val_loss: 0.0306
# Epoch 470/1000
#  - 0s - loss: 0.0309 - val_loss: 0.0303
# Epoch 471/1000
#  - 0s - loss: 0.0307 - val_loss: 0.0300
# Epoch 472/1000
#  - 0s - loss: 0.0304 - val_loss: 0.0298
# Epoch 473/1000
#  - 0s - loss: 0.0302 - val_loss: 0.0295
# Epoch 474/1000
#  - 0s - loss: 0.0299 - val_loss: 0.0293
# Epoch 475/1000
#  - 0s - loss: 0.0296 - val_loss: 0.0290
# Epoch 476/1000
#  - 0s - loss: 0.0294 - val_loss: 0.0288
# Epoch 477/1000
#  - 0s - loss: 0.0292 - val_loss: 0.0285
# Epoch 478/1000
#  - 0s - loss: 0.0289 - val_loss: 0.0283
# Epoch 479/1000
#  - 0s - loss: 0.0287 - val_loss: 0.0281
# Epoch 480/1000
#  - 0s - loss: 0.0284 - val_loss: 0.0278
# Epoch 481/1000
#  - 0s - loss: 0.0282 - val_loss: 0.0276
# Epoch 482/1000
#  - 0s - loss: 0.0280 - val_loss: 0.0274
# Epoch 483/1000
#  - 0s - loss: 0.0278 - val_loss: 0.0272
# Epoch 484/1000
#  - 0s - loss: 0.0275 - val_loss: 0.0269
# Epoch 485/1000
#  - 0s - loss: 0.0273 - val_loss: 0.0267
# Epoch 486/1000
#  - 0s - loss: 0.0271 - val_loss: 0.0265
# Epoch 487/1000
#  - 0s - loss: 0.0269 - val_loss: 0.0263
# Epoch 488/1000
#  - 0s - loss: 0.0267 - val_loss: 0.0261
# Epoch 489/1000
#  - 0s - loss: 0.0264 - val_loss: 0.0259
# Epoch 490/1000
#  - 0s - loss: 0.0262 - val_loss: 0.0257
# Epoch 491/1000
#  - 0s - loss: 0.0260 - val_loss: 0.0255
# Epoch 492/1000
#  - 0s - loss: 0.0258 - val_loss: 0.0253
# Epoch 493/1000
#  - 0s - loss: 0.0256 - val_loss: 0.0251
# Epoch 494/1000
#  - 0s - loss: 0.0254 - val_loss: 0.0249
# Epoch 495/1000
#  - 0s - loss: 0.0252 - val_loss: 0.0247
# Epoch 496/1000
#  - 0s - loss: 0.0250 - val_loss: 0.0245
# Epoch 497/1000
#  - 0s - loss: 0.0249 - val_loss: 0.0243
# Epoch 498/1000
#  - 0s - loss: 0.0247 - val_loss: 0.0241
# Epoch 499/1000
#  - 0s - loss: 0.0245 - val_loss: 0.0239
# Epoch 500/1000
#  - 0s - loss: 0.0243 - val_loss: 0.0237
# Epoch 501/1000
#  - 0s - loss: 0.0241 - val_loss: 0.0236
# Epoch 502/1000
#  - 0s - loss: 0.0239 - val_loss: 0.0234
# Epoch 503/1000
#  - 0s - loss: 0.0238 - val_loss: 0.0232
# Epoch 504/1000
#  - 0s - loss: 0.0236 - val_loss: 0.0230
# Epoch 505/1000
#  - 0s - loss: 0.0234 - val_loss: 0.0229
# Epoch 506/1000
#  - 0s - loss: 0.0232 - val_loss: 0.0227
# Epoch 507/1000
#  - 0s - loss: 0.0231 - val_loss: 0.0225
# Epoch 508/1000
#  - 0s - loss: 0.0229 - val_loss: 0.0224
# Epoch 509/1000
#  - 0s - loss: 0.0227 - val_loss: 0.0222
# Epoch 510/1000
#  - 0s - loss: 0.0226 - val_loss: 0.0221
# Epoch 511/1000
#  - 0s - loss: 0.0224 - val_loss: 0.0219
# Epoch 512/1000
#  - 0s - loss: 0.0223 - val_loss: 0.0217
# Epoch 513/1000
#  - 0s - loss: 0.0221 - val_loss: 0.0216
# Epoch 514/1000
#  - 0s - loss: 0.0220 - val_loss: 0.0214
# Epoch 515/1000
#  - 0s - loss: 0.0218 - val_loss: 0.0213
# Epoch 516/1000
#  - 0s - loss: 0.0217 - val_loss: 0.0211
# Epoch 517/1000
#  - 0s - loss: 0.0215 - val_loss: 0.0210
# Epoch 518/1000
#  - 0s - loss: 0.0214 - val_loss: 0.0208
# Epoch 519/1000
#  - 0s - loss: 0.0212 - val_loss: 0.0207
# Epoch 520/1000
#  - 0s - loss: 0.0211 - val_loss: 0.0206
# Epoch 521/1000
#  - 0s - loss: 0.0209 - val_loss: 0.0204
# Epoch 522/1000
#  - 0s - loss: 0.0208 - val_loss: 0.0203
# Epoch 523/1000
#  - 0s - loss: 0.0207 - val_loss: 0.0202
# Epoch 524/1000
#  - 0s - loss: 0.0205 - val_loss: 0.0200
# Epoch 525/1000
#  - 0s - loss: 0.0204 - val_loss: 0.0199
# Epoch 526/1000
#  - 0s - loss: 0.0203 - val_loss: 0.0198
# Epoch 527/1000
#  - 0s - loss: 0.0201 - val_loss: 0.0196
# Epoch 528/1000
#  - 0s - loss: 0.0200 - val_loss: 0.0195
# Epoch 529/1000
#  - 0s - loss: 0.0199 - val_loss: 0.0194
# Epoch 530/1000
#  - 0s - loss: 0.0197 - val_loss: 0.0193
# Epoch 531/1000
#  - 0s - loss: 0.0196 - val_loss: 0.0191
# Epoch 532/1000
#  - 0s - loss: 0.0195 - val_loss: 0.0190
# Epoch 533/1000
#  - 0s - loss: 0.0194 - val_loss: 0.0189
# Epoch 534/1000
#  - 0s - loss: 0.0192 - val_loss: 0.0188
# Epoch 535/1000
#  - 0s - loss: 0.0191 - val_loss: 0.0187
# Epoch 536/1000
#  - 0s - loss: 0.0190 - val_loss: 0.0185
# Epoch 537/1000
#  - 0s - loss: 0.0189 - val_loss: 0.0184
# Epoch 538/1000
#  - 0s - loss: 0.0188 - val_loss: 0.0183
# Epoch 539/1000
#  - 0s - loss: 0.0187 - val_loss: 0.0182
# Epoch 540/1000
#  - 0s - loss: 0.0186 - val_loss: 0.0181
# Epoch 541/1000
#  - 0s - loss: 0.0184 - val_loss: 0.0180
# Epoch 542/1000
#  - 0s - loss: 0.0183 - val_loss: 0.0179
# Epoch 543/1000
#  - 0s - loss: 0.0182 - val_loss: 0.0178
# Epoch 544/1000
#  - 0s - loss: 0.0181 - val_loss: 0.0177
# Epoch 545/1000
#  - 0s - loss: 0.0180 - val_loss: 0.0176
# Epoch 546/1000
#  - 0s - loss: 0.0179 - val_loss: 0.0175
# Epoch 547/1000
#  - 0s - loss: 0.0178 - val_loss: 0.0174
# Epoch 548/1000
#  - 0s - loss: 0.0177 - val_loss: 0.0173
# Epoch 549/1000
#  - 0s - loss: 0.0176 - val_loss: 0.0172
# Epoch 550/1000
#  - 0s - loss: 0.0175 - val_loss: 0.0171
# Epoch 551/1000
#  - 0s - loss: 0.0174 - val_loss: 0.0170
# Epoch 552/1000
#  - 0s - loss: 0.0173 - val_loss: 0.0169
# Epoch 553/1000
#  - 0s - loss: 0.0172 - val_loss: 0.0168
# Epoch 554/1000
#  - 0s - loss: 0.0171 - val_loss: 0.0167
# Epoch 555/1000
#  - 0s - loss: 0.0170 - val_loss: 0.0166
# Epoch 556/1000
#  - 0s - loss: 0.0169 - val_loss: 0.0165
# Epoch 557/1000
#  - 0s - loss: 0.0168 - val_loss: 0.0164
# Epoch 558/1000
#  - 0s - loss: 0.0168 - val_loss: 0.0163
# Epoch 559/1000
#  - 0s - loss: 0.0167 - val_loss: 0.0162
# Epoch 560/1000
#  - 0s - loss: 0.0166 - val_loss: 0.0162
# Epoch 561/1000
#  - 0s - loss: 0.0165 - val_loss: 0.0161
# Epoch 562/1000
#  - 0s - loss: 0.0164 - val_loss: 0.0160
# Epoch 563/1000
#  - 0s - loss: 0.0163 - val_loss: 0.0159
# Epoch 564/1000
#  - 0s - loss: 0.0162 - val_loss: 0.0158
# Epoch 565/1000
#  - 0s - loss: 0.0162 - val_loss: 0.0157
# Epoch 566/1000
#  - 0s - loss: 0.0161 - val_loss: 0.0157
# Epoch 567/1000
#  - 0s - loss: 0.0160 - val_loss: 0.0156
# Epoch 568/1000
#  - 0s - loss: 0.0159 - val_loss: 0.0155
# Epoch 569/1000
#  - 0s - loss: 0.0158 - val_loss: 0.0154
# Epoch 570/1000
#  - 0s - loss: 0.0158 - val_loss: 0.0154
# Epoch 571/1000
#  - 0s - loss: 0.0157 - val_loss: 0.0153
# Epoch 572/1000
#  - 0s - loss: 0.0156 - val_loss: 0.0152
# Epoch 573/1000
#  - 0s - loss: 0.0155 - val_loss: 0.0151
# Epoch 574/1000
#  - 0s - loss: 0.0155 - val_loss: 0.0151
# Epoch 575/1000
#  - 0s - loss: 0.0154 - val_loss: 0.0150
# Epoch 576/1000
#  - 0s - loss: 0.0153 - val_loss: 0.0149
# Epoch 577/1000
#  - 0s - loss: 0.0152 - val_loss: 0.0149
# Epoch 578/1000
#  - 0s - loss: 0.0152 - val_loss: 0.0148
# Epoch 579/1000
#  - 0s - loss: 0.0151 - val_loss: 0.0147
# Epoch 580/1000
#  - 0s - loss: 0.0150 - val_loss: 0.0146
# Epoch 581/1000
#  - 0s - loss: 0.0150 - val_loss: 0.0146
# Epoch 582/1000
#  - 0s - loss: 0.0149 - val_loss: 0.0145
# Epoch 583/1000
#  - 0s - loss: 0.0148 - val_loss: 0.0145
# Epoch 584/1000
#  - 0s - loss: 0.0148 - val_loss: 0.0144
# Epoch 585/1000
#  - 0s - loss: 0.0147 - val_loss: 0.0143
# Epoch 586/1000
#  - 0s - loss: 0.0146 - val_loss: 0.0143
# Epoch 587/1000
#  - 0s - loss: 0.0146 - val_loss: 0.0142
# Epoch 588/1000
#  - 0s - loss: 0.0145 - val_loss: 0.0141
# Epoch 589/1000
#  - 0s - loss: 0.0145 - val_loss: 0.0141
# Epoch 590/1000
#  - 0s - loss: 0.0144 - val_loss: 0.0140
# Epoch 591/1000
#  - 0s - loss: 0.0143 - val_loss: 0.0140
# Epoch 592/1000
#  - 0s - loss: 0.0143 - val_loss: 0.0139
# Epoch 593/1000
#  - 0s - loss: 0.0142 - val_loss: 0.0138
# Epoch 594/1000
#  - 0s - loss: 0.0142 - val_loss: 0.0138
# Epoch 595/1000
#  - 0s - loss: 0.0141 - val_loss: 0.0137
# Epoch 596/1000
#  - 0s - loss: 0.0140 - val_loss: 0.0137
# Epoch 597/1000
#  - 0s - loss: 0.0140 - val_loss: 0.0136
# Epoch 598/1000
#  - 0s - loss: 0.0139 - val_loss: 0.0136
# Epoch 599/1000
#  - 0s - loss: 0.0139 - val_loss: 0.0135
# Epoch 600/1000
#  - 0s - loss: 0.0138 - val_loss: 0.0135
# Epoch 601/1000
#  - 0s - loss: 0.0138 - val_loss: 0.0134
# Epoch 602/1000
#  - 0s - loss: 0.0137 - val_loss: 0.0134
# Epoch 603/1000
#  - 0s - loss: 0.0137 - val_loss: 0.0133
# Epoch 604/1000
#  - 0s - loss: 0.0136 - val_loss: 0.0133
# Epoch 605/1000
#  - 0s - loss: 0.0135 - val_loss: 0.0132
# Epoch 606/1000
#  - 0s - loss: 0.0135 - val_loss: 0.0132
# Epoch 607/1000
#  - 0s - loss: 0.0134 - val_loss: 0.0131
# Epoch 608/1000
#  - 0s - loss: 0.0134 - val_loss: 0.0131
# Epoch 609/1000
#  - 0s - loss: 0.0133 - val_loss: 0.0130
# Epoch 610/1000
#  - 0s - loss: 0.0133 - val_loss: 0.0130
# Epoch 611/1000
#  - 0s - loss: 0.0133 - val_loss: 0.0129
# Epoch 612/1000
#  - 0s - loss: 0.0132 - val_loss: 0.0129
# Epoch 613/1000
#  - 0s - loss: 0.0132 - val_loss: 0.0128
# Epoch 614/1000
#  - 0s - loss: 0.0131 - val_loss: 0.0128
# Epoch 615/1000
#  - 0s - loss: 0.0131 - val_loss: 0.0127
# Epoch 616/1000
#  - 0s - loss: 0.0130 - val_loss: 0.0127
# Epoch 617/1000
#  - 0s - loss: 0.0130 - val_loss: 0.0127
# Epoch 618/1000
#  - 0s - loss: 0.0129 - val_loss: 0.0126
# Epoch 619/1000
#  - 0s - loss: 0.0129 - val_loss: 0.0126
# Epoch 620/1000
#  - 0s - loss: 0.0128 - val_loss: 0.0125
# Epoch 621/1000
#  - 0s - loss: 0.0128 - val_loss: 0.0125
# Epoch 622/1000
#  - 0s - loss: 0.0128 - val_loss: 0.0125
# Epoch 623/1000
#  - 0s - loss: 0.0127 - val_loss: 0.0124
# Epoch 624/1000
#  - 0s - loss: 0.0127 - val_loss: 0.0124
# Epoch 625/1000
#  - 0s - loss: 0.0126 - val_loss: 0.0123
# Epoch 626/1000
#  - 0s - loss: 0.0126 - val_loss: 0.0123
# Epoch 627/1000
#  - 0s - loss: 0.0126 - val_loss: 0.0123
# Epoch 628/1000
#  - 0s - loss: 0.0125 - val_loss: 0.0122
# Epoch 629/1000
#  - 0s - loss: 0.0125 - val_loss: 0.0122
# Epoch 630/1000
#  - 0s - loss: 0.0124 - val_loss: 0.0121
# Epoch 631/1000
#  - 0s - loss: 0.0124 - val_loss: 0.0121
# Epoch 632/1000
#  - 0s - loss: 0.0124 - val_loss: 0.0121
# Epoch 633/1000
#  - 0s - loss: 0.0123 - val_loss: 0.0120
# Epoch 634/1000
#  - 0s - loss: 0.0123 - val_loss: 0.0120
# Epoch 635/1000
#  - 0s - loss: 0.0122 - val_loss: 0.0120
# Epoch 636/1000
#  - 0s - loss: 0.0122 - val_loss: 0.0119
# Epoch 637/1000
#  - 0s - loss: 0.0122 - val_loss: 0.0119
# Epoch 638/1000
#  - 0s - loss: 0.0121 - val_loss: 0.0119
# Epoch 639/1000
#  - 0s - loss: 0.0121 - val_loss: 0.0118
# Epoch 640/1000
#  - 0s - loss: 0.0121 - val_loss: 0.0118
# Epoch 641/1000
#  - 0s - loss: 0.0120 - val_loss: 0.0118
# Epoch 642/1000
#  - 0s - loss: 0.0120 - val_loss: 0.0117
# Epoch 643/1000
#  - 0s - loss: 0.0120 - val_loss: 0.0117
# Epoch 644/1000
#  - 0s - loss: 0.0119 - val_loss: 0.0117
# Epoch 645/1000
#  - 0s - loss: 0.0119 - val_loss: 0.0116
# Epoch 646/1000
#  - 0s - loss: 0.0119 - val_loss: 0.0116
# Epoch 647/1000
#  - 0s - loss: 0.0118 - val_loss: 0.0116
# Epoch 648/1000
#  - 0s - loss: 0.0118 - val_loss: 0.0115
# Epoch 649/1000
#  - 0s - loss: 0.0118 - val_loss: 0.0115
# Epoch 650/1000
#  - 0s - loss: 0.0117 - val_loss: 0.0115
# Epoch 651/1000
#  - 0s - loss: 0.0117 - val_loss: 0.0115
# Epoch 652/1000
#  - 0s - loss: 0.0117 - val_loss: 0.0114
# Epoch 653/1000
#  - 0s - loss: 0.0116 - val_loss: 0.0114
# Epoch 654/1000
#  - 0s - loss: 0.0116 - val_loss: 0.0114
# Epoch 655/1000
#  - 0s - loss: 0.0116 - val_loss: 0.0113
# Epoch 656/1000
#  - 0s - loss: 0.0116 - val_loss: 0.0113
# Epoch 657/1000
#  - 0s - loss: 0.0115 - val_loss: 0.0113
# Epoch 658/1000
#  - 0s - loss: 0.0115 - val_loss: 0.0113
# Epoch 659/1000
#  - 0s - loss: 0.0115 - val_loss: 0.0112
# Epoch 660/1000
#  - 0s - loss: 0.0114 - val_loss: 0.0112
# Epoch 661/1000
#  - 0s - loss: 0.0114 - val_loss: 0.0112
# Epoch 662/1000
#  - 0s - loss: 0.0114 - val_loss: 0.0112
# Epoch 663/1000
#  - 0s - loss: 0.0114 - val_loss: 0.0111
# Epoch 664/1000
#  - 0s - loss: 0.0113 - val_loss: 0.0111
# Epoch 665/1000
#  - 0s - loss: 0.0113 - val_loss: 0.0111
# Epoch 666/1000
#  - 0s - loss: 0.0113 - val_loss: 0.0111
# Epoch 667/1000
#  - 0s - loss: 0.0113 - val_loss: 0.0110
# Epoch 668/1000
#  - 0s - loss: 0.0112 - val_loss: 0.0110
# Epoch 669/1000
#  - 0s - loss: 0.0112 - val_loss: 0.0110
# Epoch 670/1000
#  - 0s - loss: 0.0112 - val_loss: 0.0110
# Epoch 671/1000
#  - 0s - loss: 0.0112 - val_loss: 0.0109
# Epoch 672/1000
#  - 0s - loss: 0.0111 - val_loss: 0.0109
# Epoch 673/1000
#  - 0s - loss: 0.0111 - val_loss: 0.0109
# Epoch 674/1000
#  - 0s - loss: 0.0111 - val_loss: 0.0109
# Epoch 675/1000
#  - 0s - loss: 0.0111 - val_loss: 0.0109
# Epoch 676/1000
#  - 0s - loss: 0.0110 - val_loss: 0.0108
# Epoch 677/1000
#  - 0s - loss: 0.0110 - val_loss: 0.0108
# Epoch 678/1000
#  - 0s - loss: 0.0110 - val_loss: 0.0108
# Epoch 679/1000
#  - 0s - loss: 0.0110 - val_loss: 0.0108
# Epoch 680/1000
#  - 0s - loss: 0.0109 - val_loss: 0.0108
# Epoch 681/1000
#  - 0s - loss: 0.0109 - val_loss: 0.0107
# Epoch 682/1000
#  - 0s - loss: 0.0109 - val_loss: 0.0107
# Epoch 683/1000
#  - 0s - loss: 0.0109 - val_loss: 0.0107
# Epoch 684/1000
#  - 0s - loss: 0.0109 - val_loss: 0.0107
# Epoch 685/1000
#  - 0s - loss: 0.0108 - val_loss: 0.0107
# Epoch 686/1000
#  - 0s - loss: 0.0108 - val_loss: 0.0106
# Epoch 687/1000
#  - 0s - loss: 0.0108 - val_loss: 0.0106
# Epoch 688/1000
#  - 0s - loss: 0.0108 - val_loss: 0.0106
# Epoch 689/1000
#  - 0s - loss: 0.0108 - val_loss: 0.0106
# Epoch 690/1000
#  - 0s - loss: 0.0107 - val_loss: 0.0106
# Epoch 691/1000
#  - 0s - loss: 0.0107 - val_loss: 0.0105
# Epoch 692/1000
#  - 0s - loss: 0.0107 - val_loss: 0.0105
# Epoch 693/1000
#  - 0s - loss: 0.0107 - val_loss: 0.0105
# Epoch 694/1000
#  - 0s - loss: 0.0107 - val_loss: 0.0105
# Epoch 695/1000
#  - 0s - loss: 0.0106 - val_loss: 0.0105
# Epoch 696/1000
#  - 0s - loss: 0.0106 - val_loss: 0.0105
# Epoch 697/1000
#  - 0s - loss: 0.0106 - val_loss: 0.0104
# Epoch 698/1000
#  - 0s - loss: 0.0106 - val_loss: 0.0104
# Epoch 699/1000
#  - 0s - loss: 0.0106 - val_loss: 0.0104
# Epoch 700/1000
#  - 0s - loss: 0.0105 - val_loss: 0.0104
# Epoch 701/1000
#  - 0s - loss: 0.0105 - val_loss: 0.0104
# Epoch 702/1000
#  - 0s - loss: 0.0105 - val_loss: 0.0104
# Epoch 703/1000
#  - 0s - loss: 0.0105 - val_loss: 0.0103
# Epoch 704/1000
#  - 0s - loss: 0.0105 - val_loss: 0.0103
# Epoch 705/1000
#  - 0s - loss: 0.0105 - val_loss: 0.0103
# Epoch 706/1000
#  - 0s - loss: 0.0104 - val_loss: 0.0103
# Epoch 707/1000
#  - 0s - loss: 0.0104 - val_loss: 0.0103
# Epoch 708/1000
#  - 0s - loss: 0.0104 - val_loss: 0.0103
# Epoch 709/1000
#  - 0s - loss: 0.0104 - val_loss: 0.0102
# Epoch 710/1000
#  - 0s - loss: 0.0104 - val_loss: 0.0102
# Epoch 711/1000
#  - 0s - loss: 0.0104 - val_loss: 0.0102
# Epoch 712/1000
#  - 0s - loss: 0.0103 - val_loss: 0.0102
# Epoch 713/1000
#  - 0s - loss: 0.0103 - val_loss: 0.0102
# Epoch 714/1000
#  - 0s - loss: 0.0103 - val_loss: 0.0102
# Epoch 715/1000
#  - 0s - loss: 0.0103 - val_loss: 0.0102
# Epoch 716/1000
#  - 0s - loss: 0.0103 - val_loss: 0.0101
# Epoch 717/1000
#  - 0s - loss: 0.0103 - val_loss: 0.0101
# Epoch 718/1000
#  - 0s - loss: 0.0102 - val_loss: 0.0101
# Epoch 719/1000
#  - 0s - loss: 0.0102 - val_loss: 0.0101
# Epoch 720/1000
#  - 0s - loss: 0.0102 - val_loss: 0.0101
# Epoch 721/1000
#  - 0s - loss: 0.0102 - val_loss: 0.0101
# Epoch 722/1000
#  - 0s - loss: 0.0102 - val_loss: 0.0101
# Epoch 723/1000
#  - 0s - loss: 0.0102 - val_loss: 0.0101
# Epoch 724/1000
#  - 0s - loss: 0.0102 - val_loss: 0.0100
# Epoch 725/1000
#  - 0s - loss: 0.0101 - val_loss: 0.0100
# Epoch 726/1000
#  - 0s - loss: 0.0101 - val_loss: 0.0100
# Epoch 727/1000
#  - 0s - loss: 0.0101 - val_loss: 0.0100
# Epoch 728/1000
#  - 0s - loss: 0.0101 - val_loss: 0.0100
# Epoch 729/1000
#  - 0s - loss: 0.0101 - val_loss: 0.0100
# Epoch 730/1000
#  - 0s - loss: 0.0101 - val_loss: 0.0100
# Epoch 731/1000
#  - 0s - loss: 0.0101 - val_loss: 0.0100
# Epoch 732/1000
#  - 0s - loss: 0.0101 - val_loss: 0.0099
# Epoch 733/1000
#  - 0s - loss: 0.0100 - val_loss: 0.0099
# Epoch 734/1000
#  - 0s - loss: 0.0100 - val_loss: 0.0099
# Epoch 735/1000
#  - 0s - loss: 0.0100 - val_loss: 0.0099
# Epoch 736/1000
#  - 0s - loss: 0.0100 - val_loss: 0.0099
# Epoch 737/1000
#  - 0s - loss: 0.0100 - val_loss: 0.0099
# Epoch 738/1000
#  - 0s - loss: 0.0100 - val_loss: 0.0099
# Epoch 739/1000
#  - 0s - loss: 0.0100 - val_loss: 0.0099
# Epoch 740/1000
#  - 0s - loss: 0.0100 - val_loss: 0.0099
# Epoch 741/1000
#  - 0s - loss: 0.0099 - val_loss: 0.0098
# Epoch 742/1000
#  - 0s - loss: 0.0099 - val_loss: 0.0098
# Epoch 743/1000
#  - 0s - loss: 0.0099 - val_loss: 0.0098
# Epoch 744/1000
#  - 0s - loss: 0.0099 - val_loss: 0.0098
# Epoch 745/1000
#  - 0s - loss: 0.0099 - val_loss: 0.0098
# Epoch 746/1000
#  - 0s - loss: 0.0099 - val_loss: 0.0098
# Epoch 747/1000
#  - 0s - loss: 0.0099 - val_loss: 0.0098
# Epoch 748/1000
#  - 0s - loss: 0.0099 - val_loss: 0.0098
# Epoch 749/1000
#  - 0s - loss: 0.0099 - val_loss: 0.0098
# Epoch 750/1000
#  - 0s - loss: 0.0098 - val_loss: 0.0098
# Epoch 751/1000
#  - 0s - loss: 0.0098 - val_loss: 0.0098
# Epoch 752/1000
#  - 0s - loss: 0.0098 - val_loss: 0.0097
# Epoch 753/1000
#  - 0s - loss: 0.0098 - val_loss: 0.0097
# Epoch 754/1000
#  - 0s - loss: 0.0098 - val_loss: 0.0097
# Epoch 755/1000
#  - 0s - loss: 0.0098 - val_loss: 0.0097
# Epoch 756/1000
#  - 0s - loss: 0.0098 - val_loss: 0.0097
# Epoch 757/1000
#  - 0s - loss: 0.0098 - val_loss: 0.0097
# Epoch 758/1000
#  - 0s - loss: 0.0098 - val_loss: 0.0097
# Epoch 759/1000
#  - 0s - loss: 0.0098 - val_loss: 0.0097
# Epoch 760/1000
#  - 0s - loss: 0.0097 - val_loss: 0.0097
# Epoch 761/1000
#  - 0s - loss: 0.0097 - val_loss: 0.0097
# Epoch 762/1000
#  - 0s - loss: 0.0097 - val_loss: 0.0097
# Epoch 763/1000
#  - 0s - loss: 0.0097 - val_loss: 0.0097
# Epoch 764/1000
#  - 0s - loss: 0.0097 - val_loss: 0.0096
# Epoch 765/1000
#  - 0s - loss: 0.0097 - val_loss: 0.0096
# Epoch 766/1000
#  - 0s - loss: 0.0097 - val_loss: 0.0096
# Epoch 767/1000
#  - 0s - loss: 0.0097 - val_loss: 0.0096
# Epoch 768/1000
#  - 0s - loss: 0.0097 - val_loss: 0.0096
# Epoch 769/1000
#  - 0s - loss: 0.0097 - val_loss: 0.0096
# Epoch 770/1000
#  - 0s - loss: 0.0097 - val_loss: 0.0096
# Epoch 771/1000
#  - 0s - loss: 0.0096 - val_loss: 0.0096
# Epoch 772/1000
#  - 0s - loss: 0.0096 - val_loss: 0.0096
# Epoch 773/1000
#  - 0s - loss: 0.0096 - val_loss: 0.0096
# Epoch 774/1000
#  - 0s - loss: 0.0096 - val_loss: 0.0096
# Epoch 775/1000
#  - 0s - loss: 0.0096 - val_loss: 0.0096
# Epoch 776/1000
#  - 0s - loss: 0.0096 - val_loss: 0.0096
# Epoch 777/1000
#  - 0s - loss: 0.0096 - val_loss: 0.0096
# Epoch 778/1000
#  - 0s - loss: 0.0096 - val_loss: 0.0095
# Epoch 779/1000
#  - 0s - loss: 0.0096 - val_loss: 0.0095
# Epoch 780/1000
#  - 0s - loss: 0.0096 - val_loss: 0.0095
# Epoch 781/1000
#  - 0s - loss: 0.0096 - val_loss: 0.0095
# Epoch 782/1000
#  - 0s - loss: 0.0096 - val_loss: 0.0095
# Epoch 783/1000
#  - 0s - loss: 0.0095 - val_loss: 0.0095
# Epoch 784/1000
#  - 0s - loss: 0.0095 - val_loss: 0.0095
# Epoch 785/1000
#  - 0s - loss: 0.0095 - val_loss: 0.0095
# Epoch 786/1000
#  - 0s - loss: 0.0095 - val_loss: 0.0095
# Epoch 787/1000
#  - 0s - loss: 0.0095 - val_loss: 0.0095
# Epoch 788/1000
#  - 0s - loss: 0.0095 - val_loss: 0.0095
# Epoch 789/1000
#  - 0s - loss: 0.0095 - val_loss: 0.0095
# Epoch 790/1000
#  - 0s - loss: 0.0095 - val_loss: 0.0095
# Epoch 791/1000
#  - 0s - loss: 0.0095 - val_loss: 0.0095
# Epoch 792/1000
#  - 0s - loss: 0.0095 - val_loss: 0.0095
# Epoch 793/1000
#  - 0s - loss: 0.0095 - val_loss: 0.0095
# Epoch 794/1000
#  - 0s - loss: 0.0095 - val_loss: 0.0094
# Epoch 795/1000
#  - 0s - loss: 0.0095 - val_loss: 0.0094
# Epoch 796/1000
#  - 0s - loss: 0.0095 - val_loss: 0.0094
# Epoch 797/1000
#  - 0s - loss: 0.0095 - val_loss: 0.0094
# Epoch 798/1000
#  - 0s - loss: 0.0094 - val_loss: 0.0094
# Epoch 799/1000
#  - 0s - loss: 0.0094 - val_loss: 0.0094
# Epoch 800/1000
#  - 0s - loss: 0.0094 - val_loss: 0.0094
# Epoch 801/1000
#  - 0s - loss: 0.0094 - val_loss: 0.0094
# Epoch 802/1000
#  - 0s - loss: 0.0094 - val_loss: 0.0094
# Epoch 803/1000
#  - 0s - loss: 0.0094 - val_loss: 0.0094
# Epoch 804/1000
#  - 0s - loss: 0.0094 - val_loss: 0.0094
# Epoch 805/1000
#  - 0s - loss: 0.0094 - val_loss: 0.0094
# Epoch 806/1000
#  - 0s - loss: 0.0094 - val_loss: 0.0094
# Epoch 807/1000
#  - 0s - loss: 0.0094 - val_loss: 0.0094
# Epoch 808/1000
#  - 0s - loss: 0.0094 - val_loss: 0.0094
# Epoch 809/1000
#  - 0s - loss: 0.0094 - val_loss: 0.0094
# Epoch 810/1000
#  - 0s - loss: 0.0094 - val_loss: 0.0094
# Epoch 811/1000
#  - 0s - loss: 0.0094 - val_loss: 0.0094
# Epoch 812/1000
#  - 0s - loss: 0.0094 - val_loss: 0.0094
# Epoch 813/1000
#  - 0s - loss: 0.0094 - val_loss: 0.0094
# Epoch 814/1000
#  - 0s - loss: 0.0094 - val_loss: 0.0094
# Epoch 815/1000
#  - 0s - loss: 0.0093 - val_loss: 0.0093
# Epoch 816/1000
#  - 0s - loss: 0.0093 - val_loss: 0.0093
# Epoch 817/1000
#  - 0s - loss: 0.0093 - val_loss: 0.0093
# Epoch 818/1000
#  - 0s - loss: 0.0093 - val_loss: 0.0093
# Epoch 819/1000
#  - 0s - loss: 0.0093 - val_loss: 0.0093
# Epoch 820/1000
#  - 0s - loss: 0.0093 - val_loss: 0.0093
# Epoch 821/1000
#  - 0s - loss: 0.0093 - val_loss: 0.0093
# Epoch 822/1000
#  - 0s - loss: 0.0093 - val_loss: 0.0093
# Epoch 823/1000
#  - 0s - loss: 0.0093 - val_loss: 0.0093
# Epoch 824/1000
#  - 0s - loss: 0.0093 - val_loss: 0.0093
# Epoch 825/1000
#  - 0s - loss: 0.0093 - val_loss: 0.0093
# Epoch 826/1000
#  - 0s - loss: 0.0093 - val_loss: 0.0093
# Epoch 827/1000
#  - 0s - loss: 0.0093 - val_loss: 0.0093
# Epoch 828/1000
#  - 0s - loss: 0.0093 - val_loss: 0.0093
# Epoch 829/1000
#  - 0s - loss: 0.0093 - val_loss: 0.0093
# Epoch 830/1000
#  - 0s - loss: 0.0093 - val_loss: 0.0093
# Epoch 831/1000
#  - 0s - loss: 0.0093 - val_loss: 0.0093
# Epoch 832/1000
#  - 0s - loss: 0.0093 - val_loss: 0.0093
# Epoch 833/1000
#  - 0s - loss: 0.0093 - val_loss: 0.0093
# Epoch 834/1000
#  - 0s - loss: 0.0093 - val_loss: 0.0093
# Epoch 835/1000
#  - 0s - loss: 0.0093 - val_loss: 0.0093
# Epoch 836/1000
#  - 0s - loss: 0.0092 - val_loss: 0.0093
# Epoch 837/1000
#  - 0s - loss: 0.0092 - val_loss: 0.0093
# Epoch 838/1000
#  - 0s - loss: 0.0092 - val_loss: 0.0093
# Epoch 839/1000
#  - 0s - loss: 0.0092 - val_loss: 0.0093
# Epoch 840/1000
#  - 0s - loss: 0.0092 - val_loss: 0.0093
# Epoch 841/1000
#  - 0s - loss: 0.0092 - val_loss: 0.0093
# Epoch 842/1000
#  - 0s - loss: 0.0092 - val_loss: 0.0093
# Epoch 843/1000
#  - 0s - loss: 0.0092 - val_loss: 0.0092
# Epoch 844/1000
#  - 0s - loss: 0.0092 - val_loss: 0.0092
# Epoch 845/1000
#  - 0s - loss: 0.0092 - val_loss: 0.0092
# Epoch 846/1000
#  - 0s - loss: 0.0092 - val_loss: 0.0092
# Epoch 847/1000
#  - 0s - loss: 0.0092 - val_loss: 0.0092
# Epoch 848/1000
#  - 0s - loss: 0.0092 - val_loss: 0.0092
# Epoch 849/1000
#  - 0s - loss: 0.0092 - val_loss: 0.0092
# Epoch 850/1000
#  - 0s - loss: 0.0092 - val_loss: 0.0092
# Epoch 851/1000
#  - 0s - loss: 0.0092 - val_loss: 0.0092
# Epoch 852/1000
#  - 0s - loss: 0.0092 - val_loss: 0.0092
# Epoch 853/1000
#  - 0s - loss: 0.0092 - val_loss: 0.0092
# Epoch 854/1000
#  - 0s - loss: 0.0092 - val_loss: 0.0092
# Epoch 855/1000
#  - 0s - loss: 0.0092 - val_loss: 0.0092
# Epoch 856/1000
#  - 0s - loss: 0.0092 - val_loss: 0.0092
# Epoch 857/1000
#  - 0s - loss: 0.0092 - val_loss: 0.0092
# Epoch 858/1000
#  - 0s - loss: 0.0092 - val_loss: 0.0092
# Epoch 859/1000
#  - 0s - loss: 0.0092 - val_loss: 0.0092
# Epoch 860/1000
#  - 0s - loss: 0.0092 - val_loss: 0.0092
# Epoch 861/1000
#  - 0s - loss: 0.0092 - val_loss: 0.0092
# Epoch 862/1000
#  - 0s - loss: 0.0092 - val_loss: 0.0092
# Epoch 863/1000
#  - 0s - loss: 0.0091 - val_loss: 0.0092
# Epoch 864/1000
#  - 0s - loss: 0.0091 - val_loss: 0.0092
# Epoch 865/1000
#  - 0s - loss: 0.0091 - val_loss: 0.0092
# Epoch 866/1000
#  - 0s - loss: 0.0091 - val_loss: 0.0092
# Epoch 867/1000
#  - 0s - loss: 0.0091 - val_loss: 0.0092
# Epoch 868/1000
#  - 0s - loss: 0.0091 - val_loss: 0.0092
# Epoch 869/1000
#  - 0s - loss: 0.0091 - val_loss: 0.0092
# Epoch 870/1000
#  - 0s - loss: 0.0091 - val_loss: 0.0092
# Epoch 871/1000
#  - 0s - loss: 0.0091 - val_loss: 0.0092
# Epoch 872/1000
#  - 0s - loss: 0.0091 - val_loss: 0.0092
# Epoch 873/1000
#  - 0s - loss: 0.0091 - val_loss: 0.0092
# Epoch 874/1000
#  - 0s - loss: 0.0091 - val_loss: 0.0092
# Epoch 875/1000
#  - 0s - loss: 0.0091 - val_loss: 0.0092
# Epoch 876/1000
#  - 0s - loss: 0.0091 - val_loss: 0.0092
# Epoch 877/1000
#  - 0s - loss: 0.0091 - val_loss: 0.0092
# Epoch 878/1000
#  - 0s - loss: 0.0091 - val_loss: 0.0092
# Epoch 879/1000
#  - 0s - loss: 0.0091 - val_loss: 0.0092
# Epoch 880/1000
#  - 0s - loss: 0.0091 - val_loss: 0.0092
# Epoch 881/1000
#  - 0s - loss: 0.0091 - val_loss: 0.0092
# Epoch 882/1000
#  - 0s - loss: 0.0091 - val_loss: 0.0092
# Epoch 883/1000
#  - 0s - loss: 0.0091 - val_loss: 0.0092
# Epoch 884/1000
#  - 0s - loss: 0.0091 - val_loss: 0.0092
# Epoch 885/1000
#  - 0s - loss: 0.0091 - val_loss: 0.0092
# Epoch 886/1000
#  - 0s - loss: 0.0091 - val_loss: 0.0092
# Epoch 887/1000
#  - 0s - loss: 0.0091 - val_loss: 0.0092
# Epoch 888/1000
#  - 0s - loss: 0.0091 - val_loss: 0.0091
# Epoch 889/1000
#  - 0s - loss: 0.0091 - val_loss: 0.0091
# Epoch 890/1000
#  - 0s - loss: 0.0091 - val_loss: 0.0091
# Epoch 891/1000
#  - 0s - loss: 0.0091 - val_loss: 0.0091
# Epoch 892/1000
#  - 0s - loss: 0.0091 - val_loss: 0.0091
# Epoch 893/1000
#  - 0s - loss: 0.0091 - val_loss: 0.0091
# Epoch 894/1000
#  - 0s - loss: 0.0091 - val_loss: 0.0091
# Epoch 895/1000
#  - 0s - loss: 0.0091 - val_loss: 0.0091
# Epoch 896/1000
#  - 0s - loss: 0.0091 - val_loss: 0.0091
# Epoch 897/1000
#  - 0s - loss: 0.0091 - val_loss: 0.0091
# Epoch 898/1000
#  - 0s - loss: 0.0091 - val_loss: 0.0091
# Epoch 899/1000
#  - 0s - loss: 0.0091 - val_loss: 0.0091
# Epoch 900/1000
#  - 0s - loss: 0.0091 - val_loss: 0.0091
# Epoch 901/1000
#  - 0s - loss: 0.0091 - val_loss: 0.0091
# Epoch 902/1000
#  - 0s - loss: 0.0091 - val_loss: 0.0091
# Epoch 903/1000
#  - 0s - loss: 0.0090 - val_loss: 0.0091
# Epoch 904/1000
#  - 0s - loss: 0.0090 - val_loss: 0.0091
# Epoch 905/1000
#  - 0s - loss: 0.0090 - val_loss: 0.0091
# Epoch 906/1000
#  - 0s - loss: 0.0090 - val_loss: 0.0091
# Epoch 907/1000
#  - 0s - loss: 0.0090 - val_loss: 0.0091
# Epoch 908/1000
#  - 0s - loss: 0.0090 - val_loss: 0.0091
# Epoch 909/1000
#  - 0s - loss: 0.0090 - val_loss: 0.0091
# Epoch 910/1000
#  - 0s - loss: 0.0090 - val_loss: 0.0091
# Epoch 911/1000
#  - 0s - loss: 0.0090 - val_loss: 0.0091
# Epoch 912/1000
#  - 0s - loss: 0.0090 - val_loss: 0.0091
# Epoch 913/1000
#  - 0s - loss: 0.0090 - val_loss: 0.0091
# Epoch 914/1000
#  - 0s - loss: 0.0090 - val_loss: 0.0091
# Epoch 915/1000
#  - 0s - loss: 0.0090 - val_loss: 0.0091
# Epoch 916/1000
#  - 0s - loss: 0.0090 - val_loss: 0.0091
# Epoch 917/1000
#  - 0s - loss: 0.0090 - val_loss: 0.0091
# Epoch 918/1000
#  - 0s - loss: 0.0090 - val_loss: 0.0091
# Epoch 919/1000
#  - 0s - loss: 0.0090 - val_loss: 0.0091
# Epoch 920/1000
#  - 0s - loss: 0.0090 - val_loss: 0.0091
# Epoch 921/1000
#  - 0s - loss: 0.0090 - val_loss: 0.0091
# Epoch 922/1000
#  - 0s - loss: 0.0090 - val_loss: 0.0091
# Epoch 923/1000
#  - 0s - loss: 0.0090 - val_loss: 0.0091
# Epoch 924/1000
#  - 0s - loss: 0.0090 - val_loss: 0.0091
# Epoch 925/1000
#  - 0s - loss: 0.0090 - val_loss: 0.0091
# Epoch 926/1000
#  - 0s - loss: 0.0090 - val_loss: 0.0091
# Epoch 927/1000
#  - 0s - loss: 0.0090 - val_loss: 0.0091
# Epoch 928/1000
#  - 0s - loss: 0.0090 - val_loss: 0.0091
# Epoch 929/1000
#  - 0s - loss: 0.0090 - val_loss: 0.0091
# Epoch 930/1000
#  - 0s - loss: 0.0090 - val_loss: 0.0091
# Epoch 931/1000
#  - 0s - loss: 0.0090 - val_loss: 0.0091
# Epoch 932/1000
#  - 0s - loss: 0.0090 - val_loss: 0.0091
# Epoch 933/1000
#  - 0s - loss: 0.0090 - val_loss: 0.0091
# Epoch 934/1000
#  - 0s - loss: 0.0090 - val_loss: 0.0091
# Epoch 935/1000
#  - 0s - loss: 0.0090 - val_loss: 0.0091
# Epoch 936/1000
#  - 0s - loss: 0.0090 - val_loss: 0.0091
# Epoch 937/1000
#  - 0s - loss: 0.0090 - val_loss: 0.0091
# Epoch 938/1000
#  - 0s - loss: 0.0090 - val_loss: 0.0091
# Epoch 939/1000
#  - 0s - loss: 0.0090 - val_loss: 0.0091
# Epoch 940/1000
#  - 0s - loss: 0.0090 - val_loss: 0.0091
# Epoch 941/1000
#  - 0s - loss: 0.0090 - val_loss: 0.0091
# Epoch 942/1000
#  - 0s - loss: 0.0090 - val_loss: 0.0091
# Epoch 943/1000
#  - 0s - loss: 0.0090 - val_loss: 0.0091
# Epoch 944/1000
#  - 0s - loss: 0.0090 - val_loss: 0.0091
# Epoch 945/1000
#  - 0s - loss: 0.0090 - val_loss: 0.0091
# Epoch 946/1000
#  - 0s - loss: 0.0090 - val_loss: 0.0091
# Epoch 947/1000
#  - 0s - loss: 0.0090 - val_loss: 0.0091
# Epoch 948/1000
#  - 0s - loss: 0.0090 - val_loss: 0.0091
# Epoch 949/1000
#  - 0s - loss: 0.0090 - val_loss: 0.0091
# Epoch 950/1000
#  - 0s - loss: 0.0090 - val_loss: 0.0091
# Epoch 951/1000
#  - 0s - loss: 0.0090 - val_loss: 0.0091
# Epoch 952/1000
#  - 0s - loss: 0.0090 - val_loss: 0.0091
# Epoch 953/1000
#  - 0s - loss: 0.0090 - val_loss: 0.0091
# Epoch 954/1000
#  - 0s - loss: 0.0090 - val_loss: 0.0091
# Epoch 955/1000
#  - 0s - loss: 0.0090 - val_loss: 0.0091
# Epoch 956/1000
#  - 0s - loss: 0.0090 - val_loss: 0.0091
# Epoch 957/1000
#  - 0s - loss: 0.0090 - val_loss: 0.0091
# Epoch 958/1000
#  - 0s - loss: 0.0090 - val_loss: 0.0091
# Epoch 959/1000
#  - 0s - loss: 0.0090 - val_loss: 0.0091
# Epoch 960/1000
#  - 0s - loss: 0.0090 - val_loss: 0.0091
# Epoch 961/1000
#  - 0s - loss: 0.0090 - val_loss: 0.0091
# Epoch 962/1000
#  - 0s - loss: 0.0090 - val_loss: 0.0091
# Epoch 963/1000
#  - 0s - loss: 0.0090 - val_loss: 0.0091
# Epoch 964/1000
#  - 0s - loss: 0.0090 - val_loss: 0.0091
# Epoch 965/1000
#  - 0s - loss: 0.0090 - val_loss: 0.0091
# Epoch 966/1000
#  - 0s - loss: 0.0090 - val_loss: 0.0091
# Epoch 967/1000
#  - 0s - loss: 0.0090 - val_loss: 0.0091
# Epoch 968/1000
#  - 0s - loss: 0.0090 - val_loss: 0.0091
# Epoch 969/1000
#  - 0s - loss: 0.0090 - val_loss: 0.0091
# Epoch 970/1000
#  - 0s - loss: 0.0090 - val_loss: 0.0091
# Epoch 971/1000
#  - 0s - loss: 0.0090 - val_loss: 0.0091
# Epoch 972/1000
#  - 0s - loss: 0.0090 - val_loss: 0.0091
# Epoch 973/1000
#  - 0s - loss: 0.0090 - val_loss: 0.0091
# Epoch 974/1000
#  - 0s - loss: 0.0090 - val_loss: 0.0091
# Epoch 975/1000
#  - 0s - loss: 0.0089 - val_loss: 0.0091
# Epoch 976/1000
#  - 0s - loss: 0.0089 - val_loss: 0.0091
# Epoch 977/1000
#  - 0s - loss: 0.0089 - val_loss: 0.0091
# Epoch 978/1000
#  - 0s - loss: 0.0089 - val_loss: 0.0091
# Epoch 979/1000
#  - 0s - loss: 0.0089 - val_loss: 0.0091
# Epoch 980/1000
#  - 0s - loss: 0.0089 - val_loss: 0.0091
# Epoch 981/1000
#  - 0s - loss: 0.0089 - val_loss: 0.0091
# Epoch 982/1000
#  - 0s - loss: 0.0089 - val_loss: 0.0091
# Epoch 983/1000
#  - 0s - loss: 0.0089 - val_loss: 0.0091
# Epoch 984/1000
#  - 0s - loss: 0.0089 - val_loss: 0.0091
# Epoch 985/1000
#  - 0s - loss: 0.0089 - val_loss: 0.0091
# Epoch 986/1000
#  - 0s - loss: 0.0089 - val_loss: 0.0091
# Epoch 987/1000
#  - 0s - loss: 0.0089 - val_loss: 0.0091
# Epoch 988/1000
#  - 0s - loss: 0.0089 - val_loss: 0.0091
# Epoch 989/1000
#  - 0s - loss: 0.0089 - val_loss: 0.0091
# Epoch 990/1000
#  - 0s - loss: 0.0089 - val_loss: 0.0091
# Epoch 991/1000
#  - 0s - loss: 0.0089 - val_loss: 0.0091
# Epoch 992/1000
#  - 0s - loss: 0.0089 - val_loss: 0.0091
# Epoch 993/1000
#  - 0s - loss: 0.0089 - val_loss: 0.0091
# Epoch 994/1000
#  - 0s - loss: 0.0089 - val_loss: 0.0091
# Epoch 995/1000
#  - 0s - loss: 0.0089 - val_loss: 0.0091
# Epoch 996/1000
#  - 0s - loss: 0.0089 - val_loss: 0.0091
# Epoch 997/1000
#  - 0s - loss: 0.0089 - val_loss: 0.0091
# Epoch 998/1000
#  - 0s - loss: 0.0089 - val_loss: 0.0091
# Epoch 999/1000
#  - 0s - loss: 0.0089 - val_loss: 0.0091
# Epoch 1000/1000
#  - 0s - loss: 0.0089 - val_loss: 0.0091

# %%
plot_loss(history)

# %% [markdown]
# ## Training Set

# %%
# Generate predictions

model = load_model("%s.h5" % (model_name))

x_train_new = []
lumi_new = []
lumi = data[str(runs[0])]['lumiid'] 

for l in range(len(x_train)):
    if not 0 in x_train[l]:
        x_train_new.append(x_train[l])
        for i in range(WINDOW):
            lumi_new.append(lumi[l+i])
                
reconstructed = model.predict(np.array(x_train_new))

error = abs(x_train_new-reconstructed)/x_train_new

# %%
error_reformat = []
for i in range(4):
    error_reformat.append([])

for i in range(len(error)):
    for j in range(4):
        if i == len(error)-1:
            for val in error[i][WINDOW*j:WINDOW+WINDOW*j]:
                error_reformat[j].append(val)
        else:
            error_reformat[j].append(error[i][WINDOW*j])
            
inp = []
outp = []
for i in range(4):
    inp.append([])
    outp.append([])
    
for i in range(len(reconstructed)):
    for j in range(4):
        if i == len(reconstructed)-1:
            for val in reconstructed[i][WINDOW*j:WINDOW+WINDOW*j]:
                outp[j].append(val)
            for val in x_train_new[i][WINDOW*j:WINDOW+WINDOW*j]:
                inp[j].append(val)
        else:
            outp[j].append(reconstructed[i][WINDOW*j])
            inp[j].append(x_train_new[i][WINDOW*j])

# %%
labels = data['HLT']

#bins = np.linspace(0,1,50)
bins = 50
plt.figure(figsize=[20,10])
for i in range(len(error_reformat)):
    plt.subplot(2,2,i+1)
    plt.hist(error_reformat[i],bins=bins,label=labels[i],alpha=.5)
    plt.legend()

#lumi = np.linspace(0,len(error_reformat[0]),len(error_reformat[0]))
plt.figure(figsize=[20,10])
for i in range(0,4):
    plt.subplot(2,2,i+1)
    plt.scatter(lumi,error_reformat[i],label=labels[i],alpha=.5)
    plt.xlabel('lumi id')
    plt.ylabel('error')
    plt.legend()    

plt.show()

# %%
plt.figure(figsize=[10,10])
for i in range(0,4):
    plt.subplot(2,2,i+1)
    plt.plot(outp[i],inp[i],label=labels[i], linestyle='',marker='o', markersize=3, alpha=0.5)
    #plt.scatter(lumi,outp[i],label='output',alpha=.5)
    plt.xlabel('index')
    plt.ylabel('value')
    #plt.xlim(0,1.8)
    #plt.ylim(0,1.8)
    plt.legend()    

plt.show()

# %% [markdown]
# ## Test Data

# %%
# Generate predictions

model = load_model("%s.h5" % (model_name))

x_test_new = []
for l in x_test:
    if not 0 in l:
        x_test_new.append(l)
                
reconstructed = model.predict(np.array(x_test_new))

error = abs(x_test_new-reconstructed)/x_test_new

# %%
error_reformat = []
for i in range(4):
    error_reformat.append([])

for i in range(len(error)):
    for j in range(4):
        if i == len(error)-1:
            for val in error[i][WINDOW*j:WINDOW+WINDOW*j]:
                error_reformat[j].append(val)
        else:
            error_reformat[j].append(error[i][WINDOW*j])
            
inp = []
outp = []
for i in range(4):
    inp.append([])
    outp.append([])
    
for i in range(len(reconstructed)):
    for j in range(4):
        if i == len(reconstructed)-1:
            for val in reconstructed[i][WINDOW*j:WINDOW+WINDOW*j]:
                outp[j].append(val)
            for val in x_test_new[i][WINDOW*j:WINDOW+WINDOW*j]:
                inp[j].append(val)
        else:
            outp[j].append(reconstructed[i][WINDOW*j])
            inp[j].append(x_test_new[i][WINDOW*j])

# %%
labels = data['HLT']

#bins = np.linspace(0,1,50)
bins = 50
plt.figure(figsize=[20,10])
for i in range(len(error_reformat)):
    plt.subplot(2,2,i+1)
    plt.hist(error_reformat[i],bins=bins,label=labels[i],alpha=.5)
    plt.legend()

lumi = data[str(runs[2])]['lumiid'] 
#lumi = np.linspace(0,len(error_reformat[0]),len(error_reformat[0]))
plt.figure(figsize=[20,10])
for i in range(0,4):
    plt.subplot(2,2,i+1)
    plt.scatter(lumi,error_reformat[i],label=labels[i],alpha=.5)
    plt.xlabel('lumi id')
    plt.ylabel('error')
    plt.legend()    

plt.show()

# %%
plt.figure(figsize=[10,10])
for i in range(0,4):
    plt.subplot(2,2,i+1)
    plt.plot(outp[i],inp[i],label=labels[i], linestyle='',marker='o', markersize=3, alpha=0.5)
    #plt.scatter(lumi,outp[i],label='output',alpha=.5)
    plt.xlabel('index')
    plt.ylabel('value')
    #plt.xlim(0,1.8)
    #plt.ylim(0,1.8)
    plt.legend()    

plt.show()

# %%
# plt.figure(figsize=[20,10])
# for i in range(0,4):
#     plt.subplot(2,2,i+1)
#     plt.scatter(lumi,inp[i],label='input',alpha=.5)
#     plt.scatter(lumi,outp[i]/max(outp[i]),label='output',alpha=.5)
#     plt.xlabel('index')
#     plt.ylabel('value')
#     plt.legend()    

# plt.show()

# %%
# for i in range(len(outp)):
#     for j in range(i+1,len(outp)):
#         print(sum(np.array(outp[i]/max(outp[i]))-np.array(outp[j]/max(outp[j]))))

# %% [markdown]
# ## Fake Bad Data

# %%
bad = np.array(data[str(runs[2])]['bad_samples'])

# %%
bad_new = []
for l in bad:
    if not 0 in l:
        bad_new.append(l)
                
reconstructed_bad = model.predict(np.array(bad_new))

error_bad = abs(bad_new-reconstructed_bad)/bad_new

# %%
error_reformat_bad = []
for i in range(4):
    error_reformat_bad.append([])

for i in range(len(error_bad)):
    for j in range(4):
        if i == len(error_bad)-1:
            for val in error_bad[i][WINDOW*j:WINDOW+WINDOW*j]:
                error_reformat_bad[j].append(val)
        else:
            error_reformat_bad[j].append(error_bad[i][WINDOW*j])
            
inp_bad = []
outp_bad = []
for i in range(4):
    inp_bad.append([])
    outp_bad.append([])
    
for i in range(len(reconstructed_bad)):
    for j in range(4):
        if i == len(reconstructed_bad)-1:
            for val in reconstructed_bad[i][WINDOW*j:WINDOW+WINDOW*j]:
                outp_bad[j].append(val)
            for val in bad_new[i][WINDOW*j:WINDOW+WINDOW*j]:
                inp_bad[j].append(val)
        else:
            outp_bad[j].append(reconstructed_bad[i][WINDOW*j])
            inp_bad[j].append(bad_new[i][WINDOW*j])

# %%
labels = data['HLT']

#bins = np.linspace(0,1,50)
bins = 50
plt.figure(figsize=[20,10])
for i in range(len(error_reformat_bad)):
    plt.subplot(2,2,i+1)
    plt.hist(error_reformat[i],bins=bins,label='good',alpha=.5)
    plt.hist(error_reformat_bad[i],bins=bins,label='fake bad',alpha=.5)
    plt.legend()
    plt.title(labels[i])

lumi = data[str(runs[2])]['lumiid'] 
print(len(error_reformat_bad[0]),len(lumi))
#lumi = np.linspace(0,len(error_reformat_bad[0]),len(error_reformat_bad[0]))
plt.figure(figsize=[20,10])
for i in range(0,4):
    plt.subplot(2,2,i+1)
    plt.scatter(lumi,error_reformat[i],label = 'good', alpha =.5)
    plt.scatter(lumi,error_reformat_bad[i],label='fake bad',alpha=.5)
    plt.xlabel('lumi id')
    plt.ylabel('error')
    plt.legend()    
    plt.title(labels[i])

plt.show()
# Out:
# 1224 1224

# %%
plt.figure(figsize=[10,10])
for i in range(0,4):
    plt.subplot(2,2,i+1)
    plt.plot(outp_bad[i],inp_bad[i],label=labels[i], linestyle='',marker='o', markersize=3, alpha=0.5)
    plt.xlabel('index')
    plt.ylabel('value')
    #plt.xlim(0,2)
    #plt.ylim(0,2)
    plt.legend()    

plt.show()

# %%
# plt.figure(figsize=[20,10])
# for i in range(0,4):
#     plt.subplot(2,2,i+1)
#     plt.scatter(lumi,inp_bad[i],label='inp_badut',alpha=.5)
#     plt.scatter(lumi,outp_bad[i]/max(outp_bad[i]),label='outp_badut',alpha=.5)
#     plt.xlabel('index')
#     plt.ylabel('value')
#     plt.legend()    

# plt.show()

# %%
# labels = data['HLT']

# #bins = np.linspace(0,1,50)
# bins = 50
# plt.figure(figsize=[20,10])
# for i in range(len(error_reformat_bad)):
#     plt.subplot(2,2,i+1)
#     plt.hist(error_reformat_bad[i],bins=bins,label='bad',alpha=.5)
#     plt.hist(error_reformat[i],bins=bins,label='good',alpha=.5)
#     plt.legend()

# # lumi = data[str(runs[0])]['lumiid'] 
# # print(len(error_reformat_bad[0]),len(lumi))
# # #lumi = np.linspace(0,len(error_reformat_bad[0]),len(error_reformat_bad[0]))
# # plt.figure(figsize=[20,10])
# # for i in range(0,4):
# #     plt.subplot(2,2,i+1)
# #     plt.scatter(lumi,error_reformat_bad[i],label='bad',alpha=.5)
# #     plt.scatter(lumi,error_reformat[i],label='good',alpha=.5)
# #     plt.xlabel('lumi id')
# #     plt.ylabel('error')
# #     plt.legend()    

# plt.show()

# %% [markdown]
# ## Fake Bad Data - ALL

# %%
bad = np.array(data[str(runs[2])]['all_bad_samples'])

# %%
bad_new = []
for l in bad:
    if not 0 in l:
        bad_new.append(l)
                
reconstructed_bad = model.predict(np.array(bad_new))

error_bad = abs(bad_new-reconstructed_bad)/bad_new

# %%
error_reformat_bad = []
for i in range(4):
    error_reformat_bad.append([])

for i in range(len(error_bad)):
    for j in range(4):
        if i == len(error_bad)-1:
            for val in error_bad[i][WINDOW*j:WINDOW+WINDOW*j]:
                error_reformat_bad[j].append(val)
        else:
            error_reformat_bad[j].append(error_bad[i][WINDOW*j])
            
inp_bad = []
outp_bad = []
for i in range(4):
    inp_bad.append([])
    outp_bad.append([])
    
for i in range(len(reconstructed_bad)):
    for j in range(4):
        if i == len(reconstructed_bad)-1:
            for val in reconstructed_bad[i][WINDOW*j:WINDOW+WINDOW*j]:
                outp_bad[j].append(val)
            for val in bad_new[i][WINDOW*j:WINDOW+WINDOW*j]:
                inp_bad[j].append(val)
        else:
            outp_bad[j].append(reconstructed_bad[i][WINDOW*j])
            inp_bad[j].append(bad_new[i][WINDOW*j])

# %%
labels = data['HLT']

#bins = np.linspace(0,1,50)
bins = 50
plt.figure(figsize=[20,10])
for i in range(len(error_reformat_bad)):
    plt.subplot(2,2,i+1)
    plt.hist(error_reformat[i],bins=bins,label='good',alpha=.5)
    plt.hist(error_reformat_bad[i],bins=bins,label='fake bad',alpha=.5)
    plt.legend()
    plt.title(labels[i])

lumi = data[str(runs[2])]['lumiid'] 
print(len(error_reformat_bad[0]),len(lumi))
#lumi = np.linspace(0,len(error_reformat_bad[0]),len(error_reformat_bad[0]))
plt.figure(figsize=[20,10])
for i in range(0,4):
    plt.subplot(2,2,i+1)
    plt.scatter(lumi,error_reformat[i],label = 'good', alpha =.5)
    plt.scatter(lumi,error_reformat_bad[i],label='fake bad',alpha=.5)
    plt.xlabel('lumi id')
    plt.ylabel('error')
    plt.legend()    
    plt.title(labels[i])

plt.show()
# Out:
# 1224 1224

# %%
plt.figure(figsize=[10,10])
for i in range(0,4):
    plt.subplot(2,2,i+1)
    plt.plot(outp_bad[i],inp_bad[i],label=labels[i], linestyle='',marker='o', markersize=3, alpha=0.5)
    plt.xlabel('index')
    plt.ylabel('value')
    #plt.xlim(0,.6)
    #plt.ylim(0,.6)
    plt.legend()    

plt.show()

# %%
# plt.figure(figsize=[20,10])
# for i in range(0,4):
#     plt.subplot(2,2,i+1)
#     plt.scatter(lumi,inp_bad[i],label='input',alpha=.5)
#     plt.scatter(lumi,outp_bad[i]/max(outp_bad[i]),label='output',alpha=.5)
#     plt.xlabel('index')
#     plt.ylabel('value')
#     plt.legend()    

# plt.show()

# %%
# labels = data['HLT']

# #bins = np.linspace(0,1,50)
# bins = 50
# plt.figure(figsize=[20,10])
# for i in range(len(error_reformat_bad)):
#     plt.subplot(2,2,i+1)
#     plt.hist(error_reformat_bad[i],bins=bins,label='bad',alpha=.5)
#     plt.hist(error_reformat[i],bins=bins,label='good',alpha=.5)
#     plt.legend()

# # lumi = data[str(runs[0])]['lumiid'] 
# # print(len(error_reformat_bad[0]),len(lumi))
# # #lumi = np.linspace(0,len(error_reformat_bad[0]),len(error_reformat_bad[0]))
# # plt.figure(figsize=[20,10])
# # for i in range(0,4):
# #     plt.subplot(2,2,i+1)
# #     plt.scatter(lumi,error_reformat_bad[i],label='bad',alpha=.5)
# #     plt.scatter(lumi,error_reformat[i],label='good',alpha=.5)
# #     plt.xlabel('lumi id')
# #     plt.ylabel('error')
# #     plt.legend()    

# plt.show()

# %% [markdown]
# ## Real Bad Data

# %%
bad_runs = [301480]

with open('bad_data_WINDOW1.pickle', 'rb') as handle:
    baddata = pickle.load(handle)

x_test = np.array(baddata[str(bad_runs[0])]['samples'])

# %%
bad_new = []
lumi_new = []

lumiBad = baddata[str(bad_runs[0])]['lumiid']

for l in range(len(x_test)):
    if not 0 in x_test[l]:
        bad_new.append(x_test[l])
        for i in range(WINDOW):
            lumi_new.append(lumiBad[l+i])
            
lumiBad = []
for n in lumi_new:
    if n not in lumiBad:
        lumiBad.append(n)
    
                
reconstructed_bad = model.predict(np.array(bad_new))

error_bad = abs(bad_new-reconstructed_bad)/bad_new

# %%
error_reformat_bad = []
for i in range(4):
    error_reformat_bad.append([])

for i in range(len(error_bad)):
    for j in range(4):
        if i == len(error_bad)-1:
            for val in error_bad[i][WINDOW*j:WINDOW+WINDOW*j]:
                error_reformat_bad[j].append(val)
        else:
            error_reformat_bad[j].append(error_bad[i][WINDOW*j])
            
inp_bad = []
outp_bad = []
for i in range(4):
    inp_bad.append([])
    outp_bad.append([])
    
for i in range(len(reconstructed_bad)):
    for j in range(4):
        if i == len(reconstructed_bad)-1:
            for val in reconstructed_bad[i][WINDOW*j:WINDOW+WINDOW*j]:
                outp_bad[j].append(val)
            for val in bad_new[i][WINDOW*j:WINDOW+WINDOW*j]:
                inp_bad[j].append(val)
        else:
            outp_bad[j].append(reconstructed_bad[i][WINDOW*j])
            inp_bad[j].append(bad_new[i][WINDOW*j])
            
        
plt.figure()
for p in range(len(inp_bad)):
    plt.plot(lumi,inp_bad[p])
    plt.plot(lumi,bad_new[p])
    
plt.show()
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-48-2392383afd10> in <module>()
#      31 plt.figure()
#      32 for p in range(len(inp_bad)):
# ---> 33     plt.plot(lumi,inp_bad[p])
#      34     plt.plot(lumi,bad_new[p])
#      35
#
# /anaconda3/lib/python3.6/site-packages/matplotlib/pyplot.py in plot(*args, **kwargs)
#    3259                       mplDeprecation)
#    3260     try:
# -> 3261         ret = ax.plot(*args, **kwargs)
#    3262     finally:
#    3263         ax._hold = washold
#
# /anaconda3/lib/python3.6/site-packages/matplotlib/__init__.py in inner(ax, *args, **kwargs)
#    1715                     warnings.warn(msg % (label_namer, func.__name__),
#    1716                                   RuntimeWarning, stacklevel=2)
# -> 1717             return func(ax, *args, **kwargs)
#    1718         pre_doc = inner.__doc__
#    1719         if pre_doc is None:
#
# /anaconda3/lib/python3.6/site-packages/matplotlib/axes/_axes.py in plot(self, *args, **kwargs)
#    1370         kwargs = cbook.normalize_kwargs(kwargs, _alias_map)
#    1371
# -> 1372         for line in self._get_lines(*args, **kwargs):
#    1373             self.add_line(line)
#    1374             lines.append(line)
#
# /anaconda3/lib/python3.6/site-packages/matplotlib/axes/_base.py in _grab_next_args(self, *args, **kwargs)
#     402                 this += args[0],
#     403                 args = args[1:]
# --> 404             for seg in self._plot_args(this, kwargs):
#     405                 yield seg
#     406
#
# /anaconda3/lib/python3.6/site-packages/matplotlib/axes/_base.py in _plot_args(self, tup, kwargs)
#     382             x, y = index_of(tup[-1])
#     383
# --> 384         x, y = self._xy_from_xy(x, y)
#     385
#     386         if self.command == 'plot':
#
# /anaconda3/lib/python3.6/site-packages/matplotlib/axes/_base.py in _xy_from_xy(self, x, y)
#     241         if x.shape[0] != y.shape[0]:
#     242             raise ValueError("x and y must have same first dimension, but "
# --> 243                              "have shapes {} and {}".format(x.shape, y.shape))
#     244         if x.ndim > 2 or y.ndim > 2:
#     245             raise ValueError("x and y can be no greater than 2-D, but have "
#
# ValueError: x and y must have same first dimension, but have shapes (1224,) and (99,)

# %%
labels = data['HLT']

#bins = np.linspace(0,1,50)
bins = 50
plt.figure(figsize=[20,10])
for i in range(len(error_reformat_bad)):
    plt.subplot(2,2,i+1)
    plt.hist(error_reformat[i],bins=bins,label='good',alpha=.5)
    plt.hist(error_reformat_bad[i],bins=bins,label='bad',alpha=.5)
    plt.legend()
    plt.title(labels[i])

print(len(error_reformat_bad[0]),len(lumiBad))
plt.figure(figsize=[20,10])
for i in range(0,4):
    plt.subplot(2,2,i+1)
    plt.scatter(lumi,error_reformat[i],label = 'good', alpha =.5)
    plt.scatter(lumiBad,error_reformat_bad[i],label='bad',alpha=.5)
    plt.xlabel('lumi id')
    plt.ylabel('error')
    plt.legend()    
    plt.title(labels[i])

plt.show()
# Out:
# 154 154

# %%
plt.figure(figsize=[10,10])
for i in range(0,4):
    plt.subplot(2,2,i+1)
    plt.plot(outp_bad[i],inp_bad[i],label=labels[i], linestyle='',marker='o', markersize=3, alpha=0.5)
    plt.xlabel('index')
    plt.ylabel('value')
    #plt.xlim(0,.6)
    #plt.ylim(0,.6)
    plt.legend()    

plt.show()

# %% [markdown]
# ## Real Bad Data

# %%
bad_runs = [305588]

with open('bad_data_WINDOW1.pickle', 'rb') as handle:
    baddata = pickle.load(handle)

x_test = np.array(baddata[str(bad_runs[0])]['samples'])

# %%
bad_new = []
lumi_new = []

lumiBad = baddata[str(bad_runs[0])]['lumiid']

for l in range(len(x_test)):
    if not 0 in x_test[l]:
        bad_new.append(x_test[l])
        for i in range(WINDOW):
            lumi_new.append(lumiBad[l+i])
            
lumiBad = []
for n in lumi_new:
    if n not in lumiBad:
        lumiBad.append(n)
    
                
reconstructed_bad = model.predict(np.array(bad_new))

error_bad = abs(bad_new-reconstructed_bad)/bad_new

# %%
error_reformat_bad = []
for i in range(4):
    error_reformat_bad.append([])

for i in range(len(error_bad)):
    for j in range(4):
        if i == len(error_bad)-1:
            for val in error_bad[i][WINDOW*j:WINDOW+WINDOW*j]:
                error_reformat_bad[j].append(val)
        else:
            error_reformat_bad[j].append(error_bad[i][WINDOW*j])
            
inp_bad = []
outp_bad = []
for i in range(4):
    inp_bad.append([])
    outp_bad.append([])
    
for i in range(len(reconstructed_bad)):
    for j in range(4):
        if i == len(reconstructed_bad)-1:
            for val in reconstructed_bad[i][WINDOW*j:WINDOW+WINDOW*j]:
                outp_bad[j].append(val)
            for val in bad_new[i][WINDOW*j:WINDOW+WINDOW*j]:
                inp_bad[j].append(val)
        else:
            outp_bad[j].append(reconstructed_bad[i][WINDOW*j])
            inp_bad[j].append(bad_new[i][WINDOW*j])

# %%
labels = data['HLT']

#bins = np.linspace(0,1,50)
bins = 50
plt.figure(figsize=[20,10])
for i in range(len(error_reformat_bad)):
    plt.subplot(2,2,i+1)
    plt.hist(error_reformat[i],bins=bins,label='good',alpha=.5)
    plt.hist(error_reformat_bad[i],bins=bins,label='bad',alpha=.5)
    plt.legend()
    plt.title(labels[i])

print(len(error_reformat_bad[0]),len(lumiBad))
plt.figure(figsize=[20,10])
for i in range(0,4):
    plt.subplot(2,2,i+1)
    plt.scatter(lumi,error_reformat[i],label = 'good', alpha =.5)
    plt.scatter(lumiBad,error_reformat_bad[i],label='bad',alpha=.5)
    plt.xlabel('lumi id')
    plt.ylabel('error')
    plt.legend()    
    plt.title(labels[i])

plt.show()
# Out:
# 99 99

# %%
plt.figure(figsize=[10,10])
for i in range(0,4):
    plt.subplot(2,2,i+1)
    plt.plot(outp_bad[i],inp_bad[i],label=labels[i], linestyle='',marker='o', markersize=3, alpha=0.5)
    plt.xlabel('index')
    plt.ylabel('value')
    #plt.xlim(0,.6)
    #plt.ylim(0,.6)
    plt.legend()    

plt.show()
