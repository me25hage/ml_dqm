# %%
import os
import numpy as np
import matplotlib
import matplotlib.pyplot as plt
import pandas as pd
import keras
import pickle
import latex

from keras import backend as K
from keras.callbacks import EarlyStopping, ModelCheckpoint, ReduceLROnPlateau
from keras.initializers import Ones, Zeros, Constant
from keras.models import Model, load_model
from keras.layers import Dense, Input, Lambda, concatenate, SimpleRNN, Reshape, RepeatVector, PReLU, BatchNormalization, LeakyReLU
from keras.losses import mse
from keras.constraints import non_neg
# Out:
# /anaconda3/lib/python3.6/site-packages/h5py/__init__.py:36: FutureWarning: Conversion of the second argument of issubdtype from `float` to `np.floating` is deprecated. In future, it will be treated as `np.float64 == np.dtype(float).type`.
#   from ._conv import register_converters as _register_converters
# Using TensorFlow backend.

# %%
# Change presentation settings

# %matplotlib inline

matplotlib.rcParams["figure.figsize"] = (16.0, 10.0)

#matplotlib.rcParams['font.family'] = 'sans-serif'
#matplotlib.rcParams['font.sans-serif'] = ['Liberation Sans']

matplotlib.rcParams["axes.spines.left"] = True
matplotlib.rcParams["axes.spines.top"] = True
matplotlib.rcParams["axes.spines.right"] = True
matplotlib.rcParams["axes.spines.bottom"] = True
matplotlib.rcParams["axes.labelsize"] = 14
matplotlib.rcParams["axes.titlesize"] = 18

matplotlib.rcParams["xtick.top"] = True
matplotlib.rcParams["ytick.right"] = True
matplotlib.rcParams["xtick.direction"] = "in"
matplotlib.rcParams["ytick.direction"] = "in"
matplotlib.rcParams["xtick.labelsize"] = 10
matplotlib.rcParams["ytick.labelsize"] = 10
matplotlib.rcParams["xtick.major.size"] = 10
matplotlib.rcParams["ytick.major.size"] = 10
matplotlib.rcParams["xtick.minor.size"] = 5
matplotlib.rcParams["ytick.minor.size"] = 5
matplotlib.rcParams["xtick.minor.visible"] = True

#matplotlib.rcParams["text.usetex"] = True

matplotlib.rcParams["lines.linewidth"] = 2

matplotlib.rcParams["legend.fontsize"] = 14

color_palette = {"Indigo": {
                    50: "#E8EAF6",
                    100: "#C5CAE9",
                    200: "#9FA8DA",
                    300: "#7986CB",
                    400: "#5C6BC0",
                    500: "#3F51B5",
                    600: "#3949AB",
                    700: "#303F9F",
                    800: "#283593",
                    900: "#1A237E"},
                 "Orange": {      
                    50: "#FFF3E0",
                    100: "#FFE0B2",
                    200: "#FFCC80",
                    300: "#FFB74D",
                    400: "#FFA726",
                    500: "#FF9800",
                    600: "#FB8C00",
                    700: "#F57C00",
                    800: "#EF6C00",
                    900: "#E65100"}
                }

line_styles = [(0, ()), (0, (1, 2)), (0, (3, 2))]

# %%
def plot_loss(data, save_name=False):
    """Plots the training and validation loss"""
    fig, ax = plt.subplots()

    plt.xlabel("Epoch", horizontalalignment='right', x=1.0)
    plt.ylabel("Cross-entropy", horizontalalignment='right', y=1.0)

    plt.plot(data["loss"], linestyle=line_styles[0], color=color_palette["Indigo"][800])
    plt.plot(data["val_loss"], linestyle=line_styles[2], color=color_palette["Orange"][400])
    plt.legend(["Training data set", "Validation data set"], loc="upper right", frameon=False)
    #plt.yscale("log")
    
    if save_name:
        fig.savefig("%s/%s.eps" % (figure_export_directory, save_name), bbox_inches="tight")

    plt.show();

# %%
def train_nn(model, x, y, batch_size, loss, name, xval, pval):
    
    adam = keras.optimizers.Adam(lr=0.003,
                                 beta_1=0.9,
                                 beta_2=0.999,
                                 epsilon=None,
                                 decay=0.0,
                                 amsgrad=False)

    early_stopper = EarlyStopping(monitor="val_loss",
                                  patience=32,
                                  verbose=True,
                                  mode="auto")

    reduce_lr = ReduceLROnPlateau(monitor="val_loss",
                                  factor=0.1,
                                  patience=24)
    
    checkpoint_callback = ModelCheckpoint(("%s.h5" % (name)),
                                          monitor="val_loss",
                                          verbose=False,
                                          save_best_only=True,
                                          mode="min")
    
    model.compile(loss=loss, optimizer=adam)
    
    history = model.fit([x,y], x,
                     batch_size=batch_size,
                     epochs=500,
                     verbose=2,
                     initial_epoch=0,
                     shuffle=True,
                     validation_data=([xval,pval],xval),
                     callbacks=[early_stopper, checkpoint_callback])
    return history

# %% [markdown]
# ## Data

# %%
good_data_file = 'PileupNewData_data.pickle'
bad_data_file = 'PileupNewData_bad.pickle'

subplot_size = [2,3]
fig_size = [20,20]

with open(good_data_file, 'rb') as handle:
    good_data = pickle.load(handle)
with open(bad_data_file, 'rb') as handle:
    bad_data = pickle.load(handle)

# %%
runlength = []
badrunlength = []
numruns = []
eras = []
runs_by_era = []
bad_runs_by_era = []
i = -1
for era in good_data['Eras']:
    runlength.append([])
    badrunlength.append([])
    runs_by_era.append([])
    bad_runs_by_era.append([])
    eras.append(era)
    i += 1
    j = 0
    for run in good_data['Eras'][era]:
        runlength[i].append(len(good_data[run]['lumiid']))
        runs_by_era[i].append(run)
        j+=1
    for run in bad_data['Eras'][era]:
        badrunlength[i].append(len(bad_data[run]['lumiid']))
        bad_runs_by_era[i].append(run)
    numruns.append(j)
    
m = numruns.index(max(numruns))
m=9
n = runlength[m].index(max(runlength[m]))
a = badrunlength[m].index(max(badrunlength[m]))

print(eras[m],runs_by_era[m][n])
print(eras[m],runs_by_era[m][n-1])
print(eras[m],bad_runs_by_era[m][a])
print(eras[m],bad_runs_by_era[m][a+2])

x_train = np.array(good_data[runs_by_era[m][n]]['samples'])
pileup_train = np.array(good_data[runs_by_era[m][n]]['pileupInput'][0])
x_test = np.array(good_data[runs_by_era[m][n-1]]['samples'])
pileup_test = np.array(good_data[runs_by_era[m][n-1]]['pileupInput'][0])
x_val = np.array(good_data[runs_by_era[m][n+1]]['samples'])
pileup_val = np.array(good_data[runs_by_era[m][n+1]]['pileupInput'][0])
x_bad1 = np.array(bad_data["302975"]['samples'])
pileup_bad1 = np.array(bad_data["302975"]['pileupInput'][0])
x_bad2 = np.array(bad_data["302995"]['samples'])
pileup_bad2 = np.array(bad_data["302995"]['pileupInput'][0])

num_rates = len(x_train[0])
print(badrunlength[m])
# Out:
# eraV310 304144
# eraV310 304125
# eraV310 302975
# eraV310 302995
# [52, 23, 12, 4, 120, 27, 21, 27, 243, 56, 54, 55, 218, 0, 583, 151, 284, 0, 2, 46, 4, 9, 9, 203, 28, 79, 35, 29, 0, 0, 0, 0]

# %%
relativeerror = r"$\frac{input rate - output rate}{|input rate| + |output rate|}$"
sumsquareddif = r"$\sum_{i} (input rate_i-output rate_i)^2$"

plots = [x_train,x_test,x_bad1,x_bad2]
titles = ["train","test","302975","302995"]

stuff = [[],[],[],[]]
lumi = [[],[],[],[]]
inst = [[],[],[],[]]
pileup = [[],[],[],[]]
for h in range(4):
    if h == 0:
        lumi[h] = good_data["304144"]['lumiid']
        inst[h] = good_data["304144"]['instlumi']
        pileup[h] = good_data["304144"]['pileup']
        stuff[h] = good_data["304144"]['rates']
    elif h == 1:
        lumi[h] = good_data["304125"]['lumiid']
        inst[h] = good_data["304125"]['instlumi']
        pileup[h] = good_data["304125"]['pileup']
        stuff[h] = good_data["304125"]['rates']
    elif h == 2:
        lumi[h] = bad_data["302975"]['lumiid']
        inst[h] = bad_data["302975"]['instlumi']
        pileup[h] = bad_data["302975"]['pileup']
        stuff[h] = bad_data["302975"]['rates']
    else:
        lumi[h] = bad_data["302995"]['lumiid']
        inst[h] = bad_data["302995"]['instlumi']
        pileup[h] = bad_data["302995"]['pileup']
        stuff[h] = bad_data["302995"]['rates']
    
labels = good_data['HLT'] 
colors = ["g","b","r","orange"]
    
plt.figure(figsize=[15,10])
for i in range(num_rates):
    plt.subplot(2,3,i+1)
    for k in range(4):
        #print(len(i[k]),len(stuff[k][i]))
        plt.scatter(lumi[k],stuff[k][i],c=colors[k],label=titles[k],alpha=.5)
    plt.xlabel('lumi id')
    plt.ylabel('rate')
    plt.ylim(0,1.1)
    plt.title(labels[i])
    plt.legend()

plt.tight_layout()

plt.figure(figsize=[15,10])
              
for i in range(num_rates):
    plt.subplot(2,3,i+1)
    for k in range(4):
        plt.scatter(inst[k][i],stuff[k][i],c=colors[k],label=titles[k],alpha=.5)
    plt.xlabel('instantaneous luminosity')
    plt.ylabel('rate')
    plt.title(labels[i])
    plt.legend()
    plt.ylim(0,1.1)

plt.tight_layout()

plt.figure(figsize=[15,10])
              
for i in range(num_rates):
    plt.subplot(2,3,i+1)
    for k in range(4):
        plt.scatter(pileup[k][i],stuff[k][i],c=colors[k],label=titles[k],alpha=.5)
    plt.xlabel('pileup')
    plt.ylabel('rate')
    plt.title(labels[i])
    plt.legend()
    plt.ylim(0,1.1)


plt.tight_layout()

plt.show()

# %% [markdown]
# ## Simple Autoencoder

# %%
model_name = "normedRateAvgByEra3"

# %%
# Define the architecture

_input = Input(shape=(6,), name="input")

middle = Dense(5,
               kernel_initializer=Ones(),
               bias_initializer=Zeros(),
               kernel_constraint=non_neg(),
               bias_constraint=non_neg(),
               activation = 'relu',
               name="middle")(_input)

norm = BatchNormalization()(middle)

hidden = Dense(2,
               kernel_initializer=Ones(),
               bias_initializer=Zeros(),
               kernel_constraint=non_neg(),
               bias_constraint=non_neg(),
               activation = 'relu',
               name="encoded")(norm)

p_layer = Input(shape=(1,), name="pileup")

concat = concatenate([p_layer,hidden])

normhidden = BatchNormalization()(concat)

middle2 = Dense(5,
               kernel_initializer=Ones(),
               bias_initializer=Zeros(),
               kernel_constraint=non_neg(),
               bias_constraint=non_neg(),
               activation = 'relu',
               name="middle2")(normhidden)

normmiddle = BatchNormalization()(middle2)

output = Dense(6,
               kernel_initializer=Ones(),
               bias_initializer=Zeros(),
               kernel_constraint=non_neg(),
               bias_constraint=non_neg(),
               activation=None,
               name="reconstructed")(normmiddle)

normout = BatchNormalization()(output)

model = Model([_input,p_layer], normout)
model.summary()
# Out:
# __________________________________________________________________________________________________
# Layer (type)                    Output Shape         Param #     Connected to
# ==================================================================================================
# input (InputLayer)              (None, 6)            0
# __________________________________________________________________________________________________
# middle (Dense)                  (None, 5)            35          input[0][0]
# __________________________________________________________________________________________________
# batch_normalization_1 (BatchNor (None, 5)            20          middle[0][0]
# __________________________________________________________________________________________________
# pileup (InputLayer)             (None, 1)            0
# __________________________________________________________________________________________________
# encoded (Dense)                 (None, 2)            12          batch_normalization_1[0][0]
# __________________________________________________________________________________________________
# concatenate_1 (Concatenate)     (None, 3)            0           pileup[0][0]
#                                                                  encoded[0][0]
# __________________________________________________________________________________________________
# batch_normalization_2 (BatchNor (None, 3)            12          concatenate_1[0][0]
# __________________________________________________________________________________________________
# middle2 (Dense)                 (None, 5)            20          batch_normalization_2[0][0]
# __________________________________________________________________________________________________
# batch_normalization_3 (BatchNor (None, 5)            20          middle2[0][0]
# __________________________________________________________________________________________________
# reconstructed (Dense)           (None, 6)            36          batch_normalization_3[0][0]
# __________________________________________________________________________________________________
# batch_normalization_4 (BatchNor (None, 6)            24          reconstructed[0][0]
# ==================================================================================================
# Total params: 179
# Trainable params: 141
# Non-trainable params: 38
# __________________________________________________________________________________________________

# %%
# Train neural networks
history = train_nn(model, x_train, pileup_train, 1024, "mse", model_name, x_val, pileup_val).history
plot_loss(history)
# Out:
# Train on 2437 samples, validate on 1763 samples
# Epoch 1/500
#  - 13s - loss: 1.1043 - val_loss: 0.7506
# Epoch 2/500
#  - 0s - loss: 1.0813 - val_loss: 0.7248
# Epoch 3/500
#  - 0s - loss: 1.0571 - val_loss: 0.6985
# Epoch 4/500
#  - 0s - loss: 1.0331 - val_loss: 0.6742
# Epoch 5/500
#  - 0s - loss: 1.0094 - val_loss: 0.6521
# Epoch 6/500
#  - 0s - loss: 0.9866 - val_loss: 0.6309
# Epoch 7/500
#  - 0s - loss: 0.9631 - val_loss: 0.6106
# Epoch 8/500
#  - 0s - loss: 0.9406 - val_loss: 0.5910
# Epoch 9/500
#  - 0s - loss: 0.9185 - val_loss: 0.5705
# Epoch 10/500
#  - 0s - loss: 0.8969 - val_loss: 0.5498
# Epoch 11/500
#  - 0s - loss: 0.8758 - val_loss: 0.5277
# Epoch 12/500
#  - 0s - loss: 0.8550 - val_loss: 0.5072
# Epoch 13/500
#  - 0s - loss: 0.8348 - val_loss: 0.4876
# Epoch 14/500
#  - 0s - loss: 0.8148 - val_loss: 0.4706
# Epoch 15/500
#  - 0s - loss: 0.7953 - val_loss: 0.4537
# Epoch 16/500
#  - 0s - loss: 0.7763 - val_loss: 0.4347
# Epoch 17/500
#  - 0s - loss: 0.7575 - val_loss: 0.4148
# Epoch 18/500
#  - 0s - loss: 0.7393 - val_loss: 0.3960
# Epoch 19/500
#  - 0s - loss: 0.7214 - val_loss: 0.3776
# Epoch 20/500
#  - 0s - loss: 0.7040 - val_loss: 0.3606
# Epoch 21/500
#  - 0s - loss: 0.6868 - val_loss: 0.3447
# Epoch 22/500
#  - 0s - loss: 0.6702 - val_loss: 0.3302
# Epoch 23/500
#  - 0s - loss: 0.6537 - val_loss: 0.3176
# Epoch 24/500
#  - 0s - loss: 0.6377 - val_loss: 0.3055
# Epoch 25/500
#  - 0s - loss: 0.6220 - val_loss: 0.2945
# Epoch 26/500
#  - 0s - loss: 0.6067 - val_loss: 0.2842
# Epoch 27/500
#  - 0s - loss: 0.5917 - val_loss: 0.2741
# Epoch 28/500
#  - 0s - loss: 0.5770 - val_loss: 0.2640
# Epoch 29/500
#  - 0s - loss: 0.5627 - val_loss: 0.2519
# Epoch 30/500
#  - 0s - loss: 0.5488 - val_loss: 0.2395
# Epoch 31/500
#  - 0s - loss: 0.5350 - val_loss: 0.2273
# Epoch 32/500
#  - 0s - loss: 0.5216 - val_loss: 0.2141
# Epoch 33/500
#  - 0s - loss: 0.5085 - val_loss: 0.2025
# Epoch 34/500
#  - 0s - loss: 0.4957 - val_loss: 0.1906
# Epoch 35/500
#  - 0s - loss: 0.4832 - val_loss: 0.1803
# Epoch 36/500
#  - 0s - loss: 0.4711 - val_loss: 0.1713
# Epoch 37/500
#  - 0s - loss: 0.4590 - val_loss: 0.1633
# Epoch 38/500
#  - 0s - loss: 0.4475 - val_loss: 0.1559
# Epoch 39/500
#  - 0s - loss: 0.4360 - val_loss: 0.1489
# Epoch 40/500
#  - 0s - loss: 0.4250 - val_loss: 0.1423
# Epoch 41/500
#  - 0s - loss: 0.4140 - val_loss: 0.1360
# Epoch 42/500
#  - 0s - loss: 0.4034 - val_loss: 0.1292
# Epoch 43/500
#  - 0s - loss: 0.3930 - val_loss: 0.1222
# Epoch 44/500
#  - 0s - loss: 0.3829 - val_loss: 0.1158
# Epoch 45/500
#  - 0s - loss: 0.3730 - val_loss: 0.1101
# Epoch 46/500
#  - 0s - loss: 0.3634 - val_loss: 0.1048
# Epoch 47/500
#  - 0s - loss: 0.3539 - val_loss: 0.0997
# Epoch 48/500
#  - 0s - loss: 0.3447 - val_loss: 0.0946
# Epoch 49/500
#  - 0s - loss: 0.3357 - val_loss: 0.0894
# Epoch 50/500
#  - 0s - loss: 0.3269 - val_loss: 0.0847
# Epoch 51/500
#  - 0s - loss: 0.3183 - val_loss: 0.0796
# Epoch 52/500
#  - 0s - loss: 0.3100 - val_loss: 0.0751
# Epoch 53/500
#  - 0s - loss: 0.3018 - val_loss: 0.0706
# Epoch 54/500
#  - 0s - loss: 0.2939 - val_loss: 0.0663
# Epoch 55/500
#  - 0s - loss: 0.2861 - val_loss: 0.0624
# Epoch 56/500
#  - 0s - loss: 0.2785 - val_loss: 0.0588
# Epoch 57/500
#  - 0s - loss: 0.2711 - val_loss: 0.0554
# Epoch 58/500
#  - 0s - loss: 0.2639 - val_loss: 0.0522
# Epoch 59/500
#  - 0s - loss: 0.2568 - val_loss: 0.0493
# Epoch 60/500
#  - 0s - loss: 0.2500 - val_loss: 0.0466
# Epoch 61/500
#  - 0s - loss: 0.2432 - val_loss: 0.0441
# Epoch 62/500
#  - 0s - loss: 0.2368 - val_loss: 0.0417
# Epoch 63/500
#  - 0s - loss: 0.2305 - val_loss: 0.0392
# Epoch 64/500
#  - 0s - loss: 0.2241 - val_loss: 0.0368
# Epoch 65/500
#  - 0s - loss: 0.2180 - val_loss: 0.0345
# Epoch 66/500
#  - 0s - loss: 0.2121 - val_loss: 0.0324
# Epoch 67/500
#  - 0s - loss: 0.2063 - val_loss: 0.0306
# Epoch 68/500
#  - 0s - loss: 0.2008 - val_loss: 0.0289
# Epoch 69/500
#  - 0s - loss: 0.1952 - val_loss: 0.0272
# Epoch 70/500
#  - 0s - loss: 0.1899 - val_loss: 0.0258
# Epoch 71/500
#  - 0s - loss: 0.1846 - val_loss: 0.0243
# Epoch 72/500
#  - 0s - loss: 0.1796 - val_loss: 0.0230
# Epoch 73/500
#  - 0s - loss: 0.1746 - val_loss: 0.0218
# Epoch 74/500
#  - 0s - loss: 0.1699 - val_loss: 0.0206
# Epoch 75/500
#  - 0s - loss: 0.1651 - val_loss: 0.0195
# Epoch 76/500
#  - 0s - loss: 0.1604 - val_loss: 0.0185
# Epoch 77/500
#  - 0s - loss: 0.1559 - val_loss: 0.0176
# Epoch 78/500
#  - 0s - loss: 0.1516 - val_loss: 0.0169
# Epoch 79/500
#  - 0s - loss: 0.1473 - val_loss: 0.0162
# Epoch 80/500
#  - 0s - loss: 0.1432 - val_loss: 0.0157
# Epoch 81/500
#  - 0s - loss: 0.1391 - val_loss: 0.0151
# Epoch 82/500
#  - 0s - loss: 0.1353 - val_loss: 0.0146
# Epoch 83/500
#  - 0s - loss: 0.1313 - val_loss: 0.0141
# Epoch 84/500
#  - 0s - loss: 0.1276 - val_loss: 0.0137
# Epoch 85/500
#  - 0s - loss: 0.1240 - val_loss: 0.0132
# Epoch 86/500
#  - 0s - loss: 0.1204 - val_loss: 0.0128
# Epoch 87/500
#  - 0s - loss: 0.1170 - val_loss: 0.0124
# Epoch 88/500
#  - 0s - loss: 0.1136 - val_loss: 0.0121
# Epoch 89/500
#  - 0s - loss: 0.1103 - val_loss: 0.0118
# Epoch 90/500
#  - 0s - loss: 0.1071 - val_loss: 0.0115
# Epoch 91/500
#  - 0s - loss: 0.1040 - val_loss: 0.0113
# Epoch 92/500
#  - 0s - loss: 0.1010 - val_loss: 0.0110
# Epoch 93/500
#  - 0s - loss: 0.0981 - val_loss: 0.0108
# Epoch 94/500
#  - 0s - loss: 0.0953 - val_loss: 0.0107
# Epoch 95/500
#  - 0s - loss: 0.0925 - val_loss: 0.0105
# Epoch 96/500
#  - 0s - loss: 0.0897 - val_loss: 0.0103
# Epoch 97/500
#  - 0s - loss: 0.0871 - val_loss: 0.0102
# Epoch 98/500
#  - 0s - loss: 0.0846 - val_loss: 0.0101
# Epoch 99/500
#  - 0s - loss: 0.0821 - val_loss: 0.0100
# Epoch 100/500
#  - 0s - loss: 0.0796 - val_loss: 0.0099
# Epoch 101/500
#  - 0s - loss: 0.0773 - val_loss: 0.0098
# Epoch 102/500
#  - 0s - loss: 0.0750 - val_loss: 0.0097
# Epoch 103/500
#  - 0s - loss: 0.0728 - val_loss: 0.0096
# Epoch 104/500
#  - 0s - loss: 0.0706 - val_loss: 0.0095
# Epoch 105/500
#  - 0s - loss: 0.0685 - val_loss: 0.0094
# Epoch 106/500
#  - 0s - loss: 0.0664 - val_loss: 0.0093
# Epoch 107/500
#  - 0s - loss: 0.0645 - val_loss: 0.0092
# Epoch 108/500
#  - 0s - loss: 0.0625 - val_loss: 0.0091
# Epoch 109/500
#  - 0s - loss: 0.0606 - val_loss: 0.0091
# Epoch 110/500
#  - 0s - loss: 0.0588 - val_loss: 0.0090
# Epoch 111/500
#  - 0s - loss: 0.0570 - val_loss: 0.0090
# Epoch 112/500
#  - 0s - loss: 0.0553 - val_loss: 0.0089
# Epoch 113/500
#  - 0s - loss: 0.0536 - val_loss: 0.0089
# Epoch 114/500
#  - 0s - loss: 0.0520 - val_loss: 0.0089
# Epoch 115/500
#  - 0s - loss: 0.0505 - val_loss: 0.0088
# Epoch 116/500
#  - 0s - loss: 0.0489 - val_loss: 0.0088
# Epoch 117/500
#  - 0s - loss: 0.0474 - val_loss: 0.0088
# Epoch 118/500
#  - 0s - loss: 0.0460 - val_loss: 0.0088
# Epoch 119/500
#  - 0s - loss: 0.0447 - val_loss: 0.0087
# Epoch 120/500
#  - 0s - loss: 0.0432 - val_loss: 0.0087
# Epoch 121/500
#  - 0s - loss: 0.0419 - val_loss: 0.0087
# Epoch 122/500
#  - 0s - loss: 0.0406 - val_loss: 0.0087
# Epoch 123/500
#  - 0s - loss: 0.0395 - val_loss: 0.0086
# Epoch 124/500
#  - 0s - loss: 0.0382 - val_loss: 0.0086
# Epoch 125/500
#  - 0s - loss: 0.0371 - val_loss: 0.0086
# Epoch 126/500
#  - 0s - loss: 0.0359 - val_loss: 0.0086
# Epoch 127/500
#  - 0s - loss: 0.0348 - val_loss: 0.0086
# Epoch 128/500
#  - 0s - loss: 0.0338 - val_loss: 0.0086
# Epoch 129/500
#  - 0s - loss: 0.0327 - val_loss: 0.0085
# Epoch 130/500
#  - 0s - loss: 0.0317 - val_loss: 0.0085
# Epoch 131/500
#  - 0s - loss: 0.0308 - val_loss: 0.0085
# Epoch 132/500
#  - 0s - loss: 0.0298 - val_loss: 0.0085
# Epoch 133/500
#  - 0s - loss: 0.0290 - val_loss: 0.0085
# Epoch 134/500
#  - 0s - loss: 0.0280 - val_loss: 0.0084
# Epoch 135/500
#  - 0s - loss: 0.0272 - val_loss: 0.0084
# Epoch 136/500
#  - 0s - loss: 0.0264 - val_loss: 0.0084
# Epoch 137/500
#  - 0s - loss: 0.0256 - val_loss: 0.0084
# Epoch 138/500
#  - 0s - loss: 0.0248 - val_loss: 0.0083
# Epoch 139/500
#  - 0s - loss: 0.0241 - val_loss: 0.0083
# Epoch 140/500
#  - 0s - loss: 0.0233 - val_loss: 0.0083
# Epoch 141/500
#  - 0s - loss: 0.0226 - val_loss: 0.0082
# Epoch 142/500
#  - 0s - loss: 0.0220 - val_loss: 0.0082
# Epoch 143/500
#  - 0s - loss: 0.0213 - val_loss: 0.0082
# Epoch 144/500
#  - 0s - loss: 0.0207 - val_loss: 0.0081
# Epoch 145/500
#  - 0s - loss: 0.0201 - val_loss: 0.0081
# Epoch 146/500
#  - 0s - loss: 0.0195 - val_loss: 0.0081
# Epoch 147/500
#  - 0s - loss: 0.0189 - val_loss: 0.0080
# Epoch 148/500
#  - 0s - loss: 0.0183 - val_loss: 0.0080
# Epoch 149/500
#  - 0s - loss: 0.0178 - val_loss: 0.0080
# Epoch 150/500
#  - 0s - loss: 0.0173 - val_loss: 0.0079
# Epoch 151/500
#  - 0s - loss: 0.0168 - val_loss: 0.0079
# Epoch 152/500
#  - 0s - loss: 0.0163 - val_loss: 0.0079
# Epoch 153/500
#  - 0s - loss: 0.0158 - val_loss: 0.0078
# Epoch 154/500
#  - 0s - loss: 0.0154 - val_loss: 0.0078
# Epoch 155/500
#  - 0s - loss: 0.0150 - val_loss: 0.0078
# Epoch 156/500
#  - 0s - loss: 0.0146 - val_loss: 0.0077
# Epoch 157/500
#  - 0s - loss: 0.0141 - val_loss: 0.0077
# Epoch 158/500
#  - 0s - loss: 0.0137 - val_loss: 0.0076
# Epoch 159/500
#  - 0s - loss: 0.0134 - val_loss: 0.0076
# Epoch 160/500
#  - 0s - loss: 0.0130 - val_loss: 0.0075
# Epoch 161/500
#  - 0s - loss: 0.0126 - val_loss: 0.0075
# Epoch 162/500
#  - 0s - loss: 0.0123 - val_loss: 0.0075
# Epoch 163/500
#  - 0s - loss: 0.0120 - val_loss: 0.0074
# Epoch 164/500
#  - 0s - loss: 0.0116 - val_loss: 0.0074
# Epoch 165/500
#  - 0s - loss: 0.0113 - val_loss: 0.0073
# Epoch 166/500
#  - 0s - loss: 0.0110 - val_loss: 0.0073
# Epoch 167/500
#  - 0s - loss: 0.0108 - val_loss: 0.0073
# Epoch 168/500
#  - 0s - loss: 0.0105 - val_loss: 0.0072
# Epoch 169/500
#  - 0s - loss: 0.0102 - val_loss: 0.0072
# Epoch 170/500
#  - 0s - loss: 0.0100 - val_loss: 0.0072
# Epoch 171/500
#  - 0s - loss: 0.0097 - val_loss: 0.0071
# Epoch 172/500
#  - 0s - loss: 0.0095 - val_loss: 0.0071
# Epoch 173/500
#  - 0s - loss: 0.0092 - val_loss: 0.0071
# Epoch 174/500
#  - 0s - loss: 0.0090 - val_loss: 0.0070
# Epoch 175/500
#  - 0s - loss: 0.0088 - val_loss: 0.0070
# Epoch 176/500
#  - 0s - loss: 0.0086 - val_loss: 0.0069
# Epoch 177/500
#  - 0s - loss: 0.0084 - val_loss: 0.0069
# Epoch 178/500
#  - 0s - loss: 0.0082 - val_loss: 0.0069
# Epoch 179/500
#  - 0s - loss: 0.0081 - val_loss: 0.0068
# Epoch 180/500
#  - 0s - loss: 0.0079 - val_loss: 0.0068
# Epoch 181/500
#  - 0s - loss: 0.0077 - val_loss: 0.0067
# Epoch 182/500
#  - 0s - loss: 0.0075 - val_loss: 0.0067
# Epoch 183/500
#  - 0s - loss: 0.0074 - val_loss: 0.0066
# Epoch 184/500
#  - 0s - loss: 0.0072 - val_loss: 0.0066
# Epoch 185/500
#  - 0s - loss: 0.0071 - val_loss: 0.0066
# Epoch 186/500
#  - 0s - loss: 0.0069 - val_loss: 0.0065
# Epoch 187/500
#  - 0s - loss: 0.0068 - val_loss: 0.0065
# Epoch 188/500
#  - 0s - loss: 0.0067 - val_loss: 0.0065
# Epoch 189/500
#  - 0s - loss: 0.0066 - val_loss: 0.0064
# Epoch 190/500
#  - 0s - loss: 0.0065 - val_loss: 0.0064
# Epoch 191/500
#  - 0s - loss: 0.0063 - val_loss: 0.0064
# Epoch 192/500
#  - 0s - loss: 0.0062 - val_loss: 0.0063
# Epoch 193/500
#  - 0s - loss: 0.0061 - val_loss: 0.0063
# Epoch 194/500
#  - 0s - loss: 0.0060 - val_loss: 0.0063
# Epoch 195/500
#  - 0s - loss: 0.0059 - val_loss: 0.0062
# Epoch 196/500
#  - 0s - loss: 0.0058 - val_loss: 0.0062
# Epoch 197/500
#  - 0s - loss: 0.0057 - val_loss: 0.0062
# Epoch 198/500
#  - 0s - loss: 0.0056 - val_loss: 0.0062
# Epoch 199/500
#  - 0s - loss: 0.0055 - val_loss: 0.0061
# Epoch 200/500
#  - 0s - loss: 0.0054 - val_loss: 0.0061
# Epoch 201/500
#  - 0s - loss: 0.0054 - val_loss: 0.0061
# Epoch 202/500
#  - 0s - loss: 0.0053 - val_loss: 0.0060
# Epoch 203/500
#  - 0s - loss: 0.0052 - val_loss: 0.0060
# Epoch 204/500
#  - 0s - loss: 0.0051 - val_loss: 0.0060
# Epoch 205/500
#  - 0s - loss: 0.0051 - val_loss: 0.0060
# Epoch 206/500
#  - 0s - loss: 0.0050 - val_loss: 0.0059
# Epoch 207/500
#  - 0s - loss: 0.0049 - val_loss: 0.0059
# Epoch 208/500
#  - 0s - loss: 0.0049 - val_loss: 0.0059
# Epoch 209/500
#  - 0s - loss: 0.0048 - val_loss: 0.0059
# Epoch 210/500
#  - 0s - loss: 0.0048 - val_loss: 0.0058
# Epoch 211/500
#  - 0s - loss: 0.0047 - val_loss: 0.0058
# Epoch 212/500
#  - 0s - loss: 0.0047 - val_loss: 0.0058
# Epoch 213/500
#  - 0s - loss: 0.0046 - val_loss: 0.0058
# Epoch 214/500
#  - 0s - loss: 0.0046 - val_loss: 0.0057
# Epoch 215/500
#  - 0s - loss: 0.0045 - val_loss: 0.0057
# Epoch 216/500
#  - 0s - loss: 0.0045 - val_loss: 0.0057
# Epoch 217/500
#  - 0s - loss: 0.0044 - val_loss: 0.0057
# Epoch 218/500
#  - 0s - loss: 0.0044 - val_loss: 0.0056
# Epoch 219/500
#  - 0s - loss: 0.0043 - val_loss: 0.0056
# Epoch 220/500
#  - 0s - loss: 0.0043 - val_loss: 0.0056
# Epoch 221/500
#  - 0s - loss: 0.0043 - val_loss: 0.0056
# Epoch 222/500
#  - 0s - loss: 0.0042 - val_loss: 0.0056
# Epoch 223/500
#  - 0s - loss: 0.0042 - val_loss: 0.0055
# Epoch 224/500
#  - 0s - loss: 0.0042 - val_loss: 0.0055
# Epoch 225/500
#  - 0s - loss: 0.0042 - val_loss: 0.0055
# Epoch 226/500
#  - 0s - loss: 0.0041 - val_loss: 0.0055
# Epoch 227/500
#  - 0s - loss: 0.0041 - val_loss: 0.0055
# Epoch 228/500
#  - 0s - loss: 0.0041 - val_loss: 0.0054
# Epoch 229/500
#  - 0s - loss: 0.0040 - val_loss: 0.0054
# Epoch 230/500
#  - 0s - loss: 0.0040 - val_loss: 0.0054
# Epoch 231/500
#  - 0s - loss: 0.0040 - val_loss: 0.0054
# Epoch 232/500
#  - 0s - loss: 0.0040 - val_loss: 0.0054
# Epoch 233/500
#  - 0s - loss: 0.0039 - val_loss: 0.0053
# Epoch 234/500
#  - 0s - loss: 0.0039 - val_loss: 0.0053
# Epoch 235/500
#  - 0s - loss: 0.0039 - val_loss: 0.0053
# Epoch 236/500
#  - 0s - loss: 0.0039 - val_loss: 0.0053
# Epoch 237/500
#  - 0s - loss: 0.0039 - val_loss: 0.0053
# Epoch 238/500
#  - 0s - loss: 0.0038 - val_loss: 0.0052
# Epoch 239/500
#  - 0s - loss: 0.0038 - val_loss: 0.0052
# Epoch 240/500
#  - 0s - loss: 0.0039 - val_loss: 0.0052
# Epoch 241/500
#  - 0s - loss: 0.0038 - val_loss: 0.0052
# Epoch 242/500
#  - 0s - loss: 0.0038 - val_loss: 0.0052
# Epoch 243/500
#  - 0s - loss: 0.0038 - val_loss: 0.0051
# Epoch 244/500
#  - 0s - loss: 0.0038 - val_loss: 0.0051
# Epoch 245/500
#  - 0s - loss: 0.0037 - val_loss: 0.0051
# Epoch 246/500
#  - 0s - loss: 0.0037 - val_loss: 0.0051
# Epoch 247/500
#  - 0s - loss: 0.0037 - val_loss: 0.0051
# Epoch 248/500
#  - 0s - loss: 0.0037 - val_loss: 0.0051
# Epoch 249/500
#  - 0s - loss: 0.0037 - val_loss: 0.0050
# Epoch 250/500
#  - 0s - loss: 0.0037 - val_loss: 0.0050
# Epoch 251/500
#  - 0s - loss: 0.0037 - val_loss: 0.0050
# Epoch 252/500
#  - 0s - loss: 0.0037 - val_loss: 0.0050
# Epoch 253/500
#  - 0s - loss: 0.0036 - val_loss: 0.0050
# Epoch 254/500
#  - 0s - loss: 0.0036 - val_loss: 0.0049
# Epoch 255/500
#  - 0s - loss: 0.0036 - val_loss: 0.0049
# Epoch 256/500
#  - 0s - loss: 0.0036 - val_loss: 0.0049
# Epoch 257/500
#  - 0s - loss: 0.0036 - val_loss: 0.0049
# Epoch 258/500
#  - 0s - loss: 0.0036 - val_loss: 0.0049
# Epoch 259/500
#  - 0s - loss: 0.0036 - val_loss: 0.0048
# Epoch 260/500
#  - 0s - loss: 0.0036 - val_loss: 0.0048
# Epoch 261/500
#  - 0s - loss: 0.0036 - val_loss: 0.0048
# Epoch 262/500
#  - 0s - loss: 0.0036 - val_loss: 0.0048
# Epoch 263/500
#  - 0s - loss: 0.0036 - val_loss: 0.0048
# Epoch 264/500
#  - 0s - loss: 0.0036 - val_loss: 0.0047
# Epoch 265/500
#  - 0s - loss: 0.0036 - val_loss: 0.0047
# Epoch 266/500
#  - 0s - loss: 0.0035 - val_loss: 0.0047
# Epoch 267/500
#  - 0s - loss: 0.0035 - val_loss: 0.0047
# Epoch 268/500
#  - 0s - loss: 0.0035 - val_loss: 0.0047
# Epoch 269/500
#  - 0s - loss: 0.0035 - val_loss: 0.0047
# Epoch 270/500
#  - 0s - loss: 0.0035 - val_loss: 0.0046
# Epoch 271/500
#  - 0s - loss: 0.0035 - val_loss: 0.0046
# Epoch 272/500
#  - 0s - loss: 0.0035 - val_loss: 0.0046
# Epoch 273/500
#  - 0s - loss: 0.0035 - val_loss: 0.0046
# Epoch 274/500
#  - 0s - loss: 0.0036 - val_loss: 0.0046
# Epoch 275/500
#  - 0s - loss: 0.0035 - val_loss: 0.0046
# Epoch 276/500
#  - 0s - loss: 0.0035 - val_loss: 0.0045
# Epoch 277/500
#  - 0s - loss: 0.0035 - val_loss: 0.0045
# Epoch 278/500
#  - 0s - loss: 0.0035 - val_loss: 0.0045
# Epoch 279/500
#  - 0s - loss: 0.0035 - val_loss: 0.0045
# Epoch 280/500
#  - 0s - loss: 0.0035 - val_loss: 0.0045
# Epoch 281/500
#  - 0s - loss: 0.0035 - val_loss: 0.0045
# Epoch 282/500
#  - 0s - loss: 0.0035 - val_loss: 0.0044
# Epoch 283/500
#  - 0s - loss: 0.0035 - val_loss: 0.0044
# Epoch 284/500
#  - 0s - loss: 0.0035 - val_loss: 0.0044
# Epoch 285/500
#  - 0s - loss: 0.0035 - val_loss: 0.0044
# Epoch 286/500
#  - 0s - loss: 0.0035 - val_loss: 0.0044
# Epoch 287/500
#  - 0s - loss: 0.0035 - val_loss: 0.0043
# Epoch 288/500
#  - 0s - loss: 0.0035 - val_loss: 0.0043
# Epoch 289/500
#  - 0s - loss: 0.0035 - val_loss: 0.0043
# Epoch 290/500
#  - 0s - loss: 0.0035 - val_loss: 0.0043
# Epoch 291/500
#  - 0s - loss: 0.0035 - val_loss: 0.0043
# Epoch 292/500
#  - 0s - loss: 0.0035 - val_loss: 0.0043
# Epoch 293/500
#  - 0s - loss: 0.0035 - val_loss: 0.0042
# Epoch 294/500
#  - 0s - loss: 0.0035 - val_loss: 0.0042
# Epoch 295/500
#  - 0s - loss: 0.0035 - val_loss: 0.0042
# Epoch 296/500
#  - 0s - loss: 0.0035 - val_loss: 0.0042
# Epoch 297/500
#  - 0s - loss: 0.0034 - val_loss: 0.0042
# Epoch 298/500
#  - 0s - loss: 0.0034 - val_loss: 0.0042
# Epoch 299/500
#  - 0s - loss: 0.0034 - val_loss: 0.0041
# Epoch 300/500
#  - 0s - loss: 0.0035 - val_loss: 0.0041
# Epoch 301/500
#  - 0s - loss: 0.0035 - val_loss: 0.0041
# Epoch 302/500
#  - 0s - loss: 0.0034 - val_loss: 0.0041
# Epoch 303/500
#  - 0s - loss: 0.0035 - val_loss: 0.0041
# Epoch 304/500
#  - 0s - loss: 0.0034 - val_loss: 0.0041
# Epoch 305/500
#  - 0s - loss: 0.0034 - val_loss: 0.0041
# Epoch 306/500
#  - 0s - loss: 0.0035 - val_loss: 0.0040
# Epoch 307/500
#  - 0s - loss: 0.0034 - val_loss: 0.0040
# Epoch 308/500
#  - 0s - loss: 0.0034 - val_loss: 0.0040
# Epoch 309/500
#  - 0s - loss: 0.0034 - val_loss: 0.0040
# Epoch 310/500
#  - 0s - loss: 0.0034 - val_loss: 0.0040
# Epoch 311/500
#  - 0s - loss: 0.0034 - val_loss: 0.0040
# Epoch 312/500
#  - 0s - loss: 0.0035 - val_loss: 0.0040
# Epoch 313/500
#  - 0s - loss: 0.0034 - val_loss: 0.0040
# Epoch 314/500
#  - 0s - loss: 0.0034 - val_loss: 0.0039
# Epoch 315/500
#  - 0s - loss: 0.0034 - val_loss: 0.0039
# Epoch 316/500
#  - 0s - loss: 0.0034 - val_loss: 0.0039
# Epoch 317/500
#  - 0s - loss: 0.0035 - val_loss: 0.0039
# Epoch 318/500
#  - 0s - loss: 0.0034 - val_loss: 0.0039
# Epoch 319/500
#  - 0s - loss: 0.0034 - val_loss: 0.0039
# Epoch 320/500
#  - 0s - loss: 0.0034 - val_loss: 0.0038
# Epoch 321/500
#  - 0s - loss: 0.0034 - val_loss: 0.0038
# Epoch 322/500
#  - 0s - loss: 0.0034 - val_loss: 0.0038
# Epoch 323/500
#  - 0s - loss: 0.0035 - val_loss: 0.0038
# Epoch 324/500
#  - 0s - loss: 0.0034 - val_loss: 0.0038
# Epoch 325/500
#  - 0s - loss: 0.0034 - val_loss: 0.0038
# Epoch 326/500
#  - 0s - loss: 0.0034 - val_loss: 0.0038
# Epoch 327/500
#  - 0s - loss: 0.0034 - val_loss: 0.0038
# Epoch 328/500
#  - 0s - loss: 0.0034 - val_loss: 0.0037
# Epoch 329/500
#  - 0s - loss: 0.0034 - val_loss: 0.0037
# Epoch 330/500
#  - 0s - loss: 0.0034 - val_loss: 0.0037
# Epoch 331/500
#  - 0s - loss: 0.0034 - val_loss: 0.0037
# Epoch 332/500
#  - 0s - loss: 0.0034 - val_loss: 0.0037
# Epoch 333/500
#  - 0s - loss: 0.0034 - val_loss: 0.0037
# Epoch 334/500
#  - 0s - loss: 0.0034 - val_loss: 0.0037
# Epoch 335/500
#  - 0s - loss: 0.0034 - val_loss: 0.0037
# Epoch 336/500
#  - 0s - loss: 0.0034 - val_loss: 0.0036
# Epoch 337/500
#  - 0s - loss: 0.0034 - val_loss: 0.0036
# Epoch 338/500
#  - 0s - loss: 0.0034 - val_loss: 0.0036
# Epoch 339/500
#  - 0s - loss: 0.0034 - val_loss: 0.0036
# Epoch 340/500
#  - 0s - loss: 0.0034 - val_loss: 0.0036
# Epoch 341/500
#  - 0s - loss: 0.0034 - val_loss: 0.0036
# Epoch 342/500
#  - 0s - loss: 0.0034 - val_loss: 0.0036
# Epoch 343/500
#  - 0s - loss: 0.0034 - val_loss: 0.0036
# Epoch 344/500
#  - 0s - loss: 0.0034 - val_loss: 0.0035
# Epoch 345/500
#  - 0s - loss: 0.0034 - val_loss: 0.0035
# Epoch 346/500
#  - 0s - loss: 0.0034 - val_loss: 0.0035
# Epoch 347/500
#  - 0s - loss: 0.0034 - val_loss: 0.0035
# Epoch 348/500
#  - 0s - loss: 0.0034 - val_loss: 0.0035
# Epoch 349/500
#  - 0s - loss: 0.0034 - val_loss: 0.0035
# Epoch 350/500
#  - 0s - loss: 0.0035 - val_loss: 0.0035
# Epoch 351/500
#  - 0s - loss: 0.0034 - val_loss: 0.0035
# Epoch 352/500
#  - 0s - loss: 0.0034 - val_loss: 0.0035
# Epoch 353/500
#  - 0s - loss: 0.0034 - val_loss: 0.0034
# Epoch 354/500
#  - 0s - loss: 0.0034 - val_loss: 0.0034
# Epoch 355/500
#  - 0s - loss: 0.0034 - val_loss: 0.0034
# Epoch 356/500
#  - 0s - loss: 0.0034 - val_loss: 0.0034
# Epoch 357/500
#  - 0s - loss: 0.0034 - val_loss: 0.0034
# Epoch 358/500
#  - 0s - loss: 0.0034 - val_loss: 0.0034
# Epoch 359/500
#  - 0s - loss: 0.0034 - val_loss: 0.0034
# Epoch 360/500
#  - 0s - loss: 0.0034 - val_loss: 0.0034
# Epoch 361/500
#  - 0s - loss: 0.0034 - val_loss: 0.0034
# Epoch 362/500
#  - 0s - loss: 0.0034 - val_loss: 0.0034
# Epoch 363/500
#  - 0s - loss: 0.0034 - val_loss: 0.0034
# Epoch 364/500
#  - 0s - loss: 0.0034 - val_loss: 0.0034
# Epoch 365/500
#  - 0s - loss: 0.0034 - val_loss: 0.0034
# Epoch 366/500
#  - 0s - loss: 0.0034 - val_loss: 0.0034
# Epoch 367/500
#  - 0s - loss: 0.0034 - val_loss: 0.0034
# Epoch 368/500
#  - 0s - loss: 0.0034 - val_loss: 0.0033
# Epoch 369/500
#  - 0s - loss: 0.0034 - val_loss: 0.0033
# Epoch 370/500
#  - 0s - loss: 0.0034 - val_loss: 0.0033
# Epoch 371/500
#  - 0s - loss: 0.0034 - val_loss: 0.0033
# Epoch 372/500
#  - 0s - loss: 0.0034 - val_loss: 0.0033
# Epoch 373/500
#  - 0s - loss: 0.0034 - val_loss: 0.0033
# Epoch 374/500
#  - 0s - loss: 0.0034 - val_loss: 0.0033
# Epoch 375/500
#  - 0s - loss: 0.0034 - val_loss: 0.0033
# Epoch 376/500
#  - 0s - loss: 0.0034 - val_loss: 0.0033
# Epoch 377/500
#  - 0s - loss: 0.0035 - val_loss: 0.0033
# Epoch 378/500
#  - 0s - loss: 0.0034 - val_loss: 0.0033
# Epoch 379/500
#  - 0s - loss: 0.0034 - val_loss: 0.0033
# Epoch 380/500
#  - 0s - loss: 0.0034 - val_loss: 0.0033
# Epoch 381/500
#  - 0s - loss: 0.0034 - val_loss: 0.0033
# Epoch 382/500
#  - 0s - loss: 0.0034 - val_loss: 0.0033
# Epoch 383/500
#  - 0s - loss: 0.0034 - val_loss: 0.0033
# Epoch 384/500
#  - 0s - loss: 0.0034 - val_loss: 0.0033
# Epoch 385/500
#  - 0s - loss: 0.0034 - val_loss: 0.0033
# Epoch 386/500
#  - 0s - loss: 0.0034 - val_loss: 0.0033
# Epoch 387/500
#  - 0s - loss: 0.0034 - val_loss: 0.0033
# Epoch 388/500
#  - 0s - loss: 0.0034 - val_loss: 0.0033
# Epoch 389/500
#  - 0s - loss: 0.0035 - val_loss: 0.0033
# Epoch 390/500
#  - 0s - loss: 0.0034 - val_loss: 0.0033
# Epoch 391/500
#  - 0s - loss: 0.0034 - val_loss: 0.0032
# Epoch 392/500
#  - 0s - loss: 0.0034 - val_loss: 0.0032
# Epoch 393/500
#  - 0s - loss: 0.0034 - val_loss: 0.0032
# Epoch 394/500
#  - 0s - loss: 0.0035 - val_loss: 0.0032
# Epoch 395/500
#  - 0s - loss: 0.0034 - val_loss: 0.0032
# Epoch 396/500
#  - 0s - loss: 0.0034 - val_loss: 0.0032
# Epoch 397/500
#  - 0s - loss: 0.0034 - val_loss: 0.0032
# Epoch 398/500
#  - 0s - loss: 0.0034 - val_loss: 0.0032
# Epoch 399/500
#  - 0s - loss: 0.0034 - val_loss: 0.0032
# Epoch 400/500
#  - 0s - loss: 0.0034 - val_loss: 0.0032
# Epoch 401/500
#  - 0s - loss: 0.0034 - val_loss: 0.0032
# Epoch 402/500
#  - 0s - loss: 0.0034 - val_loss: 0.0032
# Epoch 403/500
#  - 0s - loss: 0.0034 - val_loss: 0.0032
# Epoch 404/500
#  - 0s - loss: 0.0034 - val_loss: 0.0032
# Epoch 405/500
#  - 0s - loss: 0.0034 - val_loss: 0.0032
# Epoch 406/500
#  - 0s - loss: 0.0034 - val_loss: 0.0032
# Epoch 407/500
#  - 0s - loss: 0.0034 - val_loss: 0.0032
# Epoch 408/500
#  - 0s - loss: 0.0034 - val_loss: 0.0032
# Epoch 409/500
#  - 0s - loss: 0.0034 - val_loss: 0.0032
# Epoch 410/500
#  - 0s - loss: 0.0034 - val_loss: 0.0032
# Epoch 411/500
#  - 0s - loss: 0.0034 - val_loss: 0.0032
# Epoch 412/500
#  - 0s - loss: 0.0034 - val_loss: 0.0032
# Epoch 413/500
#  - 0s - loss: 0.0034 - val_loss: 0.0032
# Epoch 414/500
#  - 0s - loss: 0.0034 - val_loss: 0.0032
# Epoch 415/500
#  - 0s - loss: 0.0034 - val_loss: 0.0032
# Epoch 416/500
#  - 0s - loss: 0.0034 - val_loss: 0.0032
# Epoch 417/500
#  - 0s - loss: 0.0034 - val_loss: 0.0032
# Epoch 418/500
#  - 0s - loss: 0.0034 - val_loss: 0.0032
# Epoch 419/500
#  - 0s - loss: 0.0034 - val_loss: 0.0032
# Epoch 420/500
#  - 0s - loss: 0.0034 - val_loss: 0.0032
# Epoch 421/500
#  - 0s - loss: 0.0034 - val_loss: 0.0032
# Epoch 422/500
#  - 0s - loss: 0.0034 - val_loss: 0.0032
# Epoch 423/500
#  - 0s - loss: 0.0034 - val_loss: 0.0032
# Epoch 424/500
#  - 0s - loss: 0.0034 - val_loss: 0.0032
# Epoch 425/500
#  - 0s - loss: 0.0034 - val_loss: 0.0032
# Epoch 426/500
#  - 0s - loss: 0.0034 - val_loss: 0.0032
# Epoch 427/500
#  - 0s - loss: 0.0034 - val_loss: 0.0032
# Epoch 428/500
#  - 0s - loss: 0.0034 - val_loss: 0.0032
# Epoch 429/500
#  - 0s - loss: 0.0034 - val_loss: 0.0032
# Epoch 430/500
#  - 0s - loss: 0.0034 - val_loss: 0.0032
# Epoch 431/500
#  - 0s - loss: 0.0034 - val_loss: 0.0032
# Epoch 432/500
#  - 0s - loss: 0.0034 - val_loss: 0.0032
# Epoch 433/500
#  - 0s - loss: 0.0034 - val_loss: 0.0032
# Epoch 434/500
#  - 0s - loss: 0.0034 - val_loss: 0.0032
# Epoch 435/500
#  - 0s - loss: 0.0034 - val_loss: 0.0032
# Epoch 436/500
#  - 0s - loss: 0.0034 - val_loss: 0.0032
# Epoch 437/500
#  - 0s - loss: 0.0034 - val_loss: 0.0032
# Epoch 438/500
#  - 0s - loss: 0.0034 - val_loss: 0.0032
# Epoch 439/500
#  - 0s - loss: 0.0034 - val_loss: 0.0032
# Epoch 440/500
#  - 0s - loss: 0.0034 - val_loss: 0.0032
# Epoch 441/500
#  - 0s - loss: 0.0034 - val_loss: 0.0032
# Epoch 442/500
#  - 0s - loss: 0.0034 - val_loss: 0.0032
# Epoch 443/500
#  - 0s - loss: 0.0034 - val_loss: 0.0032
# Epoch 444/500
#  - 0s - loss: 0.0034 - val_loss: 0.0032
# Epoch 445/500
#  - 0s - loss: 0.0034 - val_loss: 0.0032
# Epoch 446/500
#  - 0s - loss: 0.0034 - val_loss: 0.0032
# Epoch 447/500
#  - 0s - loss: 0.0034 - val_loss: 0.0032
# Epoch 448/500
#  - 0s - loss: 0.0034 - val_loss: 0.0032
# Epoch 449/500
#  - 0s - loss: 0.0034 - val_loss: 0.0032
# Epoch 450/500
#  - 0s - loss: 0.0034 - val_loss: 0.0032
# Epoch 451/500
#  - 0s - loss: 0.0034 - val_loss: 0.0032
# Epoch 452/500
#  - 0s - loss: 0.0034 - val_loss: 0.0032
# Epoch 453/500
#  - 0s - loss: 0.0034 - val_loss: 0.0032
# Epoch 454/500
#  - 0s - loss: 0.0034 - val_loss: 0.0032
# Epoch 455/500
#  - 0s - loss: 0.0034 - val_loss: 0.0031
# Epoch 456/500
#  - 0s - loss: 0.0034 - val_loss: 0.0031
# Epoch 457/500
#  - 0s - loss: 0.0034 - val_loss: 0.0031
# Epoch 458/500
#  - 0s - loss: 0.0034 - val_loss: 0.0031
# Epoch 459/500
#  - 0s - loss: 0.0034 - val_loss: 0.0031
# Epoch 460/500
#  - 0s - loss: 0.0034 - val_loss: 0.0031
# Epoch 461/500
#  - 0s - loss: 0.0034 - val_loss: 0.0031
# Epoch 462/500
#  - 0s - loss: 0.0034 - val_loss: 0.0031
# Epoch 463/500
#  - 0s - loss: 0.0034 - val_loss: 0.0031
# Epoch 464/500
#  - 0s - loss: 0.0035 - val_loss: 0.0031
# Epoch 465/500
#  - 0s - loss: 0.0034 - val_loss: 0.0031
# Epoch 466/500
#  - 0s - loss: 0.0034 - val_loss: 0.0031
# Epoch 467/500
#  - 0s - loss: 0.0034 - val_loss: 0.0031
# Epoch 468/500
#  - 0s - loss: 0.0034 - val_loss: 0.0031
# Epoch 469/500
#  - 0s - loss: 0.0034 - val_loss: 0.0031
# Epoch 470/500
#  - 0s - loss: 0.0034 - val_loss: 0.0031
# Epoch 471/500
#  - 0s - loss: 0.0034 - val_loss: 0.0031
# Epoch 472/500
#  - 0s - loss: 0.0034 - val_loss: 0.0031
# Epoch 473/500
#  - 0s - loss: 0.0034 - val_loss: 0.0031
# Epoch 474/500
#  - 0s - loss: 0.0034 - val_loss: 0.0031
# Epoch 475/500
#  - 0s - loss: 0.0034 - val_loss: 0.0031
# Epoch 476/500
#  - 0s - loss: 0.0034 - val_loss: 0.0031
# Epoch 477/500
#  - 0s - loss: 0.0034 - val_loss: 0.0031
# Epoch 478/500
#  - 0s - loss: 0.0034 - val_loss: 0.0031
# Epoch 479/500
#  - 0s - loss: 0.0034 - val_loss: 0.0031
# Epoch 480/500
#  - 0s - loss: 0.0034 - val_loss: 0.0031
# Epoch 481/500
#  - 0s - loss: 0.0035 - val_loss: 0.0031
# Epoch 482/500
#  - 0s - loss: 0.0034 - val_loss: 0.0031
# Epoch 483/500
#  - 0s - loss: 0.0034 - val_loss: 0.0031
# Epoch 484/500
#  - 0s - loss: 0.0034 - val_loss: 0.0031
# Epoch 485/500
#  - 0s - loss: 0.0034 - val_loss: 0.0031
# Epoch 486/500
#  - 0s - loss: 0.0034 - val_loss: 0.0031
# Epoch 487/500
#  - 0s - loss: 0.0034 - val_loss: 0.0031
# Epoch 488/500
#  - 0s - loss: 0.0034 - val_loss: 0.0031
# Epoch 489/500
#  - 0s - loss: 0.0034 - val_loss: 0.0031
# Epoch 490/500
#  - 0s - loss: 0.0034 - val_loss: 0.0031
# Epoch 491/500
#  - 0s - loss: 0.0034 - val_loss: 0.0031
# Epoch 492/500
#  - 0s - loss: 0.0034 - val_loss: 0.0031
# Epoch 493/500
#  - 0s - loss: 0.0034 - val_loss: 0.0031
# Epoch 494/500
#  - 0s - loss: 0.0034 - val_loss: 0.0031
# Epoch 495/500
#  - 0s - loss: 0.0034 - val_loss: 0.0031
# Epoch 496/500
#  - 0s - loss: 0.0034 - val_loss: 0.0031
# Epoch 497/500
#  - 0s - loss: 0.0034 - val_loss: 0.0031
# Epoch 498/500
#  - 0s - loss: 0.0034 - val_loss: 0.0031
# Epoch 499/500
#  - 0s - loss: 0.0034 - val_loss: 0.0031
# Epoch 500/500
#  - 0s - loss: 0.0034 - val_loss: 0.0031

# %%
plot_loss(history)

# %% [markdown]
# ## Training Set

# %%
samples = good_data[runs_by_era[m][n]]['samples']
lumi_train = good_data[runs_by_era[m][n]]['lumiid']
pileup_train = good_data[runs_by_era[m][n]]['pileup'][0]
inputs = []
for s in range(len(samples)):
    for r in range(len(samples[s])):
        if s == 0:
            inputs.append([])
        inputs[r].append(samples[s][r])
            
plt.figure()
fig,ax=plt.subplots()
for r in range(len(inputs)):
    ax.scatter(lumi_train,inputs[r],label=labels[r])
ax.legend(loc='lower left', bbox_to_anchor= (1.01, 0), ncol=1, 
              borderaxespad=0, frameon=False)
plt.xlabel('lumi id')
plt.ylabel('rate/pileup')

plt.figure()
fig,ax=plt.subplots()
for r in range(len(inputs)):
    ax.scatter(pileup_train,inputs[r],label=labels[r])
ax.legend(loc='lower left', bbox_to_anchor= (1.01, 0), ncol=1, 
              borderaxespad=0, frameon=False)
plt.xlabel('pileup')
plt.ylabel('rate/pileup')
plt.show()

# %%
# Generate predictions

model = load_model("%s.h5" % (model_name))
    
reconstructed_train = model.predict([np.array(x_train),pileup_train])

error = (x_train-reconstructed_train)/(abs(x_train)+abs(reconstructed_train))

# %%
error_train_reformat = []
max_error_train = []
inp = []
outp = []
for i in range(num_rates):
    error_train_reformat.append([])
    inp.append([])
    outp.append([])

for i in range(len(error)):
    max_error_train.append(max(error[i]))
    for j in range(num_rates):
        error_train_reformat[j].append(error[i][j])
        outp[j].append(reconstructed_train[i][j])
        inp[j].append(x_train[i][j])

# %%
#bins = np.linspace(0,1,50)

plt.figure(figsize=[15,10])
for i in range(len(error_train_reformat)):
    plt.subplot(2,3,i+1)
    bins = np.linspace(min(error_train_reformat[i]),max(error_train_reformat[i]),50)
    plt.hist(error_train_reformat[i],bins=bins,label=labels[i],alpha=.5)
    plt.title(labels[i])
    plt.xlim(-1.1,1.1)
    plt.xlabel(relativeerror)
plt.tight_layout()

plt.figure(figsize=[15,10])
mins = []
maxes = []
for err in error_train_reformat:
    mins.append(min(err))
    maxes.append(max(err))
bins = np.linspace(min(mins),max(maxes),50)
for i in range(len(error_train_reformat)):
    plt.hist(error_train_reformat[i],bins=bins,label=labels[i],alpha=.5)
plt.title('Relative Error Per HLT Part')
plt.xlabel(relativeerror)
plt.legend()
plt.tight_layout()

#lumi_train = np.linspace(0,len(error_train_reformat0]),len(error_train_reformat0]))
plt.figure(figsize=[15,10])
for i in range(num_rates):
    plt.subplot(2,3,i+1)
    plt.scatter(lumi_train,error_train_reformat[i],label=labels[i],alpha=.5)
    plt.xlabel('lumi id')
    plt.ylabel('error')
    plt.title(labels[i])  
    plt.ylim(-1,1)
plt.tight_layout()


plt.show()

# %%
plt.figure(figsize=[15,10])
for i in range(num_rates):
    plt.subplot(2,3,i+1)
    plt.plot(outp[i],inp[i],label=labels[i], linestyle='',marker='o', markersize=3, alpha=0.5)
    #plt.scatter(lumi_train,outp[i],label='output',alpha=.5)
    plt.xlabel('output')
    plt.ylabel('input')
    plt.title(labels[i])
    plt.axis('square')
    plt.xlim(0,5)
    plt.ylim(0,5)
    
plt.figure(figsize=[20,10])
for i in range(num_rates):
    plt.subplot(2,3,i+1)
    plt.plot(lumi_train,inp[i],label='Input', linestyle='',marker='o', markersize=5)
    plt.plot(lumi_train,outp[i],label='Output', linestyle='',marker='^',markersize=5,alpha=.2)
    plt.title(labels[i])
    plt.xlabel('Lumi ID')
    plt.ylabel('Rate/Pileup')
    #plt.xlim(0,.5)
    plt.ylim(0,5)
    plt.legend()    
plt.tight_layout()
    

plt.tight_layout()
plt.show()

# %%
error_train = []
for r in range(len(reconstructed_train)):
    temp = 0
    for s in range(len(reconstructed_train[r])):
        temp+=(reconstructed_train[r][s]-x_train[r][s])**2
    error_train.append(temp)

bins = np.linspace(min(error_train),max(error_train),50)
plt.figure()
plt.hist(error_train,bins=bins,density=True)
plt.xlabel(sumsquareddif)
plt.title('Training')
plt.yscale('log')

plt.figure()
bins = np.linspace(min(max_error_train),max(max_error_train),50)
plt.hist(max_error_train,bins=bins,density=True,label='Training')
plt.xlabel('Max Error Per Sample')

plt.show()

# %%
output_rates = []
input_rates = []

for r in range(num_rates):
    output_rates.append([])
    input_rates.append([])

for r in range(len(reconstructed_train)):
    for o in range(num_rates):
        output_rates[o].append(reconstructed_train[r][o]*pileup_train[r])
        input_rates[o].append(x_train[r][o]*pileup_train[r])
    
plt.figure(figsize=[15,10])
              
for i in range(num_rates):
    plt.subplot(2,3,i+1)
    plt.scatter(pileup_train,input_rates[i],label='Input',alpha=.5)
    plt.scatter(pileup_train,output_rates[i],label='Output',alpha=.1)
    plt.xlabel('pileup')
    plt.ylabel('rate')
    plt.title(labels[i])
    plt.legend()
    #plt.ylim(0,45)

plt.tight_layout()

plt.show()

# %%
print(reconstructed_train[0])
# Out:
# [0.5970225  0.41119093 0.33065012 0.4556364  1.007549   2.8557267 ]
